# %%
import glob
import json
import os
import pickle
import random
import traceback
from typing import Tuple

import numpy as np
import pandas as pd
import seaborn as sns
from keras.models import Sequential, load_model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Lambda, LeakyReLU, AveragePooling2D, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from matplotlib import pyplot as plt
from matplotlib.pyplot import hist
from PIL import Image
from scipy.stats import zscore
from sklearn import metrics
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm

# %%
import csv
import time

# %% [markdown]
# ## Config & Constants

# %%
IMAGE_WIDTH, IMAGE_HEIGHT = 227, 227
random.seed(52)

# %% [markdown]
# ## Methods

# %% [markdown]
# ### Image Utilities

# %%
def batch_generator(input_data, output_data, batch_size, is_training):
    input_data_batch = np.empty([batch_size, IMAGE_HEIGHT, IMAGE_WIDTH, 1])
    output_data_batch = np.empty([batch_size, 1])
    while True:
        index = 0
        for i in np.random.permutation(input_data.shape[0]):
            input_data_batch[index] = input_data[i]
            output_data_batch[index] = output_data[i]
            index += 1
            if index == batch_size:
                break
        yield input_data_batch, output_data_batch


def _preprocess(image_loc: str) -> np.ndarray:
    f_image = Image.open(image_loc).convert('L')
    f_image = f_image.resize((IMAGE_WIDTH, IMAGE_HEIGHT), Image.ANTIALIAS)
    image = np.asarray(f_image)
    image = np.expand_dims(image, axis=0)
    image = np.expand_dims(image, axis=3)
    return image


def preprocess(loc: str) -> np.ndarray:
    """Safety wrapper over _preprocess.
    
    Args:
        loc: File location to check if dir or an image.
        
    Returns:
        Preprocessed image(s) as an ndarray.
    """
    if os.path.isdir(loc):
        current = np.concatenate((
            [_preprocess(os.path.join(loc, image)) for image in os.listdir(loc)
             if '.png' in image]
        ))
    else:
        current = _preprocess(loc)
    return current


def generate_data_arrays(
    covid_data: str = 'rsc/New_Data_CoV2/COVID/',
    noncovid_data: str = 'rsc/New_Data_CoV2/non-COVID/',
    others_data:  str = 'rsc/New_Data_CoV2/Others/',
    image_output: str = 'rsc/input_data_v2',
    label_output: str = 'rsc/output_data_v2',
    regenerate: bool = True
) -> Tuple[np.ndarray, np.ndarray]:
    """Loads COVID images into ndarrays.
    
    Args:
        covid_data: Relative path to folder containing COVID images.
        noncovid_data: Relative path to folder containing non-COVID images.
        others_data: Relative path to folder containing Others images.
        image_output: Relative path (with filename) to save loaded images to.
        label_output: Relative path (with filename) to save loaded classes (labels) to.
        regenerate: If True, will regenerate saved ndarray files for both image_output
            and label_output, even if they already exist (overwriting them). If False,
            will simply load and return the aforementioned.
        
    Returns:
        Tuple of ndarrays. The first is the loaded image data in one large ndarray,
        and the second is the loaded labels, also in a large ndarray. These directly
        match up to each other ONLY when both arrays (and their respective files)
        are generated at the same time with this method.
    """
    if (regenerate is False and 
        os.path.isfile(f'{out_input_data}.npy') and
        os.path.isfile(f'{out_output_data}.npy')):
        return (np.load(f'{out_input_data}.npy'),
                np.load(f'{out_output_data}.npy'))
    
    if not ((cd := os.path.exists(covid_data)) and (ncd := os.path.exists(noncovid_data))):
        if (others_data is not None) and not (odd := os.path.exists(others_data)):
            raise NotADirectoryError("Directories do not exist.")
        else:
            raise NotADirectoryError("COVID/non-COVID directories do not exist.")
    
    im_data = np.empty([1, IMAGE_WIDTH, IMAGE_WIDTH, 1])
    output = np.array([0])

    print('Loading Covid Data')
    for i in tqdm(glob.glob(os.path.join(covid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([1])), axis=0)

    print('Loading non-Covid Data')
    for i in tqdm(glob.glob(os.path.join(noncovid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([0])), axis=0)
        
    if others_data is not None:
        print('Loading Others Data')
        for i in tqdm(glob.glob(os.path.join(others_data, '**'))):
            current = preprocess(i)
            im_data = np.concatenate((im_data, current))
            output = np.concatenate((output, np.array([-1])), axis=0)
    else:
        print('Others data not provided; skipping.')


    print('Finished Loading Data')
    im_data = np.delete(im_data, 0, axis=0)
    output = np.delete(output, 0, axis=0)

    zip_data = list(zip(im_data, output))
    random.shuffle(zip_data)
    im_data, output = zip(*zip_data)

    np.save(f'{image_output}', im_data)
    np.save(f'{label_output}', output)
    return im_data, output


def load_data(image_loc: str, label_loc: str, **kwargs) -> Tuple[np.ndarray, np.ndarray]:
    """Attempts to load generated images and labels.
    
    If either is not found, attempts to (re)generate them using the default
    input arguments to the generation method for the raw data, but the input
    `image_loc` and `label_loc` parameters for the output arrays. If this
    still does not work, returns a general error and exits.
    
    Args:
        image_loc: Relative path to saved image ndarray file.
        label_loc: Relative path to saved label ndarray file.
        
    Returns:
        Tuple of ndarrays. The first array holds the loaded image data, whilst
        the second array holds their respective labels.
    
    """
    try:
        image_data = np.load(f'{image_loc}.npy')
        label_data = np.load(f'{label_loc}.npy')
        return image_data, label_data
    
    except FileNotFoundError:
        try:
            image_data, label_data = generate_data_arrays(
                image_output = image_loc,
                label_output = label_loc,
                **kwargs
            )
            return image_data, label_data
        
        except Exception as e:
            traceback.print_exc()

# %% [markdown]
# ## Model Playground

# %%
#Version 1
im_data_v1, output_v1 = load_data(
    image_loc = 'rsc/input_data_v1',
    label_loc = 'rsc/output_data_v1',
    covid_data = 'rsc/Data_CoV2/COVID/',
    noncovid_data = 'rsc/Data_CoV2/non-COVID/',
    others_data = None,
)

x_train, x_test, y_train, y_test = train_test_split(im_data_v1, output_v1, random_state=42)

# %%
def visualize_data(images, categories):
    fig = plt.figure(figsize=(14, 6))
    fig.patch.set_facecolor('white')
    for i in range(3 * 7):
        plt.subplot(3, 7, i+1)
        plt.xticks([])
        plt.yticks([])
        plt.imshow(images[i], cmap='gray')
        class_index = categories[i].argmax()
    plt.show()
    
visualize_data(x_train, y_train)

# %%
datagen = ImageDataGenerator(rotation_range=10,
                             zoom_range=0.20,
                             horizontal_flip=True,
                             fill_mode="nearest")
datagen.fit(x_train)

it = datagen.flow(x_train, y_train, shuffle=False)
batch_images, batch_labels = next(it)
visualize_data(batch_images, batch_labels)

# %%
def make_model(X_Train, Y_Train, X_Test, Y_Test, model_dir: str):
    if not os.path.exists(model_dir):
        os.makedirs(model_dir)
    #X_Train, X_Test, Y_Train, Y_Test = train_test_split(input_data, output_data, test_size=0.1)

    for_pad = lambda s: s if s > 2 else 3

    model = Sequential()
    model.add(Lambda(lambda x: x, input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 1)))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=8, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))



    #model.add(ZeroPadding2D(padding=(for_pad(19) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(Conv2D(kernel_size=(3, 3), filters=2, strides=(1, 1),activation='relu'))

    model.add(Flatten())

    model.add(Dropout(rate=0.4))
    model.add(Dense(units=338, activation='relu'))
    model.add(Dense(units=1, activation='sigmoid'))

    model.compile(optimizer=Adam(lr=3e-4), loss='binary_crossentropy', metrics=["accuracy"])
    model.summary()

    checkpoint = ModelCheckpoint(os.path.join(model_dir, 'xRGM2.2'), verbose=1, period=1, save_best_only=True)
    batchsize = 128
    hist = model.fit(datagen.flow(X_Train, Y_Train, 128, True),
                        validation_data=(batch_generator(X_Test, Y_Test, 128, False)), callbacks=[checkpoint],
                        verbose=1, epochs=75, steps_per_epoch=len(x_train)//batchsize, validation_steps=len(x_test)//batchsize)

    with open(os.path.join('models', 'xRGM2.2-Net-HistDict'), 'wb') as f:
        pickle.dump(hist.history, f)

    model.save(model_dir)
    
    return model
#changed steps and epochs and batchsize
#added data augmentation

# %%
# %%time
model_dir: str = 'model/xRGM2.2'
xRGM = make_model(x_train, y_train.reshape(-1,1), x_test, y_test.reshape(-1,1), model_dir=model_dir)

v_classify = np.vectorize(lambda x: np.round(x, 0))
# xRGMCT2 = load_model('models/xRGMCT2L.h5')
# print(xRGMCT2.history)
y_pred = (xRGM.predict(x_test))

#print(y_test)
#print(y_pred)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda (Lambda)              (None, 227, 227, 1)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 225, 225, 8)       80
# _________________________________________________________________
# batch_normalization (BatchNo (None, 225, 225, 8)       32
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 225, 225, 8)       0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 110, 110, 16)      1168
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 110, 110, 16)      64
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 110, 110, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 108, 108, 32)      4640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 108, 108, 32)      128
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 108, 108, 32)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 108, 108, 16)      528
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 108, 108, 16)      64
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 108, 108, 16)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 106, 106, 32)      4640
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 106, 106, 32)      128
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 106, 106, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 104, 104, 64)      18496
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 104, 104, 64)      256
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 104, 104, 64)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 104, 104, 32)      2080
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 104, 104, 32)      128
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 104, 104, 32)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 102, 102, 64)      18496
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 102, 102, 64)      256
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 102, 102, 64)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 100, 100, 128)     73856
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 100, 100, 128)     512
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 100, 100, 128)     0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 100, 100, 64)      8256
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 100, 100, 64)      256
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 98, 98, 128)       73856
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 98, 98, 128)       512
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 98, 98, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 49, 49, 128)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 47, 47, 256)       295168
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 47, 47, 256)       1024
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 47, 47, 256)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 47, 47, 128)       32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 47, 47, 128)       512
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 47, 47, 128)       0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 23, 23, 128)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 21, 21, 256)       295168
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 21, 21, 256)       1024
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 21, 21, 256)       0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 10, 10, 256)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 10, 10, 128)       32896
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 8, 8, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 338)               5538130
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 339
# =================================================================
# Total params: 6,702,293
# Trainable params: 6,699,077
# Non-trainable params: 3,216
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/75
# 14/14 [==============================] - 525s 37s/step - loss: 1.8258 - accuracy: 0.5437 - val_loss: 0.6934 - val_accuracy: 0.4668
#
# Epoch 00001: val_loss improved from inf to 0.69343, saving model to model/xRGM2.2/xRGM2.2
# INFO:tensorflow:Assets written to: model/xRGM2.2/xRGM2.2/assets
# Epoch 2/75
# 14/14 [==============================] - 564s 40s/step - loss: 0.5121 - accuracy: 0.7533 - val_loss: 0.7010 - val_accuracy: 0.4805
#
# Epoch 00002: val_loss did not improve from 0.69343
# Epoch 3/75
# 14/14 [==============================] - 658s 47s/step - loss: 0.3631 - accuracy: 0.8503 - val_loss: 0.6899 - val_accuracy: 0.4902
#
# Epoch 00003: val_loss improved from 0.69343 to 0.68989, saving model to model/xRGM2.2/xRGM2.2
# INFO:tensorflow:Assets written to: model/xRGM2.2/xRGM2.2/assets
# Epoch 4/75
# 14/14 [==============================] - 696s 50s/step - loss: 0.2801 - accuracy: 0.8769 - val_loss: 0.6887 - val_accuracy: 0.5586
#
# Epoch 00004: val_loss improved from 0.68989 to 0.68873, saving model to model/xRGM2.2/xRGM2.2
# INFO:tensorflow:Assets written to: model/xRGM2.2/xRGM2.2/assets
# Epoch 5/75
# 14/14 [==============================] - 664s 48s/step - loss: 0.2563 - accuracy: 0.8919 - val_loss: 0.6790 - val_accuracy: 0.5938
#
# Epoch 00005: val_loss improved from 0.68873 to 0.67902, saving model to model/xRGM2.2/xRGM2.2
# INFO:tensorflow:Assets written to: model/xRGM2.2/xRGM2.2/assets
# Epoch 6/75
# 14/14 [==============================] - 672s 50s/step - loss: 0.2164 - accuracy: 0.9135 - val_loss: 0.6751 - val_accuracy: 0.5605
#
# Epoch 00006: val_loss improved from 0.67902 to 0.67514, saving model to model/xRGM2.2/xRGM2.2
# INFO:tensorflow:Assets written to: model/xRGM2.2/xRGM2.2/assets
# Epoch 7/75
# 14/14 [==============================] - 624s 44s/step - loss: 0.2380 - accuracy: 0.8923 - val_loss: 0.7544 - val_accuracy: 0.4961
#
# Epoch 00007: val_loss did not improve from 0.67514
# Epoch 8/75
# 14/14 [==============================] - 601s 43s/step - loss: 0.2076 - accuracy: 0.9184 - val_loss: 0.7820 - val_accuracy: 0.5195
#
# Epoch 00008: val_loss did not improve from 0.67514
# Epoch 9/75
# 14/14 [==============================] - 664s 48s/step - loss: 0.1648 - accuracy: 0.9279 - val_loss: 0.8692 - val_accuracy: 0.5020
#
# Epoch 00009: val_loss did not improve from 0.67514
# Epoch 10/75
# 14/14 [==============================] - 668s 48s/step - loss: 0.1642 - accuracy: 0.9330 - val_loss: 1.0207 - val_accuracy: 0.4941
#
# Epoch 00010: val_loss did not improve from 0.67514
# Epoch 11/75
# 14/14 [==============================] - 688s 49s/step - loss: 0.1777 - accuracy: 0.9272 - val_loss: 0.8847 - val_accuracy: 0.5293
#
# Epoch 00011: val_loss did not improve from 0.67514
# Epoch 12/75
# 14/14 [==============================] - 652s 47s/step - loss: 0.1601 - accuracy: 0.9332 - val_loss: 1.0925 - val_accuracy: 0.5137
#
# Epoch 00012: val_loss did not improve from 0.67514
# Epoch 13/75
# 14/14 [==============================] - 681s 49s/step - loss: 0.1480 - accuracy: 0.9466 - val_loss: 1.4534 - val_accuracy: 0.5195
#
# Epoch 00013: val_loss did not improve from 0.67514
# Epoch 14/75
# 14/14 [==============================] - 681s 48s/step - loss: 0.1173 - accuracy: 0.9513 - val_loss: 1.9019 - val_accuracy: 0.5098
#
# Epoch 00014: val_loss did not improve from 0.67514
# Epoch 15/75
# 14/14 [==============================] - 661s 47s/step - loss: 0.1446 - accuracy: 0.9457 - val_loss: 2.2701 - val_accuracy: 0.5000
#
# Epoch 00015: val_loss did not improve from 0.67514
# Epoch 16/75
# 14/14 [==============================] - 592s 42s/step - loss: 0.1172 - accuracy: 0.9489 - val_loss: 2.4893 - val_accuracy: 0.4844
#
# Epoch 00016: val_loss did not improve from 0.67514
# Epoch 17/75
# 14/14 [==============================] - 604s 43s/step - loss: 0.1118 - accuracy: 0.9586 - val_loss: 2.1058 - val_accuracy: 0.5352
#
# Epoch 00017: val_loss did not improve from 0.67514
# Epoch 18/75
# 14/14 [==============================] - 691s 49s/step - loss: 0.1076 - accuracy: 0.9579 - val_loss: 2.4137 - val_accuracy: 0.4902
#
# Epoch 00018: val_loss did not improve from 0.67514
# Epoch 19/75
# 14/14 [==============================] - 676s 48s/step - loss: 0.0898 - accuracy: 0.9610 - val_loss: 1.4695 - val_accuracy: 0.5703
#
# Epoch 00019: val_loss did not improve from 0.67514
# Epoch 20/75
# 14/14 [==============================] - 671s 48s/step - loss: 0.0999 - accuracy: 0.9608 - val_loss: 2.6330 - val_accuracy: 0.5391
#
# Epoch 00020: val_loss did not improve from 0.67514
# Epoch 21/75
# 14/14 [==============================] - 648s 46s/step - loss: 0.1002 - accuracy: 0.9668 - val_loss: 0.7500 - val_accuracy: 0.7500
#
# Epoch 00021: val_loss did not improve from 0.67514
# Epoch 22/75
# 14/14 [==============================] - 669s 48s/step - loss: 0.0973 - accuracy: 0.9650 - val_loss: 0.6157 - val_accuracy: 0.8340
#
# Epoch 00022: val_loss improved from 0.67514 to 0.61569, saving model to model/xRGM2.2/xRGM2.2
# INFO:tensorflow:Assets written to: model/xRGM2.2/xRGM2.2/assets
# Epoch 23/75
# 14/14 [==============================] - 695s 50s/step - loss: 0.1117 - accuracy: 0.9560 - val_loss: 0.6067 - val_accuracy: 0.8242
#
# Epoch 00023: val_loss improved from 0.61569 to 0.60671, saving model to model/xRGM2.2/xRGM2.2
# INFO:tensorflow:Assets written to: model/xRGM2.2/xRGM2.2/assets
# Epoch 24/75
# 14/14 [==============================] - 608s 43s/step - loss: 0.0757 - accuracy: 0.9743 - val_loss: 0.4157 - val_accuracy: 0.8418
#
# Epoch 00024: val_loss improved from 0.60671 to 0.41573, saving model to model/xRGM2.2/xRGM2.2
# INFO:tensorflow:Assets written to: model/xRGM2.2/xRGM2.2/assets
# Epoch 25/75
# 14/14 [==============================] - 630s 45s/step - loss: 0.0846 - accuracy: 0.9726 - val_loss: 0.5891 - val_accuracy: 0.8574
#
# Epoch 00025: val_loss did not improve from 0.41573
# Epoch 26/75
# 14/14 [==============================] - 643s 46s/step - loss: 0.1120 - accuracy: 0.9484 - val_loss: 0.6647 - val_accuracy: 0.8613
#
# Epoch 00026: val_loss did not improve from 0.41573
# Epoch 27/75
# 14/14 [==============================] - 680s 48s/step - loss: 0.0714 - accuracy: 0.9730 - val_loss: 0.4134 - val_accuracy: 0.9043
#
# Epoch 00027: val_loss improved from 0.41573 to 0.41340, saving model to model/xRGM2.2/xRGM2.2
# INFO:tensorflow:Assets written to: model/xRGM2.2/xRGM2.2/assets
# Epoch 28/75
# 14/14 [==============================] - 682s 48s/step - loss: 0.0863 - accuracy: 0.9689 - val_loss: 0.5325 - val_accuracy: 0.8340
#
# Epoch 00028: val_loss did not improve from 0.41340
# Epoch 29/75
# 14/14 [==============================] - 675s 48s/step - loss: 0.0648 - accuracy: 0.9796 - val_loss: 0.2894 - val_accuracy: 0.9238
#
# Epoch 00029: val_loss improved from 0.41340 to 0.28940, saving model to model/xRGM2.2/xRGM2.2
# INFO:tensorflow:Assets written to: model/xRGM2.2/xRGM2.2/assets
# Epoch 30/75
# 14/14 [==============================] - 683s 49s/step - loss: 0.0433 - accuracy: 0.9830 - val_loss: 0.2926 - val_accuracy: 0.9160
#
# Epoch 00030: val_loss did not improve from 0.28940
# Epoch 31/75
# 14/14 [==============================] - 660s 47s/step - loss: 0.0603 - accuracy: 0.9783 - val_loss: 0.7019 - val_accuracy: 0.8125
#
# Epoch 00031: val_loss did not improve from 0.28940
# Epoch 32/75
# 14/14 [==============================] - 646s 46s/step - loss: 0.0601 - accuracy: 0.9824 - val_loss: 0.3320 - val_accuracy: 0.9082
#
# Epoch 00032: val_loss did not improve from 0.28940
# Epoch 33/75
# 14/14 [==============================] - 609s 44s/step - loss: 0.0584 - accuracy: 0.9779 - val_loss: 0.9901 - val_accuracy: 0.7715
#
# Epoch 00033: val_loss did not improve from 0.28940
# Epoch 34/75
# 14/14 [==============================] - 679s 48s/step - loss: 0.0697 - accuracy: 0.9715 - val_loss: 0.8270 - val_accuracy: 0.7871
#
# Epoch 00034: val_loss did not improve from 0.28940
# Epoch 35/75
# 14/14 [==============================] - 647s 46s/step - loss: 0.0581 - accuracy: 0.9812 - val_loss: 1.0371 - val_accuracy: 0.7461
#
# Epoch 00035: val_loss did not improve from 0.28940
# Epoch 36/75
# 14/14 [==============================] - 672s 48s/step - loss: 0.0573 - accuracy: 0.9798 - val_loss: 0.4767 - val_accuracy: 0.8516
#
# Epoch 00036: val_loss did not improve from 0.28940
# Epoch 37/75
# 14/14 [==============================] - 699s 50s/step - loss: 0.0506 - accuracy: 0.9780 - val_loss: 0.1823 - val_accuracy: 0.9160
#
# Epoch 00037: val_loss improved from 0.28940 to 0.18231, saving model to model/xRGM2.2/xRGM2.2
# INFO:tensorflow:Assets written to: model/xRGM2.2/xRGM2.2/assets
# Epoch 38/75
# 14/14 [==============================] - 669s 48s/step - loss: 0.0419 - accuracy: 0.9873 - val_loss: 0.2129 - val_accuracy: 0.9258
#
# Epoch 00038: val_loss did not improve from 0.18231
# Epoch 39/75
# 14/14 [==============================] - 680s 50s/step - loss: 0.0771 - accuracy: 0.9712 - val_loss: 0.4350 - val_accuracy: 0.9102
#
# Epoch 00039: val_loss did not improve from 0.18231
# Epoch 40/75
# 14/14 [==============================] - 587s 42s/step - loss: 0.0553 - accuracy: 0.9765 - val_loss: 0.2102 - val_accuracy: 0.9434
#
# Epoch 00040: val_loss did not improve from 0.18231
# Epoch 41/75
# 14/14 [==============================] - 622s 44s/step - loss: 0.0642 - accuracy: 0.9749 - val_loss: 0.1676 - val_accuracy: 0.9512
#
# Epoch 00041: val_loss improved from 0.18231 to 0.16758, saving model to model/xRGM2.2/xRGM2.2
# INFO:tensorflow:Assets written to: model/xRGM2.2/xRGM2.2/assets
# Epoch 42/75
# 14/14 [==============================] - 675s 48s/step - loss: 0.0696 - accuracy: 0.9738 - val_loss: 0.1603 - val_accuracy: 0.9375
#
# Epoch 00042: val_loss improved from 0.16758 to 0.16028, saving model to model/xRGM2.2/xRGM2.2
# INFO:tensorflow:Assets written to: model/xRGM2.2/xRGM2.2/assets
# Epoch 43/75
# 14/14 [==============================] - 669s 48s/step - loss: 0.0410 - accuracy: 0.9836 - val_loss: 0.1868 - val_accuracy: 0.9375
#
# Epoch 00043: val_loss did not improve from 0.16028
# Epoch 44/75
# 14/14 [==============================] - 665s 47s/step - loss: 0.0332 - accuracy: 0.9902 - val_loss: 0.2231 - val_accuracy: 0.9473
#
# Epoch 00044: val_loss did not improve from 0.16028
# Epoch 45/75
# 14/14 [==============================] - 660s 47s/step - loss: 0.0303 - accuracy: 0.9935 - val_loss: 0.2199 - val_accuracy: 0.9414
#
# Epoch 00045: val_loss did not improve from 0.16028
# Epoch 46/75
# 14/14 [==============================] - 698s 50s/step - loss: 0.0271 - accuracy: 0.9892 - val_loss: 0.1332 - val_accuracy: 0.9473
#
# Epoch 00046: val_loss improved from 0.16028 to 0.13324, saving model to model/xRGM2.2/xRGM2.2
# INFO:tensorflow:Assets written to: model/xRGM2.2/xRGM2.2/assets
# Epoch 47/75
# 14/14 [==============================] - 672s 48s/step - loss: 0.0296 - accuracy: 0.9923 - val_loss: 0.1344 - val_accuracy: 0.9668
#
# Epoch 00047: val_loss did not improve from 0.13324
# Epoch 48/75
# 14/14 [==============================] - 645s 47s/step - loss: 0.0387 - accuracy: 0.9835 - val_loss: 0.4315 - val_accuracy: 0.8789
#
# Epoch 00048: val_loss did not improve from 0.13324
# Epoch 49/75
# 14/14 [==============================] - 559s 39s/step - loss: 0.0395 - accuracy: 0.9865 - val_loss: 0.1874 - val_accuracy: 0.9316
#
# Epoch 00049: val_loss did not improve from 0.13324
# Epoch 50/75
# 14/14 [==============================] - 668s 48s/step - loss: 0.0302 - accuracy: 0.9892 - val_loss: 0.5422 - val_accuracy: 0.8691
#
# Epoch 00050: val_loss did not improve from 0.13324
# Epoch 51/75
# 14/14 [==============================] - 690s 49s/step - loss: 0.0284 - accuracy: 0.9927 - val_loss: 0.1852 - val_accuracy: 0.9219
#
# Epoch 00051: val_loss did not improve from 0.13324
# Epoch 52/75
# 14/14 [==============================] - 669s 49s/step - loss: 0.0628 - accuracy: 0.9736 - val_loss: 0.4303 - val_accuracy: 0.8848
#
# Epoch 00052: val_loss did not improve from 0.13324
# Epoch 53/75
# 14/14 [==============================] - 689s 51s/step - loss: 0.0516 - accuracy: 0.9804 - val_loss: 0.2637 - val_accuracy: 0.9316
#
# Epoch 00053: val_loss did not improve from 0.13324
# Epoch 54/75
# 14/14 [==============================] - 634s 46s/step - loss: 0.0272 - accuracy: 0.9919 - val_loss: 0.0956 - val_accuracy: 0.9531
#
# Epoch 00054: val_loss improved from 0.13324 to 0.09565, saving model to model/xRGM2.2/xRGM2.2
# INFO:tensorflow:Assets written to: model/xRGM2.2/xRGM2.2/assets
# Epoch 55/75
# 14/14 [==============================] - 705s 51s/step - loss: 0.0290 - accuracy: 0.9900 - val_loss: 0.1362 - val_accuracy: 0.9453
#
# Epoch 00055: val_loss did not improve from 0.09565
# Epoch 56/75
# 14/14 [==============================] - 653s 46s/step - loss: 0.0275 - accuracy: 0.9930 - val_loss: 0.1596 - val_accuracy: 0.9473
#
# Epoch 00056: val_loss did not improve from 0.09565
# Epoch 57/75
# 14/14 [==============================] - 601s 43s/step - loss: 0.0464 - accuracy: 0.9814 - val_loss: 0.2618 - val_accuracy: 0.9355
#
# Epoch 00057: val_loss did not improve from 0.09565
# Epoch 58/75
# 14/14 [==============================] - 661s 47s/step - loss: 0.0330 - accuracy: 0.9835 - val_loss: 0.5685 - val_accuracy: 0.8477
#
# Epoch 00058: val_loss did not improve from 0.09565
# Epoch 59/75
# 14/14 [==============================] - 652s 47s/step - loss: 0.0310 - accuracy: 0.9867 - val_loss: 1.2716 - val_accuracy: 0.7461
#
# Epoch 00059: val_loss did not improve from 0.09565
# Epoch 60/75
# 14/14 [==============================] - 719s 52s/step - loss: 0.0269 - accuracy: 0.9947 - val_loss: 0.0926 - val_accuracy: 0.9727
#
# Epoch 00060: val_loss improved from 0.09565 to 0.09257, saving model to model/xRGM2.2/xRGM2.2
# INFO:tensorflow:Assets written to: model/xRGM2.2/xRGM2.2/assets
# Epoch 61/75
# 14/14 [==============================] - 670s 48s/step - loss: 0.0172 - accuracy: 0.9931 - val_loss: 0.1647 - val_accuracy: 0.9297
#
# Epoch 00061: val_loss did not improve from 0.09257
# Epoch 62/75
# 14/14 [==============================] - 689s 49s/step - loss: 0.0300 - accuracy: 0.9849 - val_loss: 0.7114 - val_accuracy: 0.8730
#
# Epoch 00062: val_loss did not improve from 0.09257
# Epoch 63/75
# 14/14 [==============================] - 646s 46s/step - loss: 0.0188 - accuracy: 0.9941 - val_loss: 0.3285 - val_accuracy: 0.9160
#
# Epoch 00063: val_loss did not improve from 0.09257
# Epoch 64/75
# 14/14 [==============================] - 641s 46s/step - loss: 0.0134 - accuracy: 0.9967 - val_loss: 0.2267 - val_accuracy: 0.9473
#
# Epoch 00064: val_loss did not improve from 0.09257
# Epoch 65/75
# 14/14 [==============================] - 632s 45s/step - loss: 0.0114 - accuracy: 0.9989 - val_loss: 0.1702 - val_accuracy: 0.9375
#
# Epoch 00065: val_loss did not improve from 0.09257
# Epoch 66/75
# 14/14 [==============================] - 646s 46s/step - loss: 0.0189 - accuracy: 0.9949 - val_loss: 0.1508 - val_accuracy: 0.9473
#
# Epoch 00066: val_loss did not improve from 0.09257
# Epoch 67/75
# 14/14 [==============================] - 689s 49s/step - loss: 0.0106 - accuracy: 0.9990 - val_loss: 0.1022 - val_accuracy: 0.9629
#
# Epoch 00067: val_loss did not improve from 0.09257
# Epoch 68/75
# 14/14 [==============================] - 635s 45s/step - loss: 0.0202 - accuracy: 0.9930 - val_loss: 0.1560 - val_accuracy: 0.9414
#
# Epoch 00068: val_loss did not improve from 0.09257
# Epoch 69/75
# 14/14 [==============================] - 683s 49s/step - loss: 0.0087 - accuracy: 0.9985 - val_loss: 0.1677 - val_accuracy: 0.9473
#
# Epoch 00069: val_loss did not improve from 0.09257
# Epoch 70/75
# 14/14 [==============================] - 685s 49s/step - loss: 0.0111 - accuracy: 0.9972 - val_loss: 0.1087 - val_accuracy: 0.9590
#
# Epoch 00070: val_loss did not improve from 0.09257
# Epoch 71/75
# 14/14 [==============================] - 674s 48s/step - loss: 0.0226 - accuracy: 0.9918 - val_loss: 0.3939 - val_accuracy: 0.8848
#
# Epoch 00071: val_loss did not improve from 0.09257
# Epoch 72/75
# 14/14 [==============================] - 671s 48s/step - loss: 0.0110 - accuracy: 0.9970 - val_loss: 0.0641 - val_accuracy: 0.9766
#
# Epoch 00072: val_loss improved from 0.09257 to 0.06407, saving model to model/xRGM2.2/xRGM2.2
# INFO:tensorflow:Assets written to: model/xRGM2.2/xRGM2.2/assets
# Epoch 73/75
# 14/14 [==============================] - 569s 41s/step - loss: 0.0157 - accuracy: 0.9954 - val_loss: 0.1348 - val_accuracy: 0.9570
#
# Epoch 00073: val_loss did not improve from 0.06407
# Epoch 74/75
# 14/14 [==============================] - 669s 48s/step - loss: 0.0120 - accuracy: 0.9970 - val_loss: 0.1142 - val_accuracy: 0.9668
#
# Epoch 00074: val_loss did not improve from 0.06407
# Epoch 75/75
# 14/14 [==============================] - 686s 49s/step - loss: 0.0269 - accuracy: 0.9900 - val_loss: 0.4070 - val_accuracy: 0.9219
#
# Epoch 00075: val_loss did not improve from 0.06407
# INFO:tensorflow:Assets written to: model/xRGM2.2/assets
# CPU times: user 1d 18h 18min 22s, sys: 1h 4min 5s, total: 1d 19h 22min 27s
# Wall time: 13h 48min 45s

# %%
confusion_matrix = pd.DataFrame(metrics.confusion_matrix(y_test, v_classify(y_pred)),
                                columns=['Predicted Negative', 'Predicted Positive'],
                                index=['Actual Negative', 'Actual Positive'])

tp, tn, fp, fn = (
    confusion_matrix.iloc[1,1], 
    confusion_matrix.iloc[0,0], 
    confusion_matrix.iloc[0,1], 
    confusion_matrix.iloc[1,0]
)

accuracy = (tp + tn) / (tp + tn + fp + fn)
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
f1_score = 2 * ((specificity * sensitivity) / (specificity + sensitivity))

with open(os.path.join(f'{model_dir}', 'metrics.csv'), 'a', encoding='utf-8') as f:
    f.write(
        f'{time.strftime("%Y-%m-%dT%H:%M:%S-05:00", time.localtime())}, {accuracy}, {sensitivity}, {specificity}, {f1_score}\n'
    )

print(f'Accuracy:    {accuracy}')
print(f'Sensitivity: {sensitivity}')
print(f'Specificity: {specificity}')
print(f'F1 Score:    {f1_score}')
print('\n')
print(confusion_matrix)
# Out:
# Accuracy:    0.9436392914653784
# Sensitivity: 0.9129032258064517
# Specificity: 0.9742765273311897
# F1 Score:    0.9425919106533366
#
#
#                  Predicted Negative  Predicted Positive
# Actual Negative                 303                   8
# Actual Positive                  27                 283

# %%
disease_types=['COVID', 'non-COVID']
Y_pred = np.argmax(y_pred)
Y_true = np.argmax(y_test)

plt.figure(figsize=(7, 7))
ax = sns.heatmap(confusion_matrix , cmap=plt.cm.GnBu , 
                 annot=True, fmt='d',square=True, xticklabels=disease_types, 
                 yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
plt.show()

# %%
def plot_model_history(model_history):
   fig, axs = plt.subplots(1,2,figsize=(15,5))
   # summarize history for accuracy
   axs[0].plot(range(1, len(model_history['accuracy']) + 1), model_history['accuracy'])
   axs[0].plot(range(1, len(model_history['val_accuracy']) + 1), model_history['val_accuracy'])
   axs[0].set_title('Model Accuracy')
   axs[0].set_ylabel('Accuracy')
   axs[0].set_xlabel('Epoch')
   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
   axs[0].legend(['train', 'val'], loc='best')
   # summarize history for loss
   axs[1].plot(range(1, len(model_history['loss'])+1), model_history['loss'])
   axs[1].plot(range(1, len(model_history['val_loss']) + 1), model_history['val_loss'])
   axs[1].set_title('Model Loss')
   axs[1].set_ylabel('Loss')
   axs[1].set_xlabel('Epoch')
   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
   axs[1].legend(['train', 'val'], loc='best')
   plt.show()

# %%
with open(os.path.join('models', 'xRGM2.2-Net-HistDict'), 'rb') as f:
    history = pickle.load(f)
    
plot_model_history(history)
# Out:
# <ipython-input-12-25025fac5012>:9: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
# <ipython-input-12-25025fac5012>:17: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
