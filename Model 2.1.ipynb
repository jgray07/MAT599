# %%
import glob
import json
import os
import pickle
import random
import traceback
from typing import Tuple

import numpy as np
import pandas as pd
import seaborn as sns
from keras.models import Sequential, load_model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Lambda, LeakyReLU, AveragePooling2D, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from matplotlib import pyplot as plt
from matplotlib.pyplot import hist
from PIL import Image
from scipy.stats import zscore
from sklearn import metrics
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %%
import csv
import time

# %% [markdown]
# ## Config & Constants

# %%
IMAGE_WIDTH, IMAGE_HEIGHT = 227, 227
random.seed(52)

# %% [markdown]
# ## Methods

# %% [markdown]
# ### Image Utilities

# %%
def batch_generator(input_data, output_data, batch_size, is_training):
    input_data_batch = np.empty([batch_size, IMAGE_HEIGHT, IMAGE_WIDTH, 1])
    output_data_batch = np.empty([batch_size, 1])
    while True:
        index = 0
        for i in np.random.permutation(input_data.shape[0]):
            input_data_batch[index] = input_data[i]
            output_data_batch[index] = output_data[i]
            index += 1
            if index == batch_size:
                break
        yield input_data_batch, output_data_batch


def _preprocess(image_loc: str) -> np.ndarray:
    f_image = Image.open(image_loc).convert('L')
    f_image = f_image.resize((IMAGE_WIDTH, IMAGE_HEIGHT), Image.ANTIALIAS)
    image = np.asarray(f_image)
    image = np.expand_dims(image, axis=0)
    image = np.expand_dims(image, axis=3)
    return image


def preprocess(loc: str) -> np.ndarray:
    """Safety wrapper over _preprocess.
    
    Args:
        loc: File location to check if dir or an image.
        
    Returns:
        Preprocessed image(s) as an ndarray.
    """
    if os.path.isdir(loc):
        current = np.concatenate((
            [_preprocess(os.path.join(loc, image)) for image in os.listdir(loc)
             if '.png' in image]
        ))
    else:
        current = _preprocess(loc)
    return current


def generate_data_arrays(
    covid_data: str = 'rsc/New_Data_CoV2/COVID/',
    noncovid_data: str = 'rsc/New_Data_CoV2/non-COVID/',
    others_data:  str = 'rsc/New_Data_CoV2/Others/',
    image_output: str = 'rsc/input_data_v2',
    label_output: str = 'rsc/output_data_v2',
    regenerate: bool = True
) -> Tuple[np.ndarray, np.ndarray]:
    """Loads COVID images into ndarrays.
    
    Args:
        covid_data: Relative path to folder containing COVID images.
        noncovid_data: Relative path to folder containing non-COVID images.
        others_data: Relative path to folder containing Others images.
        image_output: Relative path (with filename) to save loaded images to.
        label_output: Relative path (with filename) to save loaded classes (labels) to.
        regenerate: If True, will regenerate saved ndarray files for both image_output
            and label_output, even if they already exist (overwriting them). If False,
            will simply load and return the aforementioned.
        
    Returns:
        Tuple of ndarrays. The first is the loaded image data in one large ndarray,
        and the second is the loaded labels, also in a large ndarray. These directly
        match up to each other ONLY when both arrays (and their respective files)
        are generated at the same time with this method.
    """
    if (regenerate is False and 
        os.path.isfile(f'{out_input_data}.npy') and
        os.path.isfile(f'{out_output_data}.npy')):
        return (np.load(f'{out_input_data}.npy'),
                np.load(f'{out_output_data}.npy'))
    
    if not ((cd := os.path.exists(covid_data)) and (ncd := os.path.exists(noncovid_data))):
        if (others_data is not None) and not (odd := os.path.exists(others_data)):
            raise NotADirectoryError("Directories do not exist.")
        else:
            raise NotADirectoryError("COVID/non-COVID directories do not exist.")
    
    im_data = np.empty([1, IMAGE_WIDTH, IMAGE_WIDTH, 1])
    output = np.array([0])

    print('Loading Covid Data')
    for i in tqdm(glob.glob(os.path.join(covid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([1])), axis=0)

    print('Loading non-Covid Data')
    for i in tqdm(glob.glob(os.path.join(noncovid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([0])), axis=0)
        
    if others_data is not None:
        print('Loading Others Data')
        for i in tqdm(glob.glob(os.path.join(others_data, '**'))):
            current = preprocess(i)
            im_data = np.concatenate((im_data, current))
            output = np.concatenate((output, np.array([-1])), axis=0)
    else:
        print('Others data not provided; skipping.')


    print('Finished Loading Data')
    im_data = np.delete(im_data, 0, axis=0)
    output = np.delete(output, 0, axis=0)

    zip_data = list(zip(im_data, output))
    random.shuffle(zip_data)
    im_data, output = zip(*zip_data)

    np.save(f'{image_output}', im_data)
    np.save(f'{label_output}', output)
    return im_data, output


def load_data(image_loc: str, label_loc: str, **kwargs) -> Tuple[np.ndarray, np.ndarray]:
    """Attempts to load generated images and labels.
    
    If either is not found, attempts to (re)generate them using the default
    input arguments to the generation method for the raw data, but the input
    `image_loc` and `label_loc` parameters for the output arrays. If this
    still does not work, returns a general error and exits.
    
    Args:
        image_loc: Relative path to saved image ndarray file.
        label_loc: Relative path to saved label ndarray file.
        
    Returns:
        Tuple of ndarrays. The first array holds the loaded image data, whilst
        the second array holds their respective labels.
    
    """
    try:
        image_data = np.load(f'{image_loc}.npy')
        label_data = np.load(f'{label_loc}.npy')
        return image_data, label_data
    
    except FileNotFoundError:
        try:
            image_data, label_data = generate_data_arrays(
                image_output = image_loc,
                label_output = label_loc,
                **kwargs
            )
            return image_data, label_data
        
        except Exception as e:
            traceback.print_exc()

# %% [markdown]
# ## Model Playground

# %%
#Version 1
im_data_v1, output_v1 = load_data(
    image_loc = 'rsc/input_data_v1',
    label_loc = 'rsc/output_data_v1',
    covid_data = 'rsc/Data_CoV2/COVID/',
    noncovid_data = 'rsc/Data_CoV2/non-COVID/',
    others_data = None,
)

x_train, x_test, y_train, y_test = train_test_split(im_data_v1, output_v1, random_state=42)

# %%
def make_model(X_Train, Y_Train, X_Test, Y_Test, model_dir: str):
    if not os.path.exists(model_dir):
        os.makedirs(model_dir)
    #X_Train, X_Test, Y_Train, Y_Test = train_test_split(input_data, output_data, test_size=0.1)

    for_pad = lambda s: s if s > 2 else 3

    model = Sequential()
    model.add(Lambda(lambda x: x, input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 1)))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=8, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))



    #model.add(ZeroPadding2D(padding=(for_pad(19) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(Conv2D(kernel_size=(3, 3), filters=2, strides=(1, 1),activation='relu'))

    model.add(Flatten())

    model.add(Dropout(rate=0.3))
    model.add(Dense(units=338, activation='relu'))
    model.add(Dense(units=1, activation='sigmoid'))

    model.compile(optimizer=Adam(lr=3e-4), loss='binary_crossentropy', metrics=["accuracy"])
    model.summary()

    checkpoint = ModelCheckpoint(os.path.join(model_dir, 'xRGM1.5D0.3'), verbose=1, period=1, save_best_only=True)

    hist = model.fit_generator(batch_generator(X_Train, Y_Train, 128, True),
                        validation_data=(batch_generator(X_Test, Y_Test, 128, False)), callbacks=[checkpoint],
                        verbose=1, epochs=75, steps_per_epoch=25, validation_steps=len(X_Test))

    with open(os.path.join('models', 'xRGM1.5D0.3-Net-HistDict'), 'wb') as f:
        pickle.dump(hist.history, f)

    model.save(model_dir)
    
    return model
#changed steps and epochs and batchsize

# %%
# %%time
model_dir: str = 'model/xRGM1.5D0.3'
xRGM = make_model(x_train, y_train.reshape(-1,1), x_test, y_test.reshape(-1,1), model_dir=model_dir)

v_classify = np.vectorize(lambda x: np.round(x, 0))
# xRGMCT2 = load_model('models/xRGMCT2L.h5')
# print(xRGMCT2.history)
y_pred = (xRGM.predict(x_test))

#print(y_test)
#print(y_pred)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_1 (Lambda)            (None, 227, 227, 1)       0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 225, 225, 8)       80
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 225, 225, 8)       32
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 225, 225, 8)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 112, 112, 8)       0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 110, 110, 16)      1168
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 110, 110, 16)      64
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 110, 110, 16)      0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 108, 108, 32)      4640
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 108, 108, 32)      128
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 108, 108, 32)      0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 108, 108, 16)      528
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 108, 108, 16)      64
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 108, 108, 16)      0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 106, 106, 32)      4640
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 106, 106, 32)      128
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 106, 106, 32)      0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 104, 104, 64)      18496
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 104, 104, 64)      256
# _________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)   (None, 104, 104, 64)      0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 104, 104, 32)      2080
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 104, 104, 32)      128
# _________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)   (None, 104, 104, 32)      0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 102, 102, 64)      18496
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 102, 102, 64)      256
# _________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)   (None, 102, 102, 64)      0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 100, 100, 128)     73856
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 100, 100, 128)     512
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 100, 100, 128)     0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 100, 100, 64)      8256
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 100, 100, 64)      256
# _________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)   (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 98, 98, 128)       73856
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 98, 98, 128)       512
# _________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)   (None, 98, 98, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 49, 49, 128)       0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 47, 47, 256)       295168
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 47, 47, 256)       1024
# _________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)   (None, 47, 47, 256)       0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 47, 47, 128)       32896
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 47, 47, 128)       512
# _________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)   (None, 47, 47, 128)       0
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 23, 23, 128)       0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 21, 21, 256)       295168
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 21, 21, 256)       1024
# _________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)   (None, 21, 21, 256)       0
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 10, 10, 256)       0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 10, 10, 128)       32896
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)   (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)   (None, 8, 8, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16384)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 338)               5538130
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 339
# =================================================================
# Total params: 6,702,293
# Trainable params: 6,699,077
# Non-trainable params: 3,216
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/75
# /home/jg1994/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 25/25 [==============================] - 3828s 159s/step - loss: 1.4151 - accuracy: 0.6203 - val_loss: 0.6975 - val_accuracy: 0.5008
#
# Epoch 00001: val_loss improved from inf to 0.69750, saving model to model/xRGM1.5D0.3/xRGM1.5D0.3
# INFO:tensorflow:Assets written to: model/xRGM1.5D0.3/xRGM1.5D0.3/assets
# Epoch 2/75
# 25/25 [==============================] - 4584s 190s/step - loss: 0.2669 - accuracy: 0.8920 - val_loss: 0.7208 - val_accuracy: 0.4979
#
# Epoch 00002: val_loss did not improve from 0.69750
# Epoch 3/75
# 25/25 [==============================] - 4616s 191s/step - loss: 0.1588 - accuracy: 0.9396 - val_loss: 0.7571 - val_accuracy: 0.4998
#
# Epoch 00003: val_loss did not improve from 0.69750
# Epoch 4/75
# 25/25 [==============================] - 5335s 221s/step - loss: 0.0953 - accuracy: 0.9669 - val_loss: 0.7245 - val_accuracy: 0.5013
#
# Epoch 00004: val_loss did not improve from 0.69750
# Epoch 5/75
# 25/25 [==============================] - 5651s 234s/step - loss: 0.0546 - accuracy: 0.9840 - val_loss: 0.7328 - val_accuracy: 0.5044
#
# Epoch 00005: val_loss did not improve from 0.69750
# Epoch 6/75
# 25/25 [==============================] - 5722s 237s/step - loss: 0.0298 - accuracy: 0.9937 - val_loss: 0.6561 - val_accuracy: 0.5606
#
# Epoch 00006: val_loss improved from 0.69750 to 0.65609, saving model to model/xRGM1.5D0.3/xRGM1.5D0.3
# INFO:tensorflow:Assets written to: model/xRGM1.5D0.3/xRGM1.5D0.3/assets
# Epoch 7/75
# 25/25 [==============================] - 5688s 235s/step - loss: 0.0093 - accuracy: 0.9993 - val_loss: 0.6946 - val_accuracy: 0.5673
#
# Epoch 00007: val_loss did not improve from 0.65609
# Epoch 8/75
# 25/25 [==============================] - 5682s 235s/step - loss: 0.0061 - accuracy: 0.9997 - val_loss: 0.6021 - val_accuracy: 0.6776
#
# Epoch 00008: val_loss improved from 0.65609 to 0.60207, saving model to model/xRGM1.5D0.3/xRGM1.5D0.3
# INFO:tensorflow:Assets written to: model/xRGM1.5D0.3/xRGM1.5D0.3/assets
# Epoch 9/75
# 25/25 [==============================] - 5716s 237s/step - loss: 0.0115 - accuracy: 0.9967 - val_loss: 0.4656 - val_accuracy: 0.7866
#
# Epoch 00009: val_loss improved from 0.60207 to 0.46562, saving model to model/xRGM1.5D0.3/xRGM1.5D0.3
# INFO:tensorflow:Assets written to: model/xRGM1.5D0.3/xRGM1.5D0.3/assets
# Epoch 10/75
# 25/25 [==============================] - 5649s 234s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.4644 - val_accuracy: 0.7876
#
# Epoch 00010: val_loss improved from 0.46562 to 0.46439, saving model to model/xRGM1.5D0.3/xRGM1.5D0.3
# INFO:tensorflow:Assets written to: model/xRGM1.5D0.3/xRGM1.5D0.3/assets
# Epoch 11/75
# 25/25 [==============================] - 5694s 235s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.5013 - val_accuracy: 0.7960
#
# Epoch 00011: val_loss did not improve from 0.46439
# Epoch 12/75
# 25/25 [==============================] - 5715s 237s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4399 - val_accuracy: 0.8228
#
# Epoch 00012: val_loss improved from 0.46439 to 0.43994, saving model to model/xRGM1.5D0.3/xRGM1.5D0.3
# INFO:tensorflow:Assets written to: model/xRGM1.5D0.3/xRGM1.5D0.3/assets
# Epoch 13/75
# 25/25 [==============================] - 5612s 232s/step - loss: 4.8295e-04 - accuracy: 1.0000 - val_loss: 0.3615 - val_accuracy: 0.8470
#
# Epoch 00013: val_loss improved from 0.43994 to 0.36146, saving model to model/xRGM1.5D0.3/xRGM1.5D0.3
# INFO:tensorflow:Assets written to: model/xRGM1.5D0.3/xRGM1.5D0.3/assets
# Epoch 14/75
# 25/25 [==============================] - 5707s 236s/step - loss: 3.9486e-04 - accuracy: 1.0000 - val_loss: 0.2417 - val_accuracy: 0.8966
#
# Epoch 00014: val_loss improved from 0.36146 to 0.24172, saving model to model/xRGM1.5D0.3/xRGM1.5D0.3
# INFO:tensorflow:Assets written to: model/xRGM1.5D0.3/xRGM1.5D0.3/assets
# Epoch 15/75
# 25/25 [==============================] - 5666s 235s/step - loss: 3.5950e-04 - accuracy: 1.0000 - val_loss: 0.1609 - val_accuracy: 0.9281
#
# Epoch 00015: val_loss improved from 0.24172 to 0.16090, saving model to model/xRGM1.5D0.3/xRGM1.5D0.3
# INFO:tensorflow:Assets written to: model/xRGM1.5D0.3/xRGM1.5D0.3/assets
# Epoch 16/75
# 25/25 [==============================] - 5665s 234s/step - loss: 2.7836e-04 - accuracy: 1.0000 - val_loss: 0.1127 - val_accuracy: 0.9592
#
# Epoch 00016: val_loss improved from 0.16090 to 0.11271, saving model to model/xRGM1.5D0.3/xRGM1.5D0.3
# INFO:tensorflow:Assets written to: model/xRGM1.5D0.3/xRGM1.5D0.3/assets
# Epoch 17/75
# 25/25 [==============================] - 5726s 237s/step - loss: 2.3027e-04 - accuracy: 1.0000 - val_loss: 0.0914 - val_accuracy: 0.9624
#
# Epoch 00017: val_loss improved from 0.11271 to 0.09145, saving model to model/xRGM1.5D0.3/xRGM1.5D0.3
# INFO:tensorflow:Assets written to: model/xRGM1.5D0.3/xRGM1.5D0.3/assets
# Epoch 18/75
# 25/25 [==============================] - 5649s 234s/step - loss: 2.8838e-04 - accuracy: 1.0000 - val_loss: 0.0812 - val_accuracy: 0.9681
#
# Epoch 00018: val_loss improved from 0.09145 to 0.08117, saving model to model/xRGM1.5D0.3/xRGM1.5D0.3
# INFO:tensorflow:Assets written to: model/xRGM1.5D0.3/xRGM1.5D0.3/assets
# Epoch 19/75
# 25/25 [==============================] - 5674s 235s/step - loss: 2.2821e-04 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9699
#
# Epoch 00019: val_loss improved from 0.08117 to 0.07424, saving model to model/xRGM1.5D0.3/xRGM1.5D0.3
# INFO:tensorflow:Assets written to: model/xRGM1.5D0.3/xRGM1.5D0.3/assets
# Epoch 20/75
# 25/25 [==============================] - 5725s 237s/step - loss: 1.5288e-04 - accuracy: 1.0000 - val_loss: 0.0670 - val_accuracy: 0.9745
#
# Epoch 00020: val_loss improved from 0.07424 to 0.06698, saving model to model/xRGM1.5D0.3/xRGM1.5D0.3
# INFO:tensorflow:Assets written to: model/xRGM1.5D0.3/xRGM1.5D0.3/assets
# Epoch 21/75
# 25/25 [==============================] - 5629s 233s/step - loss: 1.7080e-04 - accuracy: 1.0000 - val_loss: 0.0656 - val_accuracy: 0.9759
#
# Epoch 00021: val_loss improved from 0.06698 to 0.06561, saving model to model/xRGM1.5D0.3/xRGM1.5D0.3
# INFO:tensorflow:Assets written to: model/xRGM1.5D0.3/xRGM1.5D0.3/assets
# Epoch 22/75
# 25/25 [==============================] - 4928s 204s/step - loss: 1.6800e-04 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9726
#
# Epoch 00022: val_loss did not improve from 0.06561
# Epoch 23/75
# 25/25 [==============================] - 4667s 193s/step - loss: 1.6212e-04 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9746
#
# Epoch 00023: val_loss did not improve from 0.06561
# Epoch 24/75
# 25/25 [==============================] - 5698s 236s/step - loss: 1.2921e-04 - accuracy: 1.0000 - val_loss: 0.0684 - val_accuracy: 0.9754
#
# Epoch 00024: val_loss did not improve from 0.06561
# Epoch 25/75
# 25/25 [==============================] - 4624s 191s/step - loss: 1.2713e-04 - accuracy: 1.0000 - val_loss: 0.0693 - val_accuracy: 0.9773
#
# Epoch 00025: val_loss did not improve from 0.06561
# Epoch 26/75
# 25/25 [==============================] - 4462s 184s/step - loss: 8.4300e-05 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9764
#
# Epoch 00026: val_loss did not improve from 0.06561
# Epoch 27/75
# 25/25 [==============================] - 4417s 183s/step - loss: 9.3621e-05 - accuracy: 1.0000 - val_loss: 0.0685 - val_accuracy: 0.9803
#
# Epoch 00027: val_loss did not improve from 0.06561
# Epoch 28/75
# 25/25 [==============================] - 4468s 185s/step - loss: 1.5182e-04 - accuracy: 1.0000 - val_loss: 0.0707 - val_accuracy: 0.9722
#
# Epoch 00028: val_loss did not improve from 0.06561
# Epoch 29/75
# 25/25 [==============================] - 4439s 184s/step - loss: 0.0390 - accuracy: 0.9864 - val_loss: 6.2493 - val_accuracy: 0.6729
#
# Epoch 00029: val_loss did not improve from 0.06561
# Epoch 30/75
# 25/25 [==============================] - 4464s 184s/step - loss: 0.1491 - accuracy: 0.9445 - val_loss: 5.0865 - val_accuracy: 0.7380
#
# Epoch 00030: val_loss did not improve from 0.06561
# Epoch 31/75
# 25/25 [==============================] - 4436s 184s/step - loss: 0.0537 - accuracy: 0.9841 - val_loss: 1.2526 - val_accuracy: 0.8380
#
# Epoch 00031: val_loss did not improve from 0.06561
# Epoch 32/75
# 25/25 [==============================] - 4467s 185s/step - loss: 0.0250 - accuracy: 0.9909 - val_loss: 0.4111 - val_accuracy: 0.9115
#
# Epoch 00032: val_loss did not improve from 0.06561
# Epoch 33/75
# 25/25 [==============================] - 4446s 184s/step - loss: 0.0114 - accuracy: 0.9959 - val_loss: 0.2584 - val_accuracy: 0.9434
#
# Epoch 00033: val_loss did not improve from 0.06561
# Epoch 34/75
# 25/25 [==============================] - 4453s 184s/step - loss: 0.0056 - accuracy: 0.9988 - val_loss: 0.1494 - val_accuracy: 0.9579
#
# Epoch 00034: val_loss did not improve from 0.06561
# Epoch 35/75
# 25/25 [==============================] - 4454s 184s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9630
#
# Epoch 00035: val_loss did not improve from 0.06561
# Epoch 36/75
# 25/25 [==============================] - 4474s 185s/step - loss: 8.3665e-04 - accuracy: 1.0000 - val_loss: 0.0960 - val_accuracy: 0.9645
#
# Epoch 00036: val_loss did not improve from 0.06561
# Epoch 37/75
# 25/25 [==============================] - 4473s 185s/step - loss: 6.9022e-04 - accuracy: 1.0000 - val_loss: 0.0880 - val_accuracy: 0.9684
#
# Epoch 00037: val_loss did not improve from 0.06561
# Epoch 38/75
# 25/25 [==============================] - 4448s 184s/step - loss: 4.4512e-04 - accuracy: 1.0000 - val_loss: 0.1040 - val_accuracy: 0.9696
#
# Epoch 00038: val_loss did not improve from 0.06561
# Epoch 39/75
# 25/25 [==============================] - 4474s 185s/step - loss: 3.1868e-04 - accuracy: 1.0000 - val_loss: 0.1135 - val_accuracy: 0.9665
#
# Epoch 00039: val_loss did not improve from 0.06561
# Epoch 40/75
# 25/25 [==============================] - 4441s 184s/step - loss: 4.0728e-04 - accuracy: 1.0000 - val_loss: 0.0824 - val_accuracy: 0.9692
#
# Epoch 00040: val_loss did not improve from 0.06561
# Epoch 41/75
# 25/25 [==============================] - 4476s 185s/step - loss: 2.1307e-04 - accuracy: 1.0000 - val_loss: 0.0843 - val_accuracy: 0.9696
#
# Epoch 00041: val_loss did not improve from 0.06561
# Epoch 42/75
# 25/25 [==============================] - 4461s 184s/step - loss: 6.3329e-04 - accuracy: 1.0000 - val_loss: 0.0878 - val_accuracy: 0.9729
#
# Epoch 00042: val_loss did not improve from 0.06561
# Epoch 43/75
# 25/25 [==============================] - 4475s 185s/step - loss: 3.3155e-04 - accuracy: 1.0000 - val_loss: 0.0765 - val_accuracy: 0.9740
#
# Epoch 00043: val_loss did not improve from 0.06561
# Epoch 44/75
# 25/25 [==============================] - 4439s 184s/step - loss: 1.7760e-04 - accuracy: 1.0000 - val_loss: 0.0765 - val_accuracy: 0.9775
#
# Epoch 00044: val_loss did not improve from 0.06561
# Epoch 45/75
# 25/25 [==============================] - 3500s 145s/step - loss: 2.1277e-04 - accuracy: 1.0000 - val_loss: 0.0776 - val_accuracy: 0.9730
#
# Epoch 00045: val_loss did not improve from 0.06561
# Epoch 46/75
# 25/25 [==============================] - 3319s 137s/step - loss: 3.4814e-04 - accuracy: 1.0000 - val_loss: 0.0956 - val_accuracy: 0.9692
#
# Epoch 00046: val_loss did not improve from 0.06561
# Epoch 47/75
# 25/25 [==============================] - 3316s 137s/step - loss: 2.5880e-04 - accuracy: 1.0000 - val_loss: 0.0834 - val_accuracy: 0.9676
#
# Epoch 00047: val_loss did not improve from 0.06561
# Epoch 48/75
# 25/25 [==============================] - 3306s 137s/step - loss: 1.6805e-04 - accuracy: 1.0000 - val_loss: 0.0765 - val_accuracy: 0.9709
#
# Epoch 00048: val_loss did not improve from 0.06561
# Epoch 49/75
# 25/25 [==============================] - 3314s 137s/step - loss: 1.2008e-04 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 0.9732
#
# Epoch 00049: val_loss did not improve from 0.06561
# Epoch 50/75
# 25/25 [==============================] - 3321s 138s/step - loss: 1.2590e-04 - accuracy: 1.0000 - val_loss: 0.0699 - val_accuracy: 0.9761
#
# Epoch 00050: val_loss did not improve from 0.06561
# Epoch 51/75
# 25/25 [==============================] - 3312s 137s/step - loss: 8.5549e-05 - accuracy: 1.0000 - val_loss: 0.0701 - val_accuracy: 0.9744
#
# Epoch 00051: val_loss did not improve from 0.06561
# Epoch 52/75
# 25/25 [==============================] - 3314s 137s/step - loss: 1.1142e-04 - accuracy: 1.0000 - val_loss: 0.0756 - val_accuracy: 0.9739
#
# Epoch 00052: val_loss did not improve from 0.06561
# Epoch 53/75
# 25/25 [==============================] - 3305s 137s/step - loss: 9.5965e-05 - accuracy: 1.0000 - val_loss: 0.0747 - val_accuracy: 0.9748
#
# Epoch 00053: val_loss did not improve from 0.06561
# Epoch 54/75
# 25/25 [==============================] - 3314s 137s/step - loss: 8.1862e-05 - accuracy: 1.0000 - val_loss: 0.0771 - val_accuracy: 0.9750
#
# Epoch 00054: val_loss did not improve from 0.06561
# Epoch 55/75
# 25/25 [==============================] - 3317s 137s/step - loss: 1.0586e-04 - accuracy: 1.0000 - val_loss: 0.0775 - val_accuracy: 0.9743
#
# Epoch 00055: val_loss did not improve from 0.06561
# Epoch 56/75
# 25/25 [==============================] - 3325s 138s/step - loss: 6.1238e-05 - accuracy: 1.0000 - val_loss: 0.0758 - val_accuracy: 0.9743
#
# Epoch 00057: val_loss did not improve from 0.06561
# Epoch 58/75
# 25/25 [==============================] - 3332s 138s/step - loss: 4.7168e-05 - accuracy: 1.0000 - val_loss: 0.0796 - val_accuracy: 0.9739
#
# Epoch 00058: val_loss did not improve from 0.06561
# Epoch 59/75
# 25/25 [==============================] - 3338s 138s/step - loss: 5.5590e-05 - accuracy: 1.0000 - val_loss: 0.0782 - val_accuracy: 0.9759
#
# Epoch 00059: val_loss did not improve from 0.06561
# Epoch 60/75
# 25/25 [==============================] - 3317s 137s/step - loss: 5.5572e-05 - accuracy: 1.0000 - val_loss: 0.0783 - val_accuracy: 0.9749
#
# Epoch 00060: val_loss did not improve from 0.06561
# Epoch 61/75
# 25/25 [==============================] - 3323s 138s/step - loss: 5.4748e-05 - accuracy: 1.0000 - val_loss: 0.0762 - val_accuracy: 0.9749
#
# Epoch 00061: val_loss did not improve from 0.06561
# Epoch 62/75
# 25/25 [==============================] - 3321s 138s/step - loss: 5.8169e-05 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9781
#
# Epoch 00062: val_loss did not improve from 0.06561
# Epoch 63/75
# 25/25 [==============================] - 3316s 137s/step - loss: 8.8611e-05 - accuracy: 1.0000 - val_loss: 0.0825 - val_accuracy: 0.9738
#
# Epoch 00063: val_loss did not improve from 0.06561
# Epoch 64/75
# 25/25 [==============================] - 3323s 138s/step - loss: 8.3775e-05 - accuracy: 1.0000 - val_loss: 0.0729 - val_accuracy: 0.9779
#
# Epoch 00064: val_loss did not improve from 0.06561
# Epoch 65/75
# 25/25 [==============================] - 3323s 138s/step - loss: 5.2482e-05 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 0.9796
#
# Epoch 00065: val_loss did not improve from 0.06561
# Epoch 66/75
# 25/25 [==============================] - 3324s 138s/step - loss: 4.4607e-05 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 0.9756
#
# Epoch 00066: val_loss did not improve from 0.06561
# Epoch 67/75
# 25/25 [==============================] - 3325s 138s/step - loss: 6.0148e-05 - accuracy: 1.0000 - val_loss: 0.0787 - val_accuracy: 0.9767
#
# Epoch 00067: val_loss did not improve from 0.06561
# Epoch 68/75
# 25/25 [==============================] - 3327s 138s/step - loss: 8.4206e-05 - accuracy: 1.0000 - val_loss: 0.0762 - val_accuracy: 0.9742
#
# Epoch 00068: val_loss did not improve from 0.06561
# Epoch 69/75
# 25/25 [==============================] - 3325s 138s/step - loss: 6.2188e-05 - accuracy: 1.0000 - val_loss: 0.0777 - val_accuracy: 0.9744
#
# Epoch 00069: val_loss did not improve from 0.06561
# Epoch 70/75
# 25/25 [==============================] - 3333s 138s/step - loss: 4.7682e-05 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 0.9772
#
# Epoch 00070: val_loss did not improve from 0.06561
# Epoch 71/75
# 25/25 [==============================] - 3325s 138s/step - loss: 4.7135e-05 - accuracy: 1.0000 - val_loss: 0.0769 - val_accuracy: 0.9776
#
# Epoch 00071: val_loss did not improve from 0.06561
# Epoch 72/75
# 25/25 [==============================] - 3314s 137s/step - loss: 4.6430e-05 - accuracy: 1.0000 - val_loss: 0.0778 - val_accuracy: 0.9754
#
# Epoch 00072: val_loss did not improve from 0.06561
# Epoch 73/75
# 25/25 [==============================] - 3312s 137s/step - loss: 7.5356e-05 - accuracy: 1.0000 - val_loss: 0.0798 - val_accuracy: 0.9776
#
# Epoch 00073: val_loss did not improve from 0.06561
# Epoch 74/75
# 25/25 [==============================] - 3315s 137s/step - loss: 3.7980e-05 - accuracy: 1.0000 - val_loss: 0.0825 - val_accuracy: 0.9738
#
# Epoch 00074: val_loss did not improve from 0.06561
# Epoch 75/75
# 25/25 [==============================] - 3310s 137s/step - loss: 5.7630e-05 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 0.9742
#
# Epoch 00075: val_loss did not improve from 0.06561
# INFO:tensorflow:Assets written to: model/xRGM1.5D0.3/assets
# CPU times: user 21d 13h 25min 15s, sys: 18h 12min 59s, total: 22d 7h 38min 14s
# Wall time: 3d 17h 43min 13s

# %%
confusion_matrix = pd.DataFrame(metrics.confusion_matrix(y_test, v_classify(y_pred)),
                                columns=['Predicted Negative', 'Predicted Positive'],
                                index=['Actual Negative', 'Actual Positive'])

tp, tn, fp, fn = (
    confusion_matrix.iloc[1,1], 
    confusion_matrix.iloc[0,0], 
    confusion_matrix.iloc[0,1], 
    confusion_matrix.iloc[1,0]
)

accuracy = (tp + tn) / (tp + tn + fp + fn)
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
f1_score = 2 * ((specificity * sensitivity) / (specificity + sensitivity))

with open(os.path.join(f'{model_dir}', 'metrics.csv'), 'a', encoding='utf-8') as f:
    f.write(
        f'{time.strftime("%Y-%m-%dT%H:%M:%S-05:00", time.localtime())}, {accuracy}, {sensitivity}, {specificity}, {f1_score}\n'
    )

print(f'Accuracy:    {accuracy}')
print(f'Sensitivity: {sensitivity}')
print(f'Specificity: {specificity}')
print(f'F1 Score:    {f1_score}')
print('\n')
print(confusion_matrix)
# Out:
# Accuracy:    0.9742351046698873
# Sensitivity: 0.967741935483871
# Specificity: 0.9807073954983923
# F1 Score:    0.9741815278147458
#
#
#                  Predicted Negative  Predicted Positive
# Actual Negative                 305                   6
# Actual Positive                  10                 300

# %%
disease_types=['COVID', 'non-COVID']
Y_pred = np.argmax(y_pred)
Y_true = np.argmax(y_test)

plt.figure(figsize=(7, 7))
ax = sns.heatmap(confusion_matrix , cmap=plt.cm.GnBu , 
                 annot=True, fmt='d',square=True, xticklabels=disease_types, 
                 yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
plt.show()

# %%
def plot_model_history(model_history):
   fig, axs = plt.subplots(1,2,figsize=(15,5))
   # summarize history for accuracy
   axs[0].plot(range(1, len(model_history['accuracy']) + 1), model_history['accuracy'])
   axs[0].plot(range(1, len(model_history['val_accuracy']) + 1), model_history['val_accuracy'])
   axs[0].set_title('Model Accuracy')
   axs[0].set_ylabel('Accuracy')
   axs[0].set_xlabel('Epoch')
   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
   axs[0].legend(['train', 'val'], loc='best')
   # summarize history for loss
   axs[1].plot(range(1, len(model_history['loss'])+1), model_history['loss'])
   axs[1].plot(range(1, len(model_history['val_loss']) + 1), model_history['val_loss'])
   axs[1].set_title('Model Loss')
   axs[1].set_ylabel('Loss')
   axs[1].set_xlabel('Epoch')
   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
   axs[1].legend(['train', 'val'], loc='best')
   plt.show()

# %%
with open(os.path.join('models', 'xRGM1.5D0.3-Net-HistDict'), 'rb') as f:
    history = pickle.load(f)
    
plot_model_history(history)
# Out:
# <ipython-input-18-25025fac5012>:9: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
# <ipython-input-18-25025fac5012>:17: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
