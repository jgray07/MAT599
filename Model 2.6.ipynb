# %%
import glob
import json
import os
import pickle
import random
import traceback
from typing import Tuple

import numpy as np
import pandas as pd
import seaborn as sns
from keras.models import Sequential, load_model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Lambda, LeakyReLU, AveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adamax
from keras.callbacks import ModelCheckpoint
from matplotlib import pyplot as plt
from matplotlib.pyplot import hist
from PIL import Image
from scipy.stats import zscore
from sklearn import metrics
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %%
import csv
import time

# %% [markdown]
# ## Config & Constants

# %%
IMAGE_WIDTH, IMAGE_HEIGHT = 227, 227
random.seed(52)

# %% [markdown]
# ## Methods

# %% [markdown]
# ### Image Utilities

# %%
def batch_generator(input_data, output_data, batch_size, is_training):
    input_data_batch = np.empty([batch_size, IMAGE_HEIGHT, IMAGE_WIDTH, 1])
    output_data_batch = np.empty([batch_size, 1])
    while True:
        index = 0
        for i in np.random.permutation(input_data.shape[0]):
            input_data_batch[index] = input_data[i]
            output_data_batch[index] = output_data[i]
            index += 1
            if index == batch_size:
                break
        yield input_data_batch, output_data_batch


def _preprocess(image_loc: str) -> np.ndarray:
    f_image = Image.open(image_loc).convert('L')
    f_image = f_image.resize((IMAGE_WIDTH, IMAGE_HEIGHT), Image.ANTIALIAS)
    image = np.asarray(f_image)
    image = np.expand_dims(image, axis=0)
    image = np.expand_dims(image, axis=3)
    return image


def preprocess(loc: str) -> np.ndarray:
    """Safety wrapper over _preprocess.
    
    Args:
        loc: File location to check if dir or an image.
        
    Returns:
        Preprocessed image(s) as an ndarray.
    """
    if os.path.isdir(loc):
        current = np.concatenate((
            [_preprocess(os.path.join(loc, image)) for image in os.listdir(loc)
             if '.png' in image]
        ))
    else:
        current = _preprocess(loc)
    return current


def generate_data_arrays(
    covid_data: str = 'rsc/New_Data_CoV2/COVID/',
    noncovid_data: str = 'rsc/New_Data_CoV2/non-COVID/',
    others_data:  str = 'rsc/New_Data_CoV2/Others/',
    image_output: str = 'rsc/input_data_v2',
    label_output: str = 'rsc/output_data_v2',
    regenerate: bool = True
) -> Tuple[np.ndarray, np.ndarray]:
    """Loads COVID images into ndarrays.
    
    Args:
        covid_data: Relative path to folder containing COVID images.
        noncovid_data: Relative path to folder containing non-COVID images.
        others_data: Relative path to folder containing Others images.
        image_output: Relative path (with filename) to save loaded images to.
        label_output: Relative path (with filename) to save loaded classes (labels) to.
        regenerate: If True, will regenerate saved ndarray files for both image_output
            and label_output, even if they already exist (overwriting them). If False,
            will simply load and return the aforementioned.
        
    Returns:
        Tuple of ndarrays. The first is the loaded image data in one large ndarray,
        and the second is the loaded labels, also in a large ndarray. These directly
        match up to each other ONLY when both arrays (and their respective files)
        are generated at the same time with this method.
    """
    if (regenerate is False and 
        os.path.isfile(f'{out_input_data}.npy') and
        os.path.isfile(f'{out_output_data}.npy')):
        return (np.load(f'{out_input_data}.npy'),
                np.load(f'{out_output_data}.npy'))
    
    if not ((cd := os.path.exists(covid_data)) and (ncd := os.path.exists(noncovid_data))):
        if (others_data is not None) and not (odd := os.path.exists(others_data)):
            raise NotADirectoryError("Directories do not exist.")
        else:
            raise NotADirectoryError("COVID/non-COVID directories do not exist.")
    
    im_data = np.empty([1, IMAGE_WIDTH, IMAGE_WIDTH, 1])
    output = np.array([0])

    print('Loading Covid Data')
    for i in tqdm(glob.glob(os.path.join(covid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([1])), axis=0)

    print('Loading non-Covid Data')
    for i in tqdm(glob.glob(os.path.join(noncovid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([0])), axis=0)
        
    if others_data is not None:
        print('Loading Others Data')
        for i in tqdm(glob.glob(os.path.join(others_data, '**'))):
            current = preprocess(i)
            im_data = np.concatenate((im_data, current))
            output = np.concatenate((output, np.array([-1])), axis=0)
    else:
        print('Others data not provided; skipping.')


    print('Finished Loading Data')
    im_data = np.delete(im_data, 0, axis=0)
    output = np.delete(output, 0, axis=0)

    zip_data = list(zip(im_data, output))
    random.shuffle(zip_data)
    im_data, output = zip(*zip_data)

    np.save(f'{image_output}', im_data)
    np.save(f'{label_output}', output)
    return im_data, output


def load_data(image_loc: str, label_loc: str, **kwargs) -> Tuple[np.ndarray, np.ndarray]:
    """Attempts to load generated images and labels.
    
    If either is not found, attempts to (re)generate them using the default
    input arguments to the generation method for the raw data, but the input
    `image_loc` and `label_loc` parameters for the output arrays. If this
    still does not work, returns a general error and exits.
    
    Args:
        image_loc: Relative path to saved image ndarray file.
        label_loc: Relative path to saved label ndarray file.
        
    Returns:
        Tuple of ndarrays. The first array holds the loaded image data, whilst
        the second array holds their respective labels.
    
    """
    try:
        image_data = np.load(f'{image_loc}.npy')
        label_data = np.load(f'{label_loc}.npy')
        return image_data, label_data
    
    except FileNotFoundError:
        try:
            image_data, label_data = generate_data_arrays(
                image_output = image_loc,
                label_output = label_loc,
                **kwargs
            )
            return image_data, label_data
        
        except Exception as e:
            traceback.print_exc()

# %% [markdown]
# ## Model Playground

# %%
#Version 1
im_data_v1, output_v1 = load_data(
    image_loc = 'rsc/input_data_v1',
    label_loc = 'rsc/output_data_v1',
    covid_data = 'rsc/Data_CoV2/COVID/',
    noncovid_data = 'rsc/Data_CoV2/non-COVID/',
    others_data = None,
)

x_train, x_test, y_train, y_test = train_test_split(im_data_v1, output_v1, random_state=42)

# %%
def make_model(X_Train, Y_Train, X_Test, Y_Test, model_dir: str):
    if not os.path.exists(model_dir):
        os.makedirs(model_dir)
    #X_Train, X_Test, Y_Train, Y_Test = train_test_split(input_data, output_data, test_size=0.1)

    for_pad = lambda s: s if s > 2 else 3

    model = Sequential()
    model.add(Lambda(lambda x: x, input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 1)))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=8, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))



    #model.add(ZeroPadding2D(padding=(for_pad(19) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(Conv2D(kernel_size=(3, 3), filters=2, strides=(1, 1),activation='relu'))

    model.add(Flatten())

    model.add(Dropout(rate=0.4))
    model.add(Dense(units=338, activation='relu'))
    model.add(Dense(units=1, activation='sigmoid'))

    model.compile(optimizer=Adamax(), loss='binary_crossentropy', metrics=["accuracy"])
    model.summary()

    checkpoint = ModelCheckpoint(os.path.join(model_dir, 'xRGM2.4'), verbose=1, period=1, save_best_only=True)

    hist = model.fit_generator(batch_generator(X_Train, Y_Train, 128, True),
                        validation_data=(batch_generator(X_Test, Y_Test, 128, False)), callbacks=[checkpoint],
                        verbose=1, epochs=75, steps_per_epoch=25, validation_steps=len(X_Test))

    with open(os.path.join('models', 'xRGM2.4-Net-HistDict'), 'wb') as f:
        pickle.dump(hist.history, f)

    model.save(model_dir)
    
    return model
#lr = 0.001

# %%
# %%time
model_dir: str = 'model/xRGM2.4'
xRGM = make_model(x_train, y_train.reshape(-1,1), x_test, y_test.reshape(-1,1), model_dir=model_dir)

v_classify = np.vectorize(lambda x: np.round(x, 0))
# xRGMCT2 = load_model('models/xRGMCT2L.h5')
# print(xRGMCT2.history)
y_pred = (xRGM.predict(x_test))

#print(y_test)
#print(y_pred)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_1 (Lambda)            (None, 227, 227, 1)       0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 225, 225, 8)       80
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 225, 225, 8)       32
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 225, 225, 8)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 112, 112, 8)       0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 110, 110, 16)      1168
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 110, 110, 16)      64
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 110, 110, 16)      0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 108, 108, 32)      4640
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 108, 108, 32)      128
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 108, 108, 32)      0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 108, 108, 16)      528
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 108, 108, 16)      64
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 108, 108, 16)      0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 106, 106, 32)      4640
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 106, 106, 32)      128
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 106, 106, 32)      0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 104, 104, 64)      18496
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 104, 104, 64)      256
# _________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)   (None, 104, 104, 64)      0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 104, 104, 32)      2080
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 104, 104, 32)      128
# _________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)   (None, 104, 104, 32)      0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 102, 102, 64)      18496
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 102, 102, 64)      256
# _________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)   (None, 102, 102, 64)      0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 100, 100, 128)     73856
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 100, 100, 128)     512
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 100, 100, 128)     0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 100, 100, 64)      8256
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 100, 100, 64)      256
# _________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)   (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 98, 98, 128)       73856
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 98, 98, 128)       512
# _________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)   (None, 98, 98, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 49, 49, 128)       0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 47, 47, 256)       295168
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 47, 47, 256)       1024
# _________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)   (None, 47, 47, 256)       0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 47, 47, 128)       32896
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 47, 47, 128)       512
# _________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)   (None, 47, 47, 128)       0
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 23, 23, 128)       0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 21, 21, 256)       295168
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 21, 21, 256)       1024
# _________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)   (None, 21, 21, 256)       0
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 10, 10, 256)       0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 10, 10, 128)       32896
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)   (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)   (None, 8, 8, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16384)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 338)               5538130
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 339
# =================================================================
# Total params: 6,702,293
# Trainable params: 6,699,077
# Non-trainable params: 3,216
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/75
# 25/25 [==============================] - 4822s 200s/step - loss: 2.1023 - accuracy: 0.6416 - val_loss: 1.8304 - val_accuracy: 0.5000
#
# Epoch 00001: val_loss improved from inf to 1.83036, saving model to model/xRGM2.4/xRGM2.4
# INFO:tensorflow:Assets written to: model/xRGM2.4/xRGM2.4/assets
# Epoch 2/75
# 25/25 [==============================] - 4864s 201s/step - loss: 0.2583 - accuracy: 0.8932 - val_loss: 0.7450 - val_accuracy: 0.5080
#
# Epoch 00002: val_loss improved from 1.83036 to 0.74496, saving model to model/xRGM2.4/xRGM2.4
# INFO:tensorflow:Assets written to: model/xRGM2.4/xRGM2.4/assets
# Epoch 3/75
# 25/25 [==============================] - 4868s 201s/step - loss: 0.1789 - accuracy: 0.9310 - val_loss: 0.7365 - val_accuracy: 0.4971
#
# Epoch 00003: val_loss improved from 0.74496 to 0.73646, saving model to model/xRGM2.4/xRGM2.4
# INFO:tensorflow:Assets written to: model/xRGM2.4/xRGM2.4/assets
# Epoch 4/75
# 25/25 [==============================] - 4876s 202s/step - loss: 0.1551 - accuracy: 0.9411 - val_loss: 0.8255 - val_accuracy: 0.4992
#
# Epoch 00004: val_loss did not improve from 0.73646
# Epoch 5/75
# 25/25 [==============================] - 4862s 201s/step - loss: 0.1010 - accuracy: 0.9634 - val_loss: 0.7454 - val_accuracy: 0.5015
#
# Epoch 00005: val_loss did not improve from 0.73646
# Epoch 6/75
# 25/25 [==============================] - 4849s 200s/step - loss: 0.0620 - accuracy: 0.9813 - val_loss: 0.8155 - val_accuracy: 0.4994
#
# Epoch 00006: val_loss did not improve from 0.73646
# Epoch 7/75
# 25/25 [==============================] - 4871s 201s/step - loss: 0.0570 - accuracy: 0.9822 - val_loss: 0.8036 - val_accuracy: 0.5010
#
# Epoch 00007: val_loss did not improve from 0.73646
# Epoch 8/75
# 25/25 [==============================] - 4864s 201s/step - loss: 0.0423 - accuracy: 0.9917 - val_loss: 1.1800 - val_accuracy: 0.5003
#
# Epoch 00008: val_loss did not improve from 0.73646
# Epoch 9/75
# 25/25 [==============================] - 4862s 201s/step - loss: 0.0325 - accuracy: 0.9938 - val_loss: 0.9009 - val_accuracy: 0.4900
#
# Epoch 00009: val_loss did not improve from 0.73646
# Epoch 10/75
# 25/25 [==============================] - 4857s 201s/step - loss: 0.0189 - accuracy: 0.9969 - val_loss: 0.7884 - val_accuracy: 0.4938
#
# Epoch 00010: val_loss did not improve from 0.73646
# Epoch 11/75
# 25/25 [==============================] - 4855s 201s/step - loss: 0.0101 - accuracy: 0.9997 - val_loss: 0.6557 - val_accuracy: 0.6247
#
# Epoch 00011: val_loss improved from 0.73646 to 0.65571, saving model to model/xRGM2.4/xRGM2.4
# INFO:tensorflow:Assets written to: model/xRGM2.4/xRGM2.4/assets
# Epoch 12/75
# 25/25 [==============================] - 4879s 202s/step - loss: 0.0073 - accuracy: 0.9999 - val_loss: 0.5821 - val_accuracy: 0.7004
#
# Epoch 00012: val_loss improved from 0.65571 to 0.58206, saving model to model/xRGM2.4/xRGM2.4
# INFO:tensorflow:Assets written to: model/xRGM2.4/xRGM2.4/assets
# Epoch 13/75
# 25/25 [==============================] - 4865s 201s/step - loss: 0.0154 - accuracy: 0.9952 - val_loss: 0.6202 - val_accuracy: 0.7122
#
# Epoch 00013: val_loss did not improve from 0.58206
# Epoch 14/75
# 25/25 [==============================] - 4866s 201s/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.4434 - val_accuracy: 0.7913
#
# Epoch 00014: val_loss improved from 0.58206 to 0.44339, saving model to model/xRGM2.4/xRGM2.4
# INFO:tensorflow:Assets written to: model/xRGM2.4/xRGM2.4/assets
# Epoch 15/75
# 25/25 [==============================] - 4858s 201s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.5165 - val_accuracy: 0.7925
#
# Epoch 00015: val_loss did not improve from 0.44339
# Epoch 16/75
# 25/25 [==============================] - 4872s 201s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4123 - val_accuracy: 0.8315
#
# Epoch 00016: val_loss improved from 0.44339 to 0.41226, saving model to model/xRGM2.4/xRGM2.4
# INFO:tensorflow:Assets written to: model/xRGM2.4/xRGM2.4/assets
# Epoch 17/75
# 25/25 [==============================] - 4862s 201s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2889 - val_accuracy: 0.8716
#
# Epoch 00017: val_loss improved from 0.41226 to 0.28886, saving model to model/xRGM2.4/xRGM2.4
# INFO:tensorflow:Assets written to: model/xRGM2.4/xRGM2.4/assets
# Epoch 18/75
# 25/25 [==============================] - 4863s 201s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9474
#
# Epoch 00018: val_loss improved from 0.28886 to 0.14801, saving model to model/xRGM2.4/xRGM2.4
# INFO:tensorflow:Assets written to: model/xRGM2.4/xRGM2.4/assets
# Epoch 19/75
# 25/25 [==============================] - 4856s 201s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1055 - val_accuracy: 0.9635
#
# Epoch 00019: val_loss improved from 0.14801 to 0.10552, saving model to model/xRGM2.4/xRGM2.4
# INFO:tensorflow:Assets written to: model/xRGM2.4/xRGM2.4/assets
# Epoch 20/75
# 25/25 [==============================] - 4868s 201s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1026 - val_accuracy: 0.9662
#
# Epoch 00020: val_loss improved from 0.10552 to 0.10257, saving model to model/xRGM2.4/xRGM2.4
# INFO:tensorflow:Assets written to: model/xRGM2.4/xRGM2.4/assets
# Epoch 21/75
# 25/25 [==============================] - 4858s 201s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0842 - val_accuracy: 0.9724
#
# Epoch 00021: val_loss improved from 0.10257 to 0.08420, saving model to model/xRGM2.4/xRGM2.4
# INFO:tensorflow:Assets written to: model/xRGM2.4/xRGM2.4/assets
# Epoch 22/75
# 25/25 [==============================] - 4855s 201s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0995 - val_accuracy: 0.9674
#
# Epoch 00022: val_loss did not improve from 0.08420
# Epoch 23/75
# 25/25 [==============================] - 4862s 201s/step - loss: 7.7988e-04 - accuracy: 1.0000 - val_loss: 0.0750 - val_accuracy: 0.9708
#
# Epoch 00023: val_loss improved from 0.08420 to 0.07500, saving model to model/xRGM2.4/xRGM2.4
# INFO:tensorflow:Assets written to: model/xRGM2.4/xRGM2.4/assets
# Epoch 24/75
# 25/25 [==============================] - 4866s 201s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0616 - val_accuracy: 0.9725
#
# Epoch 00024: val_loss improved from 0.07500 to 0.06159, saving model to model/xRGM2.4/xRGM2.4
# INFO:tensorflow:Assets written to: model/xRGM2.4/xRGM2.4/assets
# Epoch 25/75
# 25/25 [==============================] - 4871s 201s/step - loss: 7.5935e-04 - accuracy: 1.0000 - val_loss: 0.0642 - val_accuracy: 0.9769
#
# Epoch 00025: val_loss did not improve from 0.06159
# Epoch 26/75
# 25/25 [==============================] - 4863s 201s/step - loss: 5.6591e-04 - accuracy: 1.0000 - val_loss: 0.0624 - val_accuracy: 0.9773
#
# Epoch 00026: val_loss did not improve from 0.06159
# Epoch 27/75
# 25/25 [==============================] - 4873s 202s/step - loss: 8.5693e-04 - accuracy: 1.0000 - val_loss: 0.0570 - val_accuracy: 0.9771
#
# Epoch 00027: val_loss improved from 0.06159 to 0.05702, saving model to model/xRGM2.4/xRGM2.4
# INFO:tensorflow:Assets written to: model/xRGM2.4/xRGM2.4/assets
# Epoch 28/75
# 25/25 [==============================] - 4858s 201s/step - loss: 5.6235e-04 - accuracy: 1.0000 - val_loss: 0.0529 - val_accuracy: 0.9796
#
# Epoch 00028: val_loss improved from 0.05702 to 0.05291, saving model to model/xRGM2.4/xRGM2.4
# INFO:tensorflow:Assets written to: model/xRGM2.4/xRGM2.4/assets
# Epoch 29/75
# 25/25 [==============================] - 4866s 201s/step - loss: 4.5464e-04 - accuracy: 1.0000 - val_loss: 0.0593 - val_accuracy: 0.9782
#
# Epoch 00029: val_loss did not improve from 0.05291
# Epoch 30/75
# 25/25 [==============================] - 4852s 201s/step - loss: 5.1303e-04 - accuracy: 1.0000 - val_loss: 0.0474 - val_accuracy: 0.9791
#
# Epoch 00030: val_loss improved from 0.05291 to 0.04738, saving model to model/xRGM2.4/xRGM2.4
# INFO:tensorflow:Assets written to: model/xRGM2.4/xRGM2.4/assets
# Epoch 31/75
# 25/25 [==============================] - 4862s 201s/step - loss: 4.3150e-04 - accuracy: 1.0000 - val_loss: 0.0516 - val_accuracy: 0.9772
#
# Epoch 00031: val_loss did not improve from 0.04738
# Epoch 32/75
# 25/25 [==============================] - 4862s 201s/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.2684 - val_accuracy: 0.9290
#
# Epoch 00032: val_loss did not improve from 0.04738
# Epoch 33/75
# 25/25 [==============================] - 4856s 201s/step - loss: 0.0081 - accuracy: 0.9977 - val_loss: 0.2236 - val_accuracy: 0.9328
#
# Epoch 00033: val_loss did not improve from 0.04738
# Epoch 34/75
# 25/25 [==============================] - 4856s 201s/step - loss: 0.0052 - accuracy: 0.9998 - val_loss: 0.0900 - val_accuracy: 0.9688
#
# Epoch 00034: val_loss did not improve from 0.04738
# Epoch 35/75
# 25/25 [==============================] - 4848s 200s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0667 - val_accuracy: 0.9797
#
# Epoch 00035: val_loss did not improve from 0.04738
# Epoch 36/75
# 25/25 [==============================] - 4858s 201s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0671 - val_accuracy: 0.9743
#
# Epoch 00036: val_loss did not improve from 0.04738
# Epoch 37/75
# 25/25 [==============================] - 4849s 201s/step - loss: 6.2969e-04 - accuracy: 1.0000 - val_loss: 0.0515 - val_accuracy: 0.9824
#
# Epoch 00037: val_loss did not improve from 0.04738
# Epoch 38/75
# 25/25 [==============================] - 4858s 201s/step - loss: 6.8054e-04 - accuracy: 1.0000 - val_loss: 0.0503 - val_accuracy: 0.9811
#
# Epoch 00038: val_loss did not improve from 0.04738
# Epoch 39/75
# 25/25 [==============================] - 4855s 201s/step - loss: 3.1070e-04 - accuracy: 1.0000 - val_loss: 0.0441 - val_accuracy: 0.9858
#
# Epoch 00039: val_loss improved from 0.04738 to 0.04408, saving model to model/xRGM2.4/xRGM2.4
# INFO:tensorflow:Assets written to: model/xRGM2.4/xRGM2.4/assets
# Epoch 40/75
# 25/25 [==============================] - 4849s 201s/step - loss: 3.5288e-04 - accuracy: 1.0000 - val_loss: 0.0437 - val_accuracy: 0.9839
#
# Epoch 00040: val_loss improved from 0.04408 to 0.04373, saving model to model/xRGM2.4/xRGM2.4
# INFO:tensorflow:Assets written to: model/xRGM2.4/xRGM2.4/assets
# Epoch 41/75
# 25/25 [==============================] - 4871s 201s/step - loss: 2.1946e-04 - accuracy: 1.0000 - val_loss: 0.0426 - val_accuracy: 0.9830
#
# Epoch 00041: val_loss improved from 0.04373 to 0.04262, saving model to model/xRGM2.4/xRGM2.4
# INFO:tensorflow:Assets written to: model/xRGM2.4/xRGM2.4/assets
# Epoch 42/75
# 25/25 [==============================] - 4872s 201s/step - loss: 2.4805e-04 - accuracy: 1.0000 - val_loss: 0.0489 - val_accuracy: 0.9776
#
# Epoch 00042: val_loss did not improve from 0.04262
# Epoch 43/75
# 25/25 [==============================] - 4868s 201s/step - loss: 2.0028e-04 - accuracy: 1.0000 - val_loss: 0.0484 - val_accuracy: 0.9805
#
# Epoch 00043: val_loss did not improve from 0.04262
# Epoch 44/75
# 25/25 [==============================] - 4869s 201s/step - loss: 1.9074e-04 - accuracy: 1.0000 - val_loss: 0.0478 - val_accuracy: 0.9792
#
# Epoch 00044: val_loss did not improve from 0.04262
# Epoch 45/75
# 25/25 [==============================] - 4862s 201s/step - loss: 1.6986e-04 - accuracy: 1.0000 - val_loss: 0.0473 - val_accuracy: 0.9821
#
# Epoch 00045: val_loss did not improve from 0.04262
# Epoch 46/75
# 25/25 [==============================] - 4849s 200s/step - loss: 1.4564e-04 - accuracy: 1.0000 - val_loss: 0.0466 - val_accuracy: 0.9828
#
# Epoch 00046: val_loss did not improve from 0.04262
# Epoch 47/75
# 25/25 [==============================] - 4861s 201s/step - loss: 1.4581e-04 - accuracy: 1.0000 - val_loss: 0.0465 - val_accuracy: 0.9822
#
# Epoch 00047: val_loss did not improve from 0.04262
# Epoch 48/75
# 25/25 [==============================] - 4866s 201s/step - loss: 1.1185e-04 - accuracy: 1.0000 - val_loss: 0.0459 - val_accuracy: 0.9823
#
# Epoch 00048: val_loss did not improve from 0.04262
# Epoch 49/75
# 25/25 [==============================] - 4869s 201s/step - loss: 1.5233e-04 - accuracy: 1.0000 - val_loss: 0.0507 - val_accuracy: 0.9805
#
# Epoch 00049: val_loss did not improve from 0.04262
# Epoch 50/75
# 25/25 [==============================] - 4855s 201s/step - loss: 1.5833e-04 - accuracy: 1.0000 - val_loss: 0.0518 - val_accuracy: 0.9808
#
# Epoch 00050: val_loss did not improve from 0.04262
# Epoch 51/75
# 25/25 [==============================] - 4869s 201s/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.1031 - val_accuracy: 0.9778
#
# Epoch 00051: val_loss did not improve from 0.04262
# Epoch 52/75
# 25/25 [==============================] - 4867s 201s/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0810 - val_accuracy: 0.9684
#
# Epoch 00052: val_loss did not improve from 0.04262
# Epoch 53/75
# 25/25 [==============================] - 4871s 201s/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.6176 - val_accuracy: 0.8703
#
# Epoch 00053: val_loss did not improve from 0.04262
# Epoch 54/75
# 25/25 [==============================] - 4890s 202s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1728 - val_accuracy: 0.9573
#
# Epoch 00054: val_loss did not improve from 0.04262
# Epoch 55/75
# 25/25 [==============================] - 4875s 201s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0949 - val_accuracy: 0.9754
#
# Epoch 00055: val_loss did not improve from 0.04262
# Epoch 56/75
# 25/25 [==============================] - 4869s 201s/step - loss: 7.6894e-04 - accuracy: 1.0000 - val_loss: 0.0573 - val_accuracy: 0.9774
#
# Epoch 00056: val_loss did not improve from 0.04262
# Epoch 57/75
# 25/25 [==============================] - 4874s 201s/step - loss: 3.5015e-04 - accuracy: 1.0000 - val_loss: 0.0541 - val_accuracy: 0.9803
#
# Epoch 00057: val_loss did not improve from 0.04262
# Epoch 58/75
# 25/25 [==============================] - 4864s 201s/step - loss: 3.9764e-04 - accuracy: 1.0000 - val_loss: 0.0544 - val_accuracy: 0.9805
#
# Epoch 00058: val_loss did not improve from 0.04262
# Epoch 59/75
# 25/25 [==============================] - 4871s 201s/step - loss: 1.6374e-04 - accuracy: 1.0000 - val_loss: 0.0494 - val_accuracy: 0.9787
#
# Epoch 00059: val_loss did not improve from 0.04262
# Epoch 60/75
# 25/25 [==============================] - 4856s 201s/step - loss: 1.5019e-04 - accuracy: 1.0000 - val_loss: 0.0481 - val_accuracy: 0.9776
#
# Epoch 00060: val_loss did not improve from 0.04262
# Epoch 61/75
# 25/25 [==============================] - 4866s 201s/step - loss: 1.7194e-04 - accuracy: 1.0000 - val_loss: 0.0454 - val_accuracy: 0.9811
#
# Epoch 00061: val_loss did not improve from 0.04262
# Epoch 62/75
# 25/25 [==============================] - 4864s 201s/step - loss: 1.0241e-04 - accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 0.9832
#
# Epoch 00062: val_loss improved from 0.04262 to 0.04227, saving model to model/xRGM2.4/xRGM2.4
# INFO:tensorflow:Assets written to: model/xRGM2.4/xRGM2.4/assets
# Epoch 63/75
# 25/25 [==============================] - 4869s 201s/step - loss: 6.3123e-05 - accuracy: 1.0000 - val_loss: 0.0461 - val_accuracy: 0.9821
#
# Epoch 00063: val_loss did not improve from 0.04227
# Epoch 64/75
# 25/25 [==============================] - 4861s 201s/step - loss: 1.7787e-04 - accuracy: 1.0000 - val_loss: 0.0464 - val_accuracy: 0.9827
#
# Epoch 00064: val_loss did not improve from 0.04227
# Epoch 65/75
# 25/25 [==============================] - 4866s 201s/step - loss: 1.1732e-04 - accuracy: 1.0000 - val_loss: 0.0492 - val_accuracy: 0.9807
#
# Epoch 00065: val_loss did not improve from 0.04227
# Epoch 66/75
# 25/25 [==============================] - 4845s 200s/step - loss: 6.6105e-05 - accuracy: 1.0000 - val_loss: 0.0473 - val_accuracy: 0.9837
#
# Epoch 00066: val_loss did not improve from 0.04227
# Epoch 67/75
# 25/25 [==============================] - 4856s 201s/step - loss: 7.1686e-05 - accuracy: 1.0000 - val_loss: 0.0492 - val_accuracy: 0.9807
#
# Epoch 00067: val_loss did not improve from 0.04227
# Epoch 68/75
# 25/25 [==============================] - 4851s 200s/step - loss: 5.0262e-05 - accuracy: 1.0000 - val_loss: 0.0478 - val_accuracy: 0.9806
#
# Epoch 00068: val_loss did not improve from 0.04227
# Epoch 69/75
# 25/25 [==============================] - 4868s 201s/step - loss: 7.4843e-05 - accuracy: 1.0000 - val_loss: 0.0504 - val_accuracy: 0.9816
#
# Epoch 00069: val_loss did not improve from 0.04227
# Epoch 70/75
# 25/25 [==============================] - 4856s 201s/step - loss: 6.2306e-05 - accuracy: 1.0000 - val_loss: 0.0478 - val_accuracy: 0.9806
#
# Epoch 00070: val_loss did not improve from 0.04227
# Epoch 71/75
# 25/25 [==============================] - 4853s 201s/step - loss: 6.0995e-05 - accuracy: 1.0000 - val_loss: 0.0459 - val_accuracy: 0.9802
#
# Epoch 00071: val_loss did not improve from 0.04227
# Epoch 72/75
# 25/25 [==============================] - 4854s 201s/step - loss: 5.4054e-05 - accuracy: 1.0000 - val_loss: 0.0485 - val_accuracy: 0.9789
#
# Epoch 00072: val_loss did not improve from 0.04227
# Epoch 73/75
# 25/25 [==============================] - 4853s 201s/step - loss: 6.4621e-05 - accuracy: 1.0000 - val_loss: 0.0449 - val_accuracy: 0.9852
#
# Epoch 00073: val_loss did not improve from 0.04227
# Epoch 74/75
# 25/25 [==============================] - 4854s 201s/step - loss: 5.1856e-05 - accuracy: 1.0000 - val_loss: 0.0463 - val_accuracy: 0.9842
#
# Epoch 00074: val_loss did not improve from 0.04227
# Epoch 75/75
# 25/25 [==============================] - 1941s 79s/step - loss: 4.3734e-05 - accuracy: 1.0000 - val_loss: 0.0438 - val_accuracy: 0.9813
#
# Epoch 00075: val_loss did not improve from 0.04227
# INFO:tensorflow:Assets written to: model/xRGM2.4/assets
# CPU times: user 21d 10h 50min 3s, sys: 16h 50min 4s, total: 22d 3h 40min 7s
# Wall time: 4d 4h 36min 4s

# %%
confusion_matrix = pd.DataFrame(metrics.confusion_matrix(y_test, v_classify(y_pred)),
                                columns=['Predicted Negative', 'Predicted Positive'],
                                index=['Actual Negative', 'Actual Positive'])

tp, tn, fp, fn = (
    confusion_matrix.iloc[1,1], 
    confusion_matrix.iloc[0,0], 
    confusion_matrix.iloc[0,1], 
    confusion_matrix.iloc[1,0]
)

accuracy = (tp + tn) / (tp + tn + fp + fn)
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
f1_score = 2 * ((specificity * sensitivity) / (specificity + sensitivity))

with open(os.path.join(f'{model_dir}', 'metrics.csv'), 'a', encoding='utf-8') as f:
    f.write(
        f'{time.strftime("%Y-%m-%dT%H:%M:%S-05:00", time.localtime())}, {accuracy}, {sensitivity}, {specificity}, {f1_score}\n'
    )

print(f'Accuracy:    {accuracy}')
print(f'Sensitivity: {sensitivity}')
print(f'Specificity: {specificity}')
print(f'F1 Score:    {f1_score}')
print('\n')
print(confusion_matrix)
# Out:
# Accuracy:    0.9806763285024155
# Sensitivity: 0.9774193548387097
# Specificity: 0.9839228295819936
# F1 Score:    0.9806603100061875
#
#
#                  Predicted Negative  Predicted Positive
# Actual Negative                 306                   5
# Actual Positive                   7                 303

# %%
disease_types=['COVID', 'non-COVID']
Y_pred = np.argmax(y_pred)
Y_true = np.argmax(y_test)

plt.figure(figsize=(7, 7))
ax = sns.heatmap(confusion_matrix , cmap=plt.cm.GnBu , 
                 annot=True, fmt='d',square=True, xticklabels=disease_types, 
                 yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
plt.show()

# %%
def plot_model_history(model_history):
   fig, axs = plt.subplots(1,2,figsize=(15,5))
   # summarize history for accuracy
   axs[0].plot(range(1, len(model_history['accuracy']) + 1), model_history['accuracy'])
   axs[0].plot(range(1, len(model_history['val_accuracy']) + 1), model_history['val_accuracy'])
   axs[0].set_title('Model Accuracy')
   axs[0].set_ylabel('Accuracy')
   axs[0].set_xlabel('Epoch')
   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
   axs[0].legend(['train', 'val'], loc='best')
   # summarize history for loss
   axs[1].plot(range(1, len(model_history['loss'])+1), model_history['loss'])
   axs[1].plot(range(1, len(model_history['val_loss']) + 1), model_history['val_loss'])
   axs[1].set_title('Model Loss')
   axs[1].set_ylabel('Loss')
   axs[1].set_xlabel('Epoch')
   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
   axs[1].legend(['train', 'val'], loc='best')
   plt.show()

# %%
with open(os.path.join('models', 'xRGM2.4-Net-HistDict'), 'rb') as f:
    history = pickle.load(f)
    
plot_model_history(history)
# Out:
# <ipython-input-21-25025fac5012>:9: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
# <ipython-input-21-25025fac5012>:17: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
