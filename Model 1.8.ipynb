# %%
import glob
import json
import os
import pickle
import random
import traceback
from typing import Tuple

import numpy as np
import pandas as pd
import seaborn as sns
from keras.models import Sequential, load_model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Lambda, LeakyReLU, AveragePooling2D, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from matplotlib import pyplot as plt
from matplotlib.pyplot import hist
from PIL import Image
from scipy.stats import zscore
from sklearn import metrics
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %%
import csv
import time

# %% [markdown]
# ## Config & Constants

# %%
IMAGE_WIDTH, IMAGE_HEIGHT = 227, 227
random.seed(52)

# %% [markdown]
# ## Methods

# %% [markdown]
# ### Image Utilities

# %%
def batch_generator(input_data, output_data, batch_size, is_training):
    input_data_batch = np.empty([batch_size, IMAGE_HEIGHT, IMAGE_WIDTH, 1])
    output_data_batch = np.empty([batch_size, 1])
    while True:
        index = 0
        for i in np.random.permutation(input_data.shape[0]):
            input_data_batch[index] = input_data[i]
            output_data_batch[index] = output_data[i]
            index += 1
            if index == batch_size:
                break
        yield input_data_batch, output_data_batch


def _preprocess(image_loc: str) -> np.ndarray:
    f_image = Image.open(image_loc).convert('L')
    f_image = f_image.resize((IMAGE_WIDTH, IMAGE_HEIGHT), Image.ANTIALIAS)
    image = np.asarray(f_image)
    image = np.expand_dims(image, axis=0)
    image = np.expand_dims(image, axis=3)
    return image


def preprocess(loc: str) -> np.ndarray:
    """Safety wrapper over _preprocess.
    
    Args:
        loc: File location to check if dir or an image.
        
    Returns:
        Preprocessed image(s) as an ndarray.
    """
    if os.path.isdir(loc):
        current = np.concatenate((
            [_preprocess(os.path.join(loc, image)) for image in os.listdir(loc)
             if '.png' in image]
        ))
    else:
        current = _preprocess(loc)
    return current


def generate_data_arrays(
    covid_data: str = 'rsc/New_Data_CoV2/COVID/',
    noncovid_data: str = 'rsc/New_Data_CoV2/non-COVID/',
    others_data:  str = 'rsc/New_Data_CoV2/Others/',
    image_output: str = 'rsc/input_data_v2',
    label_output: str = 'rsc/output_data_v2',
    regenerate: bool = True
) -> Tuple[np.ndarray, np.ndarray]:
    """Loads COVID images into ndarrays.
    
    Args:
        covid_data: Relative path to folder containing COVID images.
        noncovid_data: Relative path to folder containing non-COVID images.
        others_data: Relative path to folder containing Others images.
        image_output: Relative path (with filename) to save loaded images to.
        label_output: Relative path (with filename) to save loaded classes (labels) to.
        regenerate: If True, will regenerate saved ndarray files for both image_output
            and label_output, even if they already exist (overwriting them). If False,
            will simply load and return the aforementioned.
        
    Returns:
        Tuple of ndarrays. The first is the loaded image data in one large ndarray,
        and the second is the loaded labels, also in a large ndarray. These directly
        match up to each other ONLY when both arrays (and their respective files)
        are generated at the same time with this method.
    """
    if (regenerate is False and 
        os.path.isfile(f'{out_input_data}.npy') and
        os.path.isfile(f'{out_output_data}.npy')):
        return (np.load(f'{out_input_data}.npy'),
                np.load(f'{out_output_data}.npy'))
    
    if not ((cd := os.path.exists(covid_data)) and (ncd := os.path.exists(noncovid_data))):
        if (others_data is not None) and not (odd := os.path.exists(others_data)):
            raise NotADirectoryError("Directories do not exist.")
        else:
            raise NotADirectoryError("COVID/non-COVID directories do not exist.")
    
    im_data = np.empty([1, IMAGE_WIDTH, IMAGE_WIDTH, 1])
    output = np.array([0])

    print('Loading Covid Data')
    for i in tqdm(glob.glob(os.path.join(covid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([1])), axis=0)

    print('Loading non-Covid Data')
    for i in tqdm(glob.glob(os.path.join(noncovid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([0])), axis=0)
        
    if others_data is not None:
        print('Loading Others Data')
        for i in tqdm(glob.glob(os.path.join(others_data, '**'))):
            current = preprocess(i)
            im_data = np.concatenate((im_data, current))
            output = np.concatenate((output, np.array([-1])), axis=0)
    else:
        print('Others data not provided; skipping.')


    print('Finished Loading Data')
    im_data = np.delete(im_data, 0, axis=0)
    output = np.delete(output, 0, axis=0)

    zip_data = list(zip(im_data, output))
    random.shuffle(zip_data)
    im_data, output = zip(*zip_data)

    np.save(f'{image_output}', im_data)
    np.save(f'{label_output}', output)
    return im_data, output


def load_data(image_loc: str, label_loc: str, **kwargs) -> Tuple[np.ndarray, np.ndarray]:
    """Attempts to load generated images and labels.
    
    If either is not found, attempts to (re)generate them using the default
    input arguments to the generation method for the raw data, but the input
    `image_loc` and `label_loc` parameters for the output arrays. If this
    still does not work, returns a general error and exits.
    
    Args:
        image_loc: Relative path to saved image ndarray file.
        label_loc: Relative path to saved label ndarray file.
        
    Returns:
        Tuple of ndarrays. The first array holds the loaded image data, whilst
        the second array holds their respective labels.
    
    """
    try:
        image_data = np.load(f'{image_loc}.npy')
        label_data = np.load(f'{label_loc}.npy')
        return image_data, label_data
    
    except FileNotFoundError:
        try:
            image_data, label_data = generate_data_arrays(
                image_output = image_loc,
                label_output = label_loc,
                **kwargs
            )
            return image_data, label_data
        
        except Exception as e:
            traceback.print_exc()

# %% [markdown]
# ## Model Playground

# %%
#Version 1
im_data_v1, output_v1 = load_data(
    image_loc = 'rsc/input_data_v1',
    label_loc = 'rsc/output_data_v1',
    covid_data = 'rsc/Data_CoV2/COVID/',
    noncovid_data = 'rsc/Data_CoV2/non-COVID/',
    others_data = None,
)

x_train, x_test, y_train, y_test = train_test_split(im_data_v1, output_v1, random_state=42)

# %%
def make_model(X_Train, Y_Train, X_Test, Y_Test, model_dir: str):
    if not os.path.exists(model_dir):
        os.makedirs(model_dir)
    #X_Train, X_Test, Y_Train, Y_Test = train_test_split(input_data, output_data, test_size=0.1)

    for_pad = lambda s: s if s > 2 else 3

    model = Sequential()
    model.add(Lambda(lambda x: x, input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 1)))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=8, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))



    #model.add(ZeroPadding2D(padding=(for_pad(19) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(Conv2D(kernel_size=(3, 3), filters=2, strides=(1, 1),activation='relu'))

    model.add(Flatten())

    model.add(Dropout(rate=0.4))
    model.add(Dense(units=338, activation='relu'))
    model.add(Dense(units=1, activation='sigmoid'))

    model.compile(optimizer=Adam(lr=3e-4), loss='binary_crossentropy', metrics=["accuracy"])
    model.summary()

    checkpoint = ModelCheckpoint(os.path.join(model_dir, 'xRGM1.8'), verbose=1, period=1, save_best_only=True)

    hist = model.fit_generator(batch_generator(X_Train, Y_Train, 128, True),
                        validation_data=(batch_generator(X_Test, Y_Test, 128, False)), callbacks=[checkpoint],
                        verbose=1, epochs=100, steps_per_epoch=15, validation_steps=len(X_Test))

    with open(os.path.join('models', 'xRGM1.8-Net-HistDict'), 'wb') as f:
        pickle.dump(hist.history, f)

    model.save(model_dir)
    
    return model
#changed steps and epochs and batchsize

# %%
# %%time
model_dir: str = 'model/xRGM1.8'
xRGM = make_model(x_train, y_train.reshape(-1,1), x_test, y_test.reshape(-1,1), model_dir=model_dir)

v_classify = np.vectorize(lambda x: np.round(x, 0))
# xRGMCT2 = load_model('models/xRGMCT2L.h5')
# print(xRGMCT2.history)
y_pred = (xRGM.predict(x_test))

#print(y_test)
#print(y_pred)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda (Lambda)              (None, 227, 227, 1)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 225, 225, 8)       80
# _________________________________________________________________
# batch_normalization (BatchNo (None, 225, 225, 8)       32
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 225, 225, 8)       0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 110, 110, 16)      1168
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 110, 110, 16)      64
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 110, 110, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 108, 108, 32)      4640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 108, 108, 32)      128
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 108, 108, 32)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 108, 108, 16)      528
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 108, 108, 16)      64
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 108, 108, 16)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 106, 106, 32)      4640
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 106, 106, 32)      128
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 106, 106, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 104, 104, 64)      18496
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 104, 104, 64)      256
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 104, 104, 64)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 104, 104, 32)      2080
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 104, 104, 32)      128
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 104, 104, 32)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 102, 102, 64)      18496
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 102, 102, 64)      256
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 102, 102, 64)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 100, 100, 128)     73856
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 100, 100, 128)     512
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 100, 100, 128)     0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 100, 100, 64)      8256
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 100, 100, 64)      256
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 98, 98, 128)       73856
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 98, 98, 128)       512
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 98, 98, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 49, 49, 128)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 47, 47, 256)       295168
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 47, 47, 256)       1024
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 47, 47, 256)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 47, 47, 128)       32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 47, 47, 128)       512
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 47, 47, 128)       0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 23, 23, 128)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 21, 21, 256)       295168
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 21, 21, 256)       1024
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 21, 21, 256)       0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 10, 10, 256)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 10, 10, 128)       32896
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 8, 8, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 338)               5538130
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 339
# =================================================================
# Total params: 6,702,293
# Trainable params: 6,699,077
# Non-trainable params: 3,216
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# /home/jg1994/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 15/15 [==============================] - 13285s 941s/step - loss: 1.6232 - accuracy: 0.6100 - val_loss: 0.6975 - val_accuracy: 0.5012
#
# Epoch 00001: val_loss improved from inf to 0.69748, saving model to model/xRGM1.8/xRGM1.8
# INFO:tensorflow:Assets written to: model/xRGM1.8/xRGM1.8/assets
# Epoch 2/100
# 15/15 [==============================] - 13230s 938s/step - loss: 0.3740 - accuracy: 0.8482 - val_loss: 0.7168 - val_accuracy: 0.4991
#
# Epoch 00002: val_loss did not improve from 0.69748
# Epoch 3/100
# 15/15 [==============================] - 13395s 949s/step - loss: 0.2734 - accuracy: 0.8835 - val_loss: 0.7488 - val_accuracy: 0.5005
#
# Epoch 00003: val_loss did not improve from 0.69748
# Epoch 4/100
# 15/15 [==============================] - 13266s 940s/step - loss: 0.2758 - accuracy: 0.8849 - val_loss: 0.8114 - val_accuracy: 0.4987
#
# Epoch 00004: val_loss did not improve from 0.69748
# Epoch 5/100
# 15/15 [==============================] - 13178s 934s/step - loss: 0.1792 - accuracy: 0.9269 - val_loss: 0.9511 - val_accuracy: 0.5004
#
# Epoch 00005: val_loss did not improve from 0.69748
# Epoch 6/100
# 15/15 [==============================] - 13312s 943s/step - loss: 0.1325 - accuracy: 0.9487 - val_loss: 1.1068 - val_accuracy: 0.4969
#
# Epoch 00006: val_loss did not improve from 0.69748
# Epoch 7/100
# 15/15 [==============================] - 13894s 984s/step - loss: 0.0986 - accuracy: 0.9614 - val_loss: 0.9079 - val_accuracy: 0.4995
#
# Epoch 00007: val_loss did not improve from 0.69748
# Epoch 8/100
# 15/15 [==============================] - 13263s 940s/step - loss: 0.0705 - accuracy: 0.9770 - val_loss: 0.9801 - val_accuracy: 0.5008
#
# Epoch 00008: val_loss did not improve from 0.69748
# Epoch 9/100
# 15/15 [==============================] - 13212s 936s/step - loss: 0.0692 - accuracy: 0.9755 - val_loss: 1.0259 - val_accuracy: 0.5003
#
# Epoch 00009: val_loss did not improve from 0.69748
# Epoch 10/100
# 15/15 [==============================] - 13192s 935s/step - loss: 0.0358 - accuracy: 0.9905 - val_loss: 0.6691 - val_accuracy: 0.5833
#
# Epoch 00010: val_loss improved from 0.69748 to 0.66907, saving model to model/xRGM1.8/xRGM1.8
# INFO:tensorflow:Assets written to: model/xRGM1.8/xRGM1.8/assets
# Epoch 11/100
# 15/15 [==============================] - 13147s 932s/step - loss: 0.0304 - accuracy: 0.9931 - val_loss: 0.8616 - val_accuracy: 0.5065
#
# Epoch 00011: val_loss did not improve from 0.66907
# Epoch 12/100
# 15/15 [==============================] - 13528s 959s/step - loss: 0.0313 - accuracy: 0.9898 - val_loss: 0.8616 - val_accuracy: 0.4547
#
# Epoch 00012: val_loss did not improve from 0.66907
# Epoch 13/100
# 15/15 [==============================] - 13061s 926s/step - loss: 0.0123 - accuracy: 0.9992 - val_loss: 0.9440 - val_accuracy: 0.4723
#
# Epoch 00013: val_loss did not improve from 0.66907
# Epoch 14/100
# 15/15 [==============================] - 13082s 927s/step - loss: 0.0082 - accuracy: 0.9985 - val_loss: 0.7230 - val_accuracy: 0.6236
#
# Epoch 00014: val_loss did not improve from 0.66907
# Epoch 15/100
# 15/15 [==============================] - 13251s 939s/step - loss: 0.0049 - accuracy: 0.9994 - val_loss: 0.7863 - val_accuracy: 0.6694
#
# Epoch 00015: val_loss did not improve from 0.66907
# Epoch 16/100
# 15/15 [==============================] - 13188s 934s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.8527 - val_accuracy: 0.6835
#
# Epoch 00016: val_loss did not improve from 0.66907
# Epoch 17/100
# 15/15 [==============================] - 13251s 939s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.8438 - val_accuracy: 0.6909
#
# Epoch 00017: val_loss did not improve from 0.66907
# Epoch 18/100
# 15/15 [==============================] - 13103s 928s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.9813 - val_accuracy: 0.6811
#
# Epoch 00018: val_loss did not improve from 0.66907
# Epoch 19/100
# 15/15 [==============================] - 7065s 498s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.9014 - val_accuracy: 0.6918
#
# Epoch 00019: val_loss did not improve from 0.66907
# Epoch 20/100
# 15/15 [==============================] - 6288s 445s/step - loss: 9.0471e-04 - accuracy: 1.0000 - val_loss: 0.9506 - val_accuracy: 0.7021
#
# Epoch 00020: val_loss did not improve from 0.66907
# Epoch 21/100
# 15/15 [==============================] - 6078s 430s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.7775 - val_accuracy: 0.7378
#
# Epoch 00021: val_loss did not improve from 0.66907
# Epoch 22/100
# 15/15 [==============================] - 6070s 430s/step - loss: 6.8419e-04 - accuracy: 1.0000 - val_loss: 0.7652 - val_accuracy: 0.7571
#
# Epoch 00022: val_loss did not improve from 0.66907
# Epoch 23/100
# 15/15 [==============================] - 6082s 431s/step - loss: 7.2847e-04 - accuracy: 1.0000 - val_loss: 0.5530 - val_accuracy: 0.7947
#
# Epoch 00023: val_loss improved from 0.66907 to 0.55304, saving model to model/xRGM1.8/xRGM1.8
# INFO:tensorflow:Assets written to: model/xRGM1.8/xRGM1.8/assets
# Epoch 24/100
# 15/15 [==============================] - 6106s 432s/step - loss: 5.1179e-04 - accuracy: 1.0000 - val_loss: 0.4806 - val_accuracy: 0.8106
#
# Epoch 00024: val_loss improved from 0.55304 to 0.48059, saving model to model/xRGM1.8/xRGM1.8
# INFO:tensorflow:Assets written to: model/xRGM1.8/xRGM1.8/assets
# Epoch 25/100
# 15/15 [==============================] - 6133s 435s/step - loss: 4.4114e-04 - accuracy: 1.0000 - val_loss: 0.3315 - val_accuracy: 0.8755
#
# Epoch 00025: val_loss improved from 0.48059 to 0.33149, saving model to model/xRGM1.8/xRGM1.8
# INFO:tensorflow:Assets written to: model/xRGM1.8/xRGM1.8/assets
# Epoch 26/100
# 15/15 [==============================] - 6152s 436s/step - loss: 5.6568e-04 - accuracy: 1.0000 - val_loss: 0.2805 - val_accuracy: 0.9001
#
# Epoch 00026: val_loss improved from 0.33149 to 0.28054, saving model to model/xRGM1.8/xRGM1.8
# INFO:tensorflow:Assets written to: model/xRGM1.8/xRGM1.8/assets
# Epoch 27/100
# 15/15 [==============================] - 6075s 431s/step - loss: 2.7775e-04 - accuracy: 1.0000 - val_loss: 0.2145 - val_accuracy: 0.9199
#
# Epoch 00027: val_loss improved from 0.28054 to 0.21450, saving model to model/xRGM1.8/xRGM1.8
# INFO:tensorflow:Assets written to: model/xRGM1.8/xRGM1.8/assets
# Epoch 28/100
# 15/15 [==============================] - 6072s 431s/step - loss: 3.0299e-04 - accuracy: 1.0000 - val_loss: 0.1668 - val_accuracy: 0.9371
#
# Epoch 00028: val_loss improved from 0.21450 to 0.16676, saving model to model/xRGM1.8/xRGM1.8
# INFO:tensorflow:Assets written to: model/xRGM1.8/xRGM1.8/assets
# Epoch 29/100
# 15/15 [==============================] - 6069s 431s/step - loss: 4.1256e-04 - accuracy: 1.0000 - val_loss: 0.1315 - val_accuracy: 0.9482
#
# Epoch 00029: val_loss improved from 0.16676 to 0.13146, saving model to model/xRGM1.8/xRGM1.8
# INFO:tensorflow:Assets written to: model/xRGM1.8/xRGM1.8/assets
# Epoch 30/100
# 15/15 [==============================] - 6080s 431s/step - loss: 2.3658e-04 - accuracy: 1.0000 - val_loss: 0.1232 - val_accuracy: 0.9509
#
# Epoch 00030: val_loss improved from 0.13146 to 0.12319, saving model to model/xRGM1.8/xRGM1.8
# INFO:tensorflow:Assets written to: model/xRGM1.8/xRGM1.8/assets
# Epoch 31/100
# 15/15 [==============================] - 6066s 430s/step - loss: 4.2948e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9508
#
# Epoch 00031: val_loss did not improve from 0.12319
# Epoch 32/100
# 15/15 [==============================] - 6067s 430s/step - loss: 0.0367 - accuracy: 0.9929 - val_loss: 4.2630 - val_accuracy: 0.5923
#
# Epoch 00032: val_loss did not improve from 0.12319
# Epoch 33/100
# 15/15 [==============================] - 6064s 430s/step - loss: 0.0202 - accuracy: 0.9953 - val_loss: 4.2811 - val_accuracy: 0.6056
#
# Epoch 00033: val_loss did not improve from 0.12319
# Epoch 34/100
# 15/15 [==============================] - 6061s 429s/step - loss: 0.0259 - accuracy: 0.9915 - val_loss: 0.7643 - val_accuracy: 0.8705
#
# Epoch 00034: val_loss did not improve from 0.12319
# Epoch 35/100
# 15/15 [==============================] - 6074s 430s/step - loss: 0.0230 - accuracy: 0.9913 - val_loss: 1.4813 - val_accuracy: 0.7510
#
# Epoch 00035: val_loss did not improve from 0.12319
# Epoch 36/100
# 15/15 [==============================] - 6064s 429s/step - loss: 0.0172 - accuracy: 0.9962 - val_loss: 12.3569 - val_accuracy: 0.5131
# Epoch 00036: val_loss did not improve from 0.12319
# Epoch 37/100
# 15/15 [==============================] - 6053s 429s/step - loss: 0.0267 - accuracy: 0.9922 - val_loss: 3.6211 - val_accuracy: 0.7252
#
# Epoch 00037: val_loss did not improve from 0.12319
# Epoch 38/100
# 15/15 [==============================] - 6913s 490s/step - loss: 0.0723 - accuracy: 0.9735 - val_loss: 3.6173 - val_accuracy: 0.6441
#
# Epoch 00038: val_loss did not improve from 0.12319
# Epoch 39/100
# 15/15 [==============================] - 6753s 478s/step - loss: 0.0299 - accuracy: 0.9858 - val_loss: 0.7680 - val_accuracy: 0.8455
#
# Epoch 00039: val_loss did not improve from 0.12319
# Epoch 40/100
# 15/15 [==============================] - 6101s 432s/step - loss: 0.0125 - accuracy: 0.9976 - val_loss: 1.1280 - val_accuracy: 0.7936
#
# Epoch 00040: val_loss did not improve from 0.12319
# Epoch 41/100
# 15/15 [==============================] - 6068s 430s/step - loss: 0.0105 - accuracy: 0.9966 - val_loss: 0.5630 - val_accuracy: 0.8648
#
# Epoch 00041: val_loss did not improve from 0.12319
# Epoch 42/100
# 15/15 [==============================] - 6064s 429s/step - loss: 0.0087 - accuracy: 0.9973 - val_loss: 0.7383 - val_accuracy: 0.8557
#
# Epoch 00042: val_loss did not improve from 0.12319
# Epoch 43/100
# 15/15 [==============================] - 6059s 429s/step - loss: 0.0090 - accuracy: 0.9988 - val_loss: 0.4427 - val_accuracy: 0.8803
#
# Epoch 00043: val_loss did not improve from 0.12319
# Epoch 44/100
# 15/15 [==============================] - 6073s 430s/step - loss: 0.0046 - accuracy: 0.9990 - val_loss: 0.7732 - val_accuracy: 0.8397
#
# Epoch 00044: val_loss did not improve from 0.12319
# Epoch 45/100
# 15/15 [==============================] - 6073s 430s/step - loss: 0.0058 - accuracy: 0.9978 - val_loss: 0.1417 - val_accuracy: 0.9483
#
# Epoch 00045: val_loss did not improve from 0.12319
# Epoch 46/100
# 15/15 [==============================] - 6072s 430s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1200 - val_accuracy: 0.9650
#
# Epoch 00046: val_loss improved from 0.12319 to 0.12002, saving model to model/xRGM1.8/xRGM1.8
# INFO:tensorflow:Assets written to: model/xRGM1.8/xRGM1.8/assets
# Epoch 47/100
# 15/15 [==============================] - 6089s 431s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1146 - val_accuracy: 0.9678
#
# Epoch 00047: val_loss improved from 0.12002 to 0.11461, saving model to model/xRGM1.8/xRGM1.8
# INFO:tensorflow:Assets written to: model/xRGM1.8/xRGM1.8/assets
# Epoch 48/100
# 15/15 [==============================] - 6081s 431s/step - loss: 3.0616e-04 - accuracy: 1.0000 - val_loss: 0.1267 - val_accuracy: 0.9657
#
# Epoch 00048: val_loss did not improve from 0.11461
# Epoch 49/100
# 15/15 [==============================] - 6081s 431s/step - loss: 2.1363e-04 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9674
#
# Epoch 00049: val_loss did not improve from 0.11461
# Epoch 50/100
# 15/15 [==============================] - 6117s 433s/step - loss: 1.7332e-04 - accuracy: 1.0000 - val_loss: 0.1176 - val_accuracy: 0.9671
#
# Epoch 00050: val_loss did not improve from 0.11461
# Epoch 51/100
# 15/15 [==============================] - 6127s 434s/step - loss: 1.7163e-04 - accuracy: 1.0000 - val_loss: 0.1038 - val_accuracy: 0.9672
#
# Epoch 00051: val_loss improved from 0.11461 to 0.10376, saving model to model/xRGM1.8/xRGM1.8
# INFO:tensorflow:Assets written to: model/xRGM1.8/xRGM1.8/assets
# Epoch 52/100
# 15/15 [==============================] - 6142s 435s/step - loss: 1.2213e-04 - accuracy: 1.0000 - val_loss: 0.1003 - val_accuracy: 0.9675
#
# Epoch 00052: val_loss improved from 0.10376 to 0.10029, saving model to model/xRGM1.8/xRGM1.8
# INFO:tensorflow:Assets written to: model/xRGM1.8/xRGM1.8/assets
# Epoch 53/100
# 15/15 [==============================] - 6097s 432s/step - loss: 1.4523e-04 - accuracy: 1.0000 - val_loss: 0.1027 - val_accuracy: 0.9680
#
# Epoch 00053: val_loss did not improve from 0.10029
# Epoch 54/100
# 15/15 [==============================] - 6067s 430s/step - loss: 1.2972e-04 - accuracy: 1.0000 - val_loss: 0.0994 - val_accuracy: 0.9685
#
# Epoch 00054: val_loss improved from 0.10029 to 0.09941, saving model to model/xRGM1.8/xRGM1.8
# INFO:tensorflow:Assets written to: model/xRGM1.8/xRGM1.8/assets
# Epoch 55/100
# 15/15 [==============================] - 6089s 431s/step - loss: 9.2468e-05 - accuracy: 1.0000 - val_loss: 0.0986 - val_accuracy: 0.9679
#
# Epoch 00055: val_loss improved from 0.09941 to 0.09859, saving model to model/xRGM1.8/xRGM1.8
# INFO:tensorflow:Assets written to: model/xRGM1.8/xRGM1.8/assets
# Epoch 56/100
# 15/15 [==============================] - 6070s 430s/step - loss: 8.9425e-05 - accuracy: 1.0000 - val_loss: 0.1030 - val_accuracy: 0.9670
#
# Epoch 00056: val_loss did not improve from 0.09859
# Epoch 57/100
# 15/15 [==============================] - 6061s 429s/step - loss: 9.0148e-05 - accuracy: 1.0000 - val_loss: 0.1031 - val_accuracy: 0.9685
#
# Epoch 00057: val_loss did not improve from 0.09859
# Epoch 58/100
# 15/15 [==============================] - 6061s 429s/step - loss: 9.9082e-05 - accuracy: 1.0000 - val_loss: 0.0886 - val_accuracy: 0.9715
#
# Epoch 00058: val_loss improved from 0.09859 to 0.08858, saving model to model/xRGM1.8/xRGM1.8
# INFO:tensorflow:Assets written to: model/xRGM1.8/xRGM1.8/assets
# Epoch 59/100
# 15/15 [==============================] - 6073s 430s/step - loss: 1.1115e-04 - accuracy: 1.0000 - val_loss: 0.0908 - val_accuracy: 0.9711
#
# Epoch 00059: val_loss did not improve from 0.08858
# Epoch 60/100
# 15/15 [==============================] - 6076s 430s/step - loss: 7.5900e-05 - accuracy: 1.0000 - val_loss: 0.0863 - val_accuracy: 0.9732
#
# Epoch 00060: val_loss improved from 0.08858 to 0.08628, saving model to model/xRGM1.8/xRGM1.8
# INFO:tensorflow:Assets written to: model/xRGM1.8/xRGM1.8/assets
# Epoch 61/100
# 15/15 [==============================] - 6086s 431s/step - loss: 5.8620e-05 - accuracy: 1.0000 - val_loss: 0.0841 - val_accuracy: 0.9747
#
# Epoch 00061: val_loss improved from 0.08628 to 0.08409, saving model to model/xRGM1.8/xRGM1.8
# INFO:tensorflow:Assets written to: model/xRGM1.8/xRGM1.8/assets
# Epoch 62/100
# 15/15 [==============================] - 6078s 430s/step - loss: 7.3301e-05 - accuracy: 1.0000 - val_loss: 0.0886 - val_accuracy: 0.9695
#
# Epoch 00062: val_loss did not improve from 0.08409
# Epoch 63/100
# 15/15 [==============================] - 6109s 433s/step - loss: 9.6303e-05 - accuracy: 1.0000 - val_loss: 0.0804 - val_accuracy: 0.9731
#
# Epoch 00063: val_loss improved from 0.08409 to 0.08041, saving model to model/xRGM1.8/xRGM1.8
# INFO:tensorflow:Assets written to: model/xRGM1.8/xRGM1.8/assets
# Epoch 64/100
# 15/15 [==============================] - 6144s 435s/step - loss: 5.9807e-05 - accuracy: 1.0000 - val_loss: 0.0846 - val_accuracy: 0.9731
#
# Epoch 00064: val_loss did not improve from 0.08041
# Epoch 65/100
# 15/15 [==============================] - 6154s 436s/step - loss: 4.2688e-05 - accuracy: 1.0000 - val_loss: 0.0851 - val_accuracy: 0.9709
#
# Epoch 00065: val_loss did not improve from 0.08041
# Epoch 66/100
# 15/15 [==============================] - 6086s 431s/step - loss: 6.3559e-05 - accuracy: 1.0000 - val_loss: 0.0820 - val_accuracy: 0.9721
#
# Epoch 00066: val_loss did not improve from 0.08041
# Epoch 67/100
# 15/15 [==============================] - 6051s 428s/step - loss: 5.3783e-05 - accuracy: 1.0000 - val_loss: 0.0869 - val_accuracy: 0.9715
#
# Epoch 00067: val_loss did not improve from 0.08041
# Epoch 68/100
# 15/15 [==============================] - 6053s 429s/step - loss: 1.1198e-04 - accuracy: 1.0000 - val_loss: 0.0800 - val_accuracy: 0.9732
#
# Epoch 00068: val_loss improved from 0.08041 to 0.08003, saving model to model/xRGM1.8/xRGM1.8
# INFO:tensorflow:Assets written to: model/xRGM1.8/xRGM1.8/assets
# Epoch 69/100
# 15/15 [==============================] - 6074s 430s/step - loss: 8.6117e-05 - accuracy: 1.0000 - val_loss: 0.0796 - val_accuracy: 0.9713
#
# Epoch 00069: val_loss improved from 0.08003 to 0.07963, saving model to model/xRGM1.8/xRGM1.8
# INFO:tensorflow:Assets written to: model/xRGM1.8/xRGM1.8/assets
# Epoch 70/100
# 15/15 [==============================] - 6059s 429s/step - loss: 1.6420e-04 - accuracy: 1.0000 - val_loss: 0.0889 - val_accuracy: 0.9702
#
# Epoch 00070: val_loss did not improve from 0.07963
# Epoch 71/100
# 15/15 [==============================] - 6080s 431s/step - loss: 5.9608e-05 - accuracy: 1.0000 - val_loss: 0.0925 - val_accuracy: 0.9718
#
# Epoch 00071: val_loss did not improve from 0.07963
# Epoch 72/100
# 15/15 [==============================] - 4731s 334s/step - loss: 5.6231e-05 - accuracy: 1.0000 - val_loss: 0.0904 - val_accuracy: 0.9729
#
# Epoch 00072: val_loss did not improve from 0.07963
# Epoch 73/100
# 15/15 [==============================] - 4616s 327s/step - loss: 6.5664e-05 - accuracy: 1.0000 - val_loss: 0.0847 - val_accuracy: 0.9731
#
# Epoch 00073: val_loss did not improve from 0.07963
# Epoch 74/100
# 15/15 [==============================] - 4613s 327s/step - loss: 6.5093e-05 - accuracy: 1.0000 - val_loss: 0.0884 - val_accuracy: 0.9722
#
# Epoch 00074: val_loss did not improve from 0.07963
# Epoch 75/100
# 15/15 [==============================] - 4625s 327s/step - loss: 4.3697e-05 - accuracy: 1.0000 - val_loss: 0.0890 - val_accuracy: 0.9708
#
# Epoch 00075: val_loss did not improve from 0.07963
# Epoch 76/100
# 15/15 [==============================] - 4661s 330s/step - loss: 4.4080e-05 - accuracy: 1.0000 - val_loss: 0.0935 - val_accuracy: 0.9704
#
# Epoch 00076: val_loss did not improve from 0.07963
# Epoch 77/100
# 15/15 [==============================] - 4685s 332s/step - loss: 4.5759e-05 - accuracy: 1.0000 - val_loss: 0.0945 - val_accuracy: 0.9707
#
# Epoch 00077: val_loss did not improve from 0.07963
# Epoch 78/100
# 15/15 [==============================] - 4665s 331s/step - loss: 2.9319e-05 - accuracy: 1.0000 - val_loss: 0.0942 - val_accuracy: 0.9689
#
# Epoch 00078: val_loss did not improve from 0.07963
# Epoch 79/100
# 15/15 [==============================] - 4602s 326s/step - loss: 3.7430e-05 - accuracy: 1.0000 - val_loss: 0.0914 - val_accuracy: 0.9698
#
# Epoch 00079: val_loss did not improve from 0.07963
# Epoch 80/100
# 15/15 [==============================] - 4590s 325s/step - loss: 4.5087e-05 - accuracy: 1.0000 - val_loss: 0.0935 - val_accuracy: 0.9714
#
# Epoch 00080: val_loss did not improve from 0.07963
# Epoch 81/100
# 15/15 [==============================] - 4625s 327s/step - loss: 3.8187e-05 - accuracy: 1.0000 - val_loss: 0.0943 - val_accuracy: 0.9712
#
# Epoch 00081: val_loss did not improve from 0.07963
# Epoch 82/100
# 15/15 [==============================] - 3685s 260s/step - loss: 1.0152e-04 - accuracy: 1.0000 - val_loss: 0.0954 - val_accuracy: 0.9714
#
# Epoch 00082: val_loss did not improve from 0.07963
# Epoch 83/100
# 15/15 [==============================] - 3226s 228s/step - loss: 3.8282e-05 - accuracy: 1.0000 - val_loss: 0.0959 - val_accuracy: 0.9709
#
# Epoch 00083: val_loss did not improve from 0.07963
# Epoch 84/100
# 15/15 [==============================] - 3221s 228s/step - loss: 2.3507e-05 - accuracy: 1.0000 - val_loss: 0.0980 - val_accuracy: 0.9725
#
# Epoch 00084: val_loss did not improve from 0.07963
# Epoch 85/100
# 15/15 [==============================] - 3215s 227s/step - loss: 2.5887e-05 - accuracy: 1.0000 - val_loss: 0.1001 - val_accuracy: 0.9722
#
# Epoch 00085: val_loss did not improve from 0.07963
# Epoch 86/100
# 15/15 [==============================] - 3220s 228s/step - loss: 2.5136e-05 - accuracy: 1.0000 - val_loss: 0.0993 - val_accuracy: 0.9720
#
# Epoch 00086: val_loss did not improve from 0.07963
# Epoch 87/100
# 15/15 [==============================] - 3222s 228s/step - loss: 2.5538e-05 - accuracy: 1.0000 - val_loss: 0.0935 - val_accuracy: 0.9736
#
# Epoch 00087: val_loss did not improve from 0.07963
# Epoch 88/100
# 15/15 [==============================] - 3222s 228s/step - loss: 3.2109e-05 - accuracy: 1.0000 - val_loss: 0.0941 - val_accuracy: 0.9707
#
# Epoch 00088: val_loss did not improve from 0.07963
# Epoch 89/100
# 15/15 [==============================] - 3220s 228s/step - loss: 3.9856e-05 - accuracy: 1.0000 - val_loss: 0.0944 - val_accuracy: 0.9708
#
# Epoch 00089: val_loss did not improve from 0.07963
# Epoch 90/100
# 15/15 [==============================] - 3218s 228s/step - loss: 2.6561e-05 - accuracy: 1.0000 - val_loss: 0.0939 - val_accuracy: 0.9712
#
# Epoch 00090: val_loss did not improve from 0.07963
# Epoch 91/100
# 15/15 [==============================] - 3220s 228s/step - loss: 3.4177e-05 - accuracy: 1.0000 - val_loss: 0.0945 - val_accuracy: 0.9707
#
# Epoch 00091: val_loss did not improve from 0.07963
# Epoch 92/100
# 15/15 [==============================] - 3219s 228s/step - loss: 2.8499e-05 - accuracy: 1.0000 - val_loss: 0.0908 - val_accuracy: 0.9711
#
# Epoch 00092: val_loss did not improve from 0.07963
# Epoch 93/100
# 15/15 [==============================] - 3202s 227s/step - loss: 2.9310e-05 - accuracy: 1.0000 - val_loss: 0.0926 - val_accuracy: 0.9709
#
# Epoch 00093: val_loss did not improve from 0.07963
# Epoch 94/100
# 15/15 [==============================] - 3223s 228s/step - loss: 2.0700e-05 - accuracy: 1.0000 - val_loss: 0.0946 - val_accuracy: 0.9703
#
# Epoch 00094: val_loss did not improve from 0.07963
# Epoch 95/100
# 15/15 [==============================] - 3222s 228s/step - loss: 2.0672e-05 - accuracy: 1.0000 - val_loss: 0.0905 - val_accuracy: 0.9715
#
# Epoch 00095: val_loss did not improve from 0.07963
# Epoch 96/100
# 15/15 [==============================] - 3202s 227s/step - loss: 1.5500e-05 - accuracy: 1.0000 - val_loss: 0.0947 - val_accuracy: 0.9702
#
# Epoch 00096: val_loss did not improve from 0.07963
# Epoch 97/100
# 15/15 [==============================] - 3222s 228s/step - loss: 2.5174e-05 - accuracy: 1.0000 - val_loss: 0.0929 - val_accuracy: 0.9713
#
# Epoch 00097: val_loss did not improve from 0.07963
# Epoch 98/100
# 15/15 [==============================] - 3221s 228s/step - loss: 2.7006e-05 - accuracy: 1.0000 - val_loss: 0.0887 - val_accuracy: 0.9718
#
# Epoch 00098: val_loss did not improve from 0.07963
# Epoch 99/100
# 15/15 [==============================] - 3224s 228s/step - loss: 5.0276e-05 - accuracy: 1.0000 - val_loss: 0.0855 - val_accuracy: 0.9737
#
# Epoch 00099: val_loss did not improve from 0.07963
# Epoch 100/100
# 15/15 [==============================] - 3224s 228s/step - loss: 2.3356e-05 - accuracy: 1.0000 - val_loss: 0.0861 - val_accuracy: 0.9724
#
# Epoch 00100: val_loss did not improve from 0.07963
# INFO:tensorflow:Assets written to: model/xRGM1.8/assets
# CPU times: user 26d 17h 17min 58s, sys: 20h 52min 37s, total: 27d 14h 10min 36s
# Wall time: 7d 18h 54min 9s

# %%
confusion_matrix = pd.DataFrame(metrics.confusion_matrix(y_test, v_classify(y_pred)),
                                columns=['Predicted Negative', 'Predicted Positive'],
                                index=['Actual Negative', 'Actual Positive'])

tp, tn, fp, fn = (
    confusion_matrix.iloc[1,1], 
    confusion_matrix.iloc[0,0], 
    confusion_matrix.iloc[0,1], 
    confusion_matrix.iloc[1,0]
)

accuracy = (tp + tn) / (tp + tn + fp + fn)
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
f1_score = 2 * ((specificity * sensitivity) / (specificity + sensitivity))

with open(os.path.join(f'{model_dir}', 'metrics.csv'), 'a', encoding='utf-8') as f:
    f.write(
        f'{time.strftime("%Y-%m-%dT%H:%M:%S-05:00", time.localtime())}, {accuracy}, {sensitivity}, {specificity}, {f1_score}\n'
    )

print(f'Accuracy:    {accuracy}')
print(f'Sensitivity: {sensitivity}')
print(f'Specificity: {specificity}')
print(f'F1 Score:    {f1_score}')
print('\n')
print(confusion_matrix)
# Out:
# Accuracy:    0.9726247987117552
# Sensitivity: 0.9580645161290322
# Specificity: 0.9871382636655949
# F1 Score:    0.9723841162010696
#
#
#                  Predicted Negative  Predicted Positive
# Actual Negative                 307                   4
# Actual Positive                  13                 297

# %%
disease_types=['COVID', 'non-COVID']
Y_pred = np.argmax(y_pred)
Y_true = np.argmax(y_test)

plt.figure(figsize=(7, 7))
ax = sns.heatmap(confusion_matrix , cmap=plt.cm.GnBu , 
                 annot=True, fmt='d',square=True, xticklabels=disease_types, 
                 yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
plt.show()

# %%
def plot_model_history(model_history):
   fig, axs = plt.subplots(1,2,figsize=(15,5))
   # summarize history for accuracy
   axs[0].plot(range(1, len(model_history['accuracy']) + 1), model_history['accuracy'])
   axs[0].plot(range(1, len(model_history['val_accuracy']) + 1), model_history['val_accuracy'])
   axs[0].set_title('Model Accuracy')
   axs[0].set_ylabel('Accuracy')
   axs[0].set_xlabel('Epoch')
   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
   axs[0].legend(['train', 'val'], loc='best')
   # summarize history for loss
   axs[1].plot(range(1, len(model_history['loss'])+1), model_history['loss'])
   axs[1].plot(range(1, len(model_history['val_loss']) + 1), model_history['val_loss'])
   axs[1].set_title('Model Loss')
   axs[1].set_ylabel('Loss')
   axs[1].set_xlabel('Epoch')
   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
   axs[1].legend(['train', 'val'], loc='best')
   plt.show()

# %%
with open(os.path.join('models', 'xRGM1.8-Net-HistDict'), 'rb') as f:
    history = pickle.load(f)
    
plot_model_history(history)
# Out:
# <ipython-input-10-25025fac5012>:9: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
# <ipython-input-10-25025fac5012>:17: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
