# %%
import glob
import json
import os
import pickle
import random
import traceback
from typing import Tuple

import numpy as np
import pandas as pd
import seaborn as sns
from keras.models import Sequential, load_model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Lambda, LeakyReLU, AveragePooling2D, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from matplotlib import pyplot as plt
from matplotlib.pyplot import hist
from PIL import Image
from scipy.stats import zscore
from sklearn import metrics
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %%
import csv
import time

# %% [markdown]
# ## Config & Constants

# %%
IMAGE_WIDTH, IMAGE_HEIGHT = 227, 227
random.seed(52)

# %% [markdown]
# ## Methods

# %% [markdown]
# ### Image Utilities

# %%
def batch_generator(input_data, output_data, batch_size, is_training):
    input_data_batch = np.empty([batch_size, IMAGE_HEIGHT, IMAGE_WIDTH, 1])
    output_data_batch = np.empty([batch_size, 1])
    while True:
        index = 0
        for i in np.random.permutation(input_data.shape[0]):
            input_data_batch[index] = input_data[i]
            output_data_batch[index] = output_data[i]
            index += 1
            if index == batch_size:
                break
        yield input_data_batch, output_data_batch


def _preprocess(image_loc: str) -> np.ndarray:
    f_image = Image.open(image_loc).convert('L')
    f_image = f_image.resize((IMAGE_WIDTH, IMAGE_HEIGHT), Image.ANTIALIAS)
    image = np.asarray(f_image)
    image = np.expand_dims(image, axis=0)
    image = np.expand_dims(image, axis=3)
    return image


def preprocess(loc: str) -> np.ndarray:
    """Safety wrapper over _preprocess.
    
    Args:
        loc: File location to check if dir or an image.
        
    Returns:
        Preprocessed image(s) as an ndarray.
    """
    if os.path.isdir(loc):
        current = np.concatenate((
            [_preprocess(os.path.join(loc, image)) for image in os.listdir(loc)
             if '.png' in image]
        ))
    else:
        current = _preprocess(loc)
    return current


def generate_data_arrays(
    covid_data: str = 'rsc/New_Data_CoV2/COVID/',
    noncovid_data: str = 'rsc/New_Data_CoV2/non-COVID/',
    others_data:  str = 'rsc/New_Data_CoV2/Others/',
    image_output: str = 'rsc/input_data_v2',
    label_output: str = 'rsc/output_data_v2',
    regenerate: bool = True
) -> Tuple[np.ndarray, np.ndarray]:
    """Loads COVID images into ndarrays.
    
    Args:
        covid_data: Relative path to folder containing COVID images.
        noncovid_data: Relative path to folder containing non-COVID images.
        others_data: Relative path to folder containing Others images.
        image_output: Relative path (with filename) to save loaded images to.
        label_output: Relative path (with filename) to save loaded classes (labels) to.
        regenerate: If True, will regenerate saved ndarray files for both image_output
            and label_output, even if they already exist (overwriting them). If False,
            will simply load and return the aforementioned.
        
    Returns:
        Tuple of ndarrays. The first is the loaded image data in one large ndarray,
        and the second is the loaded labels, also in a large ndarray. These directly
        match up to each other ONLY when both arrays (and their respective files)
        are generated at the same time with this method.
    """
    if (regenerate is False and 
        os.path.isfile(f'{out_input_data}.npy') and
        os.path.isfile(f'{out_output_data}.npy')):
        return (np.load(f'{out_input_data}.npy'),
                np.load(f'{out_output_data}.npy'))
    
    if not ((cd := os.path.exists(covid_data)) and (ncd := os.path.exists(noncovid_data))):
        if (others_data is not None) and not (odd := os.path.exists(others_data)):
            raise NotADirectoryError("Directories do not exist.")
        else:
            raise NotADirectoryError("COVID/non-COVID directories do not exist.")
    
    im_data = np.empty([1, IMAGE_WIDTH, IMAGE_WIDTH, 1])
    output = np.array([0])

    print('Loading Covid Data')
    for i in tqdm(glob.glob(os.path.join(covid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([1])), axis=0)

    print('Loading non-Covid Data')
    for i in tqdm(glob.glob(os.path.join(noncovid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([0])), axis=0)
        
    if others_data is not None:
        print('Loading Others Data')
        for i in tqdm(glob.glob(os.path.join(others_data, '**'))):
            current = preprocess(i)
            im_data = np.concatenate((im_data, current))
            output = np.concatenate((output, np.array([-1])), axis=0)
    else:
        print('Others data not provided; skipping.')


    print('Finished Loading Data')
    im_data = np.delete(im_data, 0, axis=0)
    output = np.delete(output, 0, axis=0)

    zip_data = list(zip(im_data, output))
    random.shuffle(zip_data)
    im_data, output = zip(*zip_data)

    np.save(f'{image_output}', im_data)
    np.save(f'{label_output}', output)
    return im_data, output


def load_data(image_loc: str, label_loc: str, **kwargs) -> Tuple[np.ndarray, np.ndarray]:
    """Attempts to load generated images and labels.
    
    If either is not found, attempts to (re)generate them using the default
    input arguments to the generation method for the raw data, but the input
    `image_loc` and `label_loc` parameters for the output arrays. If this
    still does not work, returns a general error and exits.
    
    Args:
        image_loc: Relative path to saved image ndarray file.
        label_loc: Relative path to saved label ndarray file.
        
    Returns:
        Tuple of ndarrays. The first array holds the loaded image data, whilst
        the second array holds their respective labels.
    
    """
    try:
        image_data = np.load(f'{image_loc}.npy')
        label_data = np.load(f'{label_loc}.npy')
        return image_data, label_data
    
    except FileNotFoundError:
        try:
            image_data, label_data = generate_data_arrays(
                image_output = image_loc,
                label_output = label_loc,
                **kwargs
            )
            return image_data, label_data
        
        except Exception as e:
            traceback.print_exc()

# %% [markdown]
# ## Model Playground

# %%
#Version 1
im_data_v1, output_v1 = load_data(
    image_loc = 'rsc/input_data_v1',
    label_loc = 'rsc/output_data_v1',
    covid_data = 'rsc/Data_CoV2/COVID/',
    noncovid_data = 'rsc/Data_CoV2/non-COVID/',
    others_data = None,
)

x_train, x_test, y_train, y_test = train_test_split(im_data_v1, output_v1, random_state=42)

# %%
def make_model(X_Train, Y_Train, X_Test, Y_Test, model_dir: str):
    if not os.path.exists(model_dir):
        os.makedirs(model_dir)
    #X_Train, X_Test, Y_Train, Y_Test = train_test_split(input_data, output_data, test_size=0.1)

    for_pad = lambda s: s if s > 2 else 3

    model = Sequential()
    model.add(Lambda(lambda x: x, input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 1)))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=8, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))



    #model.add(ZeroPadding2D(padding=(for_pad(19) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(Conv2D(kernel_size=(3, 3), filters=2, strides=(1, 1),activation='relu'))

    model.add(Flatten())

    model.add(Dropout(rate=0.4))
    model.add(Dense(units=338, activation='relu'))
    model.add(Dense(units=1, activation='sigmoid'))

    model.compile(optimizer=Adam(lr=3e-4), loss='binary_crossentropy', metrics=["accuracy"])
    model.summary()

    checkpoint = ModelCheckpoint(os.path.join(model_dir, 'xRGM1.6'), verbose=1, period=1, save_best_only=True)

    hist = model.fit_generator(batch_generator(X_Train, Y_Train, 64, True),
                        validation_data=(batch_generator(X_Test, Y_Test, 64, False)), callbacks=[checkpoint],
                        verbose=1, epochs=75, steps_per_epoch=25, validation_steps=len(X_Test))

    with open(os.path.join('models', 'xRGM1.6-Net-HistDict'), 'wb') as f:
        pickle.dump(hist.history, f)

    model.save(model_dir)
    
    return model
#changed steps and epochs and batchsize

# %%
# %%time 
model_dir: str = 'model/xRGM1.6'
xRGM = make_model(x_train, y_train.reshape(-1,1), x_test, y_test.reshape(-1,1), model_dir=model_dir)

v_classify = np.vectorize(lambda x: np.round(x, 0))
# xRGMCT2 = load_model('models/xRGMCT2L.h5')
# print(xRGMCT2.history)
y_pred = (xRGM.predict(x_test))

#print(y_test)
#print(y_pred)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_1 (Lambda)            (None, 227, 227, 1)       0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 225, 225, 8)       80
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 225, 225, 8)       32
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 225, 225, 8)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 112, 112, 8)       0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 110, 110, 16)      1168
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 110, 110, 16)      64
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 110, 110, 16)      0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 108, 108, 32)      4640
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 108, 108, 32)      128
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 108, 108, 32)      0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 108, 108, 16)      528
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 108, 108, 16)      64
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 108, 108, 16)      0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 106, 106, 32)      4640
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 106, 106, 32)      128
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 106, 106, 32)      0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 104, 104, 64)      18496
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 104, 104, 64)      256
# _________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)   (None, 104, 104, 64)      0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 104, 104, 32)      2080
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 104, 104, 32)      128
# _________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)   (None, 104, 104, 32)      0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 102, 102, 64)      18496
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 102, 102, 64)      256
# _________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)   (None, 102, 102, 64)      0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 100, 100, 128)     73856
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 100, 100, 128)     512
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 100, 100, 128)     0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 100, 100, 64)      8256
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 100, 100, 64)      256
# _________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)   (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 98, 98, 128)       73856
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 98, 98, 128)       512
# _________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)   (None, 98, 98, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 49, 49, 128)       0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 47, 47, 256)       295168
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 47, 47, 256)       1024
# _________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)   (None, 47, 47, 256)       0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 47, 47, 128)       32896
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 47, 47, 128)       512
# _________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)   (None, 47, 47, 128)       0
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 23, 23, 128)       0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 21, 21, 256)       295168
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 21, 21, 256)       1024
# _________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)   (None, 21, 21, 256)       0
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 10, 10, 256)       0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 10, 10, 128)       32896
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)   (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)   (None, 8, 8, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16384)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 338)               5538130
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 339
# =================================================================
# Total params: 6,702,293
# Trainable params: 6,699,077
# Non-trainable params: 3,216
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/75
# /home/jg1994/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 25/25 [==============================] - 944s 39s/step - loss: 1.0391 - accuracy: 0.6666 - val_loss: 0.7006 - val_accuracy: 0.4992
#
# Epoch 00001: val_loss improved from inf to 0.70063, saving model to model/xRGM1.6/xRGM1.6
# INFO:tensorflow:Assets written to: model/xRGM1.6/xRGM1.6/assets
# Epoch 2/75
# 25/25 [==============================] - 940s 39s/step - loss: 0.3250 - accuracy: 0.8672 - val_loss: 0.7321 - val_accuracy: 0.5003
#
# Epoch 00002: val_loss did not improve from 0.70063
# Epoch 3/75
# 25/25 [==============================] - 943s 39s/step - loss: 0.1997 - accuracy: 0.9285 - val_loss: 0.7881 - val_accuracy: 0.5010
#
# Epoch 00003: val_loss did not improve from 0.70063
# Epoch 4/75
# 25/25 [==============================] - 944s 39s/step - loss: 0.1263 - accuracy: 0.9539 - val_loss: 0.6817 - val_accuracy: 0.6157
#
# Epoch 00004: val_loss improved from 0.70063 to 0.68168, saving model to model/xRGM1.6/xRGM1.6
# INFO:tensorflow:Assets written to: model/xRGM1.6/xRGM1.6/assets
# Epoch 5/75
# 25/25 [==============================] - 945s 39s/step - loss: 0.1360 - accuracy: 0.9449 - val_loss: 0.6990 - val_accuracy: 0.5020
#
# Epoch 00005: val_loss did not improve from 0.68168
# Epoch 6/75
# 25/25 [==============================] - 941s 39s/step - loss: 0.0961 - accuracy: 0.9626 - val_loss: 0.7185 - val_accuracy: 0.5443
#
# Epoch 00006: val_loss did not improve from 0.68168
# Epoch 7/75
# 25/25 [==============================] - 941s 39s/step - loss: 0.0593 - accuracy: 0.9807 - val_loss: 0.7027 - val_accuracy: 0.5492
#
# Epoch 00007: val_loss did not improve from 0.68168
# Epoch 8/75
# 25/25 [==============================] - 940s 39s/step - loss: 0.0321 - accuracy: 0.9900 - val_loss: 0.6150 - val_accuracy: 0.6646
#
# Epoch 00008: val_loss improved from 0.68168 to 0.61504, saving model to model/xRGM1.6/xRGM1.6
# INFO:tensorflow:Assets written to: model/xRGM1.6/xRGM1.6/assets
# Epoch 9/75
# 25/25 [==============================] - 940s 39s/step - loss: 0.0321 - accuracy: 0.9915 - val_loss: 0.5805 - val_accuracy: 0.7064
#
# Epoch 00009: val_loss improved from 0.61504 to 0.58054, saving model to model/xRGM1.6/xRGM1.6
# INFO:tensorflow:Assets written to: model/xRGM1.6/xRGM1.6/assets
# Epoch 10/75
# 25/25 [==============================] - 941s 39s/step - loss: 0.0537 - accuracy: 0.9836 - val_loss: 0.8690 - val_accuracy: 0.6625
#
# Epoch 00010: val_loss did not improve from 0.58054
# Epoch 11/75
# 25/25 [==============================] - 941s 39s/step - loss: 0.0420 - accuracy: 0.9856 - val_loss: 0.8396 - val_accuracy: 0.6672
#
# Epoch 00011: val_loss did not improve from 0.58054
# Epoch 12/75
# 25/25 [==============================] - 940s 39s/step - loss: 0.0307 - accuracy: 0.9905 - val_loss: 0.9308 - val_accuracy: 0.7012
#
# Epoch 00012: val_loss did not improve from 0.58054
# Epoch 13/75
# 25/25 [==============================] - 940s 39s/step - loss: 0.0118 - accuracy: 0.9981 - val_loss: 0.8208 - val_accuracy: 0.7182
#
# Epoch 00013: val_loss did not improve from 0.58054
# Epoch 14/75
# 25/25 [==============================] - 941s 39s/step - loss: 0.0070 - accuracy: 0.9984 - val_loss: 0.5116 - val_accuracy: 0.8014
#
# Epoch 00014: val_loss improved from 0.58054 to 0.51157, saving model to model/xRGM1.6/xRGM1.6
# INFO:tensorflow:Assets written to: model/xRGM1.6/xRGM1.6/assets
# Epoch 15/75
# 25/25 [==============================] - 946s 39s/step - loss: 0.0066 - accuracy: 0.9992 - val_loss: 0.4762 - val_accuracy: 0.8213
#
# Epoch 00015: val_loss improved from 0.51157 to 0.47622, saving model to model/xRGM1.6/xRGM1.6
# INFO:tensorflow:Assets written to: model/xRGM1.6/xRGM1.6/assets
# Epoch 16/75
# 25/25 [==============================] - 943s 39s/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.3857 - val_accuracy: 0.8589
#
# Epoch 00016: val_loss improved from 0.47622 to 0.38568, saving model to model/xRGM1.6/xRGM1.6
# INFO:tensorflow:Assets written to: model/xRGM1.6/xRGM1.6/assets
# Epoch 17/75
# 25/25 [==============================] - 941s 39s/step - loss: 0.0056 - accuracy: 0.9987 - val_loss: 0.1405 - val_accuracy: 0.9373
#
# Epoch 00017: val_loss improved from 0.38568 to 0.14051, saving model to model/xRGM1.6/xRGM1.6
# INFO:tensorflow:Assets written to: model/xRGM1.6/xRGM1.6/assets
# Epoch 18/75
# 25/25 [==============================] - 954s 39s/step - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.2912 - val_accuracy: 0.9147
#
# Epoch 00018: val_loss did not improve from 0.14051
# Epoch 19/75
# 25/25 [==============================] - 1771s 73s/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.1215 - val_accuracy: 0.9633
#
# Epoch 00019: val_loss improved from 0.14051 to 0.12146, saving model to model/xRGM1.6/xRGM1.6
# INFO:tensorflow:Assets written to: model/xRGM1.6/xRGM1.6/assets
# Epoch 20/75
# 25/25 [==============================] - 3129s 130s/step - loss: 0.0037 - accuracy: 0.9982 - val_loss: 0.2766 - val_accuracy: 0.9022
#
# Epoch 00020: val_loss did not improve from 0.12146
# Epoch 21/75
# 25/25 [==============================] - 3007s 124s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0970 - val_accuracy: 0.9701
#
# Epoch 00021: val_loss improved from 0.12146 to 0.09695, saving model to model/xRGM1.6/xRGM1.6
# INFO:tensorflow:Assets written to: model/xRGM1.6/xRGM1.6/assets
# Epoch 22/75
# 25/25 [==============================] - 3185s 132s/step - loss: 0.0026 - accuracy: 0.9990 - val_loss: 0.1204 - val_accuracy: 0.9488
#
# Epoch 00022: val_loss did not improve from 0.09695
# Epoch 23/75
# 25/25 [==============================] - 3085s 127s/step - loss: 0.0100 - accuracy: 0.9972 - val_loss: 0.3638 - val_accuracy: 0.8990
#
# Epoch 00023: val_loss did not improve from 0.09695
# Epoch 24/75
# 25/25 [==============================] - 3034s 125s/step - loss: 0.0345 - accuracy: 0.9868 - val_loss: 1.2892 - val_accuracy: 0.8496
#
# Epoch 00024: val_loss did not improve from 0.09695
# Epoch 25/75
# 25/25 [==============================] - 3204s 133s/step - loss: 0.0548 - accuracy: 0.9846 - val_loss: 2.7968 - val_accuracy: 0.7379
#
# Epoch 00025: val_loss did not improve from 0.09695
# Epoch 26/75
# 25/25 [==============================] - 3032s 125s/step - loss: 0.0510 - accuracy: 0.9855 - val_loss: 2.3998 - val_accuracy: 0.7619
#
# Epoch 00026: val_loss did not improve from 0.09695
# Epoch 27/75
# 25/25 [==============================] - 3235s 134s/step - loss: 0.0213 - accuracy: 0.9928 - val_loss: 0.1643 - val_accuracy: 0.9505
#
# Epoch 00027: val_loss did not improve from 0.09695
# Epoch 28/75
# 25/25 [==============================] - 3030s 125s/step - loss: 0.0198 - accuracy: 0.9944 - val_loss: 0.3861 - val_accuracy: 0.9082
#
# Epoch 00028: val_loss did not improve from 0.09695
# Epoch 29/75
# 25/25 [==============================] - 3152s 130s/step - loss: 0.0126 - accuracy: 0.9949 - val_loss: 0.6585 - val_accuracy: 0.8868
#
# Epoch 00029: val_loss did not improve from 0.09695
# Epoch 30/75
# 25/25 [==============================] - 3134s 130s/step - loss: 0.0443 - accuracy: 0.9832 - val_loss: 1.7637 - val_accuracy: 0.7590
#
# Epoch 00030: val_loss did not improve from 0.09695
# Epoch 31/75
# 25/25 [==============================] - 3030s 125s/step - loss: 0.0455 - accuracy: 0.9848 - val_loss: 0.4008 - val_accuracy: 0.9146
#
# Epoch 00031: val_loss did not improve from 0.09695
# Epoch 32/75
# 25/25 [==============================] - 3243s 134s/step - loss: 0.0157 - accuracy: 0.9944 - val_loss: 0.2403 - val_accuracy: 0.9417
#
# Epoch 00032: val_loss did not improve from 0.09695
# Epoch 33/75
# 25/25 [==============================] - 3056s 126s/step - loss: 0.0154 - accuracy: 0.9962 - val_loss: 0.4041 - val_accuracy: 0.9200
#
# Epoch 00033: val_loss did not improve from 0.09695
# Epoch 34/75
# 25/25 [==============================] - 3238s 134s/step - loss: 0.0099 - accuracy: 0.9971 - val_loss: 0.3281 - val_accuracy: 0.9260
#
# Epoch 00034: val_loss did not improve from 0.09695
# Epoch 35/75
# 25/25 [==============================] - 2872s 119s/step - loss: 0.0061 - accuracy: 0.9992 - val_loss: 0.2332 - val_accuracy: 0.9493
#
# Epoch 00035: val_loss did not improve from 0.09695
# Epoch 36/75
# 25/25 [==============================] - 2478s 102s/step - loss: 0.0095 - accuracy: 0.9957 - val_loss: 0.3004 - val_accuracy: 0.9349
#
# Epoch 00036: val_loss did not improve from 0.09695
# Epoch 37/75
# 25/25 [==============================] - 2533s 105s/step - loss: 0.0186 - accuracy: 0.9938 - val_loss: 0.2218 - val_accuracy: 0.9371
#
# Epoch 00037: val_loss did not improve from 0.09695
# Epoch 38/75
# 25/25 [==============================] - 2366s 98s/step - loss: 0.0046 - accuracy: 0.9994 - val_loss: 0.8364 - val_accuracy: 0.8670
#
# Epoch 00038: val_loss did not improve from 0.09695
# Epoch 39/75
# 25/25 [==============================] - 2610s 108s/step - loss: 0.0034 - accuracy: 0.9998 - val_loss: 0.1105 - val_accuracy: 0.9626
#
# Epoch 00039: val_loss did not improve from 0.09695
# Epoch 40/75
# 25/25 [==============================] - 2386s 99s/step - loss: 9.4956e-04 - accuracy: 1.0000 - val_loss: 0.1124 - val_accuracy: 0.9652
#
# Epoch 00040: val_loss did not improve from 0.09695
# Epoch 41/75
# 25/25 [==============================] - 2615s 108s/step - loss: 3.4328e-04 - accuracy: 1.0000 - val_loss: 0.1017 - val_accuracy: 0.9670
#
# Epoch 00041: val_loss did not improve from 0.09695
# Epoch 42/75
# 25/25 [==============================] - 2416s 100s/step - loss: 3.8121e-04 - accuracy: 1.0000 - val_loss: 0.0987 - val_accuracy: 0.9717
#
# Epoch 00042: val_loss did not improve from 0.09695
# Epoch 43/75
# 25/25 [==============================] - 2493s 103s/step - loss: 2.0547e-04 - accuracy: 1.0000 - val_loss: 0.0964 - val_accuracy: 0.9734
#
# Epoch 00043: val_loss improved from 0.09695 to 0.09639, saving model to model/xRGM1.6/xRGM1.6
# INFO:tensorflow:Assets written to: model/xRGM1.6/xRGM1.6/assets
# Epoch 44/75
# 25/25 [==============================] - 2551s 106s/step - loss: 2.0038e-04 - accuracy: 1.0000 - val_loss: 0.0864 - val_accuracy: 0.9742
#
# Epoch 00044: val_loss improved from 0.09639 to 0.08639, saving model to model/xRGM1.6/xRGM1.6
# INFO:tensorflow:Assets written to: model/xRGM1.6/xRGM1.6/assets
# Epoch 45/75
# 25/25 [==============================] - 2385s 99s/step - loss: 1.7961e-04 - accuracy: 1.0000 - val_loss: 0.0866 - val_accuracy: 0.9736
#
# Epoch 00045: val_loss did not improve from 0.08639
# Epoch 46/75
# 25/25 [==============================] - 2616s 108s/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.1735 - val_accuracy: 0.9483
#
# Epoch 00046: val_loss did not improve from 0.08639
# Epoch 47/75
# 25/25 [==============================] - 2382s 98s/step - loss: 3.7946e-04 - accuracy: 1.0000 - val_loss: 0.1995 - val_accuracy: 0.9577
#
# Epoch 00047: val_loss did not improve from 0.08639
# Epoch 48/75
# 25/25 [==============================] - 2616s 108s/step - loss: 3.3653e-04 - accuracy: 1.0000 - val_loss: 0.1624 - val_accuracy: 0.9653
#
# Epoch 00048: val_loss did not improve from 0.08639
# Epoch 49/75
# 25/25 [==============================] - 2401s 99s/step - loss: 9.9101e-05 - accuracy: 1.0000 - val_loss: 0.1493 - val_accuracy: 0.9671
#
# Epoch 00049: val_loss did not improve from 0.08639
# Epoch 50/75
# 25/25 [==============================] - 2480s 103s/step - loss: 9.7989e-05 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9712
#
# Epoch 00050: val_loss did not improve from 0.08639
# Epoch 51/75
# 25/25 [==============================] - 2525s 105s/step - loss: 2.6193e-04 - accuracy: 1.0000 - val_loss: 0.0974 - val_accuracy: 0.9751
#
# Epoch 00051: val_loss did not improve from 0.08639
# Epoch 52/75
# 25/25 [==============================] - 2397s 99s/step - loss: 9.8184e-05 - accuracy: 1.0000 - val_loss: 0.1084 - val_accuracy: 0.9755
#
# Epoch 00052: val_loss did not improve from 0.08639
# Epoch 53/75
# 25/25 [==============================] - 2628s 109s/step - loss: 1.0221e-04 - accuracy: 1.0000 - val_loss: 0.1031 - val_accuracy: 0.9753
#
# Epoch 00053: val_loss did not improve from 0.08639
# Epoch 54/75
# 25/25 [==============================] - 2400s 99s/step - loss: 6.5587e-05 - accuracy: 1.0000 - val_loss: 0.1018 - val_accuracy: 0.9763
#
# Epoch 00054: val_loss did not improve from 0.08639
# Epoch 55/75
# 25/25 [==============================] - 2620s 108s/step - loss: 9.4196e-05 - accuracy: 1.0000 - val_loss: 0.1094 - val_accuracy: 0.9741
#
# Epoch 00055: val_loss did not improve from 0.08639
# Epoch 56/75
# 25/25 [==============================] - 2417s 100s/step - loss: 2.0474e-04 - accuracy: 1.0000 - val_loss: 0.1730 - val_accuracy: 0.9650
#
# Epoch 00056: val_loss did not improve from 0.08639
# Epoch 57/75
# 25/25 [==============================] - 2474s 102s/step - loss: 9.8266e-05 - accuracy: 1.0000 - val_loss: 0.1430 - val_accuracy: 0.9658
#
# Epoch 00057: val_loss did not improve from 0.08639
# Epoch 58/75
# 25/25 [==============================] - 1892s 78s/step - loss: 9.4520e-05 - accuracy: 1.0000 - val_loss: 0.0866 - val_accuracy: 0.9768
#
# Epoch 00058: val_loss did not improve from 0.08639
# Epoch 59/75
# 25/25 [==============================] - 1701s 70s/step - loss: 4.4985e-05 - accuracy: 1.0000 - val_loss: 0.0889 - val_accuracy: 0.9749
#
# Epoch 00059: val_loss did not improve from 0.08639
# Epoch 60/75
# 25/25 [==============================] - 1990s 82s/step - loss: 7.6674e-05 - accuracy: 1.0000 - val_loss: 0.0937 - val_accuracy: 0.9739
#
# Epoch 00060: val_loss did not improve from 0.08639
# Epoch 61/75
# 25/25 [==============================] - 1710s 71s/step - loss: 2.5338e-05 - accuracy: 1.0000 - val_loss: 0.0904 - val_accuracy: 0.9754
#
# Epoch 00061: val_loss did not improve from 0.08639
# Epoch 62/75
# 25/25 [==============================] - 1993s 82s/step - loss: 3.2261e-05 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9743
#
# Epoch 00062: val_loss did not improve from 0.08639
# Epoch 63/75
# 25/25 [==============================] - 1731s 71s/step - loss: 3.6745e-05 - accuracy: 1.0000 - val_loss: 0.0897 - val_accuracy: 0.9768
#
# Epoch 00063: val_loss did not improve from 0.08639
# Epoch 64/75
# 25/25 [==============================] - 1852s 77s/step - loss: 3.8015e-05 - accuracy: 1.0000 - val_loss: 0.0946 - val_accuracy: 0.9763
#
# Epoch 00064: val_loss did not improve from 0.08639
# Epoch 65/75
# 25/25 [==============================] - 1865s 77s/step - loss: 2.0368e-05 - accuracy: 1.0000 - val_loss: 0.1037 - val_accuracy: 0.9748
#
# Epoch 00065: val_loss did not improve from 0.08639
# Epoch 66/75
# 25/25 [==============================] - 1711s 71s/step - loss: 5.4315e-05 - accuracy: 1.0000 - val_loss: 0.0939 - val_accuracy: 0.9741
#
# Epoch 00066: val_loss did not improve from 0.08639
# Epoch 67/75
# 25/25 [==============================] - 1989s 82s/step - loss: 2.2447e-05 - accuracy: 1.0000 - val_loss: 0.0950 - val_accuracy: 0.9741
#
# Epoch 00067: val_loss did not improve from 0.08639
# Epoch 68/75
# 25/25 [==============================] - 1711s 71s/step - loss: 5.1891e-05 - accuracy: 1.0000 - val_loss: 0.0930 - val_accuracy: 0.9750
#
# Epoch 00068: val_loss did not improve from 0.08639
# Epoch 69/75
# 25/25 [==============================] - 1990s 82s/step - loss: 2.6829e-05 - accuracy: 1.0000 - val_loss: 0.0961 - val_accuracy: 0.9739
#
# Epoch 00069: val_loss did not improve from 0.08639
# Epoch 70/75
# 25/25 [==============================] - 1722s 71s/step - loss: 2.0818e-05 - accuracy: 1.0000 - val_loss: 0.0973 - val_accuracy: 0.9748
#
# Epoch 00070: val_loss did not improve from 0.08639
# Epoch 71/75
# 25/25 [==============================] - 1878s 78s/step - loss: 6.5661e-05 - accuracy: 1.0000 - val_loss: 0.0958 - val_accuracy: 0.9746
#
# Epoch 00071: val_loss did not improve from 0.08639
# Epoch 72/75
# 25/25 [==============================] - 1839s 76s/step - loss: 2.1180e-05 - accuracy: 1.0000 - val_loss: 0.1013 - val_accuracy: 0.9726
#
# Epoch 00072: val_loss did not improve from 0.08639
# Epoch 73/75
# 25/25 [==============================] - 1734s 72s/step - loss: 3.7089e-05 - accuracy: 1.0000 - val_loss: 0.0977 - val_accuracy: 0.9738
#
# Epoch 00073: val_loss did not improve from 0.08639
# Epoch 74/75
# 25/25 [==============================] - 1974s 82s/step - loss: 2.9790e-05 - accuracy: 1.0000 - val_loss: 0.0958 - val_accuracy: 0.9735
#
# Epoch 00074: val_loss did not improve from 0.08639
# Epoch 75/75
# 25/25 [==============================] - 1718s 71s/step - loss: 2.4186e-05 - accuracy: 1.0000 - val_loss: 0.0926 - val_accuracy: 0.9760
#
# Epoch 00075: val_loss did not improve from 0.08639
# INFO:tensorflow:Assets written to: model/xRGM1.6/assets
# CPU times: user 10d 16h 43min 41s, sys: 9h 33min 10s, total: 11d 2h 16min 51s
# Wall time: 1d 19h 26min 27s

# %%
# %%time
confusion_matrix = pd.DataFrame(metrics.confusion_matrix(y_test, v_classify(y_pred)),
                                columns=['Predicted Negative', 'Predicted Positive'],
                                index=['Actual Negative', 'Actual Positive'])

tp, tn, fp, fn = (
    confusion_matrix.iloc[1,1], 
    confusion_matrix.iloc[0,0], 
    confusion_matrix.iloc[0,1], 
    confusion_matrix.iloc[1,0]
)

accuracy = (tp + tn) / (tp + tn + fp + fn)
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
f1_score = 2 * ((specificity * sensitivity) / (specificity + sensitivity))

with open(os.path.join(f'{model_dir}', 'metrics.csv'), 'a', encoding='utf-8') as f:
    f.write(
        f'{time.strftime("%Y-%m-%dT%H:%M:%S-05:00", time.localtime())}, {accuracy}, {sensitivity}, {specificity}, {f1_score}\n'
    )

print(f'Accuracy:    {accuracy}')
print(f'Sensitivity: {sensitivity}')
print(f'Specificity: {specificity}')
print(f'F1 Score:    {f1_score}')
print('\n')
print(confusion_matrix)
# Out:
# Accuracy:    0.9742351046698873
# Sensitivity: 0.9580645161290322
# Specificity: 0.9903536977491961
# F1 Score:    0.9739415588218071
#
#
#                  Predicted Negative  Predicted Positive
# Actual Negative                 308                   3
# Actual Positive                  13                 297
# CPU times: user 20.2 ms, sys: 691 µs, total: 20.9 ms
# Wall time: 29.5 ms

# %%
disease_types=['COVID', 'non-COVID']
Y_pred = np.argmax(y_pred)
Y_true = np.argmax(y_test)

plt.figure(figsize=(7, 7))
ax = sns.heatmap(confusion_matrix , cmap=plt.cm.GnBu , 
                 annot=True, fmt='d',square=True, xticklabels=disease_types, 
                 yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
plt.show()

# %%
def plot_model_history(model_history):
   fig, axs = plt.subplots(1,2,figsize=(15,5))
   # summarize history for accuracy
   axs[0].plot(range(1, len(model_history['accuracy']) + 1), model_history['accuracy'])
   axs[0].plot(range(1, len(model_history['val_accuracy']) + 1), model_history['val_accuracy'])
   axs[0].set_title('Model Accuracy')
   axs[0].set_ylabel('Accuracy')
   axs[0].set_xlabel('Epoch')
   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
   axs[0].legend(['train', 'val'], loc='best')
   # summarize history for loss
   axs[1].plot(range(1, len(model_history['loss'])+1), model_history['loss'])
   axs[1].plot(range(1, len(model_history['val_loss']) + 1), model_history['val_loss'])
   axs[1].set_title('Model Loss')
   axs[1].set_ylabel('Loss')
   axs[1].set_xlabel('Epoch')
   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
   axs[1].legend(['train', 'val'], loc='best')
   plt.show()

# %%
with open(os.path.join('models', 'xRGM1.6-Net-HistDict'), 'rb') as f:
    history = pickle.load(f)
    
plot_model_history(history)
# Out:
# <ipython-input-23-25025fac5012>:9: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
# <ipython-input-23-25025fac5012>:17: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
