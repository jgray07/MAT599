# %%
import glob
import json
import os
import pickle
import random
import traceback
from typing import Tuple

import numpy as np
import pandas as pd
import seaborn as sns
from keras.models import Sequential, load_model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Lambda, LeakyReLU, AveragePooling2D, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from matplotlib import pyplot as plt
from matplotlib.pyplot import hist
from PIL import Image
from scipy.stats import zscore
from sklearn import metrics
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %%
import csv
import time

# %% [markdown]
# ## Config & Constants

# %%
IMAGE_WIDTH, IMAGE_HEIGHT = 227, 227
random.seed(52)

# %% [markdown]
# ## Methods

# %% [markdown]
# ### Image Utilities

# %%
def batch_generator(input_data, output_data, batch_size, is_training):
    input_data_batch = np.empty([batch_size, IMAGE_HEIGHT, IMAGE_WIDTH, 1])
    output_data_batch = np.empty([batch_size, 1])
    while True:
        index = 0
        for i in np.random.permutation(input_data.shape[0]):
            input_data_batch[index] = input_data[i]
            output_data_batch[index] = output_data[i]
            index += 1
            if index == batch_size:
                break
        yield input_data_batch, output_data_batch


def _preprocess(image_loc: str) -> np.ndarray:
    f_image = Image.open(image_loc).convert('L')
    f_image = f_image.resize((IMAGE_WIDTH, IMAGE_HEIGHT), Image.ANTIALIAS)
    image = np.asarray(f_image)
    image = np.expand_dims(image, axis=0)
    image = np.expand_dims(image, axis=3)
    return image


def preprocess(loc: str) -> np.ndarray:
    """Safety wrapper over _preprocess.
    
    Args:
        loc: File location to check if dir or an image.
        
    Returns:
        Preprocessed image(s) as an ndarray.
    """
    if os.path.isdir(loc):
        current = np.concatenate((
            [_preprocess(os.path.join(loc, image)) for image in os.listdir(loc)
             if '.png' in image]
        ))
    else:
        current = _preprocess(loc)
    return current


def generate_data_arrays(
    covid_data: str = 'rsc/New_Data_CoV2/COVID/',
    noncovid_data: str = 'rsc/New_Data_CoV2/non-COVID/',
    others_data:  str = 'rsc/New_Data_CoV2/Others/',
    image_output: str = 'rsc/input_data_v2',
    label_output: str = 'rsc/output_data_v2',
    regenerate: bool = True
) -> Tuple[np.ndarray, np.ndarray]:
    """Loads COVID images into ndarrays.
    
    Args:
        covid_data: Relative path to folder containing COVID images.
        noncovid_data: Relative path to folder containing non-COVID images.
        others_data: Relative path to folder containing Others images.
        image_output: Relative path (with filename) to save loaded images to.
        label_output: Relative path (with filename) to save loaded classes (labels) to.
        regenerate: If True, will regenerate saved ndarray files for both image_output
            and label_output, even if they already exist (overwriting them). If False,
            will simply load and return the aforementioned.
        
    Returns:
        Tuple of ndarrays. The first is the loaded image data in one large ndarray,
        and the second is the loaded labels, also in a large ndarray. These directly
        match up to each other ONLY when both arrays (and their respective files)
        are generated at the same time with this method.
    """
    if (regenerate is False and 
        os.path.isfile(f'{out_input_data}.npy') and
        os.path.isfile(f'{out_output_data}.npy')):
        return (np.load(f'{out_input_data}.npy'),
                np.load(f'{out_output_data}.npy'))
    
    if not ((cd := os.path.exists(covid_data)) and (ncd := os.path.exists(noncovid_data))):
        if (others_data is not None) and not (odd := os.path.exists(others_data)):
            raise NotADirectoryError("Directories do not exist.")
        else:
            raise NotADirectoryError("COVID/non-COVID directories do not exist.")
    
    im_data = np.empty([1, IMAGE_WIDTH, IMAGE_WIDTH, 1])
    output = np.array([0])

    print('Loading Covid Data')
    for i in tqdm(glob.glob(os.path.join(covid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([1])), axis=0)

    print('Loading non-Covid Data')
    for i in tqdm(glob.glob(os.path.join(noncovid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([0])), axis=0)
        
    if others_data is not None:
        print('Loading Others Data')
        for i in tqdm(glob.glob(os.path.join(others_data, '**'))):
            current = preprocess(i)
            im_data = np.concatenate((im_data, current))
            output = np.concatenate((output, np.array([-1])), axis=0)
    else:
        print('Others data not provided; skipping.')


    print('Finished Loading Data')
    im_data = np.delete(im_data, 0, axis=0)
    output = np.delete(output, 0, axis=0)

    zip_data = list(zip(im_data, output))
    random.shuffle(zip_data)
    im_data, output = zip(*zip_data)

    np.save(f'{image_output}', im_data)
    np.save(f'{label_output}', output)
    return im_data, output


def load_data(image_loc: str, label_loc: str, **kwargs) -> Tuple[np.ndarray, np.ndarray]:
    """Attempts to load generated images and labels.
    
    If either is not found, attempts to (re)generate them using the default
    input arguments to the generation method for the raw data, but the input
    `image_loc` and `label_loc` parameters for the output arrays. If this
    still does not work, returns a general error and exits.
    
    Args:
        image_loc: Relative path to saved image ndarray file.
        label_loc: Relative path to saved label ndarray file.
        
    Returns:
        Tuple of ndarrays. The first array holds the loaded image data, whilst
        the second array holds their respective labels.
    
    """
    try:
        image_data = np.load(f'{image_loc}.npy')
        label_data = np.load(f'{label_loc}.npy')
        return image_data, label_data
    
    except FileNotFoundError:
        try:
            image_data, label_data = generate_data_arrays(
                image_output = image_loc,
                label_output = label_loc,
                **kwargs
            )
            return image_data, label_data
        
        except Exception as e:
            traceback.print_exc()

# %% [markdown]
# ## Model Playground

# %%
#Version 1
im_data_v4, output_v4 = load_data(
    image_loc = 'rsc/input_data_v4',
    label_loc = 'rsc/output_data_v4',
    covid_data = 'rsc/New_Data_CoV2/Covid/',
    noncovid_data = 'rsc/New_Data_CoV2/Non-Covid/',
    others_data = None,
)

x_train, x_test, y_train, y_test = train_test_split(im_data_v4, output_v4, random_state=42)

# %%
def make_model(X_Train, Y_Train, X_Test, Y_Test, model_dir: str):
    if not os.path.exists(model_dir):
        os.makedirs(model_dir)
    #X_Train, X_Test, Y_Train, Y_Test = train_test_split(input_data, output_data, test_size=0.1)

    for_pad = lambda s: s if s > 2 else 3

    model = Sequential()
    model.add(Lambda(lambda x: x, input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 1)))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=8, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))



    #model.add(ZeroPadding2D(padding=(for_pad(19) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(Conv2D(kernel_size=(3, 3), filters=2, strides=(1, 1),activation='relu'))

    model.add(Flatten())

    model.add(Dropout(rate=0.4))
    model.add(Dense(units=338, activation='relu'))
    model.add(Dense(units=1, activation='sigmoid'))

    model.compile(optimizer=Adam(lr=3e-4), loss='binary_crossentropy', metrics=["accuracy"])
    model.summary()

    checkpoint = ModelCheckpoint(os.path.join(model_dir, 'xRGM3.2'), verbose=1, period=1, save_best_only=True)

    hist = model.fit_generator(batch_generator(X_Train, Y_Train, 128, True),
                        validation_data=(batch_generator(X_Test, Y_Test, 128, False)), callbacks=[checkpoint],
                        verbose=1, epochs=75, steps_per_epoch=25, validation_steps=len(X_Test))

    with open(os.path.join('models', 'xRGM3.2-Net-HistDict'), 'wb') as f:
        pickle.dump(hist.history, f)

    model.save(model_dir)
    
    return model
#covid vs noncovid

# %%
# %%time
model_dir: str = 'model/xRGM3.2'
xRGM = make_model(x_train, y_train.reshape(-1,1), x_test, y_test.reshape(-1,1), model_dir=model_dir)

v_classify = np.vectorize(lambda x: np.round(x, 0))
# xRGMCT2 = load_model('models/xRGMCT2L.h5')
# print(xRGMCT2.history)
y_pred = (xRGM.predict(x_test))

#print(y_test)
#print(y_pred)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda (Lambda)              (None, 227, 227, 1)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 225, 225, 8)       80
# _________________________________________________________________
# batch_normalization (BatchNo (None, 225, 225, 8)       32
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 225, 225, 8)       0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 110, 110, 16)      1168
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 110, 110, 16)      64
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 110, 110, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 108, 108, 32)      4640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 108, 108, 32)      128
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 108, 108, 32)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 108, 108, 16)      528
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 108, 108, 16)      64
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 108, 108, 16)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 106, 106, 32)      4640
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 106, 106, 32)      128
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 106, 106, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 104, 104, 64)      18496
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 104, 104, 64)      256
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 104, 104, 64)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 104, 104, 32)      2080
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 104, 104, 32)      128
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 104, 104, 32)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 102, 102, 64)      18496
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 102, 102, 64)      256
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 102, 102, 64)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 100, 100, 128)     73856
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 100, 100, 128)     512
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 100, 100, 128)     0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 100, 100, 64)      8256
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 100, 100, 64)      256
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 98, 98, 128)       73856
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 98, 98, 128)       512
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 98, 98, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 49, 49, 128)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 47, 47, 256)       295168
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 47, 47, 256)       1024
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 47, 47, 256)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 47, 47, 128)       32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 47, 47, 128)       512
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 47, 47, 128)       0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 23, 23, 128)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 21, 21, 256)       295168
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 21, 21, 256)       1024
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 21, 21, 256)       0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 10, 10, 256)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 10, 10, 128)       32896
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 8, 8, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 338)               5538130
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 339
# =================================================================
# Total params: 6,702,293
# Trainable params: 6,699,077
# Non-trainable params: 3,216
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# /home/jg1994/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/75
# 25/25 [==============================] - 1522s 61s/step - loss: 0.4995 - accuracy: 0.8252 - val_loss: nan - val_accuracy: 0.7266
#
# Epoch 00001: val_loss did not improve from inf
# Epoch 2/75
# 25/25 [==============================] - 1527s 62s/step - loss: 5.9127e-04 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7344
#
# Epoch 00002: val_loss did not improve from inf
# Epoch 3/75
# 25/25 [==============================] - 1651s 67s/step - loss: 1.2344e-04 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7344
#
# Epoch 00003: val_loss did not improve from inf
# Epoch 4/75
# 25/25 [==============================] - 1657s 67s/step - loss: 7.3832e-05 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6719
#
# Epoch 00004: val_loss did not improve from inf
# Epoch 5/75
# 25/25 [==============================] - 1340s 54s/step - loss: 5.5451e-05 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6094
#
# Epoch 00005: val_loss did not improve from inf
# Epoch 6/75
# 25/25 [==============================] - 1345s 55s/step - loss: 4.8473e-05 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.3125
#
# Epoch 00006: val_loss did not improve from inf
# Epoch 7/75
# 25/25 [==============================] - 1358s 55s/step - loss: 3.3703e-05 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.2891
#
# Epoch 00007: val_loss did not improve from inf
# Epoch 8/75
# 25/25 [==============================] - 1229s 50s/step - loss: 2.9860e-05 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.3516
#
# Epoch 00008: val_loss did not improve from inf
# Epoch 9/75
# 25/25 [==============================] - 1176s 48s/step - loss: 2.7971e-05 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.3672
#
# Epoch 00009: val_loss did not improve from inf
# Epoch 10/75
# 25/25 [==============================] - 1360s 55s/step - loss: 2.3108e-05 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.5391
#
# Epoch 00010: val_loss did not improve from inf
# Epoch 11/75
# 25/25 [==============================] - 1357s 55s/step - loss: 2.3693e-05 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.5859
#
# Epoch 00011: val_loss did not improve from inf
# Epoch 12/75
# 25/25 [==============================] - 1057s 42s/step - loss: 1.9593e-05 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.5938
#
# Epoch 00012: val_loss did not improve from inf
# Epoch 13/75
# 25/25 [==============================] - 1352s 55s/step - loss: 1.5628e-05 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6172
#
# Epoch 00013: val_loss did not improve from inf
# Epoch 14/75
# 25/25 [==============================] - 1356s 55s/step - loss: 1.5714e-05 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6250
#
# Epoch 00014: val_loss did not improve from inf
# Epoch 15/75
# 25/25 [==============================] - 1236s 50s/step - loss: 1.4516e-05 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6562
#
# Epoch 00015: val_loss did not improve from inf
# Epoch 16/75
# 25/25 [==============================] - 1158s 47s/step - loss: 1.3276e-05 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6641
#
# Epoch 00016: val_loss did not improve from inf
# Epoch 17/75
# 25/25 [==============================] - 1356s 55s/step - loss: 1.1464e-05 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6641
#
# Epoch 00017: val_loss did not improve from inf
# Epoch 18/75
# 25/25 [==============================] - 1358s 55s/step - loss: 1.1027e-05 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6719
#
# Epoch 00018: val_loss did not improve from inf
# Epoch 19/75
# 25/25 [==============================] - 1053s 42s/step - loss: 9.1351e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6797
#
# Epoch 00019: val_loss did not improve from inf
# Epoch 20/75
# 25/25 [==============================] - 1345s 55s/step - loss: 1.0960e-05 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6797
#
# Epoch 00020: val_loss did not improve from inf
# Epoch 21/75
# 25/25 [==============================] - 1351s 55s/step - loss: 8.3792e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6719
#
# Epoch 00021: val_loss did not improve from inf
# Epoch 22/75
# 25/25 [==============================] - 1251s 50s/step - loss: 7.8532e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6719
#
# Epoch 00022: val_loss did not improve from inf
# Epoch 23/75
# 25/25 [==============================] - 1140s 46s/step - loss: 8.3340e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6719
#
# Epoch 00023: val_loss did not improve from inf
# Epoch 24/75
# 25/25 [==============================] - 1356s 55s/step - loss: 7.4107e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6719
#
# Epoch 00024: val_loss did not improve from inf
# Epoch 25/75
# 25/25 [==============================] - 1358s 55s/step - loss: 6.4159e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6719
#
# Epoch 00025: val_loss did not improve from inf
# Epoch 26/75
# 25/25 [==============================] - 1073s 43s/step - loss: 6.0415e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6719
#
# Epoch 00026: val_loss did not improve from inf
# Epoch 27/75
# 25/25 [==============================] - 1329s 54s/step - loss: 6.2295e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6719
#
# Epoch 00027: val_loss did not improve from inf
# Epoch 28/75
# 25/25 [==============================] - 1358s 55s/step - loss: 5.5155e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6719
#
# Epoch 00028: val_loss did not improve from inf
# Epoch 29/75
# 25/25 [==============================] - 1263s 51s/step - loss: 5.5296e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6719
#
# Epoch 00029: val_loss did not improve from inf
# Epoch 30/75
# 25/25 [==============================] - 1139s 46s/step - loss: 5.1931e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6719
#
# Epoch 00030: val_loss did not improve from inf
# Epoch 31/75
# 25/25 [==============================] - 1349s 55s/step - loss: 4.8482e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6719
#
# Epoch 00031: val_loss did not improve from inf
# Epoch 32/75
# 25/25 [==============================] - 1359s 55s/step - loss: 4.6193e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6719
#
# Epoch 00032: val_loss did not improve from inf
# Epoch 33/75
# 25/25 [==============================] - 1077s 43s/step - loss: 4.5213e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6719
#
# Epoch 00033: val_loss did not improve from inf
# Epoch 34/75
# 25/25 [==============================] - 1312s 53s/step - loss: 3.9851e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6719
#
# Epoch 00034: val_loss did not improve from inf
# Epoch 35/75
# 25/25 [==============================] - 1355s 55s/step - loss: 4.3246e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6719
#
# Epoch 00035: val_loss did not improve from inf
# Epoch 36/75
# 25/25 [==============================] - 1286s 52s/step - loss: 3.4199e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6797
#
# Epoch 00036: val_loss did not improve from inf
# Epoch 37/75
# 25/25 [==============================] - 1114s 45s/step - loss: 3.4014e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6875
#
# Epoch 00037: val_loss did not improve from inf
# Epoch 38/75
# 25/25 [==============================] - 1352s 55s/step - loss: 3.3645e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6875
#
# Epoch 00038: val_loss did not improve from inf
# Epoch 39/75
# 25/25 [==============================] - 1355s 55s/step - loss: 3.4338e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6797
#
# Epoch 00039: val_loss did not improve from inf
# Epoch 40/75
# 25/25 [==============================] - 1098s 44s/step - loss: 2.9406e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6797
#
# Epoch 00040: val_loss did not improve from inf
# Epoch 41/75
# 25/25 [==============================] - 1303s 53s/step - loss: 2.9121e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6875
#
# Epoch 00041: val_loss did not improve from inf
# Epoch 42/75
# 25/25 [==============================] - 1361s 55s/step - loss: 2.9606e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6875
#
# Epoch 00042: val_loss did not improve from inf
# Epoch 43/75
# 25/25 [==============================] - 1297s 52s/step - loss: 2.7021e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6875
#
# Epoch 00043: val_loss did not improve from inf
# Epoch 44/75
# 25/25 [==============================] - 1117s 45s/step - loss: 2.5064e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6797
#
# Epoch 00044: val_loss did not improve from inf
# Epoch 45/75
# 25/25 [==============================] - 1359s 55s/step - loss: 2.3698e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6797
#
# Epoch 00045: val_loss did not improve from inf
# Epoch 46/75
# 25/25 [==============================] - 1360s 55s/step - loss: 2.4151e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6797
#
# Epoch 00046: val_loss did not improve from inf
# Epoch 47/75
# 25/25 [==============================] - 1105s 44s/step - loss: 2.4524e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6875
#
# Epoch 00047: val_loss did not improve from inf
# Epoch 48/75
# 25/25 [==============================] - 1286s 52s/step - loss: 2.3311e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6875
#
# Epoch 00048: val_loss did not improve from inf
# Epoch 49/75
# 25/25 [==============================] - 1354s 55s/step - loss: 2.4341e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6797
#
# Epoch 00049: val_loss did not improve from inf
# Epoch 50/75
# 25/25 [==============================] - 1323s 53s/step - loss: 2.0664e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6953
#
# Epoch 00050: val_loss did not improve from inf
# Epoch 51/75
# 25/25 [==============================] - 1091s 44s/step - loss: 1.9179e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6953
#
# Epoch 00051: val_loss did not improve from inf
# Epoch 52/75
# 25/25 [==============================] - 1354s 55s/step - loss: 1.9144e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6953
#
# Epoch 00052: val_loss did not improve from inf
# Epoch 53/75
# 25/25 [==============================] - 1356s 55s/step - loss: 2.1478e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7031
#
# Epoch 00053: val_loss did not improve from inf
# Epoch 54/75
# 25/25 [==============================] - 1125s 45s/step - loss: 1.7381e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7031
#
# Epoch 00054: val_loss did not improve from inf
# Epoch 55/75
# 25/25 [==============================] - 1283s 52s/step - loss: 1.7791e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7031
#
# Epoch 00055: val_loss did not improve from inf
# Epoch 56/75
# 25/25 [==============================] - 1361s 55s/step - loss: 1.7802e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.6953
#
# Epoch 00056: val_loss did not improve from inf
# Epoch 57/75
# 25/25 [==============================] - 1327s 54s/step - loss: 1.7245e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7031
#
# Epoch 00057: val_loss did not improve from inf
# Epoch 58/75
# 25/25 [==============================] - 1085s 44s/step - loss: 1.6089e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7031
#
# Epoch 00058: val_loss did not improve from inf
# Epoch 59/75
# 25/25 [==============================] - 1359s 55s/step - loss: 1.6028e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7031
#
# Epoch 00059: val_loss did not improve from inf
# Epoch 60/75
# 25/25 [==============================] - 1358s 55s/step - loss: 1.5494e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7031
#
# Epoch 00060: val_loss did not improve from inf
# Epoch 61/75
# 25/25 [==============================] - 1131s 45s/step - loss: 1.3754e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7031
#
# Epoch 00061: val_loss did not improve from inf
# Epoch 62/75
# 25/25 [==============================] - 1272s 52s/step - loss: 1.3941e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7031
#
# Epoch 00062: val_loss did not improve from inf
# Epoch 63/75
# 25/25 [==============================] - 1360s 55s/step - loss: 1.3134e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7031
#
# Epoch 00063: val_loss did not improve from inf
# Epoch 64/75
# 25/25 [==============================] - 1337s 54s/step - loss: 1.1798e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7031
#
# Epoch 00064: val_loss did not improve from inf
# Epoch 65/75
# 25/25 [==============================] - 1079s 44s/step - loss: 1.4556e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7109
#
# Epoch 00065: val_loss did not improve from inf
# Epoch 66/75
# 25/25 [==============================] - 1359s 55s/step - loss: 1.2178e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7109
#
# Epoch 00066: val_loss did not improve from inf
# Epoch 67/75
# 25/25 [==============================] - 1355s 55s/step - loss: 1.2120e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7109
#
# Epoch 00067: val_loss did not improve from inf
# Epoch 68/75
# 25/25 [==============================] - 1141s 46s/step - loss: 1.3349e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7109
#
# Epoch 00068: val_loss did not improve from inf
# Epoch 69/75
# 25/25 [==============================] - 1262s 51s/step - loss: 1.1762e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7109
#
# Epoch 00069: val_loss did not improve from inf
# Epoch 70/75
# 25/25 [==============================] - 1358s 55s/step - loss: 1.3031e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7109
#
# Epoch 00070: val_loss did not improve from inf
# Epoch 71/75
# 25/25 [==============================] - 1351s 55s/step - loss: 1.1302e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7109
#
# Epoch 00071: val_loss did not improve from inf
# Epoch 72/75
# 25/25 [==============================] - 1069s 43s/step - loss: 1.2090e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7109
#
# Epoch 00072: val_loss did not improve from inf
# Epoch 73/75
# 25/25 [==============================] - 1359s 55s/step - loss: 1.0528e-06 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7109
#
# Epoch 00073: val_loss did not improve from inf
# Epoch 74/75
# 25/25 [==============================] - 1352s 55s/step - loss: 9.5818e-07 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7109
#
# Epoch 00074: val_loss did not improve from inf
# Epoch 75/75
# 25/25 [==============================] - 1146s 46s/step - loss: 9.7372e-07 - accuracy: 1.0000 - val_loss: nan - val_accuracy: 0.7109
#
# Epoch 00075: val_loss did not improve from inf
# INFO:tensorflow:Assets written to: model/xRGM3.2/assets
# CPU times: user 4d 14h 41min 42s, sys: 3h 12min 28s, total: 4d 17h 54min 10s
# Wall time: 1d 2h 49min 47s

# %%
confusion_matrix = pd.DataFrame(metrics.confusion_matrix(y_test, v_classify(y_pred)),
                                columns=['Predicted Negative', 'Predicted Positive'],
                                index=['Actual Negative', 'Actual Positive'])

tp, tn, fp, fn = (
    confusion_matrix.iloc[1,1], 
    confusion_matrix.iloc[0,0], 
    confusion_matrix.iloc[0,1], 
    confusion_matrix.iloc[1,0]
)

accuracy = (tp + tn) / (tp + tn + fp + fn)
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
f1_score = 2 * ((specificity * sensitivity) / (specificity + sensitivity))

with open(os.path.join(f'{model_dir}', 'metrics.csv'), 'a', encoding='utf-8') as f:
    f.write(
        f'{time.strftime("%Y-%m-%dT%H:%M:%S-05:00", time.localtime())}, {accuracy}, {sensitivity}, {specificity}, {f1_score}\n'
    )

print(f'Accuracy:    {accuracy}')
print(f'Sensitivity: {sensitivity}')
print(f'Specificity: {specificity}')
print(f'F1 Score:    {f1_score}')
print('\n')
print(confusion_matrix)
# Out:
# Accuracy:    0.9811320754716981
# Sensitivity: 0.9411764705882353
# Specificity: 1.0
# F1 Score:    0.9696969696969697
#
#
#                  Predicted Negative  Predicted Positive
# Actual Negative                  36                   0
# Actual Positive                   1                  16

# %%
disease_types=['COVID', 'non-COVID']
Y_pred = np.argmax(y_pred)
Y_true = np.argmax(y_test)

plt.figure(figsize=(7, 7))
ax = sns.heatmap(confusion_matrix , cmap=plt.cm.GnBu , 
                 annot=True, fmt='d',square=True, xticklabels=disease_types, 
                 yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
plt.show()

# %%
def plot_model_history(model_history):
   fig, axs = plt.subplots(1,2,figsize=(15,5))
   # summarize history for accuracy
   axs[0].plot(range(1, len(model_history['accuracy']) + 1), model_history['accuracy'])
   axs[0].plot(range(1, len(model_history['val_accuracy']) + 1), model_history['val_accuracy'])
   axs[0].set_title('Model Accuracy')
   axs[0].set_ylabel('Accuracy')
   axs[0].set_xlabel('Epoch')
   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
   axs[0].legend(['train', 'val'], loc='best')
   # summarize history for loss
   axs[1].plot(range(1, len(model_history['loss'])+1), model_history['loss'])
   axs[1].plot(range(1, len(model_history['val_loss']) + 1), model_history['val_loss'])
   axs[1].set_title('Model Loss')
   axs[1].set_ylabel('Loss')
   axs[1].set_xlabel('Epoch')
   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
   axs[1].legend(['train', 'val'], loc='best')
   plt.show()

# %%
with open(os.path.join('models', 'xRGM3.2-Net-HistDict'), 'rb') as f:
    history = pickle.load(f)
    
plot_model_history(history)
# Out:
# <ipython-input-12-25025fac5012>:9: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
# <ipython-input-12-25025fac5012>:17: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
