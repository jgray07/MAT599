# %%
import glob
import json
import os
import pickle
import random
import traceback
from typing import Tuple

import cv2 as cv
import numpy as np
import pandas as pd
import seaborn as sns
from keras.models import Sequential, load_model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Lambda, LeakyReLU, AveragePooling2D, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from matplotlib import pyplot as plt
from matplotlib.pyplot import hist
from PIL import Image
from scipy.stats import zscore
from sklearn import metrics
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %%
import csv
import time

# %% [markdown]
# ## Config & Constants

# %%
IMAGE_WIDTH, IMAGE_HEIGHT = 227, 227
random.seed(52)

# %% [markdown]
# ## Methods

# %% [markdown]
# ### Image Utilities

# %%
def batch_generator(input_data, output_data, batch_size, is_training):
    input_data_batch = np.empty([batch_size, IMAGE_HEIGHT, IMAGE_WIDTH, 1])
    output_data_batch = np.empty([batch_size, 1])
    while True:
        index = 0
        for i in np.random.permutation(input_data.shape[0]):
            input_data_batch[index] = input_data[i]
            output_data_batch[index] = output_data[i]
            index += 1
            if index == batch_size:
                break
        yield input_data_batch, output_data_batch


def _preprocess(image_loc: str) -> np.ndarray:
    f_image = Image.open(image_loc).convert('L')
    f_image = f_image.resize((IMAGE_WIDTH, IMAGE_HEIGHT), Image.ANTIALIAS)
    image = np.asarray(f_image)
    image = np.expand_dims(image, axis=0)
    image = np.expand_dims(image, axis=3)
    return image


def preprocess(loc: str) -> np.ndarray:
    """Safety wrapper over _preprocess.
    
    Args:
        loc: File location to check if dir or an image.
        
    Returns:
        Preprocessed image(s) as an ndarray.
    """
    if os.path.isdir(loc):
        current = np.concatenate((
            [_preprocess(os.path.join(loc, image)) for image in os.listdir(loc)
             if '.png' in image]
        ))
    else:
        current = _preprocess(loc)
    return current


def generate_data_arrays(
    covid_data: str = 'rsc/New_Data_CoV2/COVID/',
    noncovid_data: str = 'rsc/New_Data_CoV2/non-COVID/',
    others_data:  str = 'rsc/New_Data_CoV2/Others/',
    image_output: str = 'rsc/input_data_v2',
    label_output: str = 'rsc/output_data_v2',
    regenerate: bool = True
) -> Tuple[np.ndarray, np.ndarray]:
    """Loads COVID images into ndarrays.
    
    Args:
        covid_data: Relative path to folder containing COVID images.
        noncovid_data: Relative path to folder containing non-COVID images.
        others_data: Relative path to folder containing Others images.
        image_output: Relative path (with filename) to save loaded images to.
        label_output: Relative path (with filename) to save loaded classes (labels) to.
        regenerate: If True, will regenerate saved ndarray files for both image_output
            and label_output, even if they already exist (overwriting them). If False,
            will simply load and return the aforementioned.
        
    Returns:
        Tuple of ndarrays. The first is the loaded image data in one large ndarray,
        and the second is the loaded labels, also in a large ndarray. These directly
        match up to each other ONLY when both arrays (and their respective files)
        are generated at the same time with this method.
    """
    if (regenerate is False and 
        os.path.isfile(f'{out_input_data}.npy') and
        os.path.isfile(f'{out_output_data}.npy')):
        return (np.load(f'{out_input_data}.npy'),
                np.load(f'{out_output_data}.npy'))
    
    if not ((cd := os.path.exists(covid_data)) and (ncd := os.path.exists(noncovid_data))):
        if (others_data is not None) and not (odd := os.path.exists(others_data)):
            raise NotADirectoryError("Directories do not exist.")
        else:
            raise NotADirectoryError("COVID/non-COVID directories do not exist.")
    
    im_data = np.empty([1, IMAGE_WIDTH, IMAGE_WIDTH, 1])
    output = np.array([0])

    print('Loading Covid Data')
    for i in tqdm(glob.glob(os.path.join(covid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([1])), axis=0)

    print('Loading non-Covid Data')
    for i in tqdm(glob.glob(os.path.join(noncovid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([0])), axis=0)
        
    if others_data is not None:
        print('Loading Others Data')
        for i in tqdm(glob.glob(os.path.join(others_data, '**'))):
            current = preprocess(i)
            im_data = np.concatenate((im_data, current))
            output = np.concatenate((output, np.array([-1])), axis=0)
    else:
        print('Others data not provided; skipping.')


    print('Finished Loading Data')
    im_data = np.delete(im_data, 0, axis=0)
    output = np.delete(output, 0, axis=0)

    zip_data = list(zip(im_data, output))
    random.shuffle(zip_data)
    im_data, output = zip(*zip_data)

    np.save(f'{image_output}', im_data)
    np.save(f'{label_output}', output)
    return im_data, output


def load_data(image_loc: str, label_loc: str, **kwargs) -> Tuple[np.ndarray, np.ndarray]:
    """Attempts to load generated images and labels.
    
    If either is not found, attempts to (re)generate them using the default
    input arguments to the generation method for the raw data, but the input
    `image_loc` and `label_loc` parameters for the output arrays. If this
    still does not work, returns a general error and exits.
    
    Args:
        image_loc: Relative path to saved image ndarray file.
        label_loc: Relative path to saved label ndarray file.
        
    Returns:
        Tuple of ndarrays. The first array holds the loaded image data, whilst
        the second array holds their respective labels.
    
    """
    try:
        image_data = np.load(f'{image_loc}.npy')
        label_data = np.load(f'{label_loc}.npy')
        return image_data, label_data
    
    except FileNotFoundError:
        try:
            image_data, label_data = generate_data_arrays(
                image_output = image_loc,
                label_output = label_loc,
                **kwargs
            )
            return image_data, label_data
        
        except Exception as e:
            traceback.print_exc()

# %% [markdown]
# ## Model Playground

# %%
import os
from skimage import io

# our folder path containing some images
folder_path = 'rsc/Data_CoV2/COVID'

# loop on all files of the folder and build a list of files paths
images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
i: int = 0
for image_path in images:
    img = cv.imread(image_path)
    grayimg = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    clahe = cv.createCLAHE()
    cl_img = clahe.apply(grayimg)
    ret, thresh = cv.threshold(cl_img, 0, 255,
                             cv.THRESH_BINARY + cv.THRESH_OTSU)
    
    new_file_path = f"rsc/CLAHET_Data_CoV2/COVID/augmented_image_{i}.jpg"
    cv.imwrite(new_file_path, thresh)
    i += 1

# %%
# our folder path containing some images
folder_path = 'rsc/Data_CoV2/non-COVID'

# loop on all files of the folder and build a list of files paths
images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
i: int = 0
for image_path in images:
    img = cv.imread(image_path)
    grayimg = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    clahe = cv.createCLAHE()
    cl_img = clahe.apply(grayimg)
    ret, thresh = cv.threshold(cl_img, 0, 255,
                             cv.THRESH_BINARY + cv.THRESH_OTSU)
    
    new_file_path = f"rsc/CLAHET_Data_CoV2/non-COVID/augmented_image_{i}.jpg"
    cv.imwrite(new_file_path, thresh)
    i += 1

# %%
#Version 1
im_data_v1, output_v1 = load_data(
    image_loc = 'rsc/input_data_v1',
    label_loc = 'rsc/output_data_v1',
    covid_data = 'rsc/CLAHET_Data_CoV2/COVID/',
    noncovid_data = 'rsc/CLAHET_Data_CoV2/non-COVID/',
    others_data = None,
)

x_train, x_test, y_train, y_test = train_test_split(im_data_v1, output_v1, random_state=42)

# %%
def make_model(X_Train, Y_Train, X_Test, Y_Test, model_dir: str):
    if not os.path.exists(model_dir):
        os.makedirs(model_dir)
    #X_Train, X_Test, Y_Train, Y_Test = train_test_split(input_data, output_data, test_size=0.1)

    for_pad = lambda s: s if s > 2 else 3

    model = Sequential()
    model.add(Lambda(lambda x: x, input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 1)))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=8, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))



    #model.add(ZeroPadding2D(padding=(for_pad(19) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(Conv2D(kernel_size=(3, 3), filters=2, strides=(1, 1),activation='relu'))

    model.add(Flatten())

    model.add(Dropout(rate=0.4))
    model.add(Dense(units=338, activation='relu'))
    model.add(Dense(units=1, activation='sigmoid'))

    model.compile(optimizer=Adam(lr=3e-4), loss='binary_crossentropy', metrics=["accuracy"])
    model.summary()

    checkpoint = ModelCheckpoint(os.path.join(model_dir, 'xRGM4.3'), verbose=1, period=1, save_best_only=True)

    hist = model.fit(batch_generator(X_Train, Y_Train, 128, True),
                        validation_data=(batch_generator(X_Test, Y_Test, 128, False)), callbacks=[checkpoint],
                        verbose=1, epochs=75, steps_per_epoch=25, validation_steps=len(X_Test))

    with open(os.path.join('models', 'xRGM4.3-Net-HistDict'), 'wb') as f:
        pickle.dump(hist.history, f)

    model.save(model_dir)
    
    return model
#changed steps and epochs and batchsize

# %%
# %%time
model_dir: str = 'model/xRGM4.3'
xRGM = make_model(x_train, y_train.reshape(-1,1), x_test, y_test.reshape(-1,1), model_dir=model_dir)

v_classify = np.vectorize(lambda x: np.round(x, 0))
# xRGMCT2 = load_model('models/xRGMCT2L.h5')
# print(xRGMCT2.history)
y_pred = (xRGM.predict(x_test))

#print(y_test)
#print(y_pred)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda (Lambda)              (None, 227, 227, 1)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 225, 225, 8)       80
# _________________________________________________________________
# batch_normalization (BatchNo (None, 225, 225, 8)       32
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 225, 225, 8)       0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 110, 110, 16)      1168
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 110, 110, 16)      64
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 110, 110, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 108, 108, 32)      4640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 108, 108, 32)      128
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 108, 108, 32)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 108, 108, 16)      528
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 108, 108, 16)      64
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 108, 108, 16)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 106, 106, 32)      4640
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 106, 106, 32)      128
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 106, 106, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 104, 104, 64)      18496
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 104, 104, 64)      256
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 104, 104, 64)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 104, 104, 32)      2080
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 104, 104, 32)      128
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 104, 104, 32)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 102, 102, 64)      18496
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 102, 102, 64)      256
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 102, 102, 64)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 100, 100, 128)     73856
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 100, 100, 128)     512
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 100, 100, 128)     0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 100, 100, 64)      8256
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 100, 100, 64)      256
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 98, 98, 128)       73856
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 98, 98, 128)       512
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 98, 98, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 49, 49, 128)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 47, 47, 256)       295168
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 47, 47, 256)       1024
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 47, 47, 256)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 47, 47, 128)       32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 47, 47, 128)       512
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 47, 47, 128)       0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 23, 23, 128)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 21, 21, 256)       295168
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 21, 21, 256)       1024
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 21, 21, 256)       0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 10, 10, 256)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 10, 10, 128)       32896
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 8, 8, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 338)               5538130
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 339
# =================================================================
# Total params: 6,702,293
# Trainable params: 6,699,077
# Non-trainable params: 3,216
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/75
# 25/25 [==============================] - 7996s 330s/step - loss: 0.9594 - accuracy: 0.6749 - val_loss: 0.6929 - val_accuracy: 0.4983
#
# Epoch 00001: val_loss improved from inf to 0.69290, saving model to model/xRGM4.3/xRGM4.3
# INFO:tensorflow:Assets written to: model/xRGM4.3/xRGM4.3/assets
# Epoch 2/75
# 25/25 [==============================] - 7956s 329s/step - loss: 0.2028 - accuracy: 0.9144 - val_loss: 0.6959 - val_accuracy: 0.5022
#
# Epoch 00002: val_loss did not improve from 0.69290
# Epoch 3/75
# 25/25 [==============================] - 7978s 330s/step - loss: 0.1210 - accuracy: 0.9487 - val_loss: 0.7562 - val_accuracy: 0.4999
#
# Epoch 00003: val_loss did not improve from 0.69290
# Epoch 4/75
# 25/25 [==============================] - 7965s 330s/step - loss: 0.0734 - accuracy: 0.9764 - val_loss: 0.9366 - val_accuracy: 0.5001
#
# Epoch 00004: val_loss did not improve from 0.69290
# Epoch 5/75
# 25/25 [==============================] - 7964s 329s/step - loss: 0.0635 - accuracy: 0.9782 - val_loss: 0.7067 - val_accuracy: 0.5462
#
# Epoch 00005: val_loss did not improve from 0.69290
# Epoch 6/75
# 25/25 [==============================] - 7959s 329s/step - loss: 0.0397 - accuracy: 0.9893 - val_loss: 0.9103 - val_accuracy: 0.5165
#
# Epoch 00006: val_loss did not improve from 0.69290
# Epoch 7/75
# 25/25 [==============================] - 7981s 330s/step - loss: 0.0378 - accuracy: 0.9852 - val_loss: 2.5668 - val_accuracy: 0.5003
#
# Epoch 00007: val_loss did not improve from 0.69290
# Epoch 8/75
# 25/25 [==============================] - 7965s 330s/step - loss: 0.0171 - accuracy: 0.9940 - val_loss: 1.6674 - val_accuracy: 0.5014
#
# Epoch 00008: val_loss did not improve from 0.69290
# Epoch 9/75
# 25/25 [==============================] - 7985s 330s/step - loss: 0.0066 - accuracy: 0.9996 - val_loss: 2.6238 - val_accuracy: 0.5051
#
# Epoch 00009: val_loss did not improve from 0.69290
# Epoch 10/75
# 25/25 [==============================] - 7967s 330s/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 2.4731 - val_accuracy: 0.5109
#
# Epoch 00010: val_loss did not improve from 0.69290
# Epoch 11/75
# 25/25 [==============================] - 7974s 330s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.6548 - val_accuracy: 0.5468
#
# Epoch 00011: val_loss did not improve from 0.69290
# Epoch 12/75
# 25/25 [==============================] - 9275s 384s/step - loss: 6.2050e-04 - accuracy: 1.0000 - val_loss: 2.4119 - val_accuracy: 0.5966
#
# Epoch 00012: val_loss did not improve from 0.69290
# Epoch 13/75
# 25/25 [==============================] - 8653s 358s/step - loss: 5.2869e-04 - accuracy: 1.0000 - val_loss: 2.0024 - val_accuracy: 0.6219
#
# Epoch 00013: val_loss did not improve from 0.69290
# Epoch 14/75
# 25/25 [==============================] - 9438s 391s/step - loss: 4.7840e-04 - accuracy: 1.0000 - val_loss: 1.6426 - val_accuracy: 0.6569
#
# Epoch 00014: val_loss did not improve from 0.69290
# Epoch 15/75
# 25/25 [==============================] - 9465s 391s/step - loss: 1.9801e-04 - accuracy: 1.0000 - val_loss: 0.9881 - val_accuracy: 0.7229
#
# Epoch 00015: val_loss did not improve from 0.69290
# Epoch 16/75
# 25/25 [==============================] - 9480s 392s/step - loss: 2.3103e-04 - accuracy: 1.0000 - val_loss: 0.4988 - val_accuracy: 0.8426
#
# Epoch 00016: val_loss improved from 0.69290 to 0.49882, saving model to model/xRGM4.3/xRGM4.3
# INFO:tensorflow:Assets written to: model/xRGM4.3/xRGM4.3/assets
# Epoch 17/75
# 25/25 [==============================] - 9513s 394s/step - loss: 2.5485e-04 - accuracy: 1.0000 - val_loss: 0.2986 - val_accuracy: 0.9053
#
# Epoch 00017: val_loss improved from 0.49882 to 0.29864, saving model to model/xRGM4.3/xRGM4.3
# INFO:tensorflow:Assets written to: model/xRGM4.3/xRGM4.3/assets
# Epoch 18/75
# 25/25 [==============================] - 9491s 393s/step - loss: 2.3124e-04 - accuracy: 1.0000 - val_loss: 0.2065 - val_accuracy: 0.9358
#
# Epoch 00018: val_loss improved from 0.29864 to 0.20654, saving model to model/xRGM4.3/xRGM4.3
# INFO:tensorflow:Assets written to: model/xRGM4.3/xRGM4.3/assets
# Epoch 19/75
# 25/25 [==============================] - 9486s 393s/step - loss: 1.6755e-04 - accuracy: 1.0000 - val_loss: 0.1740 - val_accuracy: 0.9464
#
# Epoch 00019: val_loss improved from 0.20654 to 0.17399, saving model to model/xRGM4.3/xRGM4.3
# INFO:tensorflow:Assets written to: model/xRGM4.3/xRGM4.3/assets
# Epoch 20/75
# 25/25 [==============================] - 9495s 393s/step - loss: 1.2377e-04 - accuracy: 1.0000 - val_loss: 0.1434 - val_accuracy: 0.9512
#
# Epoch 00020: val_loss improved from 0.17399 to 0.14337, saving model to model/xRGM4.3/xRGM4.3
# INFO:tensorflow:Assets written to: model/xRGM4.3/xRGM4.3/assets
# Epoch 21/75
# 25/25 [==============================] - 9463s 391s/step - loss: 1.3071e-04 - accuracy: 1.0000 - val_loss: 0.1265 - val_accuracy: 0.9587
#
# Epoch 00021: val_loss improved from 0.14337 to 0.12654, saving model to model/xRGM4.3/xRGM4.3
# INFO:tensorflow:Assets written to: model/xRGM4.3/xRGM4.3/assets
# Epoch 22/75
# 25/25 [==============================] - 9461s 391s/step - loss: 1.2162e-04 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 0.9621
#
# Epoch 00022: val_loss improved from 0.12654 to 0.11612, saving model to model/xRGM4.3/xRGM4.3
# INFO:tensorflow:Assets written to: model/xRGM4.3/xRGM4.3/assets
# Epoch 23/75
# 25/25 [==============================] - 9513s 393s/step - loss: 1.0574e-04 - accuracy: 1.0000 - val_loss: 0.1137 - val_accuracy: 0.9644
#
# Epoch 00023: val_loss improved from 0.11612 to 0.11368, saving model to model/xRGM4.3/xRGM4.3
# INFO:tensorflow:Assets written to: model/xRGM4.3/xRGM4.3/assets
# Epoch 24/75
# 25/25 [==============================] - 9481s 392s/step - loss: 1.0670e-04 - accuracy: 1.0000 - val_loss: 0.0990 - val_accuracy: 0.9668
#
# Epoch 00024: val_loss improved from 0.11368 to 0.09898, saving model to model/xRGM4.3/xRGM4.3
# INFO:tensorflow:Assets written to: model/xRGM4.3/xRGM4.3/assets
# Epoch 25/75
# 25/25 [==============================] - 9500s 393s/step - loss: 2.6570e-04 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9651
#
# Epoch 00025: val_loss did not improve from 0.09898
# Epoch 26/75
# 25/25 [==============================] - 9458s 391s/step - loss: 1.1656e-04 - accuracy: 1.0000 - val_loss: 0.1135 - val_accuracy: 0.9672
#
# Epoch 00026: val_loss did not improve from 0.09898
# Epoch 27/75
# 25/25 [==============================] - 9465s 391s/step - loss: 1.1287e-04 - accuracy: 1.0000 - val_loss: 0.1037 - val_accuracy: 0.9699
#
# Epoch 00027: val_loss did not improve from 0.09898
# Epoch 28/75
# 25/25 [==============================] - 9464s 391s/step - loss: 6.9925e-05 - accuracy: 1.0000 - val_loss: 0.1058 - val_accuracy: 0.9692
#
# Epoch 00028: val_loss did not improve from 0.09898
# Epoch 29/75
# 25/25 [==============================] - 9476s 392s/step - loss: 7.5951e-05 - accuracy: 1.0000 - val_loss: 0.1040 - val_accuracy: 0.9677
#
# Epoch 00029: val_loss did not improve from 0.09898
# Epoch 30/75
# 25/25 [==============================] - 9449s 391s/step - loss: 5.8494e-05 - accuracy: 1.0000 - val_loss: 0.1086 - val_accuracy: 0.9673
#
# Epoch 00030: val_loss did not improve from 0.09898
# Epoch 31/75
# 25/25 [==============================] - 9507s 393s/step - loss: 4.2205e-05 - accuracy: 1.0000 - val_loss: 0.1102 - val_accuracy: 0.9685
#
# Epoch 00031: val_loss did not improve from 0.09898
# Epoch 32/75
# 25/25 [==============================] - 9445s 390s/step - loss: 6.8191e-05 - accuracy: 1.0000 - val_loss: 0.1109 - val_accuracy: 0.9661
#
# Epoch 00032: val_loss did not improve from 0.09898
# Epoch 33/75
# 25/25 [==============================] - 9472s 392s/step - loss: 4.8603e-05 - accuracy: 1.0000 - val_loss: 0.1147 - val_accuracy: 0.9700
#
# Epoch 00033: val_loss did not improve from 0.09898
# Epoch 34/75
# 25/25 [==============================] - 9462s 391s/step - loss: 5.8199e-05 - accuracy: 1.0000 - val_loss: 0.1084 - val_accuracy: 0.9701
#
# Epoch 00034: val_loss did not improve from 0.09898
# Epoch 35/75
# 25/25 [==============================] - 9417s 389s/step - loss: 7.4210e-05 - accuracy: 1.0000 - val_loss: 0.1122 - val_accuracy: 0.9676
#
# Epoch 00035: val_loss did not improve from 0.09898
# Epoch 36/75
# 25/25 [==============================] - 9425s 390s/step - loss: 4.2358e-05 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.9694
#
# Epoch 00036: val_loss did not improve from 0.09898
# Epoch 37/75
# 25/25 [==============================] - 9447s 391s/step - loss: 4.7516e-05 - accuracy: 1.0000 - val_loss: 0.1139 - val_accuracy: 0.9689
#
# Epoch 00037: val_loss did not improve from 0.09898
# Epoch 38/75
# 25/25 [==============================] - 9414s 389s/step - loss: 4.5384e-05 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9697
#
# Epoch 00038: val_loss did not improve from 0.09898
# Epoch 39/75
# 25/25 [==============================] - 9410s 389s/step - loss: 3.8730e-05 - accuracy: 1.0000 - val_loss: 0.1134 - val_accuracy: 0.9713
#
# Epoch 00039: val_loss did not improve from 0.09898
# Epoch 40/75
# 25/25 [==============================] - 9480s 392s/step - loss: 5.4424e-05 - accuracy: 1.0000 - val_loss: 0.1143 - val_accuracy: 0.9698
#
# Epoch 00040: val_loss did not improve from 0.09898
# Epoch 41/75
# 25/25 [==============================] - 9488s 392s/step - loss: 3.0805e-05 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9705
#
# Epoch 00041: val_loss did not improve from 0.09898
# Epoch 42/75
# 25/25 [==============================] - 9456s 391s/step - loss: 3.0462e-05 - accuracy: 1.0000 - val_loss: 0.1207 - val_accuracy: 0.9704
#
# Epoch 00042: val_loss did not improve from 0.09898
# Epoch 43/75
# 25/25 [==============================] - 9438s 390s/step - loss: 2.5905e-05 - accuracy: 1.0000 - val_loss: 0.1185 - val_accuracy: 0.9707
#
# Epoch 00043: val_loss did not improve from 0.09898
# Epoch 44/75
# 25/25 [==============================] - 9458s 391s/step - loss: 3.5273e-05 - accuracy: 1.0000 - val_loss: 0.1168 - val_accuracy: 0.9710
#
# Epoch 00044: val_loss did not improve from 0.09898
# Epoch 45/75
# 25/25 [==============================] - 9456s 391s/step - loss: 1.1060e-04 - accuracy: 1.0000 - val_loss: 0.1164 - val_accuracy: 0.9709
#
# Epoch 00045: val_loss did not improve from 0.09898
# Epoch 46/75
# 25/25 [==============================] - 9431s 390s/step - loss: 3.9785e-05 - accuracy: 1.0000 - val_loss: 0.1123 - val_accuracy: 0.9662
#
# Epoch 00046: val_loss did not improve from 0.09898
# Epoch 47/75
# 25/25 [==============================] - 9428s 390s/step - loss: 4.9902e-05 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9699
#
# Epoch 00047: val_loss did not improve from 0.09898
# Epoch 48/75
# 25/25 [==============================] - 9452s 391s/step - loss: 0.0476 - accuracy: 0.9880 - val_loss: 2.8704 - val_accuracy: 0.8092
#
# Epoch 00048: val_loss did not improve from 0.09898
# Epoch 49/75
# 25/25 [==============================] - 9463s 391s/step - loss: 0.1847 - accuracy: 0.9369 - val_loss: 3.7043 - val_accuracy: 0.7544
#
# Epoch 00049: val_loss did not improve from 0.09898
# Epoch 50/75
# 25/25 [==============================] - 8395s 347s/step - loss: 0.0744 - accuracy: 0.9716 - val_loss: 10.9534 - val_accuracy: 0.6259
#
# Epoch 00050: val_loss did not improve from 0.09898
# Epoch 51/75
# 25/25 [==============================] - 7941s 328s/step - loss: 0.0375 - accuracy: 0.9855 - val_loss: 4.5693 - val_accuracy: 0.6752
#
# Epoch 00051: val_loss did not improve from 0.09898
# Epoch 52/75
# 25/25 [==============================] - 7964s 329s/step - loss: 0.0249 - accuracy: 0.9915 - val_loss: 1.3427 - val_accuracy: 0.8109
#
# Epoch 00052: val_loss did not improve from 0.09898
# Epoch 53/75
# 25/25 [==============================] - 7934s 328s/step - loss: 0.0115 - accuracy: 0.9967 - val_loss: 1.4737 - val_accuracy: 0.7968
#
# Epoch 00053: val_loss did not improve from 0.09898
# Epoch 54/75
# 25/25 [==============================] - 7934s 328s/step - loss: 0.0054 - accuracy: 0.9986 - val_loss: 1.1761 - val_accuracy: 0.7927
#
# Epoch 00054: val_loss did not improve from 0.09898
# Epoch 55/75
# 25/25 [==============================] - 7938s 328s/step - loss: 0.0041 - accuracy: 0.9990 - val_loss: 0.9498 - val_accuracy: 0.8247
#
# Epoch 00055: val_loss did not improve from 0.09898
# Epoch 56/75
# 25/25 [==============================] - 7925s 328s/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.4135 - val_accuracy: 0.8926
#
# Epoch 00056: val_loss did not improve from 0.09898
# Epoch 57/75
# 25/25 [==============================] - 7959s 329s/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 1.6440 - val_accuracy: 0.7626
#
# Epoch 00057: val_loss did not improve from 0.09898
# Epoch 58/75
# 25/25 [==============================] - 7940s 328s/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.4202 - val_accuracy: 0.8929
#
# Epoch 00058: val_loss did not improve from 0.09898
# Epoch 59/75
# 25/25 [==============================] - 8023s 332s/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.2495 - val_accuracy: 0.9312
#
# Epoch 00059: val_loss did not improve from 0.09898
# Epoch 60/75
# 25/25 [==============================] - 9591s 397s/step - loss: 8.6880e-04 - accuracy: 0.9999 - val_loss: 0.3144 - val_accuracy: 0.9232
#
# Epoch 00060: val_loss did not improve from 0.09898
# Epoch 61/75
# 25/25 [==============================] - 9588s 397s/step - loss: 0.0051 - accuracy: 0.9973 - val_loss: 0.4049 - val_accuracy: 0.9011
#
# Epoch 00061: val_loss did not improve from 0.09898
# Epoch 62/75
# 25/25 [==============================] - 9539s 395s/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.3467 - val_accuracy: 0.9028
#
# Epoch 00062: val_loss did not improve from 0.09898
# Epoch 63/75
# 25/25 [==============================] - 9559s 395s/step - loss: 6.9661e-04 - accuracy: 1.0000 - val_loss: 0.2449 - val_accuracy: 0.9323
#
# Epoch 00063: val_loss did not improve from 0.09898
# Epoch 64/75
# 25/25 [==============================] - 9541s 395s/step - loss: 4.3927e-04 - accuracy: 1.0000 - val_loss: 0.1839 - val_accuracy: 0.9520
#
# Epoch 00064: val_loss did not improve from 0.09898
# Epoch 65/75
# 25/25 [==============================] - 9536s 394s/step - loss: 1.8497e-04 - accuracy: 1.0000 - val_loss: 0.1752 - val_accuracy: 0.9520
#
# Epoch 00065: val_loss did not improve from 0.09898
# Epoch 66/75
# 25/25 [==============================] - 9544s 395s/step - loss: 9.9437e-05 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9648
#
# Epoch 00066: val_loss did not improve from 0.09898
# Epoch 67/75
# 25/25 [==============================] - 9544s 395s/step - loss: 7.9080e-05 - accuracy: 1.0000 - val_loss: 0.1370 - val_accuracy: 0.9645
#
# Epoch 00067: val_loss did not improve from 0.09898
# Epoch 68/75
# 25/25 [==============================] - 9562s 395s/step - loss: 6.3025e-05 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9640
#
# Epoch 00068: val_loss did not improve from 0.09898
# Epoch 69/75
# 25/25 [==============================] - 9553s 395s/step - loss: 1.4898e-04 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 0.9652
#
# Epoch 00069: val_loss did not improve from 0.09898
# Epoch 70/75
# 25/25 [==============================] - 10258s 424s/step - loss: 5.3154e-05 - accuracy: 1.0000 - val_loss: 0.1220 - val_accuracy: 0.9660
#
# Epoch 00070: val_loss did not improve from 0.09898
# Epoch 71/75
# 25/25 [==============================] - 12563s 520s/step - loss: 7.9440e-05 - accuracy: 1.0000 - val_loss: 0.1300 - val_accuracy: 0.9641
#
# Epoch 00071: val_loss did not improve from 0.09898
# Epoch 72/75
# 25/25 [==============================] - 12515s 518s/step - loss: 5.3103e-05 - accuracy: 1.0000 - val_loss: 0.1309 - val_accuracy: 0.9659
#
# Epoch 00072: val_loss did not improve from 0.09898
# Epoch 73/75
# 25/25 [==============================] - 12513s 518s/step - loss: 6.8734e-05 - accuracy: 1.0000 - val_loss: 0.1254 - val_accuracy: 0.9677
#
# Epoch 00073: val_loss did not improve from 0.09898
# Epoch 74/75
# 25/25 [==============================] - 12518s 518s/step - loss: 5.7434e-05 - accuracy: 1.0000 - val_loss: 0.1204 - val_accuracy: 0.9651
#
# Epoch 00074: val_loss did not improve from 0.09898
# Epoch 75/75
# 25/25 [==============================] - 12536s 518s/step - loss: 7.3301e-05 - accuracy: 1.0000 - val_loss: 0.1313 - val_accuracy: 0.9658
#
# Epoch 00075: val_loss did not improve from 0.09898
# INFO:tensorflow:Assets written to: model/xRGM4.3/assets
# CPU times: user 21d 3h 27min 31s, sys: 14h 40min 1s, total: 21d 18h 7min 32s
# Wall time: 8d 1h 11min 7s

# %%
confusion_matrix = pd.DataFrame(metrics.confusion_matrix(y_test, v_classify(y_pred)),
                                columns=['Predicted Negative', 'Predicted Positive'],
                                index=['Actual Negative', 'Actual Positive'])

tp, tn, fp, fn = (
    confusion_matrix.iloc[1,1], 
    confusion_matrix.iloc[0,0], 
    confusion_matrix.iloc[0,1], 
    confusion_matrix.iloc[1,0]
)

accuracy = (tp + tn) / (tp + tn + fp + fn)
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
f1_score = 2 * ((specificity * sensitivity) / (specificity + sensitivity))

with open(os.path.join(f'{model_dir}', 'metrics.csv'), 'a', encoding='utf-8') as f:
    f.write(
        f'{time.strftime("%Y-%m-%dT%H:%M:%S-05:00", time.localtime())}, {accuracy}, {sensitivity}, {specificity}, {f1_score}\n'
    )

print(f'Accuracy:    {accuracy}')
print(f'Sensitivity: {sensitivity}')
print(f'Specificity: {specificity}')
print(f'F1 Score:    {f1_score}')
print('\n')
print(confusion_matrix)
# Out:
# Accuracy:    0.966183574879227
# Sensitivity: 0.9612903225806452
# Specificity: 0.9710610932475884
# F1 Score:    0.9661510053784796
#
#
#                  Predicted Negative  Predicted Positive
# Actual Negative                 302                   9
# Actual Positive                  12                 298

# %%
disease_types=['COVID', 'non-COVID']
Y_pred = np.argmax(y_pred)
Y_true = np.argmax(y_test)

plt.figure(figsize=(7, 7))
ax = sns.heatmap(confusion_matrix , cmap=plt.cm.GnBu , 
                 annot=True, fmt='d',square=True, xticklabels=disease_types, 
                 yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
plt.show()

# %%
def plot_model_history(model_history):
   fig, axs = plt.subplots(1,2,figsize=(15,5))
   # summarize history for accuracy
   axs[0].plot(range(1, len(model_history['accuracy']) + 1), model_history['accuracy'])
   axs[0].plot(range(1, len(model_history['val_accuracy']) + 1), model_history['val_accuracy'])
   axs[0].set_title('Model Accuracy')
   axs[0].set_ylabel('Accuracy')
   axs[0].set_xlabel('Epoch')
   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
   axs[0].legend(['train', 'val'], loc='best')
   # summarize history for loss
   axs[1].plot(range(1, len(model_history['loss'])+1), model_history['loss'])
   axs[1].plot(range(1, len(model_history['val_loss']) + 1), model_history['val_loss'])
   axs[1].set_title('Model Loss')
   axs[1].set_ylabel('Loss')
   axs[1].set_xlabel('Epoch')
   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
   axs[1].legend(['train', 'val'], loc='best')
   plt.show()

# %%
with open(os.path.join('models', 'xRGM4.3-Net-HistDict'), 'rb') as f:
    history = pickle.load(f)
    
plot_model_history(history)
# Out:
# <ipython-input-17-25025fac5012>:9: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
# <ipython-input-17-25025fac5012>:17: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
