# %%
import glob
import json
import os
import pickle
import random
import traceback
from typing import Tuple

import cv2 as cv
import numpy as np
import pandas as pd
import seaborn as sns
from keras.models import Sequential, load_model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Lambda, LeakyReLU, AveragePooling2D, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from matplotlib import pyplot as plt
from matplotlib.pyplot import hist
from PIL import Image
from scipy.stats import zscore
from sklearn import metrics
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %%
import csv
import time

# %% [markdown]
# ## Config & Constants

# %%
IMAGE_WIDTH, IMAGE_HEIGHT = 227, 227
random.seed(52)

# %% [markdown]
# ## Methods

# %% [markdown]
# ### Image Utilities

# %%
def batch_generator(input_data, output_data, batch_size, is_training):
    input_data_batch = np.empty([batch_size, IMAGE_HEIGHT, IMAGE_WIDTH, 1])
    output_data_batch = np.empty([batch_size, 1])
    while True:
        index = 0
        for i in np.random.permutation(input_data.shape[0]):
            input_data_batch[index] = input_data[i]
            output_data_batch[index] = output_data[i]
            index += 1
            if index == batch_size:
                break
        yield input_data_batch, output_data_batch


def _preprocess(image_loc: str) -> np.ndarray:
    f_image = Image.open(image_loc).convert('L')
    f_image = f_image.resize((IMAGE_WIDTH, IMAGE_HEIGHT), Image.ANTIALIAS)
    image = np.asarray(f_image)
    image = np.expand_dims(image, axis=0)
    image = np.expand_dims(image, axis=3)
    return image


def preprocess(loc: str) -> np.ndarray:
    """Safety wrapper over _preprocess.
    
    Args:
        loc: File location to check if dir or an image.
        
    Returns:
        Preprocessed image(s) as an ndarray.
    """
    if os.path.isdir(loc):
        current = np.concatenate((
            [_preprocess(os.path.join(loc, image)) for image in os.listdir(loc)
             if '.png' in image]
        ))
    else:
        current = _preprocess(loc)
    return current


def generate_data_arrays(
    covid_data: str = 'rsc/New_Data_CoV2/COVID/',
    noncovid_data: str = 'rsc/New_Data_CoV2/non-COVID/',
    others_data:  str = 'rsc/New_Data_CoV2/Others/',
    image_output: str = 'rsc/input_data_v2',
    label_output: str = 'rsc/output_data_v2',
    regenerate: bool = True
) -> Tuple[np.ndarray, np.ndarray]:
    """Loads COVID images into ndarrays.
    
    Args:
        covid_data: Relative path to folder containing COVID images.
        noncovid_data: Relative path to folder containing non-COVID images.
        others_data: Relative path to folder containing Others images.
        image_output: Relative path (with filename) to save loaded images to.
        label_output: Relative path (with filename) to save loaded classes (labels) to.
        regenerate: If True, will regenerate saved ndarray files for both image_output
            and label_output, even if they already exist (overwriting them). If False,
            will simply load and return the aforementioned.
        
    Returns:
        Tuple of ndarrays. The first is the loaded image data in one large ndarray,
        and the second is the loaded labels, also in a large ndarray. These directly
        match up to each other ONLY when both arrays (and their respective files)
        are generated at the same time with this method.
    """
    if (regenerate is False and 
        os.path.isfile(f'{out_input_data}.npy') and
        os.path.isfile(f'{out_output_data}.npy')):
        return (np.load(f'{out_input_data}.npy'),
                np.load(f'{out_output_data}.npy'))
    
    if not ((cd := os.path.exists(covid_data)) and (ncd := os.path.exists(noncovid_data))):
        if (others_data is not None) and not (odd := os.path.exists(others_data)):
            raise NotADirectoryError("Directories do not exist.")
        else:
            raise NotADirectoryError("COVID/non-COVID directories do not exist.")
    
    im_data = np.empty([1, IMAGE_WIDTH, IMAGE_WIDTH, 1])
    output = np.array([0])

    print('Loading Covid Data')
    for i in tqdm(glob.glob(os.path.join(covid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([1])), axis=0)

    print('Loading non-Covid Data')
    for i in tqdm(glob.glob(os.path.join(noncovid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([0])), axis=0)
        
    if others_data is not None:
        print('Loading Others Data')
        for i in tqdm(glob.glob(os.path.join(others_data, '**'))):
            current = preprocess(i)
            im_data = np.concatenate((im_data, current))
            output = np.concatenate((output, np.array([-1])), axis=0)
    else:
        print('Others data not provided; skipping.')


    print('Finished Loading Data')
    im_data = np.delete(im_data, 0, axis=0)
    output = np.delete(output, 0, axis=0)

    zip_data = list(zip(im_data, output))
    random.shuffle(zip_data)
    im_data, output = zip(*zip_data)

    np.save(f'{image_output}', im_data)
    np.save(f'{label_output}', output)
    return im_data, output


def load_data(image_loc: str, label_loc: str, **kwargs) -> Tuple[np.ndarray, np.ndarray]:
    """Attempts to load generated images and labels.
    
    If either is not found, attempts to (re)generate them using the default
    input arguments to the generation method for the raw data, but the input
    `image_loc` and `label_loc` parameters for the output arrays. If this
    still does not work, returns a general error and exits.
    
    Args:
        image_loc: Relative path to saved image ndarray file.
        label_loc: Relative path to saved label ndarray file.
        
    Returns:
        Tuple of ndarrays. The first array holds the loaded image data, whilst
        the second array holds their respective labels.
    
    """
    try:
        image_data = np.load(f'{image_loc}.npy')
        label_data = np.load(f'{label_loc}.npy')
        return image_data, label_data
    
    except FileNotFoundError:
        try:
            image_data, label_data = generate_data_arrays(
                image_output = image_loc,
                label_output = label_loc,
                **kwargs
            )
            return image_data, label_data
        
        except Exception as e:
            traceback.print_exc()

# %% [markdown]
# ## Model Playground

# %%
import os
from skimage import io

# our folder path containing some images
folder_path = 'rsc/Data_CoV2/COVID'

# loop on all files of the folder and build a list of files paths
images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
i: int = 0
for image_path in images:
    img = cv.imread(image_path)
    grayimg = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    clahe = cv.createCLAHE()
    cl_img = clahe.apply(grayimg)
    
    new_file_path = f"rsc/CLAHE_Data_CoV2/COVID/augmented_image_{i}.jpg"
    cv.imwrite(new_file_path, cl_img)
    i += 1

# %%
# our folder path containing some images
folder_path = 'rsc/Data_CoV2/non-COVID'

# loop on all files of the folder and build a list of files paths
images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
i: int = 0
for image_path in images:
    img = cv.imread(image_path)
    grayimg = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    clahe = cv.createCLAHE()
    cl_img = clahe.apply(grayimg)
    
    new_file_path = f"rsc/CLAHE_Data_CoV2/non-COVID/augmented_image_{i}.jpg"
    cv.imwrite(new_file_path, cl_img)
    i += 1

# %%
#Version 1
im_data_v1, output_v1 = load_data(
    image_loc = 'rsc/input_data_v1',
    label_loc = 'rsc/output_data_v1',
    covid_data = 'rsc/CLAHE_Data_CoV2/COVID/',
    noncovid_data = 'rsc/CLAHE_Data_CoV2/non-COVID/',
    others_data = None,
)

x_train, x_test, y_train, y_test = train_test_split(im_data_v1, output_v1, random_state=42)

# %%
def make_model(X_Train, Y_Train, X_Test, Y_Test, model_dir: str):
    if not os.path.exists(model_dir):
        os.makedirs(model_dir)
    #X_Train, X_Test, Y_Train, Y_Test = train_test_split(input_data, output_data, test_size=0.1)

    for_pad = lambda s: s if s > 2 else 3

    model = Sequential()
    model.add(Lambda(lambda x: x, input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 1)))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=8, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))



    #model.add(ZeroPadding2D(padding=(for_pad(19) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(Conv2D(kernel_size=(3, 3), filters=2, strides=(1, 1),activation='relu'))

    model.add(Flatten())

    model.add(Dropout(rate=0.4))
    model.add(Dense(units=338, activation='relu'))
    model.add(Dense(units=1, activation='sigmoid'))

    model.compile(optimizer=Adam(lr=3e-4), loss='binary_crossentropy', metrics=["accuracy"])
    model.summary()

    checkpoint = ModelCheckpoint(os.path.join(model_dir, 'xRGM4.2'), verbose=1, period=1, save_best_only=True)

    hist = model.fit(batch_generator(X_Train, Y_Train, 128, True),
                        validation_data=(batch_generator(X_Test, Y_Test, 128, False)), callbacks=[checkpoint],
                        verbose=1, epochs=75, steps_per_epoch=25, validation_steps=len(X_Test))

    with open(os.path.join('models', 'xRGM4.2-Net-HistDict'), 'wb') as f:
        pickle.dump(hist.history, f)

    model.save(model_dir)
    
    return model
#changed steps and epochs and batchsize

# %%
# %%time
model_dir: str = 'model/xRGM4.2'
xRGM = make_model(x_train, y_train.reshape(-1,1), x_test, y_test.reshape(-1,1), model_dir=model_dir)

v_classify = np.vectorize(lambda x: np.round(x, 0))
# xRGMCT2 = load_model('models/xRGMCT2L.h5')
# print(xRGMCT2.history)
y_pred = (xRGM.predict(x_test))

#print(y_test)
#print(y_pred)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda (Lambda)              (None, 227, 227, 1)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 225, 225, 8)       80
# _________________________________________________________________
# batch_normalization (BatchNo (None, 225, 225, 8)       32
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 225, 225, 8)       0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 110, 110, 16)      1168
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 110, 110, 16)      64
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 110, 110, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 108, 108, 32)      4640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 108, 108, 32)      128
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 108, 108, 32)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 108, 108, 16)      528
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 108, 108, 16)      64
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 108, 108, 16)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 106, 106, 32)      4640
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 106, 106, 32)      128
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 106, 106, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 104, 104, 64)      18496
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 104, 104, 64)      256
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 104, 104, 64)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 104, 104, 32)      2080
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 104, 104, 32)      128
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 104, 104, 32)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 102, 102, 64)      18496
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 102, 102, 64)      256
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 102, 102, 64)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 100, 100, 128)     73856
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 100, 100, 128)     512
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 100, 100, 128)     0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 100, 100, 64)      8256
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 100, 100, 64)      256
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 98, 98, 128)       73856
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 98, 98, 128)       512
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 98, 98, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 49, 49, 128)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 47, 47, 256)       295168
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 47, 47, 256)       1024
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 47, 47, 256)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 47, 47, 128)       32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 47, 47, 128)       512
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 47, 47, 128)       0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 23, 23, 128)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 21, 21, 256)       295168
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 21, 21, 256)       1024
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 21, 21, 256)       0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 10, 10, 256)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 10, 10, 128)       32896
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 8, 8, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 338)               5538130
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 339
# =================================================================
# Total params: 6,702,293
# Trainable params: 6,699,077
# Non-trainable params: 3,216
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/75
# 25/25 [==============================] - 7946s 329s/step - loss: 1.9985 - accuracy: 0.5503 - val_loss: 0.6929 - val_accuracy: 0.4977
#
# Epoch 00001: val_loss improved from inf to 0.69293, saving model to model/xRGM4.2/xRGM4.2
# INFO:tensorflow:Assets written to: model/xRGM4.2/xRGM4.2/assets
# Epoch 2/75
# 25/25 [==============================] - 7974s 330s/step - loss: 0.3891 - accuracy: 0.8247 - val_loss: 0.6906 - val_accuracy: 0.6141
#
# Epoch 00002: val_loss improved from 0.69293 to 0.69065, saving model to model/xRGM4.2/xRGM4.2
# INFO:tensorflow:Assets written to: model/xRGM4.2/xRGM4.2/assets
# Epoch 3/75
# 25/25 [==============================] - 7980s 330s/step - loss: 0.2586 - accuracy: 0.8912 - val_loss: 0.6907 - val_accuracy: 0.5600
#
# Epoch 00003: val_loss did not improve from 0.69065
# Epoch 4/75
# 25/25 [==============================] - 7988s 330s/step - loss: 0.1752 - accuracy: 0.9280 - val_loss: 0.7128 - val_accuracy: 0.5026
#
# Epoch 00004: val_loss did not improve from 0.69065
# Epoch 5/75
# 25/25 [==============================] - 7982s 330s/step - loss: 0.0965 - accuracy: 0.9664 - val_loss: 1.2671 - val_accuracy: 0.4997
#
# Epoch 00005: val_loss did not improve from 0.69065
# Epoch 6/75
# 25/25 [==============================] - 7962s 329s/step - loss: 0.0578 - accuracy: 0.9839 - val_loss: 1.1070 - val_accuracy: 0.5010
#
# Epoch 00006: val_loss did not improve from 0.69065
# Epoch 7/75
# 25/25 [==============================] - 7974s 330s/step - loss: 0.0531 - accuracy: 0.9838 - val_loss: 1.5358 - val_accuracy: 0.5006
#
# Epoch 00007: val_loss did not improve from 0.69065
# Epoch 8/75
# 25/25 [==============================] - 7971s 330s/step - loss: 0.0284 - accuracy: 0.9959 - val_loss: 1.3981 - val_accuracy: 0.5221
#
# Epoch 00008: val_loss did not improve from 0.69065
# Epoch 9/75
# 25/25 [==============================] - 8000s 331s/step - loss: 0.0149 - accuracy: 0.9970 - val_loss: 1.4913 - val_accuracy: 0.5612
#
# Epoch 00009: val_loss did not improve from 0.69065
# Epoch 10/75
# 25/25 [==============================] - 7969s 330s/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 1.9853 - val_accuracy: 0.5446
#
# Epoch 00010: val_loss did not improve from 0.69065
# Epoch 11/75
# 25/25 [==============================] - 7987s 330s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.6632 - val_accuracy: 0.6147
#
# Epoch 00011: val_loss did not improve from 0.69065
# Epoch 12/75
# 25/25 [==============================] - 9228s 382s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.0407 - val_accuracy: 0.6885
#
# Epoch 00012: val_loss did not improve from 0.69065
# Epoch 13/75
# 25/25 [==============================] - 8730s 361s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.6355 - val_accuracy: 0.7544
#
# Epoch 00013: val_loss improved from 0.69065 to 0.63549, saving model to model/xRGM4.2/xRGM4.2
# INFO:tensorflow:Assets written to: model/xRGM4.2/xRGM4.2/assets
# Epoch 14/75
# 25/25 [==============================] - 9394s 389s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5469 - val_accuracy: 0.7931
#
# Epoch 00014: val_loss improved from 0.63549 to 0.54686, saving model to model/xRGM4.2/xRGM4.2
# INFO:tensorflow:Assets written to: model/xRGM4.2/xRGM4.2/assets
# Epoch 15/75
# 25/25 [==============================] - 9528s 394s/step - loss: 7.5999e-04 - accuracy: 1.0000 - val_loss: 0.2457 - val_accuracy: 0.9056
#
# Epoch 00015: val_loss improved from 0.54686 to 0.24566, saving model to model/xRGM4.2/xRGM4.2
# INFO:tensorflow:Assets written to: model/xRGM4.2/xRGM4.2/assets
# Epoch 16/75
# 25/25 [==============================] - 9522s 394s/step - loss: 7.2852e-04 - accuracy: 1.0000 - val_loss: 0.1631 - val_accuracy: 0.9328
#
# Epoch 00016: val_loss improved from 0.24566 to 0.16313, saving model to model/xRGM4.2/xRGM4.2
# INFO:tensorflow:Assets written to: model/xRGM4.2/xRGM4.2/assets
# Epoch 17/75
# 25/25 [==============================] - 9528s 394s/step - loss: 6.2623e-04 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9454
#
# Epoch 00017: val_loss improved from 0.16313 to 0.14153, saving model to model/xRGM4.2/xRGM4.2
# INFO:tensorflow:Assets written to: model/xRGM4.2/xRGM4.2/assets
# Epoch 18/75
# 25/25 [==============================] - 9508s 393s/step - loss: 5.5761e-04 - accuracy: 1.0000 - val_loss: 0.1067 - val_accuracy: 0.9587
#
# Epoch 00018: val_loss improved from 0.14153 to 0.10665, saving model to model/xRGM4.2/xRGM4.2
# INFO:tensorflow:Assets written to: model/xRGM4.2/xRGM4.2/assets
# Epoch 19/75
# 25/25 [==============================] - 9531s 394s/step - loss: 3.5415e-04 - accuracy: 1.0000 - val_loss: 0.0816 - val_accuracy: 0.9681
#
# Epoch 00019: val_loss improved from 0.10665 to 0.08158, saving model to model/xRGM4.2/xRGM4.2
# INFO:tensorflow:Assets written to: model/xRGM4.2/xRGM4.2/assets
# Epoch 20/75
# 25/25 [==============================] - 9512s 394s/step - loss: 2.5975e-04 - accuracy: 1.0000 - val_loss: 0.0709 - val_accuracy: 0.9729
#
# Epoch 00020: val_loss improved from 0.08158 to 0.07092, saving model to model/xRGM4.2/xRGM4.2
# INFO:tensorflow:Assets written to: model/xRGM4.2/xRGM4.2/assets
# Epoch 21/75
# 25/25 [==============================] - 9519s 394s/step - loss: 5.0332e-04 - accuracy: 1.0000 - val_loss: 0.0600 - val_accuracy: 0.9729
#
# Epoch 00021: val_loss improved from 0.07092 to 0.05999, saving model to model/xRGM4.2/xRGM4.2
# INFO:tensorflow:Assets written to: model/xRGM4.2/xRGM4.2/assets
# Epoch 22/75
# 25/25 [==============================] - 9553s 395s/step - loss: 2.4687e-04 - accuracy: 1.0000 - val_loss: 0.0725 - val_accuracy: 0.9694
#
# Epoch 00022: val_loss did not improve from 0.05999
# Epoch 23/75
# 25/25 [==============================] - 9533s 395s/step - loss: 2.8300e-04 - accuracy: 1.0000 - val_loss: 0.0616 - val_accuracy: 0.9710
#
# Epoch 00023: val_loss did not improve from 0.05999
# Epoch 24/75
# 25/25 [==============================] - 9520s 394s/step - loss: 1.9460e-04 - accuracy: 1.0000 - val_loss: 0.0606 - val_accuracy: 0.9712
#
# Epoch 00024: val_loss did not improve from 0.05999
# Epoch 25/75
# 25/25 [==============================] - 9503s 393s/step - loss: 2.0514e-04 - accuracy: 1.0000 - val_loss: 0.0570 - val_accuracy: 0.9720
#
# Epoch 00025: val_loss improved from 0.05999 to 0.05703, saving model to model/xRGM4.2/xRGM4.2
# INFO:tensorflow:Assets written to: model/xRGM4.2/xRGM4.2/assets
# Epoch 26/75
# 25/25 [==============================] - 9495s 393s/step - loss: 1.9791e-04 - accuracy: 1.0000 - val_loss: 0.0615 - val_accuracy: 0.9718
#
# Epoch 00026: val_loss did not improve from 0.05703
# Epoch 27/75
# 25/25 [==============================] - 9497s 393s/step - loss: 1.5457e-04 - accuracy: 1.0000 - val_loss: 0.0613 - val_accuracy: 0.9710
#
# Epoch 00027: val_loss did not improve from 0.05703
# Epoch 28/75
# 25/25 [==============================] - 9490s 393s/step - loss: 1.4190e-04 - accuracy: 1.0000 - val_loss: 0.0560 - val_accuracy: 0.9715
#
# Epoch 00028: val_loss improved from 0.05703 to 0.05596, saving model to model/xRGM4.2/xRGM4.2
# INFO:tensorflow:Assets written to: model/xRGM4.2/xRGM4.2/assets
# Epoch 29/75
# 25/25 [==============================] - 9497s 393s/step - loss: 1.7008e-04 - accuracy: 1.0000 - val_loss: 0.0555 - val_accuracy: 0.9698
#
# Epoch 00029: val_loss improved from 0.05596 to 0.05548, saving model to model/xRGM4.2/xRGM4.2
# INFO:tensorflow:Assets written to: model/xRGM4.2/xRGM4.2/assets
# Epoch 30/75
# 25/25 [==============================] - 9521s 394s/step - loss: 1.5977e-04 - accuracy: 1.0000 - val_loss: 0.0689 - val_accuracy: 0.9723
#
# Epoch 00030: val_loss did not improve from 0.05548
# Epoch 31/75
# 25/25 [==============================] - 9498s 393s/step - loss: 1.3407e-04 - accuracy: 1.0000 - val_loss: 0.0616 - val_accuracy: 0.9712
#
# Epoch 00031: val_loss did not improve from 0.05548
# Epoch 32/75
# 25/25 [==============================] - 9517s 394s/step - loss: 1.0954e-04 - accuracy: 1.0000 - val_loss: 0.0631 - val_accuracy: 0.9715
#
# Epoch 00032: val_loss did not improve from 0.05548
# Epoch 33/75
# 25/25 [==============================] - 9522s 394s/step - loss: 1.1809e-04 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9740
#
# Epoch 00033: val_loss did not improve from 0.05548
# Epoch 34/75
# 25/25 [==============================] - 9519s 394s/step - loss: 1.2996e-04 - accuracy: 1.0000 - val_loss: 0.0674 - val_accuracy: 0.9707
#
# Epoch 00034: val_loss did not improve from 0.05548
# Epoch 35/75
# 25/25 [==============================] - 9537s 395s/step - loss: 1.2367e-04 - accuracy: 1.0000 - val_loss: 0.0627 - val_accuracy: 0.9691
#
# Epoch 00035: val_loss did not improve from 0.05548
# Epoch 36/75
# 25/25 [==============================] - 9504s 393s/step - loss: 9.5454e-05 - accuracy: 1.0000 - val_loss: 0.0707 - val_accuracy: 0.9707
#
# Epoch 00036: val_loss did not improve from 0.05548
# Epoch 37/75
# 25/25 [==============================] - 9536s 395s/step - loss: 8.7183e-05 - accuracy: 1.0000 - val_loss: 0.0553 - val_accuracy: 0.9751
#
# Epoch 00037: val_loss improved from 0.05548 to 0.05528, saving model to model/xRGM4.2/xRGM4.2
# INFO:tensorflow:Assets written to: model/xRGM4.2/xRGM4.2/assets
# Epoch 38/75
# 25/25 [==============================] - 9529s 394s/step - loss: 7.8854e-05 - accuracy: 1.0000 - val_loss: 0.0740 - val_accuracy: 0.9758
#
# Epoch 00038: val_loss did not improve from 0.05528
# Epoch 39/75
# 25/25 [==============================] - 9519s 394s/step - loss: 1.1637e-04 - accuracy: 1.0000 - val_loss: 0.0627 - val_accuracy: 0.9745
#
# Epoch 00039: val_loss did not improve from 0.05528
# Epoch 40/75
# 25/25 [==============================] - 9644s 399s/step - loss: 1.5269e-04 - accuracy: 1.0000 - val_loss: 0.0734 - val_accuracy: 0.9725
#
# Epoch 00040: val_loss did not improve from 0.05528
# Epoch 41/75
# 25/25 [==============================] - 9614s 398s/step - loss: 1.2466e-04 - accuracy: 1.0000 - val_loss: 0.0574 - val_accuracy: 0.9730
#
# Epoch 00041: val_loss did not improve from 0.05528
# Epoch 42/75
# 25/25 [==============================] - 9625s 398s/step - loss: 6.0779e-05 - accuracy: 1.0000 - val_loss: 0.0616 - val_accuracy: 0.9712
#
# Epoch 00042: val_loss did not improve from 0.05528
# Epoch 43/75
# 25/25 [==============================] - 9660s 400s/step - loss: 5.7108e-05 - accuracy: 1.0000 - val_loss: 0.0602 - val_accuracy: 0.9718
#
# Epoch 00043: val_loss did not improve from 0.05528
# Epoch 44/75
# 25/25 [==============================] - 9691s 401s/step - loss: 6.0865e-05 - accuracy: 1.0000 - val_loss: 0.0680 - val_accuracy: 0.9698
#
# Epoch 00044: val_loss did not improve from 0.05528
# Epoch 45/75
# 25/25 [==============================] - 9672s 400s/step - loss: 5.3467e-05 - accuracy: 1.0000 - val_loss: 0.0634 - val_accuracy: 0.9749
#
# Epoch 00045: val_loss did not improve from 0.05528
# Epoch 46/75
# 25/25 [==============================] - 9656s 399s/step - loss: 6.4565e-05 - accuracy: 1.0000 - val_loss: 0.0674 - val_accuracy: 0.9726
#
# Epoch 00046: val_loss did not improve from 0.05528
# Epoch 47/75
# 25/25 [==============================] - 9641s 399s/step - loss: 6.6549e-05 - accuracy: 1.0000 - val_loss: 0.0589 - val_accuracy: 0.9701
#
# Epoch 00047: val_loss did not improve from 0.05528
# Epoch 48/75
# 25/25 [==============================] - 9696s 401s/step - loss: 4.3955e-05 - accuracy: 1.0000 - val_loss: 0.0617 - val_accuracy: 0.9759
#
# Epoch 00048: val_loss did not improve from 0.05528
# Epoch 49/75
# 25/25 [==============================] - 8101s 335s/step - loss: 5.1951e-05 - accuracy: 1.0000 - val_loss: 0.0604 - val_accuracy: 0.9728
#
# Epoch 00050: val_loss did not improve from 0.05528
# Epoch 51/75
# 25/25 [==============================] - 8120s 336s/step - loss: 4.1415e-05 - accuracy: 1.0000 - val_loss: 0.0647 - val_accuracy: 0.9746
#
# Epoch 00051: val_loss did not improve from 0.05528
# Epoch 52/75
# 25/25 [==============================] - 8109s 335s/step - loss: 4.2839e-05 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9725
#
# Epoch 00052: val_loss did not improve from 0.05528
# Epoch 53/75
# 25/25 [==============================] - 8104s 335s/step - loss: 4.7284e-05 - accuracy: 1.0000 - val_loss: 0.0762 - val_accuracy: 0.9748
#
# Epoch 00053: val_loss did not improve from 0.05528
# Epoch 54/75
# 25/25 [==============================] - 8099s 335s/step - loss: 4.9539e-05 - accuracy: 1.0000 - val_loss: 0.0577 - val_accuracy: 0.9743
#
# Epoch 00054: val_loss did not improve from 0.05528
# Epoch 55/75
# 25/25 [==============================] - 8106s 335s/step - loss: 4.6383e-05 - accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 0.9762
#
# Epoch 00055: val_loss did not improve from 0.05528
# Epoch 56/75
# 25/25 [==============================] - 8117s 336s/step - loss: 3.5087e-05 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9755
#
# Epoch 00056: val_loss did not improve from 0.05528
# Epoch 57/75
# 25/25 [==============================] - 8108s 335s/step - loss: 4.2079e-05 - accuracy: 1.0000 - val_loss: 0.0643 - val_accuracy: 0.9733
#
# Epoch 00057: val_loss did not improve from 0.05528
# Epoch 58/75
# 25/25 [==============================] - 8092s 335s/step - loss: 3.0565e-05 - accuracy: 1.0000 - val_loss: 0.0701 - val_accuracy: 0.9732
#
# Epoch 00058: val_loss did not improve from 0.05528
# Epoch 59/75
# 25/25 [==============================] - 9015s 373s/step - loss: 3.6096e-05 - accuracy: 1.0000 - val_loss: 0.0674 - val_accuracy: 0.9738
#
# Epoch 00059: val_loss did not improve from 0.05528
# Epoch 60/75
# 25/25 [==============================] - 9677s 400s/step - loss: 3.0294e-05 - accuracy: 1.0000 - val_loss: 0.0652 - val_accuracy: 0.9743
#
# Epoch 00060: val_loss did not improve from 0.05528
# Epoch 61/75
# 25/25 [==============================] - 9616s 398s/step - loss: 3.5899e-05 - accuracy: 1.0000 - val_loss: 0.0652 - val_accuracy: 0.9722
#
# Epoch 00061: val_loss did not improve from 0.05528
# Epoch 62/75
# 25/25 [==============================] - 9608s 397s/step - loss: 3.5039e-05 - accuracy: 1.0000 - val_loss: 0.0678 - val_accuracy: 0.9744
#
# Epoch 00062: val_loss did not improve from 0.05528
# Epoch 63/75
# 25/25 [==============================] - 9585s 396s/step - loss: 3.4198e-05 - accuracy: 1.0000 - val_loss: 0.0648 - val_accuracy: 0.9739
#
# Epoch 00063: val_loss did not improve from 0.05528
# Epoch 64/75
# 25/25 [==============================] - 9605s 397s/step - loss: 2.7311e-05 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9757
#
# Epoch 00064: val_loss did not improve from 0.05528
# Epoch 65/75
# 25/25 [==============================] - 9617s 398s/step - loss: 3.9676e-05 - accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 0.9756
#
# Epoch 00065: val_loss did not improve from 0.05528
# Epoch 66/75
# 25/25 [==============================] - 9624s 398s/step - loss: 2.5301e-05 - accuracy: 1.0000 - val_loss: 0.0781 - val_accuracy: 0.9729
#
# Epoch 00066: val_loss did not improve from 0.05528
# Epoch 67/75
# 25/25 [==============================] - 9633s 398s/step - loss: 2.3136e-05 - accuracy: 1.0000 - val_loss: 0.0715 - val_accuracy: 0.9733
#
# Epoch 00067: val_loss did not improve from 0.05528
# Epoch 68/75
# 25/25 [==============================] - 9629s 398s/step - loss: 2.4394e-05 - accuracy: 1.0000 - val_loss: 0.0708 - val_accuracy: 0.9726
#
# Epoch 00068: val_loss did not improve from 0.05528
# Epoch 69/75
# 25/25 [==============================] - 9710s 402s/step - loss: 2.4341e-05 - accuracy: 1.0000 - val_loss: 0.0701 - val_accuracy: 0.9705
#
# Epoch 00069: val_loss did not improve from 0.05528
# Epoch 70/75
# 25/25 [==============================] - 12001s 496s/step - loss: 2.8177e-05 - accuracy: 1.0000 - val_loss: 0.0730 - val_accuracy: 0.9731
#
# Epoch 00070: val_loss did not improve from 0.05528
# Epoch 71/75
# 25/25 [==============================] - 12659s 524s/step - loss: 2.5796e-05 - accuracy: 1.0000 - val_loss: 0.0659 - val_accuracy: 0.9728
#
# Epoch 00071: val_loss did not improve from 0.05528
# Epoch 72/75
# 25/25 [==============================] - 12597s 521s/step - loss: 2.3378e-05 - accuracy: 1.0000 - val_loss: 0.0713 - val_accuracy: 0.9728
#
# Epoch 00072: val_loss did not improve from 0.05528
# Epoch 73/75
# 25/25 [==============================] - 12607s 522s/step - loss: 1.8452e-05 - accuracy: 1.0000 - val_loss: 0.0729 - val_accuracy: 0.9714
#
# Epoch 00073: val_loss did not improve from 0.05528
# Epoch 74/75
# 25/25 [==============================] - 12604s 522s/step - loss: 1.8264e-05 - accuracy: 1.0000 - val_loss: 0.0693 - val_accuracy: 0.9724
#
# Epoch 00074: val_loss did not improve from 0.05528
# Epoch 75/75
# 25/25 [==============================] - 11216s 464s/step - loss: 2.2819e-05 - accuracy: 1.0000 - val_loss: 0.0679 - val_accuracy: 0.9749
#
# Epoch 00075: val_loss did not improve from 0.05528
# INFO:tensorflow:Assets written to: model/xRGM4.2/assets
# CPU times: user 21d 4h 47min 19s, sys: 14h 39min 44s, total: 21d 19h 27min 3s
# Wall time: 8d 3h 7min 34s

# %%
confusion_matrix = pd.DataFrame(metrics.confusion_matrix(y_test, v_classify(y_pred)),
                                columns=['Predicted Negative', 'Predicted Positive'],
                                index=['Actual Negative', 'Actual Positive'])

tp, tn, fp, fn = (
    confusion_matrix.iloc[1,1], 
    confusion_matrix.iloc[0,0], 
    confusion_matrix.iloc[0,1], 
    confusion_matrix.iloc[1,0]
)

accuracy = (tp + tn) / (tp + tn + fp + fn)
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
f1_score = 2 * ((specificity * sensitivity) / (specificity + sensitivity))

with open(os.path.join(f'{model_dir}', 'metrics.csv'), 'a', encoding='utf-8') as f:
    f.write(
        f'{time.strftime("%Y-%m-%dT%H:%M:%S-05:00", time.localtime())}, {accuracy}, {sensitivity}, {specificity}, {f1_score}\n'
    )

print(f'Accuracy:    {accuracy}')
print(f'Sensitivity: {sensitivity}')
print(f'Specificity: {specificity}')
print(f'F1 Score:    {f1_score}')
print('\n')
print(confusion_matrix)
# Out:
# Accuracy:    0.9742351046698873
# Sensitivity: 0.967741935483871
# Specificity: 0.9807073954983923
# F1 Score:    0.9741815278147458
#
#
#                  Predicted Negative  Predicted Positive
# Actual Negative                 305                   6
# Actual Positive                  10                 300

# %%
disease_types=['COVID', 'non-COVID']
Y_pred = np.argmax(y_pred)
Y_true = np.argmax(y_test)

plt.figure(figsize=(7, 7))
ax = sns.heatmap(confusion_matrix , cmap=plt.cm.GnBu , 
                 annot=True, fmt='d',square=True, xticklabels=disease_types, 
                 yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
plt.show()

# %%
def plot_model_history(model_history):
   fig, axs = plt.subplots(1,2,figsize=(15,5))
   # summarize history for accuracy
   axs[0].plot(range(1, len(model_history['accuracy']) + 1), model_history['accuracy'])
   axs[0].plot(range(1, len(model_history['val_accuracy']) + 1), model_history['val_accuracy'])
   axs[0].set_title('Model Accuracy')
   axs[0].set_ylabel('Accuracy')
   axs[0].set_xlabel('Epoch')
   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
   axs[0].legend(['train', 'val'], loc='best')
   # summarize history for loss
   axs[1].plot(range(1, len(model_history['loss'])+1), model_history['loss'])
   axs[1].plot(range(1, len(model_history['val_loss']) + 1), model_history['val_loss'])
   axs[1].set_title('Model Loss')
   axs[1].set_ylabel('Loss')
   axs[1].set_xlabel('Epoch')
   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
   axs[1].legend(['train', 'val'], loc='best')
   plt.show()

# %%
with open(os.path.join('models', 'xRGM4.2-Net-HistDict'), 'rb') as f:
    history = pickle.load(f)
    
plot_model_history(history)
# Out:
# <ipython-input-13-25025fac5012>:9: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
# <ipython-input-13-25025fac5012>:17: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
