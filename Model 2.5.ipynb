# %%
import glob
import json
import os
import pickle
import random
import traceback
from typing import Tuple

import numpy as np
import pandas as pd
import seaborn as sns
from keras.models import Sequential, load_model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Lambda, LeakyReLU, AveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint
from matplotlib import pyplot as plt
from matplotlib.pyplot import hist
from PIL import Image
from scipy.stats import zscore
from sklearn import metrics
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %%
import csv
import time

# %% [markdown]
# ## Config & Constants

# %%
IMAGE_WIDTH, IMAGE_HEIGHT = 227, 227
random.seed(52)

# %% [markdown]
# ## Methods

# %% [markdown]
# ### Image Utilities

# %%
def batch_generator(input_data, output_data, batch_size, is_training):
    input_data_batch = np.empty([batch_size, IMAGE_HEIGHT, IMAGE_WIDTH, 1])
    output_data_batch = np.empty([batch_size, 1])
    while True:
        index = 0
        for i in np.random.permutation(input_data.shape[0]):
            input_data_batch[index] = input_data[i]
            output_data_batch[index] = output_data[i]
            index += 1
            if index == batch_size:
                break
        yield input_data_batch, output_data_batch


def _preprocess(image_loc: str) -> np.ndarray:
    f_image = Image.open(image_loc).convert('L')
    f_image = f_image.resize((IMAGE_WIDTH, IMAGE_HEIGHT), Image.ANTIALIAS)
    image = np.asarray(f_image)
    image = np.expand_dims(image, axis=0)
    image = np.expand_dims(image, axis=3)
    return image


def preprocess(loc: str) -> np.ndarray:
    """Safety wrapper over _preprocess.
    
    Args:
        loc: File location to check if dir or an image.
        
    Returns:
        Preprocessed image(s) as an ndarray.
    """
    if os.path.isdir(loc):
        current = np.concatenate((
            [_preprocess(os.path.join(loc, image)) for image in os.listdir(loc)
             if '.png' in image]
        ))
    else:
        current = _preprocess(loc)
    return current


def generate_data_arrays(
    covid_data: str = 'rsc/New_Data_CoV2/COVID/',
    noncovid_data: str = 'rsc/New_Data_CoV2/non-COVID/',
    others_data:  str = 'rsc/New_Data_CoV2/Others/',
    image_output: str = 'rsc/input_data_v2',
    label_output: str = 'rsc/output_data_v2',
    regenerate: bool = True
) -> Tuple[np.ndarray, np.ndarray]:
    """Loads COVID images into ndarrays.
    
    Args:
        covid_data: Relative path to folder containing COVID images.
        noncovid_data: Relative path to folder containing non-COVID images.
        others_data: Relative path to folder containing Others images.
        image_output: Relative path (with filename) to save loaded images to.
        label_output: Relative path (with filename) to save loaded classes (labels) to.
        regenerate: If True, will regenerate saved ndarray files for both image_output
            and label_output, even if they already exist (overwriting them). If False,
            will simply load and return the aforementioned.
        
    Returns:
        Tuple of ndarrays. The first is the loaded image data in one large ndarray,
        and the second is the loaded labels, also in a large ndarray. These directly
        match up to each other ONLY when both arrays (and their respective files)
        are generated at the same time with this method.
    """
    if (regenerate is False and 
        os.path.isfile(f'{out_input_data}.npy') and
        os.path.isfile(f'{out_output_data}.npy')):
        return (np.load(f'{out_input_data}.npy'),
                np.load(f'{out_output_data}.npy'))
    
    if not ((cd := os.path.exists(covid_data)) and (ncd := os.path.exists(noncovid_data))):
        if (others_data is not None) and not (odd := os.path.exists(others_data)):
            raise NotADirectoryError("Directories do not exist.")
        else:
            raise NotADirectoryError("COVID/non-COVID directories do not exist.")
    
    im_data = np.empty([1, IMAGE_WIDTH, IMAGE_WIDTH, 1])
    output = np.array([0])

    print('Loading Covid Data')
    for i in tqdm(glob.glob(os.path.join(covid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([1])), axis=0)

    print('Loading non-Covid Data')
    for i in tqdm(glob.glob(os.path.join(noncovid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([0])), axis=0)
        
    if others_data is not None:
        print('Loading Others Data')
        for i in tqdm(glob.glob(os.path.join(others_data, '**'))):
            current = preprocess(i)
            im_data = np.concatenate((im_data, current))
            output = np.concatenate((output, np.array([-1])), axis=0)
    else:
        print('Others data not provided; skipping.')


    print('Finished Loading Data')
    im_data = np.delete(im_data, 0, axis=0)
    output = np.delete(output, 0, axis=0)

    zip_data = list(zip(im_data, output))
    random.shuffle(zip_data)
    im_data, output = zip(*zip_data)

    np.save(f'{image_output}', im_data)
    np.save(f'{label_output}', output)
    return im_data, output


def load_data(image_loc: str, label_loc: str, **kwargs) -> Tuple[np.ndarray, np.ndarray]:
    """Attempts to load generated images and labels.
    
    If either is not found, attempts to (re)generate them using the default
    input arguments to the generation method for the raw data, but the input
    `image_loc` and `label_loc` parameters for the output arrays. If this
    still does not work, returns a general error and exits.
    
    Args:
        image_loc: Relative path to saved image ndarray file.
        label_loc: Relative path to saved label ndarray file.
        
    Returns:
        Tuple of ndarrays. The first array holds the loaded image data, whilst
        the second array holds their respective labels.
    
    """
    try:
        image_data = np.load(f'{image_loc}.npy')
        label_data = np.load(f'{label_loc}.npy')
        return image_data, label_data
    
    except FileNotFoundError:
        try:
            image_data, label_data = generate_data_arrays(
                image_output = image_loc,
                label_output = label_loc,
                **kwargs
            )
            return image_data, label_data
        
        except Exception as e:
            traceback.print_exc()

# %% [markdown]
# ## Model Playground

# %%
#Version 1
im_data_v1, output_v1 = load_data(
    image_loc = 'rsc/input_data_v1',
    label_loc = 'rsc/output_data_v1',
    covid_data = 'rsc/Data_CoV2/COVID/',
    noncovid_data = 'rsc/Data_CoV2/non-COVID/',
    others_data = None,
)

x_train, x_test, y_train, y_test = train_test_split(im_data_v1, output_v1, random_state=42)

# %%
def make_model(X_Train, Y_Train, X_Test, Y_Test, model_dir: str):
    if not os.path.exists(model_dir):
        os.makedirs(model_dir)
    #X_Train, X_Test, Y_Train, Y_Test = train_test_split(input_data, output_data, test_size=0.1)

    for_pad = lambda s: s if s > 2 else 3

    model = Sequential()
    model.add(Lambda(lambda x: x, input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 1)))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=8, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))



    #model.add(ZeroPadding2D(padding=(for_pad(19) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(Conv2D(kernel_size=(3, 3), filters=2, strides=(1, 1),activation='relu'))

    model.add(Flatten())

    model.add(Dropout(rate=0.4))
    model.add(Dense(units=338, activation='relu'))
    model.add(Dense(units=1, activation='sigmoid'))

    model.compile(optimizer=RMSprop(), loss='binary_crossentropy', metrics=["accuracy"])
    model.summary()

    checkpoint = ModelCheckpoint(os.path.join(model_dir, 'xRGM2.5'), verbose=1, period=1, save_best_only=True)

    hist = model.fit_generator(batch_generator(X_Train, Y_Train, 128, True),
                        validation_data=(batch_generator(X_Test, Y_Test, 128, False)), callbacks=[checkpoint],
                        verbose=1, epochs=75, steps_per_epoch=25, validation_steps=len(X_Test))

    with open(os.path.join('models', 'xRGM2.5-Net-HistDict'), 'wb') as f:
        pickle.dump(hist.history, f)

    model.save(model_dir)
    
    return model
#lr=0.001

# %%
# %%time
model_dir: str = 'model/xRGM2.5'
xRGM = make_model(x_train, y_train.reshape(-1,1), x_test, y_test.reshape(-1,1), model_dir=model_dir)

v_classify = np.vectorize(lambda x: np.round(x, 0))
# xRGMCT2 = load_model('models/xRGMCT2L.h5')
# print(xRGMCT2.history)
y_pred = (xRGM.predict(x_test))

#print(y_test)
#print(y_pred)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_1 (Lambda)            (None, 227, 227, 1)       0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 225, 225, 8)       80
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 225, 225, 8)       32
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 225, 225, 8)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 112, 112, 8)       0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 110, 110, 16)      1168
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 110, 110, 16)      64
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 110, 110, 16)      0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 108, 108, 32)      4640
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 108, 108, 32)      128
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 108, 108, 32)      0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 108, 108, 16)      528
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 108, 108, 16)      64
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 108, 108, 16)      0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 106, 106, 32)      4640
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 106, 106, 32)      128
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 106, 106, 32)      0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 104, 104, 64)      18496
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 104, 104, 64)      256
# _________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)   (None, 104, 104, 64)      0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 104, 104, 32)      2080
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 104, 104, 32)      128
# _________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)   (None, 104, 104, 32)      0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 102, 102, 64)      18496
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 102, 102, 64)      256
# _________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)   (None, 102, 102, 64)      0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 100, 100, 128)     73856
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 100, 100, 128)     512
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 100, 100, 128)     0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 100, 100, 64)      8256
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 100, 100, 64)      256
# _________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)   (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 98, 98, 128)       73856
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 98, 98, 128)       512
# _________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)   (None, 98, 98, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 49, 49, 128)       0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 47, 47, 256)       295168
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 47, 47, 256)       1024
# _________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)   (None, 47, 47, 256)       0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 47, 47, 128)       32896
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 47, 47, 128)       512
# _________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)   (None, 47, 47, 128)       0
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 23, 23, 128)       0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 21, 21, 256)       295168
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 21, 21, 256)       1024
# _________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)   (None, 21, 21, 256)       0
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 10, 10, 256)       0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 10, 10, 128)       32896
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)   (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)   (None, 8, 8, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16384)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 338)               5538130
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 339
# =================================================================
# Total params: 6,702,293
# Trainable params: 6,699,077
# Non-trainable params: 3,216
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/75
# 25/25 [==============================] - 4847s 200s/step - loss: 3.4653 - accuracy: 0.5597 - val_loss: 0.7039 - val_accuracy: 0.5335
#
# Epoch 00001: val_loss improved from inf to 0.70390, saving model to model/xRGM2.5/xRGM2.5
# INFO:tensorflow:Assets written to: model/xRGM2.5/xRGM2.5/assets
# Epoch 2/75
# 25/25 [==============================] - 4885s 202s/step - loss: 0.4830 - accuracy: 0.7774 - val_loss: 0.9034 - val_accuracy: 0.4070
#
# Epoch 00002: val_loss did not improve from 0.70390
# Epoch 3/75
# 25/25 [==============================] - 4872s 201s/step - loss: 0.3758 - accuracy: 0.8471 - val_loss: 6.3327 - val_accuracy: 0.4491
#
# Epoch 00003: val_loss did not improve from 0.70390
# Epoch 4/75
# 25/25 [==============================] - 4867s 201s/step - loss: 0.4190 - accuracy: 0.8342 - val_loss: 21.6999 - val_accuracy: 0.4879
#
# Epoch 00004: val_loss did not improve from 0.70390
# Epoch 5/75
# 25/25 [==============================] - 4865s 201s/step - loss: 0.3204 - accuracy: 0.8678 - val_loss: 30.8955 - val_accuracy: 0.4733
#
# Epoch 00005: val_loss did not improve from 0.70390
# Epoch 6/75
# 25/25 [==============================] - 4860s 201s/step - loss: 0.2906 - accuracy: 0.8926 - val_loss: 9.2054 - val_accuracy: 0.5751
#
# Epoch 00006: val_loss did not improve from 0.70390
# Epoch 7/75
# 25/25 [==============================] - 4863s 201s/step - loss: 0.2088 - accuracy: 0.9152 - val_loss: 7.2393 - val_accuracy: 0.7156
#
# Epoch 00007: val_loss did not improve from 0.70390
# Epoch 8/75
# 25/25 [==============================] - 4864s 201s/step - loss: 0.2039 - accuracy: 0.9261 - val_loss: 4.2082 - val_accuracy: 0.7002
#
# Epoch 00008: val_loss did not improve from 0.70390
# Epoch 9/75
# 25/25 [==============================] - 4861s 201s/step - loss: 0.1434 - accuracy: 0.9421 - val_loss: 4.1371 - val_accuracy: 0.8200
#
# Epoch 00009: val_loss did not improve from 0.70390
# Epoch 10/75
# 25/25 [==============================] - 4858s 201s/step - loss: 0.1490 - accuracy: 0.9494 - val_loss: 4.6046 - val_accuracy: 0.7329
#
# Epoch 00010: val_loss did not improve from 0.70390
# Epoch 11/75
# 25/25 [==============================] - 4851s 201s/step - loss: 0.0830 - accuracy: 0.9674 - val_loss: 2.2758 - val_accuracy: 0.8227
#
# Epoch 00011: val_loss did not improve from 0.70390
# Epoch 12/75
# 25/25 [==============================] - 4884s 202s/step - loss: 0.0526 - accuracy: 0.9814 - val_loss: 1.3230 - val_accuracy: 0.7710
#
# Epoch 00012: val_loss did not improve from 0.70390
# Epoch 13/75
# 25/25 [==============================] - 4861s 201s/step - loss: 0.1359 - accuracy: 0.9496 - val_loss: 3.6608 - val_accuracy: 0.7899
#
# Epoch 00013: val_loss did not improve from 0.70390
# Epoch 14/75
# 25/25 [==============================] - 4865s 201s/step - loss: 0.0413 - accuracy: 0.9849 - val_loss: 3.4808 - val_accuracy: 0.7954
#
# Epoch 00014: val_loss did not improve from 0.70390
# Epoch 15/75
# 25/25 [==============================] - 4857s 201s/step - loss: 0.1267 - accuracy: 0.9630 - val_loss: 4.0125 - val_accuracy: 0.7961
#
# Epoch 00015: val_loss did not improve from 0.70390
# Epoch 16/75
# 25/25 [==============================] - 4879s 202s/step - loss: 0.0273 - accuracy: 0.9936 - val_loss: 8.7049 - val_accuracy: 0.6373
#
# Epoch 00016: val_loss did not improve from 0.70390
# Epoch 17/75
# 25/25 [==============================] - 4862s 201s/step - loss: 0.1286 - accuracy: 0.9792 - val_loss: 2.8238 - val_accuracy: 0.7726
#
# Epoch 00017: val_loss did not improve from 0.70390
# Epoch 18/75
# 25/25 [==============================] - 4869s 201s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.6698 - val_accuracy: 0.9080
#
# Epoch 00018: val_loss improved from 0.70390 to 0.66976, saving model to model/xRGM2.5/xRGM2.5
# INFO:tensorflow:Assets written to: model/xRGM2.5/xRGM2.5/assets
# Epoch 19/75
# 25/25 [==============================] - 4870s 201s/step - loss: 0.0816 - accuracy: 0.9775 - val_loss: 0.7926 - val_accuracy: 0.8905
#
# Epoch 00019: val_loss did not improve from 0.66976
# Epoch 20/75
# 25/25 [==============================] - 4871s 201s/step - loss: 0.0077 - accuracy: 0.9965 - val_loss: 0.6297 - val_accuracy: 0.9094
#
# Epoch 00020: val_loss improved from 0.66976 to 0.62974, saving model to model/xRGM2.5/xRGM2.5
# INFO:tensorflow:Assets written to: model/xRGM2.5/xRGM2.5/assets
# Epoch 21/75
# 25/25 [==============================] - 4859s 201s/step - loss: 0.0095 - accuracy: 0.9975 - val_loss: 0.8542 - val_accuracy: 0.9077
#
# Epoch 00021: val_loss did not improve from 0.62974
# Epoch 22/75
# 25/25 [==============================] - 4851s 200s/step - loss: 0.0146 - accuracy: 0.9957 - val_loss: 0.7897 - val_accuracy: 0.8868
#
# Epoch 00022: val_loss did not improve from 0.62974
# Epoch 23/75
# 25/25 [==============================] - 4861s 201s/step - loss: 7.3358e-04 - accuracy: 1.0000 - val_loss: 0.4270 - val_accuracy: 0.9245
#
# Epoch 00023: val_loss improved from 0.62974 to 0.42699, saving model to model/xRGM2.5/xRGM2.5
# INFO:tensorflow:Assets written to: model/xRGM2.5/xRGM2.5/assets
# Epoch 24/75
# 25/25 [==============================] - 4854s 201s/step - loss: 0.1390 - accuracy: 0.9703 - val_loss: 7.9982 - val_accuracy: 0.6601
#
# Epoch 00024: val_loss did not improve from 0.42699
# Epoch 25/75
# 25/25 [==============================] - 4848s 200s/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 2.3086 - val_accuracy: 0.8360
#
# Epoch 00025: val_loss did not improve from 0.42699
# Epoch 26/75
# 25/25 [==============================] - 4851s 200s/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 4.0606 - val_accuracy: 0.7587
#
# Epoch 00026: val_loss did not improve from 0.42699
# Epoch 27/75
# 25/25 [==============================] - 4851s 200s/step - loss: 0.2100 - accuracy: 0.9684 - val_loss: 1.7118 - val_accuracy: 0.8419
#
# Epoch 00027: val_loss did not improve from 0.42699
# Epoch 28/75
# 25/25 [==============================] - 4841s 200s/step - loss: 7.8169e-04 - accuracy: 1.0000 - val_loss: 0.8007 - val_accuracy: 0.8806
#
# Epoch 00028: val_loss did not improve from 0.42699
# Epoch 29/75
# 25/25 [==============================] - 4837s 200s/step - loss: 2.5239e-04 - accuracy: 1.0000 - val_loss: 0.5002 - val_accuracy: 0.9114
#
# Epoch 00029: val_loss did not improve from 0.42699
# Epoch 30/75
# 25/25 [==============================] - 4810s 199s/step - loss: 0.0254 - accuracy: 0.9958 - val_loss: 8.8490 - val_accuracy: 0.6760
#
# Epoch 00030: val_loss did not improve from 0.42699
# Epoch 31/75
# 25/25 [==============================] - 4807s 199s/step - loss: 0.0032 - accuracy: 0.9994 - val_loss: 1.4077 - val_accuracy: 0.8306
#
# Epoch 00031: val_loss did not improve from 0.42699
# Epoch 32/75
# 25/25 [==============================] - 4819s 199s/step - loss: 0.0119 - accuracy: 0.9974 - val_loss: 0.6717 - val_accuracy: 0.9230
#
# Epoch 00032: val_loss did not improve from 0.42699
# Epoch 33/75
# 25/25 [==============================] - 4817s 199s/step - loss: 0.0088 - accuracy: 0.9988 - val_loss: 0.7021 - val_accuracy: 0.9177
#
# Epoch 00033: val_loss did not improve from 0.42699
# Epoch 34/75
# 25/25 [==============================] - 4788s 198s/step - loss: 2.4203e-04 - accuracy: 1.0000 - val_loss: 0.3267 - val_accuracy: 0.9459
#
# Epoch 00034: val_loss improved from 0.42699 to 0.32669, saving model to model/xRGM2.5/xRGM2.5
# INFO:tensorflow:Assets written to: model/xRGM2.5/xRGM2.5/assets
# Epoch 35/75
# 25/25 [==============================] - 4806s 199s/step - loss: 0.0451 - accuracy: 0.9935 - val_loss: 1.8505 - val_accuracy: 0.8371
#
# Epoch 00035: val_loss did not improve from 0.32669
# Epoch 36/75
# 25/25 [==============================] - 4792s 198s/step - loss: 4.4047e-04 - accuracy: 1.0000 - val_loss: 1.2018 - val_accuracy: 0.8850
#
# Epoch 00036: val_loss did not improve from 0.32669
# Epoch 37/75
# 25/25 [==============================] - 4791s 198s/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 1.1313 - val_accuracy: 0.8776
#
# Epoch 00037: val_loss did not improve from 0.32669
# Epoch 38/75
# 25/25 [==============================] - 4783s 198s/step - loss: 0.0023 - accuracy: 0.9988 - val_loss: 1.2465 - val_accuracy: 0.8600
#
# Epoch 00038: val_loss did not improve from 0.32669
# Epoch 39/75
# 25/25 [==============================] - 4772s 197s/step - loss: 9.9084e-05 - accuracy: 1.0000 - val_loss: 0.8524 - val_accuracy: 0.8954
#
# Epoch 00039: val_loss did not improve from 0.32669
# Epoch 40/75
# 25/25 [==============================] - 4757s 196s/step - loss: 0.0146 - accuracy: 0.9976 - val_loss: 1.0355 - val_accuracy: 0.8976
#
# Epoch 00040: val_loss did not improve from 0.32669
# Epoch 41/75
# 25/25 [==============================] - 4734s 196s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5906 - val_accuracy: 0.9374
#
# Epoch 00041: val_loss did not improve from 0.32669
# Epoch 42/75
# 25/25 [==============================] - 4728s 195s/step - loss: 9.5898e-04 - accuracy: 0.9999 - val_loss: 6.9820 - val_accuracy: 0.7841
#
# Epoch 00042: val_loss did not improve from 0.32669
# Epoch 43/75
# 25/25 [==============================] - 4738s 196s/step - loss: 0.0566 - accuracy: 0.9891 - val_loss: 0.6605 - val_accuracy: 0.9250
#
# Epoch 00043: val_loss did not improve from 0.32669
# Epoch 44/75
# 25/25 [==============================] - 4740s 196s/step - loss: 3.4133e-04 - accuracy: 1.0000 - val_loss: 0.3802 - val_accuracy: 0.9589
#
# Epoch 00044: val_loss did not improve from 0.32669
# Epoch 45/75
# 25/25 [==============================] - 4750s 196s/step - loss: 8.4081e-05 - accuracy: 1.0000 - val_loss: 0.2800 - val_accuracy: 0.9657
#
# Epoch 00045: val_loss improved from 0.32669 to 0.28001, saving model to model/xRGM2.5/xRGM2.5
# INFO:tensorflow:Assets written to: model/xRGM2.5/xRGM2.5/assets
# Epoch 46/75
# 25/25 [==============================] - 4746s 196s/step - loss: 3.4826e-05 - accuracy: 1.0000 - val_loss: 0.2156 - val_accuracy: 0.9679
#
# Epoch 00046: val_loss improved from 0.28001 to 0.21558, saving model to model/xRGM2.5/xRGM2.5
# INFO:tensorflow:Assets written to: model/xRGM2.5/xRGM2.5/assets
# Epoch 47/75
# 25/25 [==============================] - 4750s 196s/step - loss: 0.0180 - accuracy: 0.9959 - val_loss: 0.9158 - val_accuracy: 0.9041
#
# Epoch 00047: val_loss did not improve from 0.21558
# Epoch 48/75
# 25/25 [==============================] - 4746s 196s/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.6371 - val_accuracy: 0.9210
#
# Epoch 00048: val_loss did not improve from 0.21558
# Epoch 49/75
# 25/25 [==============================] - 4748s 196s/step - loss: 9.6901e-05 - accuracy: 1.0000 - val_loss: 0.4986 - val_accuracy: 0.9289
#
# Epoch 00049: val_loss did not improve from 0.21558
# Epoch 50/75
# 25/25 [==============================] - 4744s 196s/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.5364 - val_accuracy: 0.9103
#
# Epoch 00050: val_loss did not improve from 0.21558
# Epoch 51/75
# 25/25 [==============================] - 4747s 196s/step - loss: 5.3725e-04 - accuracy: 1.0000 - val_loss: 0.3426 - val_accuracy: 0.9358
#
# Epoch 00051: val_loss did not improve from 0.21558
# Epoch 52/75
# 25/25 [==============================] - 4747s 196s/step - loss: 2.3364e-05 - accuracy: 1.0000 - val_loss: 0.2366 - val_accuracy: 0.9582
#
# Epoch 00052: val_loss did not improve from 0.21558
# Epoch 53/75
# 25/25 [==============================] - 4747s 196s/step - loss: 0.0056 - accuracy: 0.9988 - val_loss: 4.4403 - val_accuracy: 0.8291
#
# Epoch 00053: val_loss did not improve from 0.21558
# Epoch 54/75
# 25/25 [==============================] - 4742s 196s/step - loss: 0.0019 - accuracy: 0.9993 - val_loss: 0.3086 - val_accuracy: 0.9461
#
# Epoch 00054: val_loss did not improve from 0.21558
# Epoch 55/75
# 25/25 [==============================] - 4771s 197s/step - loss: 4.0140e-05 - accuracy: 1.0000 - val_loss: 0.2780 - val_accuracy: 0.9584
#
# Epoch 00055: val_loss did not improve from 0.21558
# Epoch 56/75
# 25/25 [==============================] - 4748s 196s/step - loss: 0.0037 - accuracy: 0.9993 - val_loss: 7.9482 - val_accuracy: 0.6387
#
# Epoch 00056: val_loss did not improve from 0.21558
# Epoch 57/75
# 25/25 [==============================] - 4748s 196s/step - loss: 0.0140 - accuracy: 0.9978 - val_loss: 0.6503 - val_accuracy: 0.9355
#
# Epoch 00057: val_loss did not improve from 0.21558
# Epoch 58/75
# 25/25 [==============================] - 4752s 196s/step - loss: 5.3851e-04 - accuracy: 1.0000 - val_loss: 0.3306 - val_accuracy: 0.9522
#
# Epoch 00058: val_loss did not improve from 0.21558
# Epoch 59/75
# 25/25 [==============================] - 4750s 196s/step - loss: 2.1080e-05 - accuracy: 1.0000 - val_loss: 0.2780 - val_accuracy: 0.9628
#
# Epoch 00059: val_loss did not improve from 0.21558
# Epoch 60/75
# 25/25 [==============================] - 4748s 196s/step - loss: 1.8945e-05 - accuracy: 1.0000 - val_loss: 0.2333 - val_accuracy: 0.9637
#
# Epoch 00060: val_loss did not improve from 0.21558
# Epoch 61/75
# 25/25 [==============================] - 4750s 196s/step - loss: 0.0093 - accuracy: 0.9983 - val_loss: 1.4098 - val_accuracy: 0.8949
#
# Epoch 00061: val_loss did not improve from 0.21558
# Epoch 62/75
# 25/25 [==============================] - 4738s 196s/step - loss: 1.9573e-04 - accuracy: 1.0000 - val_loss: 0.7423 - val_accuracy: 0.9271
#
# Epoch 00062: val_loss did not improve from 0.21558
# Epoch 63/75
# 25/25 [==============================] - 4734s 196s/step - loss: 0.0066 - accuracy: 0.9984 - val_loss: 4.2052 - val_accuracy: 0.7466
#
# Epoch 00063: val_loss did not improve from 0.21558
# Epoch 64/75
# 25/25 [==============================] - 4738s 196s/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 2.3904 - val_accuracy: 0.8297
#
# Epoch 00064: val_loss did not improve from 0.21558
# Epoch 65/75
# 25/25 [==============================] - 4760s 197s/step - loss: 0.0277 - accuracy: 0.9962 - val_loss: 11.1585 - val_accuracy: 0.6199
#
# Epoch 00065: val_loss did not improve from 0.21558
# Epoch 66/75
# 25/25 [==============================] - 4781s 198s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 4.4300 - val_accuracy: 0.7196
#
# Epoch 00066: val_loss did not improve from 0.21558
# Epoch 67/75
# 25/25 [==============================] - 4792s 198s/step - loss: 3.2690e-04 - accuracy: 1.0000 - val_loss: 2.2178 - val_accuracy: 0.7961
#
# Epoch 00067: val_loss did not improve from 0.21558
# Epoch 68/75
# 25/25 [==============================] - 4794s 199s/step - loss: 0.0127 - accuracy: 0.9981 - val_loss: 0.4406 - val_accuracy: 0.9469
#
# Epoch 00068: val_loss did not improve from 0.21558
# Epoch 69/75
# 25/25 [==============================] - 4791s 198s/step - loss: 4.1224e-05 - accuracy: 1.0000 - val_loss: 0.3147 - val_accuracy: 0.9671
#
# Epoch 00069: val_loss did not improve from 0.21558
# Epoch 70/75
# 25/25 [==============================] - 4795s 199s/step - loss: 2.2632e-05 - accuracy: 1.0000 - val_loss: 0.2765 - val_accuracy: 0.9652
#
# Epoch 00070: val_loss did not improve from 0.21558
# Epoch 71/75
# 25/25 [==============================] - 4798s 199s/step - loss: 0.0082 - accuracy: 0.9976 - val_loss: 0.6501 - val_accuracy: 0.9077
#
# Epoch 00071: val_loss did not improve from 0.21558
# Epoch 72/75
# 25/25 [==============================] - 4807s 199s/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.7323 - val_accuracy: 0.8872
#
# Epoch 00072: val_loss did not improve from 0.21558
# Epoch 73/75
# 25/25 [==============================] - 4816s 199s/step - loss: 6.9375e-05 - accuracy: 1.0000 - val_loss: 0.3699 - val_accuracy: 0.9351
#
# Epoch 00073: val_loss did not improve from 0.21558
# Epoch 74/75
# 25/25 [==============================] - 4813s 199s/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 27.0682 - val_accuracy: 0.5734
#
# Epoch 00074: val_loss did not improve from 0.21558
# Epoch 75/75
# 25/25 [==============================] - 4741s 196s/step - loss: 1.0716e-04 - accuracy: 1.0000 - val_loss: 5.1632 - val_accuracy: 0.7949
#
# Epoch 00075: val_loss did not improve from 0.21558
# INFO:tensorflow:Assets written to: model/xRGM2.5/assets
# CPU times: user 21d 10h 23min 17s, sys: 16h 59min 27s, total: 22d 3h 22min 44s
# Wall time: 4d 4h 7min 30s

# %%
confusion_matrix = pd.DataFrame(metrics.confusion_matrix(y_test, v_classify(y_pred)),
                                columns=['Predicted Negative', 'Predicted Positive'],
                                index=['Actual Negative', 'Actual Positive'])

tp, tn, fp, fn = (
    confusion_matrix.iloc[1,1], 
    confusion_matrix.iloc[0,0], 
    confusion_matrix.iloc[0,1], 
    confusion_matrix.iloc[1,0]
)

accuracy = (tp + tn) / (tp + tn + fp + fn)
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
f1_score = 2 * ((specificity * sensitivity) / (specificity + sensitivity))

with open(os.path.join(f'{model_dir}', 'metrics.csv'), 'a', encoding='utf-8') as f:
    f.write(
        f'{time.strftime("%Y-%m-%dT%H:%M:%S-05:00", time.localtime())}, {accuracy}, {sensitivity}, {specificity}, {f1_score}\n'
    )

print(f'Accuracy:    {accuracy}')
print(f'Sensitivity: {sensitivity}')
print(f'Specificity: {specificity}')
print(f'F1 Score:    {f1_score}')
print('\n')
print(confusion_matrix)
# Out:
# Accuracy:    0.7954911433172303
# Sensitivity: 0.967741935483871
# Specificity: 0.6237942122186495
# F1 Score:    0.7586027111574557
#
#
#                  Predicted Negative  Predicted Positive
# Actual Negative                 194                 117
# Actual Positive                  10                 300

# %%
disease_types=['COVID', 'non-COVID']
Y_pred = np.argmax(y_pred)
Y_true = np.argmax(y_test)

plt.figure(figsize=(7, 7))
ax = sns.heatmap(confusion_matrix , cmap=plt.cm.GnBu , 
                 annot=True, fmt='d',square=True, xticklabels=disease_types, 
                 yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
plt.show()

# %%
def plot_model_history(model_history):
   fig, axs = plt.subplots(1,2,figsize=(15,5))
   # summarize history for accuracy
   axs[0].plot(range(1, len(model_history['accuracy']) + 1), model_history['accuracy'])
   axs[0].plot(range(1, len(model_history['val_accuracy']) + 1), model_history['val_accuracy'])
   axs[0].set_title('Model Accuracy')
   axs[0].set_ylabel('Accuracy')
   axs[0].set_xlabel('Epoch')
   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
   axs[0].legend(['train', 'val'], loc='best')
   # summarize history for loss
   axs[1].plot(range(1, len(model_history['loss'])+1), model_history['loss'])
   axs[1].plot(range(1, len(model_history['val_loss']) + 1), model_history['val_loss'])
   axs[1].set_title('Model Loss')
   axs[1].set_ylabel('Loss')
   axs[1].set_xlabel('Epoch')
   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
   axs[1].legend(['train', 'val'], loc='best')
   plt.show()

# %%
with open(os.path.join('models', 'xRGM2.5-Net-HistDict'), 'rb') as f:
    history = pickle.load(f)
    
plot_model_history(history)
# Out:
# <ipython-input-21-25025fac5012>:9: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
# <ipython-input-21-25025fac5012>:17: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
