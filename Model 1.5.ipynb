# %%
import glob
import json
import os
import pickle
import random
import traceback
from typing import Tuple

import numpy as np
import pandas as pd
import seaborn as sns
from keras.models import Sequential, load_model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Lambda, LeakyReLU, AveragePooling2D, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from matplotlib import pyplot as plt
from matplotlib.pyplot import hist
from PIL import Image
from scipy.stats import zscore
from sklearn import metrics
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %%
import csv
import time

# %% [markdown]
# ## Config & Constants

# %%
IMAGE_WIDTH, IMAGE_HEIGHT = 227, 227
random.seed(52)

# %% [markdown]
# ## Methods

# %% [markdown]
# ### Image Utilities

# %%
def batch_generator(input_data, output_data, batch_size, is_training):
    input_data_batch = np.empty([batch_size, IMAGE_HEIGHT, IMAGE_WIDTH, 1])
    output_data_batch = np.empty([batch_size, 1])
    while True:
        index = 0
        for i in np.random.permutation(input_data.shape[0]):
            input_data_batch[index] = input_data[i]
            output_data_batch[index] = output_data[i]
            index += 1
            if index == batch_size:
                break
        yield input_data_batch, output_data_batch


def _preprocess(image_loc: str) -> np.ndarray:
    f_image = Image.open(image_loc).convert('L')
    f_image = f_image.resize((IMAGE_WIDTH, IMAGE_HEIGHT), Image.ANTIALIAS)
    image = np.asarray(f_image)
    image = np.expand_dims(image, axis=0)
    image = np.expand_dims(image, axis=3)
    return image


def preprocess(loc: str) -> np.ndarray:
    """Safety wrapper over _preprocess.
    
    Args:
        loc: File location to check if dir or an image.
        
    Returns:
        Preprocessed image(s) as an ndarray.
    """
    if os.path.isdir(loc):
        current = np.concatenate((
            [_preprocess(os.path.join(loc, image)) for image in os.listdir(loc)
             if '.png' in image]
        ))
    else:
        current = _preprocess(loc)
    return current


def generate_data_arrays(
    covid_data: str = 'rsc/New_Data_CoV2/COVID/',
    noncovid_data: str = 'rsc/New_Data_CoV2/non-COVID/',
    others_data:  str = 'rsc/New_Data_CoV2/Others/',
    image_output: str = 'rsc/input_data_v2',
    label_output: str = 'rsc/output_data_v2',
    regenerate: bool = True
) -> Tuple[np.ndarray, np.ndarray]:
    """Loads COVID images into ndarrays.
    
    Args:
        covid_data: Relative path to folder containing COVID images.
        noncovid_data: Relative path to folder containing non-COVID images.
        others_data: Relative path to folder containing Others images.
        image_output: Relative path (with filename) to save loaded images to.
        label_output: Relative path (with filename) to save loaded classes (labels) to.
        regenerate: If True, will regenerate saved ndarray files for both image_output
            and label_output, even if they already exist (overwriting them). If False,
            will simply load and return the aforementioned.
        
    Returns:
        Tuple of ndarrays. The first is the loaded image data in one large ndarray,
        and the second is the loaded labels, also in a large ndarray. These directly
        match up to each other ONLY when both arrays (and their respective files)
        are generated at the same time with this method.
    """
    if (regenerate is False and 
        os.path.isfile(f'{out_input_data}.npy') and
        os.path.isfile(f'{out_output_data}.npy')):
        return (np.load(f'{out_input_data}.npy'),
                np.load(f'{out_output_data}.npy'))
    
    if not ((cd := os.path.exists(covid_data)) and (ncd := os.path.exists(noncovid_data))):
        if (others_data is not None) and not (odd := os.path.exists(others_data)):
            raise NotADirectoryError("Directories do not exist.")
        else:
            raise NotADirectoryError("COVID/non-COVID directories do not exist.")
    
    im_data = np.empty([1, IMAGE_WIDTH, IMAGE_WIDTH, 1])
    output = np.array([0])

    print('Loading Covid Data')
    for i in tqdm(glob.glob(os.path.join(covid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([1])), axis=0)

    print('Loading non-Covid Data')
    for i in tqdm(glob.glob(os.path.join(noncovid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([0])), axis=0)
        
    if others_data is not None:
        print('Loading Others Data')
        for i in tqdm(glob.glob(os.path.join(others_data, '**'))):
            current = preprocess(i)
            im_data = np.concatenate((im_data, current))
            output = np.concatenate((output, np.array([-1])), axis=0)
    else:
        print('Others data not provided; skipping.')


    print('Finished Loading Data')
    im_data = np.delete(im_data, 0, axis=0)
    output = np.delete(output, 0, axis=0)

    zip_data = list(zip(im_data, output))
    random.shuffle(zip_data)
    im_data, output = zip(*zip_data)

    np.save(f'{image_output}', im_data)
    np.save(f'{label_output}', output)
    return im_data, output


def load_data(image_loc: str, label_loc: str, **kwargs) -> Tuple[np.ndarray, np.ndarray]:
    """Attempts to load generated images and labels.
    
    If either is not found, attempts to (re)generate them using the default
    input arguments to the generation method for the raw data, but the input
    `image_loc` and `label_loc` parameters for the output arrays. If this
    still does not work, returns a general error and exits.
    
    Args:
        image_loc: Relative path to saved image ndarray file.
        label_loc: Relative path to saved label ndarray file.
        
    Returns:
        Tuple of ndarrays. The first array holds the loaded image data, whilst
        the second array holds their respective labels.
    
    """
    try:
        image_data = np.load(f'{image_loc}.npy')
        label_data = np.load(f'{label_loc}.npy')
        return image_data, label_data
    
    except FileNotFoundError:
        try:
            image_data, label_data = generate_data_arrays(
                image_output = image_loc,
                label_output = label_loc,
                **kwargs
            )
            return image_data, label_data
        
        except Exception as e:
            traceback.print_exc()

# %% [markdown]
# ## Model Playground

# %%
#Version 1
im_data_v1, output_v1 = load_data(
    image_loc = 'rsc/input_data_v1',
    label_loc = 'rsc/output_data_v1',
    covid_data = 'rsc/Data_CoV2/COVID/',
    noncovid_data = 'rsc/Data_CoV2/non-COVID/',
    others_data = None,
)

x_train, x_test, y_train, y_test = train_test_split(im_data_v1, output_v1, random_state=42)

# %%
def make_model(X_Train, Y_Train, X_Test, Y_Test, model_dir: str):
    if not os.path.exists(model_dir):
        os.makedirs(model_dir)
    #X_Train, X_Test, Y_Train, Y_Test = train_test_split(input_data, output_data, test_size=0.1)

    for_pad = lambda s: s if s > 2 else 3

    model = Sequential()
    model.add(Lambda(lambda x: x, input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 1)))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=8, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))



    #model.add(ZeroPadding2D(padding=(for_pad(19) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(Conv2D(kernel_size=(3, 3), filters=2, strides=(1, 1),activation='relu'))

    model.add(Flatten())

    model.add(Dropout(rate=0.4))
    model.add(Dense(units=338, activation='relu'))
    model.add(Dense(units=1, activation='sigmoid'))

    model.compile(optimizer=Adam(lr=3e-4), loss='binary_crossentropy', metrics=["accuracy"])
    model.summary()

    checkpoint = ModelCheckpoint(os.path.join(model_dir, 'xRGM1.5'), verbose=1, period=1, save_best_only=True)

    hist = model.fit_generator(batch_generator(X_Train, Y_Train, 128, True),
                        validation_data=(batch_generator(X_Test, Y_Test, 128, False)), callbacks=[checkpoint],
                        verbose=1, epochs=75, steps_per_epoch=25, validation_steps=len(X_Test))

    with open(os.path.join('models', 'xRGM1.5-Net-HistDict'), 'wb') as f:
        pickle.dump(hist.history, f)

    model.save(model_dir)
    
    return model
#changed steps and epochs and batchsize

# %%
# %%time
model_dir: str = 'model/xRGM1.5'
xRGM = make_model(x_train, y_train.reshape(-1,1), x_test, y_test.reshape(-1,1), model_dir=model_dir)

v_classify = np.vectorize(lambda x: np.round(x, 0))
# xRGMCT2 = load_model('models/xRGMCT2L.h5')
# print(xRGMCT2.history)
y_pred = (xRGM.predict(x_test))

#print(y_test)
#print(y_pred)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda (Lambda)              (None, 227, 227, 1)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 225, 225, 8)       80
# _________________________________________________________________
# batch_normalization (BatchNo (None, 225, 225, 8)       32
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 225, 225, 8)       0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 110, 110, 16)      1168
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 110, 110, 16)      64
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 110, 110, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 108, 108, 32)      4640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 108, 108, 32)      128
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 108, 108, 32)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 108, 108, 16)      528
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 108, 108, 16)      64
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 108, 108, 16)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 106, 106, 32)      4640
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 106, 106, 32)      128
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 106, 106, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 104, 104, 64)      18496
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 104, 104, 64)      256
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 104, 104, 64)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 104, 104, 32)      2080
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 104, 104, 32)      128
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 104, 104, 32)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 102, 102, 64)      18496
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 102, 102, 64)      256
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 102, 102, 64)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 100, 100, 128)     73856
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 100, 100, 128)     512
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 100, 100, 128)     0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 100, 100, 64)      8256
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 100, 100, 64)      256
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 98, 98, 128)       73856
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 98, 98, 128)       512
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 98, 98, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 49, 49, 128)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 47, 47, 256)       295168
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 47, 47, 256)       1024
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 47, 47, 256)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 47, 47, 128)       32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 47, 47, 128)       512
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 47, 47, 128)       0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 23, 23, 128)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 21, 21, 256)       295168
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 21, 21, 256)       1024
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 21, 21, 256)       0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 10, 10, 256)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 10, 10, 128)       32896
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 8, 8, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 338)               5538130
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 339
# =================================================================
# Total params: 6,702,293
# Trainable params: 6,699,077
# Non-trainable params: 3,216
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# /home/jg1994/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/75
# 25/25 [==============================] - 14166s 586s/step - loss: 0.6631 - accuracy: 0.6130 - val_loss: 0.6934 - val_accuracy: 0.4996
#
# Epoch 00001: val_loss improved from inf to 0.69344, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 2/75
# 25/25 [==============================] - 14301s 592s/step - loss: 0.4391 - accuracy: 0.8087 - val_loss: 0.6936 - val_accuracy: 0.5001
#
# Epoch 00002: val_loss did not improve from 0.69344
# Epoch 3/75
# 25/25 [==============================] - 14454s 598s/step - loss: 0.3307 - accuracy: 0.8742 - val_loss: 0.6942 - val_accuracy: 0.5002
#
# Epoch 00003: val_loss did not improve from 0.69344
# Epoch 4/75
# 25/25 [==============================] - 14292s 591s/step - loss: 0.2760 - accuracy: 0.9075 - val_loss: 0.6984 - val_accuracy: 0.4983
#
# Epoch 00004: val_loss did not improve from 0.69344
# Epoch 5/75
# 25/25 [==============================] - 14257s 590s/step - loss: 0.2265 - accuracy: 0.9207 - val_loss: 0.6881 - val_accuracy: 0.4996
#
# Epoch 00005: val_loss improved from 0.69344 to 0.68809, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 6/75
# 25/25 [==============================] - 14774s 611s/step - loss: 0.1850 - accuracy: 0.9425 - val_loss: 0.6752 - val_accuracy: 0.5377
#
# Epoch 00006: val_loss improved from 0.68809 to 0.67518, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 7/75
# 25/25 [==============================] - 14706s 608s/step - loss: 0.1499 - accuracy: 0.9587 - val_loss: 0.6455 - val_accuracy: 0.6746
#
# Epoch 00007: val_loss improved from 0.67518 to 0.64547, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 8/75
# 25/25 [==============================] - 14291s 591s/step - loss: 0.1246 - accuracy: 0.9716 - val_loss: 0.6102 - val_accuracy: 0.7052
#
# Epoch 00008: val_loss improved from 0.64547 to 0.61017, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 9/75
# 25/25 [==============================] - 14270s 590s/step - loss: 0.1114 - accuracy: 0.9699 - val_loss: 0.5650 - val_accuracy: 0.7402
#
# Epoch 00009: val_loss improved from 0.61017 to 0.56500, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 10/75
# 25/25 [==============================] - 14194s 587s/step - loss: 0.0939 - accuracy: 0.9774 - val_loss: 0.5261 - val_accuracy: 0.7570
#
# Epoch 00010: val_loss improved from 0.56500 to 0.52613, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 11/75
# 25/25 [==============================] - 14554s 602s/step - loss: 0.0737 - accuracy: 0.9897 - val_loss: 0.4795 - val_accuracy: 0.7647
#
# Epoch 00011: val_loss improved from 0.52613 to 0.47947, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 12/75
# 25/25 [==============================] - 14141s 585s/step - loss: 0.0641 - accuracy: 0.9887 - val_loss: 0.4384 - val_accuracy: 0.8009
#
# Epoch 00012: val_loss improved from 0.47947 to 0.43842, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 13/75
# 25/25 [==============================] - 14096s 583s/step - loss: 0.0565 - accuracy: 0.9924 - val_loss: 0.3831 - val_accuracy: 0.8162
#
# Epoch 00013: val_loss improved from 0.43842 to 0.38312, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 14/75
# 25/25 [==============================] - 14355s 594s/step - loss: 0.0427 - accuracy: 0.9979 - val_loss: 0.2979 - val_accuracy: 0.8672
#
# Epoch 00014: val_loss improved from 0.38312 to 0.29789, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 15/75
# 25/25 [==============================] - 14326s 592s/step - loss: 0.0414 - accuracy: 0.9947 - val_loss: 0.2324 - val_accuracy: 0.9157
#
# Epoch 00015: val_loss improved from 0.29789 to 0.23241, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 16/75
# 25/25 [==============================] - 14219s 588s/step - loss: 0.0386 - accuracy: 0.9941 - val_loss: 0.2083 - val_accuracy: 0.9196
#
# Epoch 00016: val_loss improved from 0.23241 to 0.20828, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 17/75
# 25/25 [==============================] - 11594s 479s/step - loss: 0.0293 - accuracy: 0.9976 - val_loss: 0.1834 - val_accuracy: 0.9314
#
# Epoch 00017: val_loss improved from 0.20828 to 0.18335, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 18/75
# 25/25 [==============================] - 7462s 309s/step - loss: 0.0263 - accuracy: 0.9979 - val_loss: 0.1635 - val_accuracy: 0.9419
#
# Epoch 00018: val_loss improved from 0.18335 to 0.16354, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 19/75
# 25/25 [==============================] - 6606s 273s/step - loss: 0.0260 - accuracy: 0.9992 - val_loss: 0.1700 - val_accuracy: 0.9227
#
# Epoch 00019: val_loss did not improve from 0.16354
# Epoch 20/75
# 25/25 [==============================] - 6606s 273s/step - loss: 0.0256 - accuracy: 0.9984 - val_loss: 0.1436 - val_accuracy: 0.9503
#
# Epoch 00020: val_loss improved from 0.16354 to 0.14357, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 21/75
# 25/25 [==============================] - 6603s 273s/step - loss: 0.0203 - accuracy: 0.9977 - val_loss: 0.1499 - val_accuracy: 0.9350
#
# Epoch 00021: val_loss did not improve from 0.14357
# Epoch 22/75
# 25/25 [==============================] - 6588s 272s/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 0.9445
#
# Epoch 00022: val_loss improved from 0.14357 to 0.13949, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 23/75
# 25/25 [==============================] - 6591s 272s/step - loss: 0.0160 - accuracy: 0.9990 - val_loss: 0.1492 - val_accuracy: 0.9309
#
# Epoch 00023: val_loss did not improve from 0.13949
# Epoch 24/75
# 25/25 [==============================] - 6633s 274s/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.1454 - val_accuracy: 0.9405
#
# Epoch 00024: val_loss did not improve from 0.13949
# Epoch 25/75
# 25/25 [==============================] - 6483s 268s/step - loss: 0.0134 - accuracy: 0.9995 - val_loss: 0.1376 - val_accuracy: 0.9370
#
# Epoch 00025: val_loss improved from 0.13949 to 0.13758, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 26/75
# 25/25 [==============================] - 6468s 268s/step - loss: 0.0119 - accuracy: 0.9997 - val_loss: 0.1256 - val_accuracy: 0.9525
#
# Epoch 00026: val_loss improved from 0.13758 to 0.12560, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 27/75
# 25/25 [==============================] - 6572s 272s/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.1261 - val_accuracy: 0.9568
#
# Epoch 00027: val_loss did not improve from 0.12560
# Epoch 28/75
# 25/25 [==============================] - 6575s 272s/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.1273 - val_accuracy: 0.9526
#
# Epoch 00028: val_loss did not improve from 0.12560
# Epoch 29/75
# 25/25 [==============================] - 6585s 272s/step - loss: 0.0091 - accuracy: 0.9994 - val_loss: 0.1298 - val_accuracy: 0.9512
#
# Epoch 00029: val_loss did not improve from 0.12560
# Epoch 30/75
# 25/25 [==============================] - 6603s 273s/step - loss: 0.0070 - accuracy: 0.9996 - val_loss: 0.1249 - val_accuracy: 0.9515
#
# Epoch 00030: val_loss improved from 0.12560 to 0.12489, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 31/75
# 25/25 [==============================] - 6591s 272s/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.1229 - val_accuracy: 0.9556
# Epoch 00031: val_loss improved from 0.12489 to 0.12290, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 32/75
# 25/25 [==============================] - 6598s 273s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.1403 - val_accuracy: 0.9468
#
# Epoch 00032: val_loss did not improve from 0.12290
# Epoch 33/75
# 25/25 [==============================] - 6606s 273s/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.1283 - val_accuracy: 0.9470
#
# Epoch 00033: val_loss did not improve from 0.12290
# Epoch 34/75
# 25/25 [==============================] - 6621s 274s/step - loss: 0.0072 - accuracy: 0.9994 - val_loss: 0.1217 - val_accuracy: 0.9529
#
# Epoch 00034: val_loss improved from 0.12290 to 0.12172, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 35/75
# 25/25 [==============================] - 7265s 301s/step - loss: 0.0066 - accuracy: 0.9993 - val_loss: 0.1219 - val_accuracy: 0.9532
#
# Epoch 00035: val_loss did not improve from 0.12172
# Epoch 36/75
# 25/25 [==============================] - 7340s 304s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.1208 - val_accuracy: 0.9541
#
# Epoch 00036: val_loss improved from 0.12172 to 0.12077, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 37/75
# 25/25 [==============================] - 6610s 273s/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.1267 - val_accuracy: 0.9455
#
# Epoch 00037: val_loss did not improve from 0.12077
# Epoch 38/75
# 25/25 [==============================] - 6561s 271s/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.1197 - val_accuracy: 0.9519
#
# Epoch 00038: val_loss improved from 0.12077 to 0.11966, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 39/75
# 25/25 [==============================] - 6615s 274s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1236 - val_accuracy: 0.9514
#
# Epoch 00039: val_loss did not improve from 0.11966
# Epoch 40/75
# 25/25 [==============================] - 6612s 273s/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1298 - val_accuracy: 0.9498
#
# Epoch 00040: val_loss did not improve from 0.11966
# Epoch 41/75
# 25/25 [==============================] - 6600s 273s/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1282 - val_accuracy: 0.9533
#
# Epoch 00041: val_loss did not improve from 0.11966
# Epoch 42/75
# 25/25 [==============================] - 6618s 274s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1428 - val_accuracy: 0.9362
#
# Epoch 00042: val_loss did not improve from 0.11966
# Epoch 43/75
# 25/25 [==============================] - 6625s 274s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1234 - val_accuracy: 0.9526
#
# Epoch 00043: val_loss did not improve from 0.11966
# Epoch 44/75
# 25/25 [==============================] - 6622s 274s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1210 - val_accuracy: 0.9558
#
# Epoch 00044: val_loss did not improve from 0.11966
# Epoch 45/75
# 25/25 [==============================] - 6573s 272s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9545
#
# Epoch 00045: val_loss did not improve from 0.11966
# Epoch 46/75
# 25/25 [==============================] - 6615s 273s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1233 - val_accuracy: 0.9536
#
# Epoch 00046: val_loss did not improve from 0.11966
# Epoch 47/75
# 25/25 [==============================] - 6619s 274s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1186 - val_accuracy: 0.9557
#
# Epoch 00047: val_loss improved from 0.11966 to 0.11860, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 48/75
# 25/25 [==============================] - 6633s 274s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1226 - val_accuracy: 0.9543
#
# Epoch 00048: val_loss did not improve from 0.11860
# Epoch 49/75
# 25/25 [==============================] - 6576s 272s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1233 - val_accuracy: 0.9524
#
# Epoch 00049: val_loss did not improve from 0.11860
# Epoch 50/75
# 25/25 [==============================] - 6558s 271s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1243 - val_accuracy: 0.9529
#
# Epoch 00050: val_loss did not improve from 0.11860
# Epoch 51/75
# 25/25 [==============================] - 6585s 272s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1195 - val_accuracy: 0.9572
#
# Epoch 00051: val_loss did not improve from 0.11860
# Epoch 52/75
# 25/25 [==============================] - 6637s 274s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1183 - val_accuracy: 0.9581
#
# Epoch 00052: val_loss improved from 0.11860 to 0.11834, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 53/75
# 25/25 [==============================] - 6625s 274s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9568
#
# Epoch 00053: val_loss improved from 0.11834 to 0.11561, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 54/75
# 25/25 [==============================] - 6573s 272s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1205 - val_accuracy: 0.9531
#
# Epoch 00054: val_loss did not improve from 0.11561
# Epoch 55/75
# 25/25 [==============================] - 6609s 273s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1154 - val_accuracy: 0.9564
#
# Epoch 00055: val_loss improved from 0.11561 to 0.11537, saving model to model/xRGM1.7/xRGM1.7
# INFO:tensorflow:Assets written to: model/xRGM1.7/xRGM1.7/assets
# Epoch 56/75
# 25/25 [==============================] - 6604s 273s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 0.9546
#
# Epoch 00056: val_loss did not improve from 0.11537
# Epoch 57/75
# 25/25 [==============================] - 6595s 273s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1242 - val_accuracy: 0.9547
#
# Epoch 00057: val_loss did not improve from 0.11537
# Epoch 58/75
# 25/25 [==============================] - 6624s 274s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1188 - val_accuracy: 0.9565
#
# Epoch 00058: val_loss did not improve from 0.11537
# Epoch 59/75
# 25/25 [==============================] - 6619s 274s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1209 - val_accuracy: 0.9509
#
# Epoch 00059: val_loss did not improve from 0.11537
# Epoch 60/75
# 25/25 [==============================] - 6649s 275s/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.1252 - val_accuracy: 0.9520
#
# Epoch 00060: val_loss did not improve from 0.11537
# Epoch 61/75
# 25/25 [==============================] - 6587s 272s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1197 - val_accuracy: 0.9560
#
# Epoch 00061: val_loss did not improve from 0.11537
# Epoch 62/75
# 25/25 [==============================] - 6550s 271s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1207 - val_accuracy: 0.9557
#
# Epoch 00062: val_loss did not improve from 0.11537
# Epoch 63/75
# 25/25 [==============================] - 6557s 271s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1201 - val_accuracy: 0.9550
#
# Epoch 00063: val_loss did not improve from 0.11537
# Epoch 64/75
# 25/25 [==============================] - 6580s 272s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 0.9461
#
# Epoch 00064: val_loss did not improve from 0.11537
# Epoch 65/75
# 25/25 [==============================] - 6586s 272s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1325 - val_accuracy: 0.9494
#
# Epoch 00065: val_loss did not improve from 0.11537
# Epoch 66/75
# 25/25 [==============================] - 6032s 249s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 0.9518
#
# Epoch 00066: val_loss did not improve from 0.11537
# Epoch 67/75
# 25/25 [==============================] - 5026s 208s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1182 - val_accuracy: 0.9568
#
# Epoch 00067: val_loss did not improve from 0.11537
# Epoch 68/75
# 25/25 [==============================] - 5034s 208s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1243 - val_accuracy: 0.9574
#
# Epoch 00068: val_loss did not improve from 0.11537
# Epoch 69/75
# 25/25 [==============================] - 5032s 208s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1168 - val_accuracy: 0.9586
#
# Epoch 00069: val_loss did not improve from 0.11537
# Epoch 70/75
# 25/25 [==============================] - 5036s 208s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1233 - val_accuracy: 0.9537
#
# Epoch 00070: val_loss did not improve from 0.11537
# Epoch 71/75
# 25/25 [==============================] - 5067s 209s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1293 - val_accuracy: 0.9512
#
# Epoch 00071: val_loss did not improve from 0.11537
# Epoch 72/75
# 25/25 [==============================] - 5073s 210s/step - loss: 7.9805e-04 - accuracy: 1.0000 - val_loss: 0.1259 - val_accuracy: 0.9568
#
# Epoch 00072: val_loss did not improve from 0.11537
# Epoch 73/75
# 25/25 [==============================] - 4972s 206s/step - loss: 8.9366e-04 - accuracy: 1.0000 - val_loss: 0.1223 - val_accuracy: 0.9560
#
# Epoch 00073: val_loss did not improve from 0.11537
# Epoch 74/75
# 25/25 [==============================] - 4984s 206s/step - loss: 7.9590e-04 - accuracy: 1.0000 - val_loss: 0.1234 - val_accuracy: 0.9558
#
# Epoch 00074: val_loss did not improve from 0.11537
# Epoch 75/75
# 25/25 [==============================] - 5040s 208s/step - loss: 8.2748e-04 - accuracy: 1.0000 - val_loss: 0.1268 - val_accuracy: 0.9578
#
# Epoch 00075: val_loss did not improve from 0.11537
# INFO:tensorflow:Assets written to: model/xRGM1.7/assets
# CPU times: user 21d 4h 39min 27s, sys: 15h 56min 23s, total: 21d 20h 35min 50s
# Wall time: 7d 2h 13min 40s

# %%
confusion_matrix = pd.DataFrame(metrics.confusion_matrix(y_test, v_classify(y_pred)),
                                columns=['Predicted Negative', 'Predicted Positive'],
                                index=['Actual Negative', 'Actual Positive'])

tp, tn, fp, fn = (
    confusion_matrix.iloc[1,1], 
    confusion_matrix.iloc[0,0], 
    confusion_matrix.iloc[0,1], 
    confusion_matrix.iloc[1,0]
)

accuracy = (tp + tn) / (tp + tn + fp + fn)
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
f1_score = 2 * ((specificity * sensitivity) / (specificity + sensitivity))

with open(os.path.join(f'{model_dir}', 'metrics.csv'), 'a', encoding='utf-8') as f:
    f.write(
        f'{time.strftime("%Y-%m-%dT%H:%M:%S-05:00", time.localtime())}, {accuracy}, {sensitivity}, {specificity}, {f1_score}\n'
    )

print(f'Accuracy:    {accuracy}')
print(f'Sensitivity: {sensitivity}')
print(f'Specificity: {specificity}')
print(f'F1 Score:    {f1_score}')
print('\n')
print(confusion_matrix)
# Out:
# Accuracy:    0.9581320450885669
# Sensitivity: 0.9483870967741935
# Specificity: 0.9678456591639871
# F1 Score:    0.9580175810851773
#
#
#                  Predicted Negative  Predicted Positive
# Actual Negative                 301                  10
# Actual Positive                  16                 294

# %%
disease_types=['COVID', 'non-COVID']
Y_pred = np.argmax(y_pred)
Y_true = np.argmax(y_test)

plt.figure(figsize=(7, 7))
ax = sns.heatmap(confusion_matrix , cmap=plt.cm.GnBu , 
                 annot=True, fmt='d',square=True, xticklabels=disease_types, 
                 yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
plt.show()

# %%
def plot_model_history(model_history):
   fig, axs = plt.subplots(1,2,figsize=(15,5))
   # summarize history for accuracy
   axs[0].plot(range(1, len(model_history['accuracy']) + 1), model_history['accuracy'])
   axs[0].plot(range(1, len(model_history['val_accuracy']) + 1), model_history['val_accuracy'])
   axs[0].set_title('Model Accuracy')
   axs[0].set_ylabel('Accuracy')
   axs[0].set_xlabel('Epoch')
   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
   axs[0].legend(['train', 'val'], loc='best')
   # summarize history for loss
   axs[1].plot(range(1, len(model_history['loss'])+1), model_history['loss'])
   axs[1].plot(range(1, len(model_history['val_loss']) + 1), model_history['val_loss'])
   axs[1].set_title('Model Loss')
   axs[1].set_ylabel('Loss')
   axs[1].set_xlabel('Epoch')
   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
   axs[1].legend(['train', 'val'], loc='best')
   plt.show()

# %%
with open(os.path.join('models', 'xRGM1.5-Net-HistDict'), 'rb') as f:
    history = pickle.load(f)
    
plot_model_history(history)
# Out:
# <ipython-input-10-25025fac5012>:9: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
# <ipython-input-10-25025fac5012>:17: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
