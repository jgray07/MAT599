# %%
import glob
import json
import os
import pickle
import random
import traceback
from typing import Tuple

import numpy as np
import pandas as pd
import seaborn as sns
from keras.models import Sequential, load_model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Lambda, LeakyReLU, AveragePooling2D, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from matplotlib import pyplot as plt
from matplotlib.pyplot import hist
from PIL import Image
from scipy.stats import zscore
from sklearn import metrics
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %%
import csv
import time

# %% [markdown]
# ## Config & Constants

# %%
IMAGE_WIDTH, IMAGE_HEIGHT = 227, 227
random.seed(52)

# %% [markdown]
# ## Methods

# %% [markdown]
# ### Image Utilities

# %%
def batch_generator(input_data, output_data, batch_size, is_training):
    input_data_batch = np.empty([batch_size, IMAGE_HEIGHT, IMAGE_WIDTH, 1])
    output_data_batch = np.empty([batch_size, 1])
    while True:
        index = 0
        for i in np.random.permutation(input_data.shape[0]):
            input_data_batch[index] = input_data[i]
            output_data_batch[index] = output_data[i]
            index += 1
            if index == batch_size:
                break
        yield input_data_batch, output_data_batch


def _preprocess(image_loc: str) -> np.ndarray:
    f_image = Image.open(image_loc).convert('L')
    f_image = f_image.resize((IMAGE_WIDTH, IMAGE_HEIGHT), Image.ANTIALIAS)
    image = np.asarray(f_image)
    image = np.expand_dims(image, axis=0)
    image = np.expand_dims(image, axis=3)
    return image


def preprocess(loc: str) -> np.ndarray:
    """Safety wrapper over _preprocess.
    
    Args:
        loc: File location to check if dir or an image.
        
    Returns:
        Preprocessed image(s) as an ndarray.
    """
    if os.path.isdir(loc):
        current = np.concatenate((
            [_preprocess(os.path.join(loc, image)) for image in os.listdir(loc)
             if '.png' in image]
        ))
    else:
        current = _preprocess(loc)
    return current


def generate_data_arrays(
    covid_data: str = 'rsc/New_Data_CoV2/COVID/',
    noncovid_data: str = 'rsc/New_Data_CoV2/non-COVID/',
    others_data:  str = 'rsc/New_Data_CoV2/Others/',
    image_output: str = 'rsc/input_data_v2',
    label_output: str = 'rsc/output_data_v2',
    regenerate: bool = True
) -> Tuple[np.ndarray, np.ndarray]:
    """Loads COVID images into ndarrays.
    
    Args:
        covid_data: Relative path to folder containing COVID images.
        noncovid_data: Relative path to folder containing non-COVID images.
        others_data: Relative path to folder containing Others images.
        image_output: Relative path (with filename) to save loaded images to.
        label_output: Relative path (with filename) to save loaded classes (labels) to.
        regenerate: If True, will regenerate saved ndarray files for both image_output
            and label_output, even if they already exist (overwriting them). If False,
            will simply load and return the aforementioned.
        
    Returns:
        Tuple of ndarrays. The first is the loaded image data in one large ndarray,
        and the second is the loaded labels, also in a large ndarray. These directly
        match up to each other ONLY when both arrays (and their respective files)
        are generated at the same time with this method.
    """
    if (regenerate is False and 
        os.path.isfile(f'{out_input_data}.npy') and
        os.path.isfile(f'{out_output_data}.npy')):
        return (np.load(f'{out_input_data}.npy'),
                np.load(f'{out_output_data}.npy'))
    
    if not ((cd := os.path.exists(covid_data)) and (ncd := os.path.exists(noncovid_data))):
        if (others_data is not None) and not (odd := os.path.exists(others_data)):
            raise NotADirectoryError("Directories do not exist.")
        else:
            raise NotADirectoryError("COVID/non-COVID directories do not exist.")
    
    im_data = np.empty([1, IMAGE_WIDTH, IMAGE_WIDTH, 1])
    output = np.array([0])

    print('Loading Covid Data')
    for i in tqdm(glob.glob(os.path.join(covid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([1])), axis=0)

    print('Loading non-Covid Data')
    for i in tqdm(glob.glob(os.path.join(noncovid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([0])), axis=0)
        
    if others_data is not None:
        print('Loading Others Data')
        for i in tqdm(glob.glob(os.path.join(others_data, '**'))):
            current = preprocess(i)
            im_data = np.concatenate((im_data, current))
            output = np.concatenate((output, np.array([-1])), axis=0)
    else:
        print('Others data not provided; skipping.')


    print('Finished Loading Data')
    im_data = np.delete(im_data, 0, axis=0)
    output = np.delete(output, 0, axis=0)

    zip_data = list(zip(im_data, output))
    random.shuffle(zip_data)
    im_data, output = zip(*zip_data)

    np.save(f'{image_output}', im_data)
    np.save(f'{label_output}', output)
    return im_data, output


def load_data(image_loc: str, label_loc: str, **kwargs) -> Tuple[np.ndarray, np.ndarray]:
    """Attempts to load generated images and labels.
    
    If either is not found, attempts to (re)generate them using the default
    input arguments to the generation method for the raw data, but the input
    `image_loc` and `label_loc` parameters for the output arrays. If this
    still does not work, returns a general error and exits.
    
    Args:
        image_loc: Relative path to saved image ndarray file.
        label_loc: Relative path to saved label ndarray file.
        
    Returns:
        Tuple of ndarrays. The first array holds the loaded image data, whilst
        the second array holds their respective labels.
    
    """
    try:
        image_data = np.load(f'{image_loc}.npy')
        label_data = np.load(f'{label_loc}.npy')
        return image_data, label_data
    
    except FileNotFoundError:
        try:
            image_data, label_data = generate_data_arrays(
                image_output = image_loc,
                label_output = label_loc,
                **kwargs
            )
            return image_data, label_data
        
        except Exception as e:
            traceback.print_exc()

# %% [markdown]
# ## Model Playground

# %%
#Version 1
im_data_v1, output_v1 = load_data(
    image_loc = 'rsc/input_data_v1',
    label_loc = 'rsc/output_data_v1',
    covid_data = 'rsc/Data_CoV2/COVID/',
    noncovid_data = 'rsc/Data_CoV2/non-COVID/',
    others_data = None,
)

x_train, x_test, y_train, y_test = train_test_split(im_data_v1, output_v1, random_state=42)

# %%
def make_model(X_Train, Y_Train, X_Test, Y_Test, model_dir: str):
    if not os.path.exists(model_dir):
        os.makedirs(model_dir)
    #X_Train, X_Test, Y_Train, Y_Test = train_test_split(input_data, output_data, test_size=0.1)

    for_pad = lambda s: s if s > 2 else 3

    model = Sequential()
    model.add(Lambda(lambda x: x, input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 1)))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=8, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))



    #model.add(ZeroPadding2D(padding=(for_pad(19) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(Conv2D(kernel_size=(3, 3), filters=2, strides=(1, 1),activation='relu'))

    model.add(Flatten())

    model.add(Dense(units=338, activation='relu'))
    model.add(Dense(units=1, activation='sigmoid'))

    model.compile(optimizer=Adam(lr=3e-4), loss='binary_crossentropy', metrics=["accuracy"])
    model.summary()

    checkpoint = ModelCheckpoint(os.path.join(model_dir, 'xRGM1.5ND'), verbose=1, period=1, save_best_only=True)

    hist = model.fit_generator(batch_generator(X_Train, Y_Train, 128, True),
                        validation_data=(batch_generator(X_Test, Y_Test, 128, False)), callbacks=[checkpoint],
                        verbose=1, epochs=75, steps_per_epoch=25, validation_steps=len(X_Test))

    with open(os.path.join('models', 'xRGM1.5ND-Net-HistDict'), 'wb') as f:
        pickle.dump(hist.history, f)

    model.save(model_dir)
    
    return model
#changed steps and epochs and batchsize

# %%
# %%time
model_dir: str = 'model/xRGM1.5ND'
xRGM = make_model(x_train, y_train.reshape(-1,1), x_test, y_test.reshape(-1,1), model_dir=model_dir)

v_classify = np.vectorize(lambda x: np.round(x, 0))
# xRGMCT2 = load_model('models/xRGMCT2L.h5')
# print(xRGMCT2.history)
y_pred = (xRGM.predict(x_test))

#print(y_test)
#print(y_pred)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda (Lambda)              (None, 227, 227, 1)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 225, 225, 8)       80
# _________________________________________________________________
# batch_normalization (BatchNo (None, 225, 225, 8)       32
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 225, 225, 8)       0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 110, 110, 16)      1168
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 110, 110, 16)      64
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 110, 110, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 108, 108, 32)      4640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 108, 108, 32)      128
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 108, 108, 32)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 108, 108, 16)      528
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 108, 108, 16)      64
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 108, 108, 16)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 106, 106, 32)      4640
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 106, 106, 32)      128
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 106, 106, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 104, 104, 64)      18496
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 104, 104, 64)      256
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 104, 104, 64)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 104, 104, 32)      2080
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 104, 104, 32)      128
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 104, 104, 32)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 102, 102, 64)      18496
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 102, 102, 64)      256
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 102, 102, 64)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 100, 100, 128)     73856
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 100, 100, 128)     512
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 100, 100, 128)     0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 100, 100, 64)      8256
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 100, 100, 64)      256
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 98, 98, 128)       73856
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 98, 98, 128)       512
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 98, 98, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 49, 49, 128)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 47, 47, 256)       295168
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 47, 47, 256)       1024
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 47, 47, 256)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 47, 47, 128)       32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 47, 47, 128)       512
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 47, 47, 128)       0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 23, 23, 128)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 21, 21, 256)       295168
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 21, 21, 256)       1024
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 21, 21, 256)       0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 10, 10, 256)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 10, 10, 128)       32896
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 8, 8, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 338)               5538130
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 339
# =================================================================
# Total params: 6,702,293
# Trainable params: 6,699,077
# Non-trainable params: 3,216
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# /home/jg1994/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/75
# 25/25 [==============================] - 9577s 396s/step - loss: 1.4149 - accuracy: 0.6357 - val_loss: 0.7032 - val_accuracy: 0.4838
#
# Epoch 00001: val_loss improved from inf to 0.70315, saving model to model/xRGM1.5ND/xRGM1.5ND
# INFO:tensorflow:Assets written to: model/xRGM1.5ND/xRGM1.5ND/assets
# Epoch 2/75
# 25/25 [==============================] - 8376s 346s/step - loss: 0.2686 - accuracy: 0.8901 - val_loss: 0.7793 - val_accuracy: 0.5017
#
# Epoch 00002: val_loss did not improve from 0.70315
# Epoch 3/75
# 25/25 [==============================] - 9435s 391s/step - loss: 0.1754 - accuracy: 0.9353 - val_loss: 0.7647 - val_accuracy: 0.5012
#
# Epoch 00003: val_loss did not improve from 0.70315
# Epoch 4/75
# 25/25 [==============================] - 9439s 391s/step - loss: 0.1064 - accuracy: 0.9632 - val_loss: 0.8599 - val_accuracy: 0.5025
#
# Epoch 00004: val_loss did not improve from 0.70315
# Epoch 5/75
# 25/25 [==============================] - 9428s 390s/step - loss: 0.0603 - accuracy: 0.9829 - val_loss: 0.9209 - val_accuracy: 0.4996
#
# Epoch 00005: val_loss did not improve from 0.70315
# Epoch 6/75
# 25/25 [==============================] - 9435s 391s/step - loss: 0.0304 - accuracy: 0.9918 - val_loss: 0.8519 - val_accuracy: 0.4970
#
# Epoch 00006: val_loss did not improve from 0.70315
# Epoch 7/75
# 25/25 [==============================] - 9466s 392s/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.7970 - val_accuracy: 0.4294
#
# Epoch 00007: val_loss did not improve from 0.70315
# Epoch 8/75
# 25/25 [==============================] - 9463s 392s/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.8846 - val_accuracy: 0.4424
#
# Epoch 00008: val_loss did not improve from 0.70315
# Epoch 9/75
# 25/25 [==============================] - 9479s 393s/step - loss: 0.0032 - accuracy: 0.9999 - val_loss: 0.9144 - val_accuracy: 0.5188
#
# Epoch 00009: val_loss did not improve from 0.70315
# Epoch 10/75
# 25/25 [==============================] - 9452s 392s/step - loss: 0.0032 - accuracy: 0.9997 - val_loss: 0.9920 - val_accuracy: 0.5488
#
# Epoch 00010: val_loss did not improve from 0.70315
# Epoch 11/75
# 25/25 [==============================] - 9490s 393s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.0327 - val_accuracy: 0.6054
#
# Epoch 00011: val_loss did not improve from 0.70315
# Epoch 12/75
# 25/25 [==============================] - 9462s 392s/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.5791 - val_accuracy: 0.7396
#
# Epoch 00012: val_loss improved from 0.70315 to 0.57909, saving model to model/xRGM1.5ND/xRGM1.5ND
# INFO:tensorflow:Assets written to: model/xRGM1.5ND/xRGM1.5ND/assets
# Epoch 13/75
# 25/25 [==============================] - 9447s 391s/step - loss: 0.0038 - accuracy: 0.9994 - val_loss: 0.3243 - val_accuracy: 0.8510
#
# Epoch 00013: val_loss improved from 0.57909 to 0.32431, saving model to model/xRGM1.5ND/xRGM1.5ND
# INFO:tensorflow:Assets written to: model/xRGM1.5ND/xRGM1.5ND/assets
# Epoch 14/75
# 25/25 [==============================] - 9467s 392s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.2332 - val_accuracy: 0.8904
#
# Epoch 00014: val_loss improved from 0.32431 to 0.23320, saving model to model/xRGM1.5ND/xRGM1.5ND
# INFO:tensorflow:Assets written to: model/xRGM1.5ND/xRGM1.5ND/assets
# Epoch 15/75
# 25/25 [==============================] - 9462s 392s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1811 - val_accuracy: 0.9274
#
# Epoch 00015: val_loss improved from 0.23320 to 0.18112, saving model to model/xRGM1.5ND/xRGM1.5ND
# INFO:tensorflow:Assets written to: model/xRGM1.5ND/xRGM1.5ND/assets
# Epoch 16/75
# 25/25 [==============================] - 9464s 392s/step - loss: 6.6460e-04 - accuracy: 1.0000 - val_loss: 0.1288 - val_accuracy: 0.9516
#
# Epoch 00016: val_loss improved from 0.18112 to 0.12882, saving model to model/xRGM1.5ND/xRGM1.5ND
# INFO:tensorflow:Assets written to: model/xRGM1.5ND/xRGM1.5ND/assets
# Epoch 17/75
# 25/25 [==============================] - 9481s 393s/step - loss: 4.1026e-04 - accuracy: 1.0000 - val_loss: 0.1285 - val_accuracy: 0.9484
#
# Epoch 00017: val_loss improved from 0.12882 to 0.12850, saving model to model/xRGM1.5ND/xRGM1.5ND
# INFO:tensorflow:Assets written to: model/xRGM1.5ND/xRGM1.5ND/assets
# Epoch 18/75
# 25/25 [==============================] - 9468s 392s/step - loss: 3.2541e-04 - accuracy: 1.0000 - val_loss: 0.0820 - val_accuracy: 0.9632
#
# Epoch 00018: val_loss improved from 0.12850 to 0.08196, saving model to model/xRGM1.5ND/xRGM1.5ND
# INFO:tensorflow:Assets written to: model/xRGM1.5ND/xRGM1.5ND/assets
# Epoch 19/75
# 25/25 [==============================] - 9472s 392s/step - loss: 3.6892e-04 - accuracy: 1.0000 - val_loss: 0.0510 - val_accuracy: 0.9843
#
# Epoch 00019: val_loss improved from 0.08196 to 0.05100, saving model to model/xRGM1.5ND/xRGM1.5ND
# INFO:tensorflow:Assets written to: model/xRGM1.5ND/xRGM1.5ND/assets
# Epoch 20/75
# 25/25 [==============================] - 9490s 393s/step - loss: 2.3894e-04 - accuracy: 1.0000 - val_loss: 0.0446 - val_accuracy: 0.9877
#
# Epoch 00020: val_loss improved from 0.05100 to 0.04457, saving model to model/xRGM1.5ND/xRGM1.5ND
# INFO:tensorflow:Assets written to: model/xRGM1.5ND/xRGM1.5ND/assets
# Epoch 21/75
# 25/25 [==============================] - 9477s 393s/step - loss: 2.6398e-04 - accuracy: 1.0000 - val_loss: 0.0442 - val_accuracy: 0.9866
#
# Epoch 00021: val_loss improved from 0.04457 to 0.04423, saving model to model/xRGM1.5ND/xRGM1.5ND
# INFO:tensorflow:Assets written to: model/xRGM1.5ND/xRGM1.5ND/assets
# Epoch 22/75
# 25/25 [==============================] - 9516s 394s/step - loss: 2.0557e-04 - accuracy: 1.0000 - val_loss: 0.0447 - val_accuracy: 0.9791
#
# Epoch 00022: val_loss did not improve from 0.04423
# Epoch 23/75
# 25/25 [==============================] - 9497s 393s/step - loss: 1.6698e-04 - accuracy: 1.0000 - val_loss: 0.0531 - val_accuracy: 0.9807
#
# Epoch 00023: val_loss did not improve from 0.04423
# Epoch 24/75
# 25/25 [==============================] - 9480s 393s/step - loss: 4.6237e-04 - accuracy: 1.0000 - val_loss: 0.0507 - val_accuracy: 0.9816
#
# Epoch 00024: val_loss did not improve from 0.04423
# Epoch 25/75
# 25/25 [==============================] - 9505s 394s/step - loss: 1.9838e-04 - accuracy: 1.0000 - val_loss: 0.0454 - val_accuracy: 0.9804
#
# Epoch 00025: val_loss did not improve from 0.04423
# Epoch 26/75
# 25/25 [==============================] - 9463s 392s/step - loss: 1.1669e-04 - accuracy: 1.0000 - val_loss: 0.0471 - val_accuracy: 0.9792
#
# Epoch 00026: val_loss did not improve from 0.04423
# Epoch 27/75
# 25/25 [==============================] - 9533s 395s/step - loss: 1.1808e-04 - accuracy: 1.0000 - val_loss: 0.0410 - val_accuracy: 0.9808
#
# Epoch 00027: val_loss improved from 0.04423 to 0.04100, saving model to model/xRGM1.5ND/xRGM1.5ND
# INFO:tensorflow:Assets written to: model/xRGM1.5ND/xRGM1.5ND/assets
# Epoch 28/75
# 25/25 [==============================] - 9543s 396s/step - loss: 1.0582e-04 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9855
#
# Epoch 00028: val_loss did not improve from 0.04100
# Epoch 29/75
# 25/25 [==============================] - 9609s 398s/step - loss: 1.3193e-04 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9834
#
# Epoch 00029: val_loss improved from 0.04100 to 0.04075, saving model to model/xRGM1.5ND/xRGM1.5ND
# INFO:tensorflow:Assets written to: model/xRGM1.5ND/xRGM1.5ND/assets
# Epoch 30/75
# 25/25 [==============================] - 9635s 399s/step - loss: 9.4834e-05 - accuracy: 1.0000 - val_loss: 0.0378 - val_accuracy: 0.9844
#
# Epoch 00030: val_loss improved from 0.04075 to 0.03779, saving model to model/xRGM1.5ND/xRGM1.5ND
# INFO:tensorflow:Assets written to: model/xRGM1.5ND/xRGM1.5ND/assets
# Epoch 31/75
# 25/25 [==============================] - 9624s 399s/step - loss: 6.7712e-05 - accuracy: 1.0000 - val_loss: 0.0380 - val_accuracy: 0.9802
#
# Epoch 00031: val_loss did not improve from 0.03779
# Epoch 32/75
# 25/25 [==============================] - 9677s 401s/step - loss: 6.4609e-05 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9822
#
# Epoch 00032: val_loss did not improve from 0.03779
# Epoch 33/75
# 25/25 [==============================] - 9655s 400s/step - loss: 7.4849e-05 - accuracy: 1.0000 - val_loss: 0.0377 - val_accuracy: 0.9806
#
# Epoch 00033: val_loss improved from 0.03779 to 0.03767, saving model to model/xRGM1.5ND/xRGM1.5ND
# INFO:tensorflow:Assets written to: model/xRGM1.5ND/xRGM1.5ND/assets
# Epoch 34/75
# 25/25 [==============================] - 9665s 400s/step - loss: 7.9280e-05 - accuracy: 1.0000 - val_loss: 0.0368 - val_accuracy: 0.9838
#
# Epoch 00034: val_loss improved from 0.03767 to 0.03682, saving model to model/xRGM1.5ND/xRGM1.5ND
# INFO:tensorflow:Assets written to: model/xRGM1.5ND/xRGM1.5ND/assets
# Epoch 35/75
# 25/25 [==============================] - 9636s 399s/step - loss: 5.7264e-05 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9788
#
# Epoch 00035: val_loss did not improve from 0.03682
# Epoch 36/75
# 25/25 [==============================] - 9632s 399s/step - loss: 7.5222e-05 - accuracy: 1.0000 - val_loss: 0.0384 - val_accuracy: 0.9820
#
# Epoch 00036: val_loss did not improve from 0.03682
# Epoch 37/75
# 25/25 [==============================] - 9676s 401s/step - loss: 6.3029e-05 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9827
#
# Epoch 00037: val_loss did not improve from 0.03682
# Epoch 38/75
# 25/25 [==============================] - 9627s 399s/step - loss: 4.6480e-05 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9818
#
# Epoch 00038: val_loss did not improve from 0.03682
# Epoch 39/75
# 25/25 [==============================] - 8114s 336s/step - loss: 5.3129e-05 - accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 0.9821
#
# Epoch 00039: val_loss did not improve from 0.03682
# Epoch 40/75
# 25/25 [==============================] - 8124s 336s/step - loss: 3.7035e-05 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9815
#
# Epoch 00040: val_loss did not improve from 0.03682
# Epoch 41/75
# 25/25 [==============================] - 8107s 336s/step - loss: 4.5305e-05 - accuracy: 1.0000 - val_loss: 0.0385 - val_accuracy: 0.9806
#
# Epoch 00041: val_loss did not improve from 0.03682
# Epoch 42/75
# 25/25 [==============================] - 8117s 336s/step - loss: 3.6067e-05 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9821
#
# Epoch 00042: val_loss did not improve from 0.03682
# Epoch 43/75
# 25/25 [==============================] - 8086s 335s/step - loss: 3.6583e-05 - accuracy: 1.0000 - val_loss: 0.0391 - val_accuracy: 0.9843
#
# Epoch 00043: val_loss did not improve from 0.03682
# Epoch 44/75
# 25/25 [==============================] - 8084s 335s/step - loss: 4.1443e-05 - accuracy: 1.0000 - val_loss: 0.0384 - val_accuracy: 0.9838
#
# Epoch 00044: val_loss did not improve from 0.03682
# Epoch 45/75
# 25/25 [==============================] - 8086s 335s/step - loss: 6.2263e-05 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9804
#
# Epoch 00045: val_loss did not improve from 0.03682
# Epoch 46/75
# 25/25 [==============================] - 8094s 335s/step - loss: 4.8568e-05 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9824
#
# Epoch 00046: val_loss did not improve from 0.03682
# Epoch 47/75
# 25/25 [==============================] - 8093s 335s/step - loss: 3.5837e-05 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 0.9814
#
# Epoch 00047: val_loss did not improve from 0.03682
# Epoch 48/75
# 25/25 [==============================] - 9048s 375s/step - loss: 3.1334e-05 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9810
#
# Epoch 00048: val_loss did not improve from 0.03682
# Epoch 49/75
# 25/25 [==============================] - 9660s 400s/step - loss: 2.9439e-05 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9816
#
# Epoch 00049: val_loss did not improve from 0.03682
# Epoch 50/75
# 25/25 [==============================] - 9634s 399s/step - loss: 3.9881e-05 - accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 0.9837
#
# Epoch 00050: val_loss did not improve from 0.03682
# Epoch 51/75
# 25/25 [==============================] - 9613s 398s/step - loss: 3.4665e-05 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9838
#
# Epoch 00051: val_loss did not improve from 0.03682
# Epoch 52/75
# 25/25 [==============================] - 9608s 398s/step - loss: 3.1260e-05 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9813
#
# Epoch 00052: val_loss did not improve from 0.03682
# Epoch 53/75
# 25/25 [==============================] - 9616s 398s/step - loss: 2.7449e-05 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9840
#
# Epoch 00053: val_loss did not improve from 0.03682
# Epoch 54/75
# 25/25 [==============================] - 9613s 398s/step - loss: 2.2513e-05 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9806
#
# Epoch 00054: val_loss did not improve from 0.03682
# Epoch 55/75
# 25/25 [==============================] - 9614s 398s/step - loss: 3.0145e-05 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9825
#
# Epoch 00055: val_loss did not improve from 0.03682
# Epoch 56/75
# 25/25 [==============================] - 9635s 399s/step - loss: 3.0145e-05 - accuracy: 1.0000 - val_loss: 0.0380 - val_accuracy: 0.9830
#
# Epoch 00056: val_loss did not improve from 0.03682
# Epoch 57/75
# 25/25 [==============================] - 9652s 399s/step - loss: 2.5713e-05 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9793
#
# Epoch 00057: val_loss did not improve from 0.03682
# Epoch 58/75
# 25/25 [==============================] - 9776s 405s/step - loss: 1.9873e-05 - accuracy: 1.0000 - val_loss: 0.0426 - val_accuracy: 0.9794
#
# Epoch 00058: val_loss did not improve from 0.03682
# Epoch 59/75
# 25/25 [==============================] - 12054s 499s/step - loss: 3.3400e-05 - accuracy: 1.0000 - val_loss: 0.0434 - val_accuracy: 0.9771
#
# Epoch 00059: val_loss did not improve from 0.03682
# Epoch 60/75
# 25/25 [==============================] - 12623s 522s/step - loss: 2.6192e-05 - accuracy: 1.0000 - val_loss: 0.0434 - val_accuracy: 0.9787
#
# Epoch 00060: val_loss did not improve from 0.03682
# Epoch 61/75
# 25/25 [==============================] - 12592s 521s/step - loss: 1.8012e-05 - accuracy: 1.0000 - val_loss: 0.0437 - val_accuracy: 0.9785
#
# Epoch 00061: val_loss did not improve from 0.03682
# Epoch 62/75
# 25/25 [==============================] - 12598s 521s/step - loss: 2.1309e-05 - accuracy: 1.0000 - val_loss: 0.0455 - val_accuracy: 0.9772
#
# Epoch 00062: val_loss did not improve from 0.03682
# Epoch 63/75
# 25/25 [==============================] - 12626s 523s/step - loss: 1.6047e-05 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9777
#
# Epoch 00063: val_loss did not improve from 0.03682
# Epoch 64/75
# 25/25 [==============================] - 11092s 459s/step - loss: 1.6107e-05 - accuracy: 1.0000 - val_loss: 0.0425 - val_accuracy: 0.9776
#
# Epoch 00064: val_loss did not improve from 0.03682
# Epoch 65/75
# 25/25 [==============================] - 7945s 329s/step - loss: 1.6225e-05 - accuracy: 1.0000 - val_loss: 0.0430 - val_accuracy: 0.9812
#
# Epoch 00065: val_loss did not improve from 0.03682
# Epoch 66/75
# 25/25 [==============================] - 7953s 329s/step - loss: 1.8142e-05 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9796
#
# Epoch 00066: val_loss did not improve from 0.03682
# Epoch 67/75
# 25/25 [==============================] - 7925s 328s/step - loss: 1.6133e-05 - accuracy: 1.0000 - val_loss: 0.0430 - val_accuracy: 0.9791
#
# Epoch 00067: val_loss did not improve from 0.03682
# Epoch 68/75
# 25/25 [==============================] - 7918s 328s/step - loss: 1.7450e-05 - accuracy: 1.0000 - val_loss: 0.0436 - val_accuracy: 0.9799
#
# Epoch 00068: val_loss did not improve from 0.03682
# Epoch 69/75
# 25/25 [==============================] - 7930s 328s/step - loss: 1.2698e-05 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 0.9803
#
# Epoch 00069: val_loss did not improve from 0.03682
# Epoch 70/75
# 25/25 [==============================] - 7928s 328s/step - loss: 1.6418e-05 - accuracy: 1.0000 - val_loss: 0.0434 - val_accuracy: 0.9810
#
# Epoch 00070: val_loss did not improve from 0.03682
# Epoch 71/75
# 25/25 [==============================] - 7932s 328s/step - loss: 3.1273e-05 - accuracy: 1.0000 - val_loss: 0.0453 - val_accuracy: 0.9804
#
# Epoch 00071: val_loss did not improve from 0.03682
# Epoch 72/75
# 25/25 [==============================] - 7922s 328s/step - loss: 2.5864e-05 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9811
#
# Epoch 00072: val_loss did not improve from 0.03682
# Epoch 73/75
# 25/25 [==============================] - 7930s 328s/step - loss: 1.4484e-05 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9817
#
# Epoch 00073: val_loss did not improve from 0.03682
# Epoch 74/75
# 25/25 [==============================] - 7925s 328s/step - loss: 1.6965e-05 - accuracy: 1.0000 - val_loss: 0.0424 - val_accuracy: 0.9824
#
# Epoch 00074: val_loss did not improve from 0.03682
# Epoch 75/75
# 25/25 [==============================] - 7933s 328s/step - loss: 1.3711e-05 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 0.9819
#
# Epoch 00075: val_loss did not improve from 0.03682
# INFO:tensorflow:Assets written to: model/xRGM1.5ND/assets
# CPU times: user 21d 3h 41min 37s, sys: 14h 42min 30s, total: 21d 18h 24min 7s
# Wall time: 8d 2h 37min 15s

# %%
confusion_matrix = pd.DataFrame(metrics.confusion_matrix(y_test, v_classify(y_pred)),
                                columns=['Predicted Negative', 'Predicted Positive'],
                                index=['Actual Negative', 'Actual Positive'])

tp, tn, fp, fn = (
    confusion_matrix.iloc[1,1], 
    confusion_matrix.iloc[0,0], 
    confusion_matrix.iloc[0,1], 
    confusion_matrix.iloc[1,0]
)

accuracy = (tp + tn) / (tp + tn + fp + fn)
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
f1_score = 2 * ((specificity * sensitivity) / (specificity + sensitivity))

with open(os.path.join(f'{model_dir}', 'metrics.csv'), 'a', encoding='utf-8') as f:
    f.write(
        f'{time.strftime("%Y-%m-%dT%H:%M:%S-05:00", time.localtime())}, {accuracy}, {sensitivity}, {specificity}, {f1_score}\n'
    )

print(f'Accuracy:    {accuracy}')
print(f'Sensitivity: {sensitivity}')
print(f'Specificity: {specificity}')
print(f'F1 Score:    {f1_score}')
print('\n')
print(confusion_matrix)
# Out:
# Accuracy:    0.9822866344605475
# Sensitivity: 0.9838709677419355
# Specificity: 0.9807073954983923
# F1 Score:    0.9822866344605475
#
#
#                  Predicted Negative  Predicted Positive
# Actual Negative                 305                   6
# Actual Positive                   5                 305

# %%
disease_types=['COVID', 'non-COVID']
Y_pred = np.argmax(y_pred)
Y_true = np.argmax(y_test)

plt.figure(figsize=(7, 7))
ax = sns.heatmap(confusion_matrix , cmap=plt.cm.GnBu , 
                 annot=True, fmt='d',square=True, xticklabels=disease_types, 
                 yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
plt.show()

# %%
def plot_model_history(model_history):
   fig, axs = plt.subplots(1,2,figsize=(15,5))
   # summarize history for accuracy
   axs[0].plot(range(1, len(model_history['accuracy']) + 1), model_history['accuracy'])
   axs[0].plot(range(1, len(model_history['val_accuracy']) + 1), model_history['val_accuracy'])
   axs[0].set_title('Model Accuracy')
   axs[0].set_ylabel('Accuracy')
   axs[0].set_xlabel('Epoch')
   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
   axs[0].legend(['train', 'val'], loc='best')
   # summarize history for loss
   axs[1].plot(range(1, len(model_history['loss'])+1), model_history['loss'])
   axs[1].plot(range(1, len(model_history['val_loss']) + 1), model_history['val_loss'])
   axs[1].set_title('Model Loss')
   axs[1].set_ylabel('Loss')
   axs[1].set_xlabel('Epoch')
   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
   axs[1].legend(['train', 'val'], loc='best')
   plt.show()

# %%
with open(os.path.join('models', 'xRGM1.5ND-Net-HistDict'), 'rb') as f:
    history = pickle.load(f)
    
plot_model_history(history)
# Out:
# <ipython-input-18-25025fac5012>:9: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
# <ipython-input-18-25025fac5012>:17: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
