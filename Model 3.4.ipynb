# %%
import glob
import json
import os
import pickle
import random
import traceback
from typing import Tuple

import cv2 as cv
import numpy as np
import pandas as pd
import seaborn as sns
from keras.models import Sequential, load_model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Lambda, LeakyReLU, AveragePooling2D, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from matplotlib import pyplot as plt
from matplotlib.pyplot import hist
from PIL import Image
from scipy.stats import zscore
from sklearn import metrics
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %%
import csv
import time

# %% [markdown]
# ## Config & Constants

# %%
IMAGE_WIDTH, IMAGE_HEIGHT = 227, 227
random.seed(52)

# %% [markdown]
# ## Methods

# %% [markdown]
# ### Image Utilities

# %%
def batch_generator(input_data, output_data, batch_size, is_training):
    input_data_batch = np.empty([batch_size, IMAGE_HEIGHT, IMAGE_WIDTH, 1])
    output_data_batch = np.empty([batch_size, 1])
    while True:
        index = 0
        for i in np.random.permutation(input_data.shape[0]):
            input_data_batch[index] = input_data[i]
            output_data_batch[index] = output_data[i]
            index += 1
            if index == batch_size:
                break
        yield input_data_batch, output_data_batch


def _preprocess(image_loc: str) -> np.ndarray:
    f_image = Image.open(image_loc).convert('L')
    f_image = f_image.resize((IMAGE_WIDTH, IMAGE_HEIGHT), Image.ANTIALIAS)
    image = np.asarray(f_image)
    image = np.expand_dims(image, axis=0)
    image = np.expand_dims(image, axis=3)
    return image


def preprocess(loc: str) -> np.ndarray:
    """Safety wrapper over _preprocess.
    
    Args:
        loc: File location to check if dir or an image.
        
    Returns:
        Preprocessed image(s) as an ndarray.
    """
    if os.path.isdir(loc):
        current = np.concatenate((
            [_preprocess(os.path.join(loc, image)) for image in os.listdir(loc)
             if '.png' in image]
        ))
    else:
        current = _preprocess(loc)
    return current


def generate_data_arrays(
    covid_data: str = 'rsc/New_Data_CoV2/COVID/',
    noncovid_data: str = 'rsc/New_Data_CoV2/non-COVID/',
    others_data:  str = 'rsc/New_Data_CoV2/Others/',
    image_output: str = 'rsc/input_data_v2',
    label_output: str = 'rsc/output_data_v2',
    regenerate: bool = True
) -> Tuple[np.ndarray, np.ndarray]:
    """Loads COVID images into ndarrays.
    
    Args:
        covid_data: Relative path to folder containing COVID images.
        noncovid_data: Relative path to folder containing non-COVID images.
        others_data: Relative path to folder containing Others images.
        image_output: Relative path (with filename) to save loaded images to.
        label_output: Relative path (with filename) to save loaded classes (labels) to.
        regenerate: If True, will regenerate saved ndarray files for both image_output
            and label_output, even if they already exist (overwriting them). If False,
            will simply load and return the aforementioned.
        
    Returns:
        Tuple of ndarrays. The first is the loaded image data in one large ndarray,
        and the second is the loaded labels, also in a large ndarray. These directly
        match up to each other ONLY when both arrays (and their respective files)
        are generated at the same time with this method.
    """
    if (regenerate is False and 
        os.path.isfile(f'{out_input_data}.npy') and
        os.path.isfile(f'{out_output_data}.npy')):
        return (np.load(f'{out_input_data}.npy'),
                np.load(f'{out_output_data}.npy'))
    
    if not ((cd := os.path.exists(covid_data)) and (ncd := os.path.exists(noncovid_data))):
        if (others_data is not None) and not (odd := os.path.exists(others_data)):
            raise NotADirectoryError("Directories do not exist.")
        else:
            raise NotADirectoryError("COVID/non-COVID directories do not exist.")
    
    im_data = np.empty([1, IMAGE_WIDTH, IMAGE_WIDTH, 1])
    output = np.array([0])

    print('Loading Covid Data')
    for i in tqdm(glob.glob(os.path.join(covid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([1])), axis=0)

    print('Loading non-Covid Data')
    for i in tqdm(glob.glob(os.path.join(noncovid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([0])), axis=0)
        
    if others_data is not None:
        print('Loading Others Data')
        for i in tqdm(glob.glob(os.path.join(others_data, '**'))):
            current = preprocess(i)
            im_data = np.concatenate((im_data, current))
            output = np.concatenate((output, np.array([-1])), axis=0)
    else:
        print('Others data not provided; skipping.')


    print('Finished Loading Data')
    im_data = np.delete(im_data, 0, axis=0)
    output = np.delete(output, 0, axis=0)

    zip_data = list(zip(im_data, output))
    random.shuffle(zip_data)
    im_data, output = zip(*zip_data)

    np.save(f'{image_output}', im_data)
    np.save(f'{label_output}', output)
    return im_data, output


def load_data(image_loc: str, label_loc: str, **kwargs) -> Tuple[np.ndarray, np.ndarray]:
    """Attempts to load generated images and labels.
    
    If either is not found, attempts to (re)generate them using the default
    input arguments to the generation method for the raw data, but the input
    `image_loc` and `label_loc` parameters for the output arrays. If this
    still does not work, returns a general error and exits.
    
    Args:
        image_loc: Relative path to saved image ndarray file.
        label_loc: Relative path to saved label ndarray file.
        
    Returns:
        Tuple of ndarrays. The first array holds the loaded image data, whilst
        the second array holds their respective labels.
    
    """
    try:
        image_data = np.load(f'{image_loc}.npy')
        label_data = np.load(f'{label_loc}.npy')
        return image_data, label_data
    
    except FileNotFoundError:
        try:
            image_data, label_data = generate_data_arrays(
                image_output = image_loc,
                label_output = label_loc,
                **kwargs
            )
            return image_data, label_data
        
        except Exception as e:
            traceback.print_exc()

# %% [markdown]
# ## Model Playground

# %%
import os
from skimage import io

# our folder path containing some images
folder_path = 'rsc/Data_CoV2/COVID'

# loop on all files of the folder and build a list of files paths
images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
i: int = 0
for image_path in images:
    img = cv.imread(image_path)
    grayimg = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    equ = cv.equalizeHist(grayimg)
    
    new_file_path = f"rsc/HE_Data_CoV2/COVID/augmented_image_{i}.jpg"
    cv.imwrite(new_file_path, equ)
    i += 1

# %%
# our folder path containing some images
folder_path = 'rsc/Data_CoV2/non-COVID'

# loop on all files of the folder and build a list of files paths
images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
i: int = 0
for image_path in images:
    img = cv.imread(image_path)
    grayimg = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    equ = cv.equalizeHist(grayimg)
    
    new_file_path = f"rsc/HE_Data_CoV2/non-COVID/augmented_image_{i}.jpg"
    cv.imwrite(new_file_path, equ)
    i += 1

# %%
#Version 1
im_data_v1, output_v1 = load_data(
    image_loc = 'rsc/input_data_v1',
    label_loc = 'rsc/output_data_v1',
    covid_data = 'rsc/HE_Data_CoV2/COVID/',
    noncovid_data = 'rsc/HE_Data_CoV2/non-COVID/',
    others_data = None,
)

x_train, x_test, y_train, y_test = train_test_split(im_data_v1, output_v1, random_state=42)

# %%
def make_model(X_Train, Y_Train, X_Test, Y_Test, model_dir: str):
    if not os.path.exists(model_dir):
        os.makedirs(model_dir)
    #X_Train, X_Test, Y_Train, Y_Test = train_test_split(input_data, output_data, test_size=0.1)

    for_pad = lambda s: s if s > 2 else 3

    model = Sequential()
    model.add(Lambda(lambda x: x, input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 1)))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=8, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))



    #model.add(ZeroPadding2D(padding=(for_pad(19) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(Conv2D(kernel_size=(3, 3), filters=2, strides=(1, 1),activation='relu'))

    model.add(Flatten())

    model.add(Dropout(rate=0.4))
    model.add(Dense(units=338, activation='relu'))
    model.add(Dense(units=1, activation='sigmoid'))

    model.compile(optimizer=Adam(lr=3e-4), loss='binary_crossentropy', metrics=["accuracy"])
    model.summary()

    checkpoint = ModelCheckpoint(os.path.join(model_dir, 'xRGM4.1'), verbose=1, period=1, save_best_only=True)

    hist = model.fit(batch_generator(X_Train, Y_Train, 128, True),
                        validation_data=(batch_generator(X_Test, Y_Test, 128, False)), callbacks=[checkpoint],
                        verbose=1, epochs=75, steps_per_epoch=25, validation_steps=len(X_Test))

    with open(os.path.join('models', 'xRGM4.1-Net-HistDict'), 'wb') as f:
        pickle.dump(hist.history, f)

    model.save(model_dir)
    
    return model
#changed steps and epochs and batchsize

# %%
# %%time
model_dir: str = 'model/xRGM4.1'
xRGM = make_model(x_train, y_train.reshape(-1,1), x_test, y_test.reshape(-1,1), model_dir=model_dir)

v_classify = np.vectorize(lambda x: np.round(x, 0))
# xRGMCT2 = load_model('models/xRGMCT2L.h5')
# print(xRGMCT2.history)
y_pred = (xRGM.predict(x_test))

#print(y_test)
#print(y_pred)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_2 (Lambda)            (None, 227, 227, 1)       0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 225, 225, 8)       80
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 225, 225, 8)       32
# _________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)   (None, 225, 225, 8)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 112, 112, 8)       0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 110, 110, 16)      1168
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 110, 110, 16)      64
# _________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)   (None, 110, 110, 16)      0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 108, 108, 32)      4640
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 108, 108, 32)      128
# _________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)   (None, 108, 108, 32)      0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 108, 108, 16)      528
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 108, 108, 16)      64
# _________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)   (None, 108, 108, 16)      0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 106, 106, 32)      4640
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 106, 106, 32)      128
# _________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)   (None, 106, 106, 32)      0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 104, 104, 64)      18496
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 104, 104, 64)      256
# _________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)   (None, 104, 104, 64)      0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 104, 104, 32)      2080
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 104, 104, 32)      128
# _________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)   (None, 104, 104, 32)      0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 102, 102, 64)      18496
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 102, 102, 64)      256
# _________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)   (None, 102, 102, 64)      0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 100, 100, 128)     73856
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 100, 100, 128)     512
# _________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)   (None, 100, 100, 128)     0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 100, 100, 64)      8256
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 100, 100, 64)      256
# _________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)   (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 98, 98, 128)       73856
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 98, 98, 128)       512
# _________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)   (None, 98, 98, 128)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 49, 49, 128)       0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 47, 47, 256)       295168
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 47, 47, 256)       1024
# _________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)   (None, 47, 47, 256)       0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 47, 47, 128)       32896
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 47, 47, 128)       512
# _________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)   (None, 47, 47, 128)       0
# _________________________________________________________________
# average_pooling2d_4 (Average (None, 23, 23, 128)       0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 21, 21, 256)       295168
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 21, 21, 256)       1024
# _________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)   (None, 21, 21, 256)       0
# _________________________________________________________________
# average_pooling2d_5 (Average (None, 10, 10, 256)       0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 10, 10, 128)       32896
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)   (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)   (None, 8, 8, 256)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16384)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 338)               5538130
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 339
# =================================================================
# Total params: 6,702,293
# Trainable params: 6,699,077
# Non-trainable params: 3,216
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/75
# 25/25 [==============================] - 7924s 328s/step - loss: 0.7855 - accuracy: 0.6759 - val_loss: 0.6866 - val_accuracy: 0.5008
#
# Epoch 00001: val_loss improved from inf to 0.68661, saving model to model/xRGM4.1/xRGM4.1
# INFO:tensorflow:Assets written to: model/xRGM4.1/xRGM4.1/assets
# Epoch 2/75
# 25/25 [==============================] - 7964s 329s/step - loss: 0.1926 - accuracy: 0.9224 - val_loss: 0.6941 - val_accuracy: 0.4921
#
# Epoch 00002: val_loss did not improve from 0.68661
# Epoch 3/75
# 25/25 [==============================] - 7955s 329s/step - loss: 0.0905 - accuracy: 0.9597 - val_loss: 0.6953 - val_accuracy: 0.4996
#
# Epoch 00003: val_loss did not improve from 0.68661
# Epoch 4/75
# 25/25 [==============================] - 7982s 330s/step - loss: 0.0460 - accuracy: 0.9849 - val_loss: 0.6574 - val_accuracy: 0.6950
#
# Epoch 00004: val_loss improved from 0.68661 to 0.65735, saving model to model/xRGM4.1/xRGM4.1
# INFO:tensorflow:Assets written to: model/xRGM4.1/xRGM4.1/assets
# Epoch 5/75
# 25/25 [==============================] - 7987s 330s/step - loss: 0.0361 - accuracy: 0.9889 - val_loss: 0.9419 - val_accuracy: 0.5000
#
# Epoch 00005: val_loss did not improve from 0.65735
# Epoch 6/75
# 25/25 [==============================] - 7963s 329s/step - loss: 0.0231 - accuracy: 0.9922 - val_loss: 0.6214 - val_accuracy: 0.6634
#
# Epoch 00006: val_loss improved from 0.65735 to 0.62138, saving model to model/xRGM4.1/xRGM4.1
# INFO:tensorflow:Assets written to: model/xRGM4.1/xRGM4.1/assets
# Epoch 7/75
# 25/25 [==============================] - 8000s 331s/step - loss: 0.0299 - accuracy: 0.9879 - val_loss: 0.9159 - val_accuracy: 0.5498
#
# Epoch 00007: val_loss did not improve from 0.62138
# Epoch 8/75
# 25/25 [==============================] - 8001s 331s/step - loss: 0.0076 - accuracy: 0.9995 - val_loss: 0.7298 - val_accuracy: 0.6348
#
# Epoch 00008: val_loss did not improve from 0.62138
# Epoch 9/75
# 25/25 [==============================] - 7978s 330s/step - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.6342 - val_accuracy: 0.7386
#
# Epoch 00009: val_loss did not improve from 0.62138
# Epoch 10/75
# 25/25 [==============================] - 7965s 329s/step - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.5818 - val_accuracy: 0.7631
#
# Epoch 00010: val_loss improved from 0.62138 to 0.58184, saving model to model/xRGM4.1/xRGM4.1
# INFO:tensorflow:Assets written to: model/xRGM4.1/xRGM4.1/assets
# Epoch 11/75
# 25/25 [==============================] - 8005s 331s/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.5601 - val_accuracy: 0.8193
#
# Epoch 00011: val_loss improved from 0.58184 to 0.56012, saving model to model/xRGM4.1/xRGM4.1
# INFO:tensorflow:Assets written to: model/xRGM4.1/xRGM4.1/assets
# Epoch 12/75
# 25/25 [==============================] - 9260s 383s/step - loss: 0.0040 - accuracy: 0.9983 - val_loss: 0.4355 - val_accuracy: 0.8498
#
# Epoch 00012: val_loss improved from 0.56012 to 0.43555, saving model to model/xRGM4.1/xRGM4.1
# INFO:tensorflow:Assets written to: model/xRGM4.1/xRGM4.1/assets
# Epoch 13/75
# 25/25 [==============================] - 8698s 359s/step - loss: 0.0077 - accuracy: 0.9978 - val_loss: 0.3101 - val_accuracy: 0.8975
#
# Epoch 00013: val_loss improved from 0.43555 to 0.31014, saving model to model/xRGM4.1/xRGM4.1
# INFO:tensorflow:Assets written to: model/xRGM4.1/xRGM4.1/assets
# Epoch 14/75
# 25/25 [==============================] - 9468s 392s/step - loss: 0.0050 - accuracy: 0.9992 - val_loss: 0.3588 - val_accuracy: 0.8999
#
# Epoch 00014: val_loss did not improve from 0.31014
# Epoch 15/75
# 25/25 [==============================] - 9541s 395s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2437 - val_accuracy: 0.9143
#
# Epoch 00015: val_loss improved from 0.31014 to 0.24374, saving model to model/xRGM4.1/xRGM4.1
# INFO:tensorflow:Assets written to: model/xRGM4.1/xRGM4.1/assets
# Epoch 16/75
# 25/25 [==============================] - 9524s 394s/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.1201 - val_accuracy: 0.9594
#
# Epoch 00016: val_loss improved from 0.24374 to 0.12011, saving model to model/xRGM4.1/xRGM4.1
# INFO:tensorflow:Assets written to: model/xRGM4.1/xRGM4.1/assets
# Epoch 17/75
# 25/25 [==============================] - 9527s 394s/step - loss: 0.0018 - accuracy: 0.9999 - val_loss: 0.1960 - val_accuracy: 0.9449
#
# Epoch 00017: val_loss did not improve from 0.12011
# Epoch 18/75
# 25/25 [==============================] - 9523s 394s/step - loss: 0.0181 - accuracy: 0.9934 - val_loss: 0.1998 - val_accuracy: 0.9331
#
# Epoch 00018: val_loss did not improve from 0.12011
# Epoch 19/75
# 25/25 [==============================] - 9514s 394s/step - loss: 0.0249 - accuracy: 0.9896 - val_loss: 0.5652 - val_accuracy: 0.8967
#
# Epoch 00019: val_loss did not improve from 0.12011
# Epoch 20/75
# 25/25 [==============================] - 9501s 393s/step - loss: 0.0463 - accuracy: 0.9830 - val_loss: 0.8702 - val_accuracy: 0.7917
#
# Epoch 00020: val_loss did not improve from 0.12011
# Epoch 21/75
# 25/25 [==============================] - 9499s 393s/step - loss: 0.0251 - accuracy: 0.9913 - val_loss: 0.3161 - val_accuracy: 0.9269
#
# Epoch 00021: val_loss did not improve from 0.12011
# Epoch 22/75
# 25/25 [==============================] - 9517s 394s/step - loss: 0.0158 - accuracy: 0.9968 - val_loss: 0.3519 - val_accuracy: 0.9206
#
# Epoch 00022: val_loss did not improve from 0.12011
# Epoch 23/75
# 25/25 [==============================] - 9521s 394s/step - loss: 0.0056 - accuracy: 0.9993 - val_loss: 0.1727 - val_accuracy: 0.9539
#
# Epoch 00023: val_loss did not improve from 0.12011
# Epoch 24/75
# 25/25 [==============================] - 9502s 393s/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.2043 - val_accuracy: 0.9432
#
# Epoch 00024: val_loss did not improve from 0.12011
# Epoch 25/75
# 25/25 [==============================] - 9484s 392s/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.1832 - val_accuracy: 0.9547
#
# Epoch 00025: val_loss did not improve from 0.12011
# Epoch 26/75
# 25/25 [==============================] - 9471s 392s/step - loss: 0.0013 - accuracy: 0.9988 - val_loss: 0.1184 - val_accuracy: 0.9641
#
# Epoch 00026: val_loss improved from 0.12011 to 0.11838, saving model to model/xRGM4.1/xRGM4.1
# INFO:tensorflow:Assets written to: model/xRGM4.1/xRGM4.1/assets
# Epoch 27/75
# 25/25 [==============================] - 9528s 394s/step - loss: 2.7891e-04 - accuracy: 1.0000 - val_loss: 0.1198 - val_accuracy: 0.9680
#
# Epoch 00027: val_loss did not improve from 0.11838
# Epoch 28/75
# 25/25 [==============================] - 9478s 392s/step - loss: 2.0818e-04 - accuracy: 1.0000 - val_loss: 0.1630 - val_accuracy: 0.9625
#
# Epoch 00028: val_loss did not improve from 0.11838
# Epoch 29/75
# 25/25 [==============================] - 9498s 393s/step - loss: 3.4132e-04 - accuracy: 1.0000 - val_loss: 0.0956 - val_accuracy: 0.9735
#
# Epoch 00029: val_loss improved from 0.11838 to 0.09556, saving model to model/xRGM4.1/xRGM4.1
# INFO:tensorflow:Assets written to: model/xRGM4.1/xRGM4.1/assets
# Epoch 30/75
# 25/25 [==============================] - 9477s 392s/step - loss: 4.0275e-04 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9713
#
# Epoch 00030: val_loss did not improve from 0.09556
# Epoch 31/75
# 25/25 [==============================] - 9514s 394s/step - loss: 1.2978e-04 - accuracy: 1.0000 - val_loss: 0.1026 - val_accuracy: 0.9714
#
# Epoch 00031: val_loss did not improve from 0.09556
# Epoch 32/75
# 25/25 [==============================] - 9497s 393s/step - loss: 7.2158e-05 - accuracy: 1.0000 - val_loss: 0.1037 - val_accuracy: 0.9735
#
# Epoch 00032: val_loss did not improve from 0.09556
# Epoch 33/75
# 25/25 [==============================] - 9516s 394s/step - loss: 9.0678e-05 - accuracy: 1.0000 - val_loss: 0.1015 - val_accuracy: 0.9733
#
# Epoch 00033: val_loss did not improve from 0.09556
# Epoch 34/75
# 25/25 [==============================] - 9510s 393s/step - loss: 8.2184e-05 - accuracy: 1.0000 - val_loss: 0.0888 - val_accuracy: 0.9783
#
# Epoch 00034: val_loss improved from 0.09556 to 0.08882, saving model to model/xRGM4.1/xRGM4.1
# INFO:tensorflow:Assets written to: model/xRGM4.1/xRGM4.1/assets
# Epoch 35/75
# 25/25 [==============================] - 9502s 393s/step - loss: 2.6617e-05 - accuracy: 1.0000 - val_loss: 0.0903 - val_accuracy: 0.9778
#
# Epoch 00035: val_loss did not improve from 0.08882
# Epoch 36/75
# 25/25 [==============================] - 9488s 392s/step - loss: 4.3148e-05 - accuracy: 1.0000 - val_loss: 0.0947 - val_accuracy: 0.9775
#
# Epoch 00036: val_loss did not improve from 0.08882
# Epoch 37/75
# 25/25 [==============================] - 9500s 393s/step - loss: 3.3182e-05 - accuracy: 1.0000 - val_loss: 0.0916 - val_accuracy: 0.9794
#
# Epoch 00037: val_loss did not improve from 0.08882
# Epoch 38/75
# 25/25 [==============================] - 9472s 392s/step - loss: 3.3234e-05 - accuracy: 1.0000 - val_loss: 0.0953 - val_accuracy: 0.9773
#
# Epoch 00038: val_loss did not improve from 0.08882
# Epoch 39/75
# 25/25 [==============================] - 9519s 394s/step - loss: 1.8551e-05 - accuracy: 1.0000 - val_loss: 0.0938 - val_accuracy: 0.9774
#
# Epoch 00039: val_loss did not improve from 0.08882
# Epoch 40/75
# 25/25 [==============================] - 9570s 396s/step - loss: 3.0428e-05 - accuracy: 1.0000 - val_loss: 0.1008 - val_accuracy: 0.9758
#
# Epoch 00040: val_loss did not improve from 0.08882
# Epoch 41/75
# 25/25 [==============================] - 9626s 398s/step - loss: 5.5116e-05 - accuracy: 1.0000 - val_loss: 0.0876 - val_accuracy: 0.9829
#
# Epoch 00041: val_loss improved from 0.08882 to 0.08765, saving model to model/xRGM4.1/xRGM4.1
# INFO:tensorflow:Assets written to: model/xRGM4.1/xRGM4.1/assets
# Epoch 42/75
# 25/25 [==============================] - 9643s 399s/step - loss: 2.5387e-05 - accuracy: 1.0000 - val_loss: 0.0941 - val_accuracy: 0.9772
#
# Epoch 00042: val_loss did not improve from 0.08765
# Epoch 43/75
# 25/25 [==============================] - 9630s 398s/step - loss: 1.7376e-05 - accuracy: 1.0000 - val_loss: 0.0958 - val_accuracy: 0.9772
#
# Epoch 00043: val_loss did not improve from 0.08765
# Epoch 44/75
# 25/25 [==============================] - 9655s 399s/step - loss: 1.3369e-05 - accuracy: 1.0000 - val_loss: 0.0902 - val_accuracy: 0.9778
#
# Epoch 00044: val_loss did not improve from 0.08765
# Epoch 45/75
# 25/25 [==============================] - 9627s 398s/step - loss: 2.1440e-05 - accuracy: 1.0000 - val_loss: 0.0971 - val_accuracy: 0.9758
#
# Epoch 00045: val_loss did not improve from 0.08765
# Epoch 46/75
# 25/25 [==============================] - 9610s 397s/step - loss: 1.6783e-05 - accuracy: 1.0000 - val_loss: 0.0942 - val_accuracy: 0.9761
#
# Epoch 00046: val_loss did not improve from 0.08765
# Epoch 47/75
# 25/25 [==============================] - 9644s 399s/step - loss: 4.7524e-05 - accuracy: 1.0000 - val_loss: 0.0907 - val_accuracy: 0.9772
#
# Epoch 00047: val_loss did not improve from 0.08765
# Epoch 48/75
# 25/25 [==============================] - 9635s 398s/step - loss: 4.9379e-05 - accuracy: 1.0000 - val_loss: 0.0944 - val_accuracy: 0.9811
#
# Epoch 00048: val_loss did not improve from 0.08765
# Epoch 49/75
# 25/25 [==============================] - 9609s 397s/step - loss: 3.2631e-05 - accuracy: 1.0000 - val_loss: 0.1035 - val_accuracy: 0.9774
#
# Epoch 00049: val_loss did not improve from 0.08765
# Epoch 50/75
# 25/25 [==============================] - 8146s 336s/step - loss: 2.7827e-05 - accuracy: 1.0000 - val_loss: 0.0977 - val_accuracy: 0.9761
#
# Epoch 00050: val_loss did not improve from 0.08765
# Epoch 51/75
# 25/25 [==============================] - 8070s 334s/step - loss: 2.4358e-05 - accuracy: 1.0000 - val_loss: 0.0928 - val_accuracy: 0.9783
#
# Epoch 00051: val_loss did not improve from 0.08765
# Epoch 52/75
# 25/25 [==============================] - 8091s 334s/step - loss: 2.5334e-05 - accuracy: 1.0000 - val_loss: 0.0992 - val_accuracy: 0.9770
#
# Epoch 00052: val_loss did not improve from 0.08765
# Epoch 53/75
# 25/25 [==============================] - 8064s 333s/step - loss: 1.7856e-05 - accuracy: 1.0000 - val_loss: 0.0947 - val_accuracy: 0.9777
#
# Epoch 00053: val_loss did not improve from 0.08765
# Epoch 54/75
# 25/25 [==============================] - 8062s 333s/step - loss: 1.6793e-05 - accuracy: 1.0000 - val_loss: 0.1020 - val_accuracy: 0.9761
#
# Epoch 00054: val_loss did not improve from 0.08765
# Epoch 55/75
# 25/25 [==============================] - 8027s 332s/step - loss: 1.6647e-05 - accuracy: 1.0000 - val_loss: 0.0927 - val_accuracy: 0.9767
#
# Epoch 00055: val_loss did not improve from 0.08765
# Epoch 56/75
# 25/25 [==============================] - 8033s 332s/step - loss: 1.4972e-05 - accuracy: 1.0000 - val_loss: 0.0931 - val_accuracy: 0.9789
#
# Epoch 00056: val_loss did not improve from 0.08765
# Epoch 57/75
# 25/25 [==============================] - 8022s 332s/step - loss: 1.2816e-05 - accuracy: 1.0000 - val_loss: 0.0947 - val_accuracy: 0.9775
#
# Epoch 00057: val_loss did not improve from 0.08765
# Epoch 58/75
# 25/25 [==============================] - 8009s 331s/step - loss: 8.7133e-06 - accuracy: 1.0000 - val_loss: 0.0984 - val_accuracy: 0.9771
#
# Epoch 00058: val_loss did not improve from 0.08765
# Epoch 59/75
# 25/25 [==============================] - 8689s 360s/step - loss: 2.4225e-05 - accuracy: 1.0000 - val_loss: 0.0955 - val_accuracy: 0.9773
#
# Epoch 00059: val_loss did not improve from 0.08765
# Epoch 60/75
# 25/25 [==============================] - 9596s 397s/step - loss: 1.3985e-05 - accuracy: 1.0000 - val_loss: 0.0968 - val_accuracy: 0.9772
#
# Epoch 00060: val_loss did not improve from 0.08765
# Epoch 61/75
# 25/25 [==============================] - 9580s 396s/step - loss: 1.2887e-05 - accuracy: 1.0000 - val_loss: 0.1046 - val_accuracy: 0.9764
#
# Epoch 00061: val_loss did not improve from 0.08765
# Epoch 62/75
# 25/25 [==============================] - 9538s 394s/step - loss: 1.1399e-05 - accuracy: 1.0000 - val_loss: 0.1013 - val_accuracy: 0.9774
#
# Epoch 00062: val_loss did not improve from 0.08765
# Epoch 63/75
# 25/25 [==============================] - 9519s 393s/step - loss: 9.9620e-06 - accuracy: 1.0000 - val_loss: 0.0971 - val_accuracy: 0.9794
#
# Epoch 00063: val_loss did not improve from 0.08765
# Epoch 64/75
# 25/25 [==============================] - 9514s 393s/step - loss: 9.3902e-06 - accuracy: 1.0000 - val_loss: 0.0988 - val_accuracy: 0.9786
#
# Epoch 00064: val_loss did not improve from 0.08765
# Epoch 65/75
# 25/25 [==============================] - 9512s 393s/step - loss: 8.9416e-06 - accuracy: 1.0000 - val_loss: 0.0990 - val_accuracy: 0.9789
#
# Epoch 00065: val_loss did not improve from 0.08765
# Epoch 66/75
# 25/25 [==============================] - 9522s 394s/step - loss: 1.1366e-05 - accuracy: 1.0000 - val_loss: 0.0975 - val_accuracy: 0.9774
#
# Epoch 00066: val_loss did not improve from 0.08765
# Epoch 67/75
# 25/25 [==============================] - 9526s 394s/step - loss: 9.5284e-06 - accuracy: 1.0000 - val_loss: 0.0969 - val_accuracy: 0.9781
#
# Epoch 00067: val_loss did not improve from 0.08765
# Epoch 68/75
# 25/25 [==============================] - 9485s 392s/step - loss: 9.2243e-06 - accuracy: 1.0000 - val_loss: 0.0996 - val_accuracy: 0.9771
#
# Epoch 00068: val_loss did not improve from 0.08765
# Epoch 69/75
# 25/25 [==============================] - 9527s 394s/step - loss: 9.5953e-06 - accuracy: 1.0000 - val_loss: 0.0930 - val_accuracy: 0.9798
#
# Epoch 00069: val_loss did not improve from 0.08765
# Epoch 70/75
# 25/25 [==============================] - 11247s 465s/step - loss: 6.1724e-06 - accuracy: 1.0000 - val_loss: 0.0950 - val_accuracy: 0.9809
#
# Epoch 00070: val_loss did not improve from 0.08765
# Epoch 71/75
# 25/25 [==============================] - 12549s 519s/step - loss: 1.2753e-05 - accuracy: 1.0000 - val_loss: 0.0945 - val_accuracy: 0.9805
#
# Epoch 00071: val_loss did not improve from 0.08765
# Epoch 72/75
# 25/25 [==============================] - 12505s 517s/step - loss: 7.8346e-06 - accuracy: 1.0000 - val_loss: 0.0942 - val_accuracy: 0.9779
#
# Epoch 00072: val_loss did not improve from 0.08765
# Epoch 73/75
# 25/25 [==============================] - 12532s 518s/step - loss: 1.1445e-05 - accuracy: 1.0000 - val_loss: 0.0989 - val_accuracy: 0.9778
#
# Epoch 00073: val_loss did not improve from 0.08765
# Epoch 74/75
# 25/25 [==============================] - 12520s 518s/step - loss: 1.0462e-05 - accuracy: 1.0000 - val_loss: 0.0950 - val_accuracy: 0.9776
#
# Epoch 00074: val_loss did not improve from 0.08765
# Epoch 75/75
# 25/25 [==============================] - 12027s 497s/step - loss: 8.4997e-06 - accuracy: 1.0000 - val_loss: 0.0954 - val_accuracy: 0.9776
#
# Epoch 00075: val_loss did not improve from 0.08765
# INFO:tensorflow:Assets written to: model/xRGM4.1/assets
# CPU times: user 21d 4h 3min 14s, sys: 14h 44min 55s, total: 21d 18h 48min 10s
# Wall time: 8d 2h 23min 12s

# %%
confusion_matrix = pd.DataFrame(metrics.confusion_matrix(y_test, v_classify(y_pred)),
                                columns=['Predicted Negative', 'Predicted Positive'],
                                index=['Actual Negative', 'Actual Positive'])

tp, tn, fp, fn = (
    confusion_matrix.iloc[1,1], 
    confusion_matrix.iloc[0,0], 
    confusion_matrix.iloc[0,1], 
    confusion_matrix.iloc[1,0]
)

accuracy = (tp + tn) / (tp + tn + fp + fn)
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
f1_score = 2 * ((specificity * sensitivity) / (specificity + sensitivity))

with open(os.path.join(f'{model_dir}', 'metrics.csv'), 'a', encoding='utf-8') as f:
    f.write(
        f'{time.strftime("%Y-%m-%dT%H:%M:%S-05:00", time.localtime())}, {accuracy}, {sensitivity}, {specificity}, {f1_score}\n'
    )

print(f'Accuracy:    {accuracy}')
print(f'Sensitivity: {sensitivity}')
print(f'Specificity: {specificity}')
print(f'F1 Score:    {f1_score}')
print('\n')
print(confusion_matrix)
# Out:
# Accuracy:    0.9774557165861514
# Sensitivity: 0.967741935483871
# Specificity: 0.9871382636655949
# F1 Score:    0.9773438743566615
#
#
#                  Predicted Negative  Predicted Positive
# Actual Negative                 307                   4
# Actual Positive                  10                 300

# %%
disease_types=['COVID', 'non-COVID']
Y_pred = np.argmax(y_pred)
Y_true = np.argmax(y_test)

plt.figure(figsize=(7, 7))
ax = sns.heatmap(confusion_matrix , cmap=plt.cm.GnBu , 
                 annot=True, fmt='d',square=True, xticklabels=disease_types, 
                 yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
plt.show()

# %%
def plot_model_history(model_history):
   fig, axs = plt.subplots(1,2,figsize=(15,5))
   # summarize history for accuracy
   axs[0].plot(range(1, len(model_history['accuracy']) + 1), model_history['accuracy'])
   axs[0].plot(range(1, len(model_history['val_accuracy']) + 1), model_history['val_accuracy'])
   axs[0].set_title('Model Accuracy')
   axs[0].set_ylabel('Accuracy')
   axs[0].set_xlabel('Epoch')
   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
   axs[0].legend(['train', 'val'], loc='best')
   # summarize history for loss
   axs[1].plot(range(1, len(model_history['loss'])+1), model_history['loss'])
   axs[1].plot(range(1, len(model_history['val_loss']) + 1), model_history['val_loss'])
   axs[1].set_title('Model Loss')
   axs[1].set_ylabel('Loss')
   axs[1].set_xlabel('Epoch')
   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
   axs[1].legend(['train', 'val'], loc='best')
   plt.show()

# %%
with open(os.path.join('models', 'xRGM4.1-Net-HistDict'), 'rb') as f:
    history = pickle.load(f)
    
plot_model_history(history)
# Out:
# <ipython-input-26-25025fac5012>:9: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
# <ipython-input-26-25025fac5012>:17: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
