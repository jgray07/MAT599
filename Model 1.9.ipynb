# %%
import glob
import json
import os
import pickle
import random
import traceback
from typing import Tuple

import numpy as np
import pandas as pd
import seaborn as sns
from keras.models import Sequential, load_model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Lambda, LeakyReLU, AveragePooling2D, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from matplotlib import pyplot as plt
from matplotlib.pyplot import hist
from PIL import Image
from scipy.stats import zscore
from sklearn import metrics
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %%
import csv
import time

# %% [markdown]
# ## Config & Constants

# %%
IMAGE_WIDTH, IMAGE_HEIGHT = 227, 227
random.seed(52)

# %% [markdown]
# ## Methods

# %% [markdown]
# ### Image Utilities

# %%
def batch_generator(input_data, output_data, batch_size, is_training):
    input_data_batch = np.empty([batch_size, IMAGE_HEIGHT, IMAGE_WIDTH, 1])
    output_data_batch = np.empty([batch_size, 1])
    while True:
        index = 0
        for i in np.random.permutation(input_data.shape[0]):
            input_data_batch[index] = input_data[i]
            output_data_batch[index] = output_data[i]
            index += 1
            if index == batch_size:
                break
        yield input_data_batch, output_data_batch


def _preprocess(image_loc: str) -> np.ndarray:
    f_image = Image.open(image_loc).convert('L')
    f_image = f_image.resize((IMAGE_WIDTH, IMAGE_HEIGHT), Image.ANTIALIAS)
    image = np.asarray(f_image)
    image = np.expand_dims(image, axis=0)
    image = np.expand_dims(image, axis=3)
    return image


def preprocess(loc: str) -> np.ndarray:
    """Safety wrapper over _preprocess.
    
    Args:
        loc: File location to check if dir or an image.
        
    Returns:
        Preprocessed image(s) as an ndarray.
    """
    if os.path.isdir(loc):
        current = np.concatenate((
            [_preprocess(os.path.join(loc, image)) for image in os.listdir(loc)
             if '.png' in image]
        ))
    else:
        current = _preprocess(loc)
    return current


def generate_data_arrays(
    covid_data: str = 'rsc/New_Data_CoV2/COVID/',
    noncovid_data: str = 'rsc/New_Data_CoV2/non-COVID/',
    others_data:  str = 'rsc/New_Data_CoV2/Others/',
    image_output: str = 'rsc/input_data_v2',
    label_output: str = 'rsc/output_data_v2',
    regenerate: bool = True
) -> Tuple[np.ndarray, np.ndarray]:
    """Loads COVID images into ndarrays.
    
    Args:
        covid_data: Relative path to folder containing COVID images.
        noncovid_data: Relative path to folder containing non-COVID images.
        others_data: Relative path to folder containing Others images.
        image_output: Relative path (with filename) to save loaded images to.
        label_output: Relative path (with filename) to save loaded classes (labels) to.
        regenerate: If True, will regenerate saved ndarray files for both image_output
            and label_output, even if they already exist (overwriting them). If False,
            will simply load and return the aforementioned.
        
    Returns:
        Tuple of ndarrays. The first is the loaded image data in one large ndarray,
        and the second is the loaded labels, also in a large ndarray. These directly
        match up to each other ONLY when both arrays (and their respective files)
        are generated at the same time with this method.
    """
    if (regenerate is False and 
        os.path.isfile(f'{out_input_data}.npy') and
        os.path.isfile(f'{out_output_data}.npy')):
        return (np.load(f'{out_input_data}.npy'),
                np.load(f'{out_output_data}.npy'))
    
    if not ((cd := os.path.exists(covid_data)) and (ncd := os.path.exists(noncovid_data))):
        if (others_data is not None) and not (odd := os.path.exists(others_data)):
            raise NotADirectoryError("Directories do not exist.")
        else:
            raise NotADirectoryError("COVID/non-COVID directories do not exist.")
    
    im_data = np.empty([1, IMAGE_WIDTH, IMAGE_WIDTH, 1])
    output = np.array([0])

    print('Loading Covid Data')
    for i in tqdm(glob.glob(os.path.join(covid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([1])), axis=0)

    print('Loading non-Covid Data')
    for i in tqdm(glob.glob(os.path.join(noncovid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([0])), axis=0)
        
    if others_data is not None:
        print('Loading Others Data')
        for i in tqdm(glob.glob(os.path.join(others_data, '**'))):
            current = preprocess(i)
            im_data = np.concatenate((im_data, current))
            output = np.concatenate((output, np.array([-1])), axis=0)
    else:
        print('Others data not provided; skipping.')


    print('Finished Loading Data')
    im_data = np.delete(im_data, 0, axis=0)
    output = np.delete(output, 0, axis=0)

    zip_data = list(zip(im_data, output))
    random.shuffle(zip_data)
    im_data, output = zip(*zip_data)

    np.save(f'{image_output}', im_data)
    np.save(f'{label_output}', output)
    return im_data, output


def load_data(image_loc: str, label_loc: str, **kwargs) -> Tuple[np.ndarray, np.ndarray]:
    """Attempts to load generated images and labels.
    
    If either is not found, attempts to (re)generate them using the default
    input arguments to the generation method for the raw data, but the input
    `image_loc` and `label_loc` parameters for the output arrays. If this
    still does not work, returns a general error and exits.
    
    Args:
        image_loc: Relative path to saved image ndarray file.
        label_loc: Relative path to saved label ndarray file.
        
    Returns:
        Tuple of ndarrays. The first array holds the loaded image data, whilst
        the second array holds their respective labels.
    
    """
    try:
        image_data = np.load(f'{image_loc}.npy')
        label_data = np.load(f'{label_loc}.npy')
        return image_data, label_data
    
    except FileNotFoundError:
        try:
            image_data, label_data = generate_data_arrays(
                image_output = image_loc,
                label_output = label_loc,
                **kwargs
            )
            return image_data, label_data
        
        except Exception as e:
            traceback.print_exc()

# %% [markdown]
# ## Model Playground

# %%
#Version 1
im_data_v1, output_v1 = load_data(
    image_loc = 'rsc/input_data_v1',
    label_loc = 'rsc/output_data_v1',
    covid_data = 'rsc/Data_CoV2/COVID/',
    noncovid_data = 'rsc/Data_CoV2/non-COVID/',
    others_data = None,
)

x_train, x_test, y_train, y_test = train_test_split(im_data_v1, output_v1, random_state=42)

# %%
def make_model(X_Train, Y_Train, X_Test, Y_Test, model_dir: str):
    if not os.path.exists(model_dir):
        os.makedirs(model_dir)
    #X_Train, X_Test, Y_Train, Y_Test = train_test_split(input_data, output_data, test_size=0.1)

    for_pad = lambda s: s if s > 2 else 3

    model = Sequential()
    model.add(Lambda(lambda x: x, input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 1)))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=8, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))



    #model.add(ZeroPadding2D(padding=(for_pad(19) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(Conv2D(kernel_size=(3, 3), filters=2, strides=(1, 1),activation='relu'))

    model.add(Flatten())

    model.add(Dropout(rate=0.4))
    model.add(Dense(units=338, activation='relu'))
    model.add(Dense(units=1, activation='sigmoid'))

    model.compile(optimizer=Adam(lr=1e-5), loss='binary_crossentropy', metrics=["accuracy"])
    model.summary()

    checkpoint = ModelCheckpoint(os.path.join(model_dir, 'xRGM1.9'), verbose=1, period=1, save_best_only=True)

    hist = model.fit_generator(batch_generator(X_Train, Y_Train, 128, True),
                        validation_data=(batch_generator(X_Test, Y_Test, 128, False)), callbacks=[checkpoint],
                        verbose=1, epochs=100, steps_per_epoch=15, validation_steps=len(X_Test))

    with open(os.path.join('models', 'xRGM1.9-Net-HistDict'), 'wb') as f:
        pickle.dump(hist.history, f)

    model.save(model_dir)
    
    return model
#changed steps and epochs and batchsize

# %%
# %%time
model_dir: str = 'model/xRGM1.9'
xRGM = make_model(x_train, y_train.reshape(-1,1), x_test, y_test.reshape(-1,1), model_dir=model_dir)

v_classify = np.vectorize(lambda x: np.round(x, 0))
# xRGMCT2 = load_model('models/xRGMCT2L.h5')
# print(xRGMCT2.history)
y_pred = (xRGM.predict(x_test))

#print(y_test)
#print(y_pred)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda (Lambda)              (None, 227, 227, 1)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 225, 225, 8)       80
# _________________________________________________________________
# batch_normalization (BatchNo (None, 225, 225, 8)       32
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 225, 225, 8)       0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 110, 110, 16)      1168
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 110, 110, 16)      64
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 110, 110, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 108, 108, 32)      4640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 108, 108, 32)      128
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 108, 108, 32)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 108, 108, 16)      528
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 108, 108, 16)      64
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 108, 108, 16)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 106, 106, 32)      4640
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 106, 106, 32)      128
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 106, 106, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 104, 104, 64)      18496
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 104, 104, 64)      256
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 104, 104, 64)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 104, 104, 32)      2080
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 104, 104, 32)      128
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 104, 104, 32)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 102, 102, 64)      18496
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 102, 102, 64)      256
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 102, 102, 64)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 100, 100, 128)     73856
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 100, 100, 128)     512
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 100, 100, 128)     0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 100, 100, 64)      8256
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 100, 100, 64)      256
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 98, 98, 128)       73856
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 98, 98, 128)       512
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 98, 98, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 49, 49, 128)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 47, 47, 256)       295168
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 47, 47, 256)       1024
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 47, 47, 256)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 47, 47, 128)       32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 47, 47, 128)       512
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 47, 47, 128)       0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 23, 23, 128)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 21, 21, 256)       295168
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 21, 21, 256)       1024
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 21, 21, 256)       0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 10, 10, 256)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 10, 10, 128)       32896
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 8, 8, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 338)               5538130
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 339
# =================================================================
# Total params: 6,702,293
# Trainable params: 6,699,077
# Non-trainable params: 3,216
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# /home/jg1994/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 15/15 [==============================] - 13355s 946s/step - loss: 0.7469 - accuracy: 0.5869 - val_loss: 0.6932 - val_accuracy: 0.4997
#
# Epoch 00001: val_loss improved from inf to 0.69323, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 2/100
# 15/15 [==============================] - 13312s 944s/step - loss: 0.5081 - accuracy: 0.7529 - val_loss: 0.6934 - val_accuracy: 0.5026
#
# Epoch 00002: val_loss did not improve from 0.69323
# Epoch 3/100
# 15/15 [==============================] - 13407s 950s/step - loss: 0.4356 - accuracy: 0.8087 - val_loss: 0.6948 - val_accuracy: 0.5013
#
# Epoch 00003: val_loss did not improve from 0.69323
# Epoch 4/100
# 15/15 [==============================] - 13261s 940s/step - loss: 0.3918 - accuracy: 0.8231 - val_loss: 0.6952 - val_accuracy: 0.4548
#
# Epoch 00004: val_loss did not improve from 0.69323
# Epoch 5/100
# 15/15 [==============================] - 13185s 934s/step - loss: 0.3201 - accuracy: 0.8754 - val_loss: 0.6983 - val_accuracy: 0.4916
#
# Epoch 00005: val_loss did not improve from 0.69323
# Epoch 6/100
# 15/15 [==============================] - 13334s 945s/step - loss: 0.2748 - accuracy: 0.9084 - val_loss: 0.6984 - val_accuracy: 0.4848
#
# Epoch 00006: val_loss did not improve from 0.69323
# Epoch 7/100
# 15/15 [==============================] - 13861s 983s/step - loss: 0.2447 - accuracy: 0.9181 - val_loss: 0.7156 - val_accuracy: 0.4945
#
# Epoch 00007: val_loss did not improve from 0.69323
# Epoch 8/100
# 15/15 [==============================] - 13249s 939s/step - loss: 0.2166 - accuracy: 0.9262 - val_loss: 0.7233 - val_accuracy: 0.4946
#
# Epoch 00008: val_loss did not improve from 0.69323
# Epoch 9/100
# 15/15 [==============================] - 13246s 939s/step - loss: 0.1912 - accuracy: 0.9428 - val_loss: 0.7270 - val_accuracy: 0.4886
#
# Epoch 00009: val_loss did not improve from 0.69323
# Epoch 10/100
# 15/15 [==============================] - 13163s 933s/step - loss: 0.1921 - accuracy: 0.9302 - val_loss: 0.7594 - val_accuracy: 0.4852
#
# Epoch 00010: val_loss did not improve from 0.69323
# Epoch 11/100
# 15/15 [==============================] - 13184s 935s/step - loss: 0.1631 - accuracy: 0.9544 - val_loss: 0.8077 - val_accuracy: 0.4893
#
# Epoch 00011: val_loss did not improve from 0.69323
# Epoch 12/100
# 15/15 [==============================] - 13466s 955s/step - loss: 0.1387 - accuracy: 0.9584 - val_loss: 0.8142 - val_accuracy: 0.4780
#
# Epoch 00012: val_loss did not improve from 0.69323
# Epoch 13/100
# 15/15 [==============================] - 13139s 931s/step - loss: 0.1465 - accuracy: 0.9551 - val_loss: 0.8306 - val_accuracy: 0.4755
#
# Epoch 00013: val_loss did not improve from 0.69323
# Epoch 14/100
# 15/15 [==============================] - 13059s 926s/step - loss: 0.1252 - accuracy: 0.9629 - val_loss: 0.8494 - val_accuracy: 0.4879
#
# Epoch 00014: val_loss did not improve from 0.69323
# Epoch 15/100
# 15/15 [==============================] - 13221s 937s/step - loss: 0.1209 - accuracy: 0.9677 - val_loss: 0.8330 - val_accuracy: 0.5323
#
# Epoch 00015: val_loss did not improve from 0.69323
# Epoch 16/100
# 15/15 [==============================] - 13170s 934s/step - loss: 0.0831 - accuracy: 0.9842 - val_loss: 0.7899 - val_accuracy: 0.5445
#
# Epoch 00016: val_loss did not improve from 0.69323
# Epoch 17/100
# 15/15 [==============================] - 13260s 940s/step - loss: 0.0878 - accuracy: 0.9803 - val_loss: 0.7314 - val_accuracy: 0.5691
#
# Epoch 00017: val_loss did not improve from 0.69323
# Epoch 18/100
# 15/15 [==============================] - 13071s 926s/step - loss: 0.0862 - accuracy: 0.9777 - val_loss: 0.6989 - val_accuracy: 0.5991
#
# Epoch 00018: val_loss did not improve from 0.69323
# Epoch 19/100
# 15/15 [==============================] - 7020s 494s/step - loss: 0.0748 - accuracy: 0.9842 - val_loss: 0.6566 - val_accuracy: 0.6501
#
# Epoch 00019: val_loss improved from 0.69323 to 0.65655, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 20/100
# 15/15 [==============================] - 6244s 442s/step - loss: 0.0629 - accuracy: 0.9894 - val_loss: 0.6332 - val_accuracy: 0.6925
#
# Epoch 00020: val_loss improved from 0.65655 to 0.63323, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 21/100
# 15/15 [==============================] - 6078s 431s/step - loss: 0.0628 - accuracy: 0.9867 - val_loss: 0.5663 - val_accuracy: 0.7471
#
# Epoch 00021: val_loss improved from 0.63323 to 0.56626, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 22/100
# 15/15 [==============================] - 6072s 430s/step - loss: 0.0610 - accuracy: 0.9896 - val_loss: 0.5734 - val_accuracy: 0.7501
#
# Epoch 00022: val_loss did not improve from 0.56626
# Epoch 23/100
# 15/15 [==============================] - 6074s 430s/step - loss: 0.0547 - accuracy: 0.9929 - val_loss: 0.5542 - val_accuracy: 0.7754
#
# Epoch 00023: val_loss improved from 0.56626 to 0.55422, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 24/100
# 15/15 [==============================] - 6104s 433s/step - loss: 0.0441 - accuracy: 0.9921 - val_loss: 0.4746 - val_accuracy: 0.8075
#
# Epoch 00024: val_loss improved from 0.55422 to 0.47455, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 25/100
# 15/15 [==============================] - 6126s 434s/step - loss: 0.0515 - accuracy: 0.9901 - val_loss: 0.4816 - val_accuracy: 0.8113
#
# Epoch 00025: val_loss did not improve from 0.47455
# Epoch 26/100
# 15/15 [==============================] - 6135s 435s/step - loss: 0.0374 - accuracy: 0.9975 - val_loss: 0.4654 - val_accuracy: 0.8266
#
# Epoch 00026: val_loss improved from 0.47455 to 0.46541, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 27/100
# 15/15 [==============================] - 6084s 431s/step - loss: 0.0389 - accuracy: 0.9928 - val_loss: 0.4153 - val_accuracy: 0.8349
#
# Epoch 00027: val_loss improved from 0.46541 to 0.41532, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 28/100
# 15/15 [==============================] - 6068s 430s/step - loss: 0.0323 - accuracy: 0.9989 - val_loss: 0.3540 - val_accuracy: 0.8650
#
# Epoch 00028: val_loss improved from 0.41532 to 0.35398, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 29/100
# 15/15 [==============================] - 6059s 430s/step - loss: 0.0302 - accuracy: 0.9980 - val_loss: 0.3260 - val_accuracy: 0.8747
#
# Epoch 00029: val_loss improved from 0.35398 to 0.32601, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 30/100
# 15/15 [==============================] - 6083s 431s/step - loss: 0.0292 - accuracy: 0.9983 - val_loss: 0.3152 - val_accuracy: 0.8867
#
# Epoch 00030: val_loss improved from 0.32601 to 0.31523, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 31/100
# 15/15 [==============================] - 6082s 431s/step - loss: 0.0287 - accuracy: 0.9964 - val_loss: 0.2853 - val_accuracy: 0.8964
#
# Epoch 00031: val_loss improved from 0.31523 to 0.28528, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 32/100
# 15/15 [==============================] - 6081s 431s/step - loss: 0.0234 - accuracy: 0.9991 - val_loss: 0.2556 - val_accuracy: 0.9091
#
# Epoch 00032: val_loss improved from 0.28528 to 0.25563, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 33/100
# 15/15 [==============================] - 6073s 430s/step - loss: 0.0246 - accuracy: 0.9998 - val_loss: 0.2294 - val_accuracy: 0.8973
#
# Epoch 00033: val_loss improved from 0.25563 to 0.22942, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 34/100
# 15/15 [==============================] - 6066s 430s/step - loss: 0.0221 - accuracy: 0.9989 - val_loss: 0.2159 - val_accuracy: 0.9163
#
# Epoch 00034: val_loss improved from 0.22942 to 0.21591, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 35/100
# 15/15 [==============================] - 6076s 431s/step - loss: 0.0199 - accuracy: 0.9996 - val_loss: 0.1911 - val_accuracy: 0.9282
#
# Epoch 00035: val_loss improved from 0.21591 to 0.19114, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 36/100
# 15/15 [==============================] - 6066s 430s/step - loss: 0.0208 - accuracy: 0.9993 - val_loss: 0.1675 - val_accuracy: 0.9459
#
# Epoch 00036: val_loss improved from 0.19114 to 0.16749, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 37/100
# 15/15 [==============================] - 6047s 428s/step - loss: 0.0173 - accuracy: 0.9993 - val_loss: 0.1662 - val_accuracy: 0.9402
#
# Epoch 00037: val_loss improved from 0.16749 to 0.16620, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 38/100
# 15/15 [==============================] - 6948s 493s/step - loss: 0.0182 - accuracy: 0.9976 - val_loss: 0.1659 - val_accuracy: 0.9388
#
# Epoch 00038: val_loss improved from 0.16620 to 0.16586, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 39/100
# 15/15 [==============================] - 6701s 475s/step - loss: 0.0188 - accuracy: 0.9987 - val_loss: 0.1687 - val_accuracy: 0.9355
#
# Epoch 00039: val_loss did not improve from 0.16586
# Epoch 40/100
# 15/15 [==============================] - 6123s 434s/step - loss: 0.0141 - accuracy: 0.9997 - val_loss: 0.1349 - val_accuracy: 0.9507
#
# Epoch 00040: val_loss improved from 0.16586 to 0.13490, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 41/100
# 15/15 [==============================] - 6086s 431s/step - loss: 0.0171 - accuracy: 0.9998 - val_loss: 0.1443 - val_accuracy: 0.9516
#
# Epoch 00041: val_loss did not improve from 0.13490
# Epoch 42/100
# 15/15 [==============================] - 6052s 429s/step - loss: 0.0149 - accuracy: 0.9996 - val_loss: 0.1438 - val_accuracy: 0.9569
#
# Epoch 00042: val_loss did not improve from 0.13490
# Epoch 43/100
# 15/15 [==============================] - 6075s 430s/step - loss: 0.0132 - accuracy: 0.9986 - val_loss: 0.1447 - val_accuracy: 0.9561
#
# Epoch 00043: val_loss did not improve from 0.13490
# Epoch 44/100
# 15/15 [==============================] - 6081s 431s/step - loss: 0.0145 - accuracy: 0.9999 - val_loss: 0.1245 - val_accuracy: 0.9573
#
# Epoch 00044: val_loss improved from 0.13490 to 0.12449, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 45/100
# 15/15 [==============================] - 6071s 430s/step - loss: 0.0145 - accuracy: 0.9983 - val_loss: 0.1276 - val_accuracy: 0.9532
#
# Epoch 00045: val_loss did not improve from 0.12449
# Epoch 46/100
# 15/15 [==============================] - 6056s 429s/step - loss: 0.0124 - accuracy: 0.9988 - val_loss: 0.1249 - val_accuracy: 0.9617
#
# Epoch 00046: val_loss did not improve from 0.12449
# Epoch 47/100
# 15/15 [==============================] - 6091s 432s/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.1251 - val_accuracy: 0.9530
#
# Epoch 00047: val_loss did not improve from 0.12449
# Epoch 48/100
# 15/15 [==============================] - 6073s 430s/step - loss: 0.0083 - accuracy: 0.9999 - val_loss: 0.1209 - val_accuracy: 0.9550
#
# Epoch 00048: val_loss improved from 0.12449 to 0.12088, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 49/100
# 15/15 [==============================] - 6078s 431s/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.1227 - val_accuracy: 0.9615
#
# Epoch 00049: val_loss did not improve from 0.12088
# Epoch 50/100
# 15/15 [==============================] - 6081s 431s/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.1181 - val_accuracy: 0.9558
#
# Epoch 00050: val_loss improved from 0.12088 to 0.11809, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 51/100
# 15/15 [==============================] - 6111s 433s/step - loss: 0.0110 - accuracy: 0.9987 - val_loss: 0.1232 - val_accuracy: 0.9626
#
# Epoch 00051: val_loss did not improve from 0.11809
# Epoch 52/100
# 15/15 [==============================] - 6130s 435s/step - loss: 0.0072 - accuracy: 0.9992 - val_loss: 0.1176 - val_accuracy: 0.9598
#
# Epoch 00052: val_loss improved from 0.11809 to 0.11764, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 53/100
# 15/15 [==============================] - 6132s 435s/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.1241 - val_accuracy: 0.9619
#
# Epoch 00053: val_loss did not improve from 0.11764
# Epoch 54/100
# 15/15 [==============================] - 6085s 431s/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.1195 - val_accuracy: 0.9626
#
# Epoch 00054: val_loss did not improve from 0.11764
# Epoch 55/100
# 15/15 [==============================] - 6075s 431s/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.1180 - val_accuracy: 0.9555
#
# Epoch 00055: val_loss did not improve from 0.11764
# Epoch 56/100
# 15/15 [==============================] - 6092s 432s/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.1220 - val_accuracy: 0.9586
#
# Epoch 00056: val_loss did not improve from 0.11764
# Epoch 57/100
# 15/15 [==============================] - 6077s 431s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.1236 - val_accuracy: 0.9589
#
# Epoch 00057: val_loss did not improve from 0.11764
# Epoch 58/100
# 15/15 [==============================] - 6062s 430s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.1143 - val_accuracy: 0.9591
#
# Epoch 00058: val_loss improved from 0.11764 to 0.11431, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 59/100
# 15/15 [==============================] - 6097s 432s/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.1204 - val_accuracy: 0.9597
#
# Epoch 00059: val_loss did not improve from 0.11431
# Epoch 60/100
# 15/15 [==============================] - 6070s 430s/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.1133 - val_accuracy: 0.9627
#
# Epoch 00060: val_loss improved from 0.11431 to 0.11329, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 61/100
# 15/15 [==============================] - 6083s 431s/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.1130 - val_accuracy: 0.9549
#
# Epoch 00061: val_loss improved from 0.11329 to 0.11297, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 62/100
# 15/15 [==============================] - 6094s 432s/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.1194 - val_accuracy: 0.9570
#
# Epoch 00062: val_loss did not improve from 0.11297
# Epoch 63/100
# 15/15 [==============================] - 6088s 431s/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9542
#
# Epoch 00063: val_loss did not improve from 0.11297
# Epoch 64/100
# 15/15 [==============================] - 6126s 434s/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.1205 - val_accuracy: 0.9570
#
# Epoch 00064: val_loss did not improve from 0.11297
# Epoch 65/100
# 15/15 [==============================] - 6140s 435s/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.1200 - val_accuracy: 0.9629
#
# Epoch 00065: val_loss did not improve from 0.11297
# Epoch 66/100
# 15/15 [==============================] - 6113s 434s/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9598
#
# Epoch 00066: val_loss did not improve from 0.11297
# Epoch 67/100
# 15/15 [==============================] - 6081s 431s/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.1179 - val_accuracy: 0.9590
#
# Epoch 00067: val_loss did not improve from 0.11297
# Epoch 68/100
# 15/15 [==============================] - 6064s 430s/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9551
#
# Epoch 00068: val_loss did not improve from 0.11297
# Epoch 69/100
# 15/15 [==============================] - 6081s 431s/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1121 - val_accuracy: 0.9606
# Epoch 00069: val_loss improved from 0.11297 to 0.11214, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 70/100
# 15/15 [==============================] - 6091s 432s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9610
#
# Epoch 00070: val_loss did not improve from 0.11214
# Epoch 71/100
# 15/15 [==============================] - 6099s 432s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1166 - val_accuracy: 0.9594
#
# Epoch 00071: val_loss did not improve from 0.11214
# Epoch 72/100
# 15/15 [==============================] - 4672s 330s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1204 - val_accuracy: 0.9634
#
# Epoch 00072: val_loss did not improve from 0.11214
# Epoch 73/100
# 15/15 [==============================] - 4620s 327s/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.1232 - val_accuracy: 0.9568
#
# Epoch 00073: val_loss did not improve from 0.11214
# Epoch 74/100
# 15/15 [==============================] - 4623s 328s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9597
#
# Epoch 00075: val_loss did not improve from 0.11214
# Epoch 76/100
# 15/15 [==============================] - 4641s 329s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1202 - val_accuracy: 0.9530
#
# Epoch 00076: val_loss did not improve from 0.11214
# Epoch 77/100
# 15/15 [==============================] - 4684s 332s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1204 - val_accuracy: 0.9557
#
# Epoch 00077: val_loss did not improve from 0.11214
# Epoch 78/100
# 15/15 [==============================] - 4659s 331s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9605
#
# Epoch 00078: val_loss did not improve from 0.11214
# Epoch 79/100
# 15/15 [==============================] - 4634s 329s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1218 - val_accuracy: 0.9638
#
# Epoch 00079: val_loss did not improve from 0.11214
# Epoch 80/100
# 15/15 [==============================] - 4612s 327s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1147 - val_accuracy: 0.9637
#
# Epoch 00080: val_loss did not improve from 0.11214
# Epoch 81/100
# 15/15 [==============================] - 4622s 328s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1140 - val_accuracy: 0.9509
#
# Epoch 00081: val_loss did not improve from 0.11214
# Epoch 82/100
# 15/15 [==============================] - 3591s 254s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1185 - val_accuracy: 0.9683
#
# Epoch 00082: val_loss did not improve from 0.11214
# Epoch 83/100
# 15/15 [==============================] - 3220s 229s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1168 - val_accuracy: 0.9610
#
# Epoch 00083: val_loss did not improve from 0.11214
# Epoch 84/100
# 15/15 [==============================] - 3217s 228s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9587
#
# Epoch 00084: val_loss did not improve from 0.11214
# Epoch 85/100
# 15/15 [==============================] - 3218s 228s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9525
#
# Epoch 00085: val_loss did not improve from 0.11214
# Epoch 86/100
# 15/15 [==============================] - 3221s 229s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1269 - val_accuracy: 0.9614
#
# Epoch 00086: val_loss did not improve from 0.11214
# Epoch 87/100
# 15/15 [==============================] - 3219s 228s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1138 - val_accuracy: 0.9522
#
# Epoch 00087: val_loss did not improve from 0.11214
# Epoch 88/100
# 15/15 [==============================] - 3222s 229s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9595
#
# Epoch 00088: val_loss did not improve from 0.11214
# Epoch 89/100
# 15/15 [==============================] - 3220s 228s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9585
#
# Epoch 00089: val_loss did not improve from 0.11214
# Epoch 90/100
# 15/15 [==============================] - 3222s 229s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9615
#
# Epoch 00090: val_loss did not improve from 0.11214
# Epoch 91/100
# 15/15 [==============================] - 3219s 228s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1134 - val_accuracy: 0.9557
#
# Epoch 00091: val_loss did not improve from 0.11214
# Epoch 92/100
# 15/15 [==============================] - 3219s 228s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1096 - val_accuracy: 0.9626
#
# Epoch 00092: val_loss improved from 0.11214 to 0.10965, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 93/100
# 15/15 [==============================] - 3216s 228s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1176 - val_accuracy: 0.9654
#
# Epoch 00093: val_loss did not improve from 0.10965
# Epoch 94/100
# 15/15 [==============================] - 3227s 229s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1145 - val_accuracy: 0.9599
#
# Epoch 00094: val_loss did not improve from 0.10965
# Epoch 95/100
# 15/15 [==============================] - 3221s 229s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1092 - val_accuracy: 0.9646
#
# Epoch 00095: val_loss improved from 0.10965 to 0.10925, saving model to model/xRGM1.9/xRGM1.9
# INFO:tensorflow:Assets written to: model/xRGM1.9/xRGM1.9/assets
# Epoch 96/100
# 15/15 [==============================] - 3220s 229s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1137 - val_accuracy: 0.9574
#
# Epoch 00096: val_loss did not improve from 0.10925
# Epoch 97/100
# 15/15 [==============================] - 3222s 229s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1135 - val_accuracy: 0.9589
#
# Epoch 00097: val_loss did not improve from 0.10925
# Epoch 98/100
# 15/15 [==============================] - 3217s 228s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1149 - val_accuracy: 0.9644
#
# Epoch 00098: val_loss did not improve from 0.10925
# Epoch 99/100
# 15/15 [==============================] - 3224s 229s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1176 - val_accuracy: 0.9576
#
# Epoch 00099: val_loss did not improve from 0.10925
# Epoch 100/100
# 15/15 [==============================] - 3175s 225s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1140 - val_accuracy: 0.9581
#
# Epoch 00100: val_loss did not improve from 0.10925
# INFO:tensorflow:Assets written to: model/xRGM1.9/assets
# CPU times: user 26d 17h 15min 44s, sys: 20h 59min 24s, total: 27d 14h 15min 9s
# Wall time: 7d 18h 54min 35s

# %%
confusion_matrix = pd.DataFrame(metrics.confusion_matrix(y_test, v_classify(y_pred)),
                                columns=['Predicted Negative', 'Predicted Positive'],
                                index=['Actual Negative', 'Actual Positive'])

tp, tn, fp, fn = (
    confusion_matrix.iloc[1,1], 
    confusion_matrix.iloc[0,0], 
    confusion_matrix.iloc[0,1], 
    confusion_matrix.iloc[1,0]
)

accuracy = (tp + tn) / (tp + tn + fp + fn)
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
f1_score = 2 * ((specificity * sensitivity) / (specificity + sensitivity))

with open(os.path.join(f'{model_dir}', 'metrics.csv'), 'a', encoding='utf-8') as f:
    f.write(
        f'{time.strftime("%Y-%m-%dT%H:%M:%S-05:00", time.localtime())}, {accuracy}, {sensitivity}, {specificity}, {f1_score}\n'
    )

print(f'Accuracy:    {accuracy}')
print(f'Sensitivity: {sensitivity}')
print(f'Specificity: {specificity}')
print(f'F1 Score:    {f1_score}')
print('\n')
print(confusion_matrix)
# Out:
# Accuracy:    0.9581320450885669
# Sensitivity: 0.967741935483871
# Specificity: 0.9485530546623794
# F1 Score:    0.9580514208389715
#
#
#                  Predicted Negative  Predicted Positive
# Actual Negative                 295                  16
# Actual Positive                  10                 300

# %%
disease_types=['COVID', 'non-COVID']
Y_pred = np.argmax(y_pred)
Y_true = np.argmax(y_test)

plt.figure(figsize=(7, 7))
ax = sns.heatmap(confusion_matrix , cmap=plt.cm.GnBu , 
                 annot=True, fmt='d',square=True, xticklabels=disease_types, 
                 yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
plt.show()

# %%
def plot_model_history(model_history):
   fig, axs = plt.subplots(1,2,figsize=(15,5))
   # summarize history for accuracy
   axs[0].plot(range(1, len(model_history['accuracy']) + 1), model_history['accuracy'])
   axs[0].plot(range(1, len(model_history['val_accuracy']) + 1), model_history['val_accuracy'])
   axs[0].set_title('Model Accuracy')
   axs[0].set_ylabel('Accuracy')
   axs[0].set_xlabel('Epoch')
   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
   axs[0].legend(['train', 'val'], loc='best')
   # summarize history for loss
   axs[1].plot(range(1, len(model_history['loss'])+1), model_history['loss'])
   axs[1].plot(range(1, len(model_history['val_loss']) + 1), model_history['val_loss'])
   axs[1].set_title('Model Loss')
   axs[1].set_ylabel('Loss')
   axs[1].set_xlabel('Epoch')
   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
   axs[1].legend(['train', 'val'], loc='best')
   plt.show()

# %%
with open(os.path.join('models', 'xRGM1.9-Net-HistDict'), 'rb') as f:
    history = pickle.load(f)
    
plot_model_history(history)
# Out:
# <ipython-input-10-25025fac5012>:9: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
# <ipython-input-10-25025fac5012>:17: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
