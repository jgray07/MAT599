# %%
import glob
import json
import os
import pickle
import random
import traceback
from typing import Tuple

import numpy as np
import pandas as pd
import seaborn as sns
from keras.models import Sequential, load_model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Lambda, LeakyReLU, AveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import Nadam
from keras.callbacks import ModelCheckpoint
from matplotlib import pyplot as plt
from matplotlib.pyplot import hist
from PIL import Image
from scipy.stats import zscore
from sklearn import metrics
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %%
import csv
import time

# %% [markdown]
# ## Config & Constants

# %%
IMAGE_WIDTH, IMAGE_HEIGHT = 227, 227
random.seed(52)

# %% [markdown]
# ## Methods

# %% [markdown]
# ### Image Utilities

# %%
def batch_generator(input_data, output_data, batch_size, is_training):
    input_data_batch = np.empty([batch_size, IMAGE_HEIGHT, IMAGE_WIDTH, 1])
    output_data_batch = np.empty([batch_size, 1])
    while True:
        index = 0
        for i in np.random.permutation(input_data.shape[0]):
            input_data_batch[index] = input_data[i]
            output_data_batch[index] = output_data[i]
            index += 1
            if index == batch_size:
                break
        yield input_data_batch, output_data_batch


def _preprocess(image_loc: str) -> np.ndarray:
    f_image = Image.open(image_loc).convert('L')
    f_image = f_image.resize((IMAGE_WIDTH, IMAGE_HEIGHT), Image.ANTIALIAS)
    image = np.asarray(f_image)
    image = np.expand_dims(image, axis=0)
    image = np.expand_dims(image, axis=3)
    return image


def preprocess(loc: str) -> np.ndarray:
    """Safety wrapper over _preprocess.
    
    Args:
        loc: File location to check if dir or an image.
        
    Returns:
        Preprocessed image(s) as an ndarray.
    """
    if os.path.isdir(loc):
        current = np.concatenate((
            [_preprocess(os.path.join(loc, image)) for image in os.listdir(loc)
             if '.png' in image]
        ))
    else:
        current = _preprocess(loc)
    return current


def generate_data_arrays(
    covid_data: str = 'rsc/New_Data_CoV2/COVID/',
    noncovid_data: str = 'rsc/New_Data_CoV2/non-COVID/',
    others_data:  str = 'rsc/New_Data_CoV2/Others/',
    image_output: str = 'rsc/input_data_v2',
    label_output: str = 'rsc/output_data_v2',
    regenerate: bool = True
) -> Tuple[np.ndarray, np.ndarray]:
    """Loads COVID images into ndarrays.
    
    Args:
        covid_data: Relative path to folder containing COVID images.
        noncovid_data: Relative path to folder containing non-COVID images.
        others_data: Relative path to folder containing Others images.
        image_output: Relative path (with filename) to save loaded images to.
        label_output: Relative path (with filename) to save loaded classes (labels) to.
        regenerate: If True, will regenerate saved ndarray files for both image_output
            and label_output, even if they already exist (overwriting them). If False,
            will simply load and return the aforementioned.
        
    Returns:
        Tuple of ndarrays. The first is the loaded image data in one large ndarray,
        and the second is the loaded labels, also in a large ndarray. These directly
        match up to each other ONLY when both arrays (and their respective files)
        are generated at the same time with this method.
    """
    if (regenerate is False and 
        os.path.isfile(f'{out_input_data}.npy') and
        os.path.isfile(f'{out_output_data}.npy')):
        return (np.load(f'{out_input_data}.npy'),
                np.load(f'{out_output_data}.npy'))
    
    if not ((cd := os.path.exists(covid_data)) and (ncd := os.path.exists(noncovid_data))):
        if (others_data is not None) and not (odd := os.path.exists(others_data)):
            raise NotADirectoryError("Directories do not exist.")
        else:
            raise NotADirectoryError("COVID/non-COVID directories do not exist.")
    
    im_data = np.empty([1, IMAGE_WIDTH, IMAGE_WIDTH, 1])
    output = np.array([0])

    print('Loading Covid Data')
    for i in tqdm(glob.glob(os.path.join(covid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([1])), axis=0)

    print('Loading non-Covid Data')
    for i in tqdm(glob.glob(os.path.join(noncovid_data, '**'))):
        current = preprocess(i)
        im_data = np.concatenate((im_data, current))
        output = np.concatenate((output, np.array([0])), axis=0)
        
    if others_data is not None:
        print('Loading Others Data')
        for i in tqdm(glob.glob(os.path.join(others_data, '**'))):
            current = preprocess(i)
            im_data = np.concatenate((im_data, current))
            output = np.concatenate((output, np.array([-1])), axis=0)
    else:
        print('Others data not provided; skipping.')


    print('Finished Loading Data')
    im_data = np.delete(im_data, 0, axis=0)
    output = np.delete(output, 0, axis=0)

    zip_data = list(zip(im_data, output))
    random.shuffle(zip_data)
    im_data, output = zip(*zip_data)

    np.save(f'{image_output}', im_data)
    np.save(f'{label_output}', output)
    return im_data, output


def load_data(image_loc: str, label_loc: str, **kwargs) -> Tuple[np.ndarray, np.ndarray]:
    """Attempts to load generated images and labels.
    
    If either is not found, attempts to (re)generate them using the default
    input arguments to the generation method for the raw data, but the input
    `image_loc` and `label_loc` parameters for the output arrays. If this
    still does not work, returns a general error and exits.
    
    Args:
        image_loc: Relative path to saved image ndarray file.
        label_loc: Relative path to saved label ndarray file.
        
    Returns:
        Tuple of ndarrays. The first array holds the loaded image data, whilst
        the second array holds their respective labels.
    
    """
    try:
        image_data = np.load(f'{image_loc}.npy')
        label_data = np.load(f'{label_loc}.npy')
        return image_data, label_data
    
    except FileNotFoundError:
        try:
            image_data, label_data = generate_data_arrays(
                image_output = image_loc,
                label_output = label_loc,
                **kwargs
            )
            return image_data, label_data
        
        except Exception as e:
            traceback.print_exc()

# %% [markdown]
# ## Model Playground

# %%
#Version 1
im_data_v1, output_v1 = load_data(
    image_loc = 'rsc/input_data_v1',
    label_loc = 'rsc/output_data_v1',
    covid_data = 'rsc/Data_CoV2/COVID/',
    noncovid_data = 'rsc/Data_CoV2/non-COVID/',
    others_data = None,
)

x_train, x_test, y_train, y_test = train_test_split(im_data_v1, output_v1, random_state=42)

# %%
def make_model(X_Train, Y_Train, X_Test, Y_Test, model_dir: str):
    if not os.path.exists(model_dir):
        os.makedirs(model_dir)
    #X_Train, X_Test, Y_Train, Y_Test = train_test_split(input_data, output_data, test_size=0.1)

    for_pad = lambda s: s if s > 2 else 3

    model = Sequential()
    model.add(Lambda(lambda x: x, input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 1)))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=8, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=16, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=32, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=64, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))


    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

    #model.add(ZeroPadding2D(padding=(for_pad(3) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
    #model.add(ZeroPadding2D(padding=(for_pad(1) - 1)//2))
    model.add(Conv2D(kernel_size=(1, 1), filters=128, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))



    #model.add(ZeroPadding2D(padding=(for_pad(19) - 1)//2))
    model.add(Conv2D(kernel_size=(3, 3), filters=256, strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    #model.add(Conv2D(kernel_size=(3, 3), filters=2, strides=(1, 1),activation='relu'))

    model.add(Flatten())

    model.add(Dropout(rate=0.4))
    model.add(Dense(units=338, activation='relu'))
    model.add(Dense(units=1, activation='sigmoid'))
    
    model.compile(optimizer=Nadam(), loss='binary_crossentropy', metrics=["accuracy"])
    model.summary()

    checkpoint = ModelCheckpoint(os.path.join(model_dir, 'xRGM2.3'), verbose=1, period=1, save_best_only=True)

    hist = model.fit_generator(batch_generator(X_Train, Y_Train, 128, True),
                        validation_data=(batch_generator(X_Test, Y_Test, 128, False)), callbacks=[checkpoint],
                        verbose=1, epochs=75, steps_per_epoch=25, validation_steps=len(X_Test))

    with open(os.path.join('models', 'xRGM2.3-Net-HistDict'), 'wb') as f:
        pickle.dump(hist.history, f)

    model.save(model_dir)
    
    return model
#lr = 0.001

# %%
# %%time
model_dir: str = 'model/xRGM2.3'
xRGM = make_model(x_train, y_train.reshape(-1,1), x_test, y_test.reshape(-1,1), model_dir=model_dir)

v_classify = np.vectorize(lambda x: np.round(x, 0))
# xRGMCT2 = load_model('models/xRGMCT2L.h5')
# print(xRGMCT2.history)
y_pred = (xRGM.predict(x_test))

#print(y_test)
#print(y_pred)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_3 (Lambda)            (None, 227, 227, 1)       0
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 225, 225, 8)       80
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 225, 225, 8)       32
# _________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)   (None, 225, 225, 8)       0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 112, 112, 8)       0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 110, 110, 16)      1168
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 110, 110, 16)      64
# _________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)   (None, 110, 110, 16)      0
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 108, 108, 32)      4640
# _________________________________________________________________
# batch_normalization_50 (Batc (None, 108, 108, 32)      128
# _________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)   (None, 108, 108, 32)      0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 108, 108, 16)      528
# _________________________________________________________________
# batch_normalization_51 (Batc (None, 108, 108, 16)      64
# _________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)   (None, 108, 108, 16)      0
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 106, 106, 32)      4640
# _________________________________________________________________
# batch_normalization_52 (Batc (None, 106, 106, 32)      128
# _________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)   (None, 106, 106, 32)      0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 104, 104, 64)      18496
# _________________________________________________________________
# batch_normalization_53 (Batc (None, 104, 104, 64)      256
# _________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)   (None, 104, 104, 64)      0
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 104, 104, 32)      2080
# _________________________________________________________________
# batch_normalization_54 (Batc (None, 104, 104, 32)      128
# _________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)   (None, 104, 104, 32)      0
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 102, 102, 64)      18496
# _________________________________________________________________
# batch_normalization_55 (Batc (None, 102, 102, 64)      256
# _________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)   (None, 102, 102, 64)      0
# _________________________________________________________________
# conv2d_56 (Conv2D)           (None, 100, 100, 128)     73856
# _________________________________________________________________
# batch_normalization_56 (Batc (None, 100, 100, 128)     512
# _________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)   (None, 100, 100, 128)     0
# _________________________________________________________________
# conv2d_57 (Conv2D)           (None, 100, 100, 64)      8256
# _________________________________________________________________
# batch_normalization_57 (Batc (None, 100, 100, 64)      256
# _________________________________________________________________
# leaky_re_lu_57 (LeakyReLU)   (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_58 (Conv2D)           (None, 98, 98, 128)       73856
# _________________________________________________________________
# batch_normalization_58 (Batc (None, 98, 98, 128)       512
# _________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)   (None, 98, 98, 128)       0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 49, 49, 128)       0
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 47, 47, 256)       295168
# _________________________________________________________________
# batch_normalization_59 (Batc (None, 47, 47, 256)       1024
# _________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)   (None, 47, 47, 256)       0
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 47, 47, 128)       32896
# _________________________________________________________________
# batch_normalization_60 (Batc (None, 47, 47, 128)       512
# _________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)   (None, 47, 47, 128)       0
# _________________________________________________________________
# average_pooling2d_6 (Average (None, 23, 23, 128)       0
# _________________________________________________________________
# conv2d_61 (Conv2D)           (None, 21, 21, 256)       295168
# _________________________________________________________________
# batch_normalization_61 (Batc (None, 21, 21, 256)       1024
# _________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)   (None, 21, 21, 256)       0
# _________________________________________________________________
# average_pooling2d_7 (Average (None, 10, 10, 256)       0
# _________________________________________________________________
# conv2d_62 (Conv2D)           (None, 10, 10, 128)       32896
# _________________________________________________________________
# batch_normalization_62 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)   (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_63 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_63 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)   (None, 8, 8, 256)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16384)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 338)               5538130
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 339
# =================================================================
# Total params: 6,702,293
# Trainable params: 6,699,077
# Non-trainable params: 3,216
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/75
# /home/jg1994/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 25/25 [==============================] - 4274s 177s/step - loss: 2.6309 - accuracy: 0.6141 - val_loss: 0.7259 - val_accuracy: 0.4988
#
# Epoch 00001: val_loss improved from inf to 0.72592, saving model to model/xRGM2.3/xRGM2.3
# INFO:tensorflow:Assets written to: model/xRGM2.3/xRGM2.3/assets
# Epoch 2/75
# 25/25 [==============================] - 4747s 196s/step - loss: 0.3466 - accuracy: 0.8518 - val_loss: 0.9089 - val_accuracy: 0.5007
#
# Epoch 00002: val_loss did not improve from 0.72592
# Epoch 3/75
# 25/25 [==============================] - 4722s 195s/step - loss: 0.3583 - accuracy: 0.8564 - val_loss: 0.8821 - val_accuracy: 0.5214
#
# Epoch 00003: val_loss did not improve from 0.72592
# Epoch 4/75
# 25/25 [==============================] - 4736s 196s/step - loss: 0.1670 - accuracy: 0.9363 - val_loss: 0.8107 - val_accuracy: 0.5588
#
# Epoch 00004: val_loss did not improve from 0.72592
# Epoch 5/75
# 25/25 [==============================] - 4743s 196s/step - loss: 0.2141 - accuracy: 0.9112 - val_loss: 1.3396 - val_accuracy: 0.5425
#
# Epoch 00005: val_loss did not improve from 0.72592
# Epoch 6/75
# 25/25 [==============================] - 4757s 197s/step - loss: 0.1545 - accuracy: 0.9426 - val_loss: 1.3065 - val_accuracy: 0.5607
#
# Epoch 00006: val_loss did not improve from 0.72592
# Epoch 7/75
# 25/25 [==============================] - 4740s 196s/step - loss: 0.0977 - accuracy: 0.9676 - val_loss: 1.2664 - val_accuracy: 0.5515
#
# Epoch 00007: val_loss did not improve from 0.72592
# Epoch 8/75
# 25/25 [==============================] - 4735s 196s/step - loss: 0.0721 - accuracy: 0.9790 - val_loss: 1.6868 - val_accuracy: 0.5275
#
# Epoch 00008: val_loss did not improve from 0.72592
# Epoch 9/75
# 25/25 [==============================] - 4753s 196s/step - loss: 0.0361 - accuracy: 0.9901 - val_loss: 1.3845 - val_accuracy: 0.5320
#
# Epoch 00009: val_loss did not improve from 0.72592
# Epoch 10/75
# 25/25 [==============================] - 4746s 196s/step - loss: 0.0539 - accuracy: 0.9838 - val_loss: 0.9789 - val_accuracy: 0.8033
#
# Epoch 00010: val_loss did not improve from 0.72592
# Epoch 11/75
# 25/25 [==============================] - 4738s 196s/step - loss: 0.0936 - accuracy: 0.9634 - val_loss: 0.2520 - val_accuracy: 0.9084
#
# Epoch 00011: val_loss improved from 0.72592 to 0.25197, saving model to model/xRGM2.3/xRGM2.3
# INFO:tensorflow:Assets written to: model/xRGM2.3/xRGM2.3/assets
# Epoch 12/75
# 25/25 [==============================] - 4707s 194s/step - loss: 0.2153 - accuracy: 0.9202 - val_loss: 7.3246 - val_accuracy: 0.5069
#
# Epoch 00012: val_loss did not improve from 0.25197
# Epoch 13/75
# 25/25 [==============================] - 4732s 195s/step - loss: 0.0331 - accuracy: 0.9907 - val_loss: 1.1056 - val_accuracy: 0.8064
#
# Epoch 00013: val_loss did not improve from 0.25197
# Epoch 14/75
# 25/25 [==============================] - 4738s 196s/step - loss: 0.0180 - accuracy: 0.9959 - val_loss: 0.2758 - val_accuracy: 0.9027
#
# Epoch 00014: val_loss did not improve from 0.25197
# Epoch 15/75
# 25/25 [==============================] - 4727s 195s/step - loss: 0.0074 - accuracy: 0.9990 - val_loss: 0.1727 - val_accuracy: 0.9390
#
# Epoch 00015: val_loss improved from 0.25197 to 0.17267, saving model to model/xRGM2.3/xRGM2.3
# INFO:tensorflow:Assets written to: model/xRGM2.3/xRGM2.3/assets
# Epoch 16/75
# 25/25 [==============================] - 4713s 195s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 0.9525
#
# Epoch 00016: val_loss improved from 0.17267 to 0.13593, saving model to model/xRGM2.3/xRGM2.3
# INFO:tensorflow:Assets written to: model/xRGM2.3/xRGM2.3/assets
# Epoch 17/75
# 25/25 [==============================] - 4734s 196s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.2221 - val_accuracy: 0.9214
#
# Epoch 00017: val_loss did not improve from 0.13593
# Epoch 18/75
# 25/25 [==============================] - 4713s 195s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2112 - val_accuracy: 0.9199
#
# Epoch 00018: val_loss did not improve from 0.13593
# Epoch 19/75
# 25/25 [==============================] - 4730s 195s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2297 - val_accuracy: 0.9127
#
# Epoch 00019: val_loss did not improve from 0.13593
# Epoch 20/75
# 25/25 [==============================] - 4716s 195s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1943 - val_accuracy: 0.9235
#
# Epoch 00020: val_loss did not improve from 0.13593
# Epoch 21/75
# 25/25 [==============================] - 4728s 195s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9620
#
# Epoch 00021: val_loss improved from 0.13593 to 0.11560, saving model to model/xRGM2.3/xRGM2.3
# INFO:tensorflow:Assets written to: model/xRGM2.3/xRGM2.3/assets
# Epoch 22/75
# 25/25 [==============================] - 4747s 196s/step - loss: 9.4832e-04 - accuracy: 1.0000 - val_loss: 0.1047 - val_accuracy: 0.9632
#
# Epoch 00022: val_loss improved from 0.11560 to 0.10465, saving model to model/xRGM2.3/xRGM2.3
# INFO:tensorflow:Assets written to: model/xRGM2.3/xRGM2.3/assets
# Epoch 23/75
# 25/25 [==============================] - 4758s 197s/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 0.8907 - val_accuracy: 0.7492
#
# Epoch 00023: val_loss did not improve from 0.10465
# Epoch 24/75
# 25/25 [==============================] - 4735s 196s/step - loss: 0.1492 - accuracy: 0.9499 - val_loss: 1.7536 - val_accuracy: 0.8148
#
# Epoch 00024: val_loss did not improve from 0.10465
# Epoch 25/75
# 25/25 [==============================] - 4774s 197s/step - loss: 0.0230 - accuracy: 0.9934 - val_loss: 0.8299 - val_accuracy: 0.8728
#
# Epoch 00025: val_loss did not improve from 0.10465
# Epoch 26/75
# 25/25 [==============================] - 4789s 198s/step - loss: 0.0073 - accuracy: 0.9987 - val_loss: 0.2073 - val_accuracy: 0.9328
#
# Epoch 00026: val_loss did not improve from 0.10465
# Epoch 27/75
# 25/25 [==============================] - 4789s 198s/step - loss: 0.0045 - accuracy: 0.9999 - val_loss: 0.2155 - val_accuracy: 0.9425
#
# Epoch 00027: val_loss did not improve from 0.10465
# Epoch 28/75
# 25/25 [==============================] - 4794s 199s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2025 - val_accuracy: 0.9361
#
# Epoch 00028: val_loss did not improve from 0.10465
# Epoch 29/75
# 25/25 [==============================] - 4799s 199s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1752 - val_accuracy: 0.9395
#
# Epoch 00029: val_loss did not improve from 0.10465
# Epoch 30/75
# 25/25 [==============================] - 4825s 200s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0973 - val_accuracy: 0.9611
#
# Epoch 00030: val_loss improved from 0.10465 to 0.09726, saving model to model/xRGM2.3/xRGM2.3
# INFO:tensorflow:Assets written to: model/xRGM2.3/xRGM2.3/assets
# Epoch 31/75
# 25/25 [==============================] - 4805s 199s/step - loss: 7.8710e-04 - accuracy: 1.0000 - val_loss: 0.1926 - val_accuracy: 0.9371
#
# Epoch 00031: val_loss did not improve from 0.09726
# Epoch 32/75
# 25/25 [==============================] - 4826s 200s/step - loss: 5.7119e-04 - accuracy: 1.0000 - val_loss: 0.1318 - val_accuracy: 0.9535
#
# Epoch 00032: val_loss did not improve from 0.09726
# Epoch 33/75
# 25/25 [==============================] - 4826s 200s/step - loss: 7.6325e-04 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9513
#
# Epoch 00033: val_loss did not improve from 0.09726
# Epoch 34/75
# 25/25 [==============================] - 4827s 200s/step - loss: 5.4209e-04 - accuracy: 1.0000 - val_loss: 0.1018 - val_accuracy: 0.9624
#
# Epoch 00034: val_loss did not improve from 0.09726
# Epoch 35/75
# 25/25 [==============================] - 4834s 200s/step - loss: 4.6389e-04 - accuracy: 1.0000 - val_loss: 0.1079 - val_accuracy: 0.9613
#
# Epoch 00035: val_loss did not improve from 0.09726
# Epoch 36/75
# 25/25 [==============================] - 4836s 200s/step - loss: 6.6797e-04 - accuracy: 1.0000 - val_loss: 0.1095 - val_accuracy: 0.9557
#
# Epoch 00036: val_loss did not improve from 0.09726
# Epoch 37/75
# 25/25 [==============================] - 4839s 200s/step - loss: 3.2241e-04 - accuracy: 1.0000 - val_loss: 0.1050 - val_accuracy: 0.9534
#
# Epoch 00037: val_loss did not improve from 0.09726
# Epoch 38/75
# 25/25 [==============================] - 4838s 200s/step - loss: 2.6562e-04 - accuracy: 1.0000 - val_loss: 0.1259 - val_accuracy: 0.9510
# Epoch 00038: val_loss did not improve from 0.09726
# Epoch 39/75
# 25/25 [==============================] - 4842s 201s/step - loss: 3.1109e-04 - accuracy: 1.0000 - val_loss: 0.0990 - val_accuracy: 0.9590
#
# Epoch 00039: val_loss did not improve from 0.09726
# Epoch 40/75
# 25/25 [==============================] - 4836s 200s/step - loss: 2.6334e-04 - accuracy: 1.0000 - val_loss: 0.0973 - val_accuracy: 0.9635
#
# Epoch 00040: val_loss did not improve from 0.09726
# Epoch 41/75
# 25/25 [==============================] - 4845s 201s/step - loss: 4.1639e-04 - accuracy: 1.0000 - val_loss: 0.1334 - val_accuracy: 0.9568
#
# Epoch 00041: val_loss did not improve from 0.09726
# Epoch 42/75
# 25/25 [==============================] - 4865s 201s/step - loss: 0.6062 - accuracy: 0.8166 - val_loss: 1569.5266 - val_accuracy: 0.4998
#
# Epoch 00042: val_loss did not improve from 0.09726
# Epoch 43/75
# 25/25 [==============================] - 4873s 202s/step - loss: 0.3623 - accuracy: 0.8403 - val_loss: 269.9988 - val_accuracy: 0.4991
#
# Epoch 00043: val_loss did not improve from 0.09726
# Epoch 44/75
# 25/25 [==============================] - 4873s 202s/step - loss: 0.3159 - accuracy: 0.8583 - val_loss: 25.5707 - val_accuracy: 0.5215
#
# Epoch 00044: val_loss did not improve from 0.09726
# Epoch 45/75
# 25/25 [==============================] - 4874s 202s/step - loss: 0.2695 - accuracy: 0.8869 - val_loss: 2.0606 - val_accuracy: 0.7304
#
# Epoch 00045: val_loss did not improve from 0.09726
# Epoch 46/75
# 25/25 [==============================] - 4863s 201s/step - loss: 0.2099 - accuracy: 0.9173 - val_loss: 1.4052 - val_accuracy: 0.7258
#
# Epoch 00046: val_loss did not improve from 0.09726
# Epoch 47/75
# 25/25 [==============================] - 4859s 201s/step - loss: 0.1887 - accuracy: 0.9182 - val_loss: 1.2963 - val_accuracy: 0.7349
#
# Epoch 00047: val_loss did not improve from 0.09726
# Epoch 48/75
# 25/25 [==============================] - 4863s 201s/step - loss: 0.1742 - accuracy: 0.9235 - val_loss: 1.0473 - val_accuracy: 0.7723
#
# Epoch 00048: val_loss did not improve from 0.09726
# Epoch 49/75
# 25/25 [==============================] - 4861s 201s/step - loss: 0.1295 - accuracy: 0.9444 - val_loss: 1.0387 - val_accuracy: 0.7984
#
# Epoch 00049: val_loss did not improve from 0.09726
# Epoch 50/75
# 25/25 [==============================] - 4862s 201s/step - loss: 0.0956 - accuracy: 0.9619 - val_loss: 1.5798 - val_accuracy: 0.7167
#
# Epoch 00050: val_loss did not improve from 0.09726
# Epoch 51/75
# 25/25 [==============================] - 4868s 201s/step - loss: 0.0915 - accuracy: 0.9647 - val_loss: 1.6279 - val_accuracy: 0.7166
#
# Epoch 00051: val_loss did not improve from 0.09726
# Epoch 52/75
# 25/25 [==============================] - 4867s 201s/step - loss: 0.0900 - accuracy: 0.9667 - val_loss: 0.7761 - val_accuracy: 0.8311
#
# Epoch 00052: val_loss did not improve from 0.09726
# Epoch 53/75
# 25/25 [==============================] - 4868s 201s/step - loss: 0.0806 - accuracy: 0.9768 - val_loss: 0.6293 - val_accuracy: 0.8524
#
# Epoch 00053: val_loss did not improve from 0.09726
# Epoch 54/75
# 25/25 [==============================] - 4866s 201s/step - loss: 0.0485 - accuracy: 0.9841 - val_loss: 0.4399 - val_accuracy: 0.8874
#
# Epoch 00054: val_loss did not improve from 0.09726
# Epoch 55/75
# 25/25 [==============================] - 4896s 202s/step - loss: 0.2114 - accuracy: 0.9290 - val_loss: 5.3107 - val_accuracy: 0.7033
#
# Epoch 00055: val_loss did not improve from 0.09726
# Epoch 56/75
# 25/25 [==============================] - 4873s 202s/step - loss: 0.2179 - accuracy: 0.9055 - val_loss: 5.3588 - val_accuracy: 0.6925
#
# Epoch 00056: val_loss did not improve from 0.09726
# Epoch 57/75
# 25/25 [==============================] - 4870s 201s/step - loss: 0.1168 - accuracy: 0.9548 - val_loss: 1.4230 - val_accuracy: 0.8022
#
# Epoch 00057: val_loss did not improve from 0.09726
# Epoch 58/75
# 25/25 [==============================] - 4862s 201s/step - loss: 0.0946 - accuracy: 0.9674 - val_loss: 1.4653 - val_accuracy: 0.7911
#
# Epoch 00058: val_loss did not improve from 0.09726
# Epoch 59/75
# 25/25 [==============================] - 4865s 201s/step - loss: 0.0863 - accuracy: 0.9667 - val_loss: 1.6471 - val_accuracy: 0.7475
#
# Epoch 00059: val_loss did not improve from 0.09726
# Epoch 60/75
# 25/25 [==============================] - 4862s 201s/step - loss: 0.0753 - accuracy: 0.9674 - val_loss: 1.0663 - val_accuracy: 0.7478
#
# Epoch 00060: val_loss did not improve from 0.09726
# Epoch 61/75
# 25/25 [==============================] - 4865s 201s/step - loss: 0.0390 - accuracy: 0.9882 - val_loss: 1.9547 - val_accuracy: 0.7059
#
# Epoch 00061: val_loss did not improve from 0.09726
# Epoch 62/75
# 25/25 [==============================] - 4860s 201s/step - loss: 0.0434 - accuracy: 0.9835 - val_loss: 1.0197 - val_accuracy: 0.7572
#
# Epoch 00062: val_loss did not improve from 0.09726
# Epoch 63/75
# 25/25 [==============================] - 4862s 201s/step - loss: 0.0203 - accuracy: 0.9957 - val_loss: 0.9851 - val_accuracy: 0.7792
#
# Epoch 00063: val_loss did not improve from 0.09726
# Epoch 64/75
# 25/25 [==============================] - 4859s 201s/step - loss: 0.0204 - accuracy: 0.9947 - val_loss: 0.5151 - val_accuracy: 0.8594
#
# Epoch 00064: val_loss did not improve from 0.09726
# Epoch 65/75
# 25/25 [==============================] - 4861s 201s/step - loss: 0.0183 - accuracy: 0.9952 - val_loss: 0.2986 - val_accuracy: 0.9156
#
# Epoch 00065: val_loss did not improve from 0.09726
# Epoch 66/75
# 25/25 [==============================] - 4858s 201s/step - loss: 0.0123 - accuracy: 0.9970 - val_loss: 0.3325 - val_accuracy: 0.9170
#
# Epoch 00066: val_loss did not improve from 0.09726
# Epoch 67/75
# 25/25 [==============================] - 4869s 201s/step - loss: 0.0063 - accuracy: 0.9997 - val_loss: 0.4491 - val_accuracy: 0.8921
#
# Epoch 00067: val_loss did not improve from 0.09726
# Epoch 68/75
# 25/25 [==============================] - 4856s 201s/step - loss: 0.0102 - accuracy: 0.9968 - val_loss: 0.4405 - val_accuracy: 0.8970
#
# Epoch 00068: val_loss did not improve from 0.09726
# Epoch 69/75
# 25/25 [==============================] - 4855s 201s/step - loss: 0.0092 - accuracy: 0.9982 - val_loss: 0.1608 - val_accuracy: 0.9564
#
# Epoch 00069: val_loss did not improve from 0.09726
# Epoch 70/75
# 25/25 [==============================] - 4854s 201s/step - loss: 0.0086 - accuracy: 0.9971 - val_loss: 0.1840 - val_accuracy: 0.9491
#
# Epoch 00070: val_loss did not improve from 0.09726
# Epoch 71/75
# 25/25 [==============================] - 4856s 201s/step - loss: 0.0079 - accuracy: 0.9984 - val_loss: 0.2479 - val_accuracy: 0.9188
#
# Epoch 00071: val_loss did not improve from 0.09726
# Epoch 72/75
# 25/25 [==============================] - 4848s 201s/step - loss: 0.0044 - accuracy: 0.9993 - val_loss: 0.1662 - val_accuracy: 0.9453
#
# Epoch 00072: val_loss did not improve from 0.09726
# Epoch 73/75
# 25/25 [==============================] - 4853s 201s/step - loss: 0.0041 - accuracy: 0.9995 - val_loss: 0.2064 - val_accuracy: 0.9469
#
# Epoch 00073: val_loss did not improve from 0.09726
# Epoch 74/75
# 25/25 [==============================] - 4853s 201s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9472
#
# Epoch 00074: val_loss did not improve from 0.09726
# Epoch 75/75
# 25/25 [==============================] - 4845s 200s/step - loss: 0.0039 - accuracy: 0.9993 - val_loss: 0.2068 - val_accuracy: 0.9517
#
# Epoch 00075: val_loss did not improve from 0.09726
# INFO:tensorflow:Assets written to: model/xRGM2.3/assets
# CPU times: user 21d 10h 53min 53s, sys: 16h 53min 27s, total: 22d 3h 47min 21s
# Wall time: 4d 4h 10min 41s

# %%
confusion_matrix = pd.DataFrame(metrics.confusion_matrix(y_test, v_classify(y_pred)),
                                columns=['Predicted Negative', 'Predicted Positive'],
                                index=['Actual Negative', 'Actual Positive'])

tp, tn, fp, fn = (
    confusion_matrix.iloc[1,1], 
    confusion_matrix.iloc[0,0], 
    confusion_matrix.iloc[0,1], 
    confusion_matrix.iloc[1,0]
)

accuracy = (tp + tn) / (tp + tn + fp + fn)
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
f1_score = 2 * ((specificity * sensitivity) / (specificity + sensitivity))

with open(os.path.join(f'{model_dir}', 'metrics.csv'), 'a', encoding='utf-8') as f:
    f.write(
        f'{time.strftime("%Y-%m-%dT%H:%M:%S-05:00", time.localtime())}, {accuracy}, {sensitivity}, {specificity}, {f1_score}\n'
    )

print(f'Accuracy:    {accuracy}')
print(f'Sensitivity: {sensitivity}')
print(f'Specificity: {specificity}')
print(f'F1 Score:    {f1_score}')
print('\n')
print(confusion_matrix)
# Out:
# Accuracy:    0.9516908212560387
# Sensitivity: 0.9129032258064517
# Specificity: 0.9903536977491961
# F1 Score:    0.9500525905620378
#
#
#                  Predicted Negative  Predicted Positive
# Actual Negative                 308                   3
# Actual Positive                  27                 283

# %%
disease_types=['COVID', 'non-COVID']
Y_pred = np.argmax(y_pred)
Y_true = np.argmax(y_test)

plt.figure(figsize=(7, 7))
ax = sns.heatmap(confusion_matrix , cmap=plt.cm.GnBu , 
                 annot=True, fmt='d',square=True, xticklabels=disease_types, 
                 yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
plt.show()

# %%
def plot_model_history(model_history):
   fig, axs = plt.subplots(1,2,figsize=(15,5))
   # summarize history for accuracy
   axs[0].plot(range(1, len(model_history['accuracy']) + 1), model_history['accuracy'])
   axs[0].plot(range(1, len(model_history['val_accuracy']) + 1), model_history['val_accuracy'])
   axs[0].set_title('Model Accuracy')
   axs[0].set_ylabel('Accuracy')
   axs[0].set_xlabel('Epoch')
   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
   axs[0].legend(['train', 'val'], loc='best')
   # summarize history for loss
   axs[1].plot(range(1, len(model_history['loss'])+1), model_history['loss'])
   axs[1].plot(range(1, len(model_history['val_loss']) + 1), model_history['val_loss'])
   axs[1].set_title('Model Loss')
   axs[1].set_ylabel('Loss')
   axs[1].set_xlabel('Epoch')
   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
   axs[1].legend(['train', 'val'], loc='best')
   plt.show()

# %%
with open(os.path.join('models', 'xRGM2.3-Net-HistDict'), 'rb') as f:
    history = pickle.load(f)
    
plot_model_history(history)
# Out:
# <ipython-input-27-25025fac5012>:9: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1), len(model_history['accuracy']) / 10)
# <ipython-input-27-25025fac5012>:17: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[1].set_xticks(np.arange(1, len(model_history['loss']) + 1), len(model_history['loss']) / 10)
